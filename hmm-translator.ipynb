# %%
# read in data

readin_cn = []
readin_en = []
readin_align = []

# read in chinese sentences
with open('data/chinese', encoding='utf-8') as f:
    readin_cn=f.readlines()

# read in english sentences 
with open('data/english', encoding='utf-8') as f:
    readin_en=f.readlines()

# read in word-to-word alignment info for each sentences

with open('data/alignment', encoding='utf-8') as f:
    readin_align = f.readlines()

# %%
# remove '\n'
readin_cn_raw = [x.strip('\n') for x in readin_cn]
readin_en_raw = [x.strip('\n') for x in readin_en]
readin_align_raw = [x.strip('\n') for x in readin_align]
len(readin_en_raw),len(readin_cn_raw),len(readin_align_raw)
# Out:
# (40715, 40715, 40715)

# %%
# split out training and test set
# the readin_xx is for training and test_xx is for test

readin_cn = readin_cn_raw[:1000]
readin_en = readin_en_raw[:1000]
readin_align = readin_align_raw[:1000]

test_cn = readin_cn_raw[1000:1100]
test_en = readin_en_raw[1000:1100]
test_align = readin_align_raw[1000:1100]
len(test_en),len(test_cn),len(test_align)
# Out:
# (100, 100, 100)

# %%
len(readin_cn),len(readin_en),len(readin_align)
# Out:
# (1000, 1000, 1000)

# %% [markdown]
# Let's explore the data

# %%
readin_cn[-1]
# Out:
# '科学家 们 的 新 发现 --- 羊羊 们 可以 清理 爆炸物 的 残渣'

# %%
readin_en[-1]
# Out:
# 'Sheep Help Scientists Clean Up Explosives Residue'

# %%
readin_align[-1]
# Out:
# '1:3/1 2:3/0 7:1/1 8:1/0 10:4/1 10:5/1 11:6/1 12:6/0 13:7/1'

# %%
# test the alignment info
t_align = readin_align[-1].split(' ')
t_cn = readin_cn[-1].split(' ')
t_en = readin_en[-1].split(' ')

# remove the '/0' or '/1'
t_align = [x[:-2] for x in t_align]

# match up according to alignment info(e.g. "1:2" means that the first Chinese word is aligned to the second English word )
for al in t_align:
    p = al.split(':')
    print(t_cn[int(p[0])-1]+"-->"+t_en[int(p[1])-1])
# Out:
# 科学家-->Scientists
# 们-->Scientists
# 羊羊-->Sheep
# 们-->Sheep
# 清理-->Clean
# 清理-->Up
# 爆炸物-->Explosives
# 的-->Explosives
# 残渣-->Residue

# %%
# we notice that some chinese word can be translated to two or more english words
# also some chinese words do not have corresponding words

def matchWords(ch, en, align):
    """Given the chinese and english sentences, make a word-to-word alignment with provided alignment info
    :param ch: chinese sentence in a string(words splited by space)
    :param en: English sentence
    :param align: alignment info(e.g. '1:4/1 2:4/0 3:1/1 4:2/1 5:2/0 6:5/1')
    :return tuple(chinese words),tuple(english words(aligned to chinese words))
    """
    ch_list = ch.split(' ')
    en_list = en.split(' ')
    align_list = align.split(' ')
    
    # a list for aligned english words, should have same length as chinese word list
    en_align = ['None'] * len(ch_list)
    
    for pair in align_list:
        # remove '/', split by ":"
        p = pair[:-2].split(':')
        # check if one chinese word can be translated to two or more english words
        if 0<int(p[0])<=len(en_align) and 0<int(p[1])<=len(en_list):
            if en_align[int(p[0])-1] != 'None':
                en_align[int(p[0])-1] = en_align[int(p[0])-1]+' '+en_list[int(p[1])-1]
            else:
                en_align[int(p[0])-1] = en_list[int(p[1])-1]
    
    return tuple(ch_list), tuple(en_align)
    
# function that check the data   
def checker(ch, en, align):
    """check if the alignment data is OK(can not index out of range )
    :param ch: chinese sentence in a string(words splited by space)
    :param en: English sentence
    :param align: alignment info(e.g. '1:4/1 2:4/0 3:1/1 4:2/1 5:2/0 6:5/1')
    :return boolean, if this parallel text is ok
    """
    if align == '' or en == '' or ch == '':
        return False
    ch_list = ch.split(' ')
    en_list = en.split(' ')
    align_list = align.split(' ')
    
    ch_max = 0
    en_max = 0
    for pair in align_list:
        # remove '/', split by ":"
        p = pair[:-2].split(':')
        if int(p[0]) > ch_max:
            ch_max = int(p[0])
        if int(p[1]) > en_max:
            en_max = int(p[1])
    
    # print(str(ch_max)+' '+str(en_max))
    if ch_max <= len(ch_list) and en_max <= len(en_list):
        return True
    else:
        return False

# %%
# test alignment again
t_align = readin_align[-1]
t_cn = readin_cn[-1]
t_en = readin_en[-1]
c1, e1 = matchWords(t_cn, t_en, t_align)
for c, e in zip(c1,e1):
    print(c+'->'+e)
print()
print('original data')
print(t_cn,t_en)
# Out:
# 科学家->Scientists
# 们->Scientists
# 的->None
# 新->None
# 发现->None
# ---->None
# 羊羊->Sheep
# 们->Sheep
# 可以->None
# 清理->Clean Up
# 爆炸物->Explosives
# 的->Explosives
# 残渣->Residue
#
# original data
# 科学家 们 的 新 发现 --- 羊羊 们 可以 清理 爆炸物 的 残渣 Sheep Help Scientists Clean Up Explosives Residue

# %%
checker(t_cn, t_en, t_align)
# Out:
# True

# %%
# now we are good to go, turn the read in data into dataset(list) that contain words in tuples, 
# each tuple represent one sentence

# training set

DataSet_ch = []
DataSet_en = []

for ch, en, al in zip(readin_cn, readin_en, readin_align):
    if checker(ch, en, al):
        words_ch, aligned_en_words = matchWords(ch, en, al)
        DataSet_ch.append(words_ch)
        DataSet_en.append(aligned_en_words)

# %%
# test set
TestSet_ch = []
TestSet_en = []

for ch, en, al in zip(test_cn, test_en, test_align):
    if checker(ch, en, al):
        words_ch, aligned_en_words = matchWords(ch, en, al)
        TestSet_ch.append(words_ch)
        TestSet_en.append(aligned_en_words)

# %%
# how many parallel sentences after clean up the data
len(DataSet_ch),len(DataSet_en)
# Out:
# (999, 999)

# %%
len(TestSet_ch),len(TestSet_en)
# Out:
# (99, 99)

# %%
# validate that in every sentence, each chinese word mapping to one english word 
# (use None for some chinese words do not have corresponding words)
import random
rand_p = random.randint(0,len(DataSet_ch)-1)
print('random sentence index='+str(rand_p))
len(DataSet_ch[rand_p]) == len(DataSet_en[rand_p])
# Out:
# random sentence index=404
# True

# %%
# sample the dataset and check
for i in range(4):
    print(DataSet_ch[i])
    print(DataSet_en[i])
# Out:
# ('教区', '财务', '委员会', '认为', ',', '这项', '协议', '可能', '使得', '波士顿', '天主教会', '破产', ',', '因为', '声称', '受到', '性', '侵害', '的', '案子', '越来越', '多', ',', '而且', '「', '在', '促成', '协议', '的', '程序', '开始', '后', '情况', '已经', '有', '很', '大', '变化', '」', '。')
# ('archdiocese', 'finance', 'council', 'thinks', 'that', 'this', 'agreement', 'may', 'force', 'boston', 'catholic archdiocese', 'bankruptcy', 'None', 'as', 'alleged', 'None', 'sexual', 'abuse', 'of', 'cases', 'keep surfacing', 'keep surfacing', ',', 'and', '"', 'since', 'leading', 'agreement', 'None', 'process', 'started', 'since', 'situation', 'has', 'None', 'dramatically', 'dramatically', 'changed', '"', '.')
# ('六十六', '岁', '的', '吉欧根', '因为', '在', '一九九一年', '性', '侵害', '一', '名', '十', '岁', '男童', ',', '最近', '被', '判处', '十', '年', '徒刑', '。')
# ('66-year-old', '66-year-old', 'None', 'geoghan', 'for', 'in', '1991', 'sexual', 'molestation', 'a', 'None', '10-year-old', '10-year-old', 'boy', 'None', 'recently', 'was', 'sentenced', '10', 'years', 'imprisonment', '.')
# ('已', '被', '削去', '教士', '职务', '的', '他', '还', '面临', '其他', '刑事', '审判', '和', '数十', '件', '民事', '官司', '。')
# ('None', 'None', 'defrocked', 'priest', 'None', 'None', 'None', 'also', 'faces', 'other', 'criminal', 'trials', 'and', 'scores', 'None', 'civil', 'lawsuits', '.')
# ('美', '印', '五月', '中', '将', '举行', '四十', '年', '来', '首次', '联合', '军事', '演习')
# ('us', 'india', 'mid-may', 'mid-may', 'None', 'conduct', '4 decades', 'decades', 'None', 'first', 'joint', 'military', 'exercise')

# %%
# build up the vocabulary
DataSet_vocab = []
for sentence in DataSet_ch:
    for word in sentence:
        DataSet_vocab.append(word)
DataSet_vocab_frozen = frozenset(DataSet_vocab)
DataSet_vocab_frozen
# Out:
# frozenset({'城',
#            '云路',
#            '显现',
#            '或',
#            '设计师',
#            '尖峰',
#            '腾格里',
#            '子女',
#            '有人',
#            '十分',
#            '祈祷',
#            '锦标赛',
#            '十',
#            '纪录',
#            '名誉',
#            '任天堂',
#            '适龄前',
#            '占',
#            '攀登',
#            '乡镇',
#            '当局',
#            '外交',
#            '大将',
#            '五十',
#            '辩论',
#            '一度',
#            '55',
#            '特区',
#            '上帝',
#            '抵达',
#            '二000年',
#            '售价',
#            '维持',
#            '攻占',
#            '机密',
#            '智库',
#            '利润',
#            '东',
#            '职务',
#            '差',
#            '立方米',
#            '淘汰',
#            '本周',
#            '伊丽莎白',
#            '回顾',
#            '队长',
#            '维芳迪',
#            '激进分子',
#            '店',
#            '摆脱',
#            '循',
#            '洛美',
#            '百分之八',
#            '延长',
#            '各方',
#            '情形',
#            '随着',
#            '力克',
#            '松本市',
#            '1530.69',
#            '喜欢',
#            '移民',
#            '状况',
#            '杀',
#            'tab',
#            '年轻',
#            '放缓',
#            '建材',
#            '菲军',
#            '1%',
#            '奖章',
#            '三十二',
#            '关键',
#            '外海',
#            '狄托',
#            '那么',
#            '纷纷',
#            '行驶',
#            '应该',
#            '简直',
#            '停顿',
#            '物理学',
#            '为首',
#            '汛情',
#            '有待',
#            '二亿',
#            '玩',
#            '实业',
#            '阿拉伯',
#            '坚定',
#            '遵循',
#            '封航',
#            '运作',
#            '关怀',
#            '经营型',
#            '1250亿',
#            '18.1亿',
#            '自命不凡',
#            '诺瑟姆',
#            '二万五千',
#            '煽动',
#            '检查',
#            '缓解',
#            '前往',
#            '同情',
#            '来说',
#            '5%',
#            '二千万',
#            '强化',
#            '确定',
#            '外资',
#            '猛烈',
#            '各',
#            '理事会',
#            '该',
#            '建筑',
#            '喜剧片',
#            '澳门',
#            '责任',
#            '份',
#            '签订',
#            '大量',
#            '宣传',
#            '米纳斯州',
#            '夜里',
#            '向',
#            '严惩',
#            '十八日',
#            '事项',
#            '有条不紊',
#            '实验室',
#            '港澳',
#            '潜入',
#            '担忧',
#            '片段',
#            '希',
#            '预期',
#            '10日',
#            '严词',
#            '学童',
#            '74.34万',
#            '大幅',
#            '华人',
#            '普通',
#            '名叫',
#            '收到',
#            '诊断',
#            '大型',
#            '定居者',
#            '整体',
#            '联络',
#            '詹姆士庞德',
#            '籍',
#            '正面',
#            '作业',
#            '保护',
#            '四万一千',
#            '秘书',
#            '李',
#            '岛屿',
#            '市区',
#            '床',
#            '美洲',
#            '主流',
#            '安排',
#            '之前',
#            '招商',
#            '总会',
#            '是',
#            '扶贫',
#            '机遇',
#            '暴雨',
#            '围剿',
#            '股',
#            '姓名',
#            '电阻',
#            '首席',
#            '智力',
#            '电话',
#            '经纪人',
#            '声望',
#            '名厨',
#            '迎战',
#            '独霸',
#            '民族',
#            '生涯',
#            '进程',
#            '肯尼亚',
#            '奥姆教',
#            '密切',
#            '金刚山',
#            '夫妇',
#            '面包',
#            '台商',
#            '兼',
#            '栅栏',
#            '费用',
#            '增长率',
#            '再',
#            '3月',
#            '代理商',
#            '接着',
#            '新近',
#            '16亿',
#            '假如',
#            '房',
#            '水位',
#            '广州',
#            '普尔',
#            '首都',
#            '今晚',
#            '看见',
#            '空前',
#            '协查',
#            'Verizon',
#            '三十一日',
#            '重新',
#            '低于',
#            '绝',
#            '顾问',
#            '统一',
#            '尽快',
#            '哲宁市',
#            '多元化',
#            '矛枪',
#            '旧',
#            '创新',
#            '查韦斯',
#            '二○○一年',
#            '主教练',
#            '具名',
#            '林',
#            '获得',
#            '随行',
#            '和',
#            '同学',
#            '极富',
#            '负债',
#            '速水优',
#            '家属',
#            '杂志',
#            '自携',
#            '留学生',
#            '战略性',
#            '随后',
#            '资讯',
#            '谈判',
#            '台北',
#            '部队',
#            '组',
#            '总是',
#            '文军',
#            '债务',
#            '员工',
#            '冰雪',
#            '新加坡',
#            '上学',
#            '外',
#            '安',
#            '三十',
#            '召回',
#            '负责人',
#            '项',
#            '回应',
#            '冯',
#            '大满贯',
#            '需要',
#            '儿子',
#            '探索',
#            '兵力',
#            '房屋',
#            '沙丹.胡笙',
#            '提出',
#            '脚蹼',
#            '场馆',
#            '推出',
#            '五三年',
#            '有些',
#            '王国',
#            '中旬',
#            '持',
#            '热力',
#            '字母',
#            '天主教',
#            '嫌犯',
#            '下属',
#            '抵销',
#            '小组',
#            '一百二十',
#            '1990年',
#            '佛罗里达州',
#            '昂贵',
#            '交通',
#            '恐怖',
#            '当年',
#            '欧洲',
#            '开销',
#            '360',
#            '适值',
#            '奥新社',
#            '委员会',
#            '刺激',
#            '取材',
#            '国务卿',
#            '奢侈品',
#            '影艺界',
#            '散播',
#            '以为',
#            '撞',
#            '大概',
#            '全国',
#            '哈卡马达',
#            '阿布杜拉',
#            '们',
#            '机关',
#            '男性',
#            '小时',
#            '年龄',
#            '厘',
#            '迷人',
#            '最佳',
#            '问题',
#            '破发',
#            '吸入',
#            '情事',
#            '稍后',
#            '强硬',
#            '约克',
#            '观察员',
#            '沿着',
#            '杀戮',
#            '公司',
#            '好用的',
#            '金融',
#            '四千',
#            '高峰',
#            '迄',
#            '推选',
#            '罗',
#            '事发',
#            '倒闭',
#            '发育',
#            '就业',
#            '波动',
#            '媒体界',
#            '深入',
#            '销售',
#            '裨益',
#            '罗马尼亚',
#            '审判',
#            '拉美',
#            '震愕',
#            '有趣',
#            '930',
#            '赞赏',
#            '种子',
#            '批准',
#            '堪称',
#            '下滑',
#            '真挚',
#            '四百五十三',
#            '开发',
#            '10亿',
#            '新闻',
#            '结合',
#            '同班',
#            '尽',
#            '搬起',
#            '2',
#            '发现',
#            '侵袭',
#            '开火',
#            '一九九八年',
#            '百万富翁',
#            '三分之二',
#            '成功',
#            '腐败',
#            '原定',
#            '工程师',
#            '节制',
#            '主任',
#            '结算',
#            '近年来',
#            '比',
#            '改进',
#            '改行',
#            '短期',
#            '坦克车',
#            '番禺',
#            '得分',
#            '质量',
#            '七',
#            '淮菜',
#            '也许',
#            '无数',
#            '奥',
#            '家庭',
#            '届',
#            '捉拿',
#            '提议',
#            '唯一',
#            '少',
#            '网球场',
#            '停止',
#            '鞋',
#            '商人',
#            '宣誓',
#            '不幸',
#            '购买',
#            '港元',
#            '安民',
#            '经验',
#            '课题',
#            '减缓',
#            '希望',
#            '侦察',
#            '贺兰',
#            '该行',
#            '百分之三十',
#            '公开赛',
#            '东南',
#            '知道',
#            '白金汉宫',
#            '顺便',
#            '必然',
#            '您',
#            '自治县',
#            '2.6%',
#            '大修',
#            '俄方',
#            '所',
#            '22%',
#            '1997年',
#            '武铉',
#            '管道',
#            '以来',
#            '共产',
#            '果决',
#            '住房率',
#            '11日',
#            '鼓舞',
#            '来临',
#            '刚',
#            '市长',
#            '法郎',
#            '电视台',
#            '敦促',
#            '低声',
#            '有起有落',
#            '社交',
#            '二',
#            '不安',
#            '250',
#            '中的',
#            '3',
#            '标志',
#            '作出',
#            '大获全胜',
#            '原告',
#            '开发商',
#            '引起',
#            '误解',
#            '嫦丽',
#            '驱逐',
#            '止',
#            '百分之二点六',
#            '百分之十五',
#            '急迫',
#            '中程',
#            '高级',
#            '满意',
#            '23日',
#            '任何人',
#            '公车',
#            '引来',
#            '网球',
#            '曼彻斯特',
#            '介入',
#            '禁牧',
#            '近来',
#            '拉丁',
#            '昨晚',
#            '退休',
#            '一齐',
#            '女孩',
#            '裂',
#            '全欧',
#            '鲍威尔',
#            '担纲',
#            '口蹄疫',
#            '普希金',
#            '一致',
#            '几十',
#            '企业家',
#            '负',
#            '情节',
#            '面积',
#            '队员',
#            '发布',
#            '比如',
#            '十二日',
#            '驶过',
#            '两万',
#            '展开',
#            '引用',
#            '分享',
#            '缺陷',
#            '新疆大学',
#            '特别',
#            '活塞队',
#            '遭到',
#            '地',
#            '最高点',
#            '高涨',
#            '番',
#            '新疆',
#            '宝库',
#            '而',
#            '冒险家',
#            '下令',
#            '改革',
#            '出锋头',
#            '夏洛特',
#            '如今',
#            '泰国',
#            '背景',
#            '距离',
#            '引发',
#            '额外',
#            '手榴弹',
#            '出乎',
#            '旅游',
#            'flash',
#            '公告',
#            '3.4%',
#            '根据',
#            '头',
#            '灵魂',
#            '芝加哥',
#            '中国',
#            '保卫',
#            '陕西省',
#            '机构',
#            '市集',
#            '火灾',
#            '大批',
#            '实质',
#            '英雄',
#            '市中心',
#            '资源',
#            '引述',
#            '肖像',
#            '航线',
#            '转移',
#            '全体',
#            '会议',
#            '未遂',
#            '物资',
#            '专业',
#            '福斯特',
#            '福斯',
#            '克什米尔',
#            '单向',
#            '仍',
#            '北马里安纳',
#            '设法',
#            '广泛',
#            '大批量',
#            '干部',
#            '存有',
#            '纵火',
#            '虽然',
#            '中学生',
#            '旨在',
#            '沙漠',
#            '社会',
#            '逾',
#            '破案',
#            '机师',
#            '通缉',
#            '调整',
#            '犯罪',
#            '事务',
#            '接触',
#            '丧生',
#            '兼任',
#            '做',
#            '怀疑',
#            '尤为',
#            '研究',
#            '童年',
#            '口碑',
#            '观看',
#            '每天',
#            '生意',
#            '阻挡',
#            '大中',
#            '主题',
#            '后',
#            '金麦',
#            '签',
#            '学校',
#            '困境',
#            '习惯',
#            '一百五十一',
#            '黑店',
#            '场',
#            '分',
#            '悬赏',
#            '曼德拉',
#            '比率',
#            '乔布斯',
#            '自由派',
#            '需求量',
#            '信任',
#            '初期',
#            '专机',
#            '立场',
#            '泄露出',
#            '西安',
#            '时候',
#            '预测',
#            '缓',
#            '油',
#            '局面',
#            '失败',
#            '开放',
#            '要件',
#            '情势',
#            '走',
#            '旗下',
#            '近',
#            '重',
#            '地震',
#            '尼亚美',
#            '卡纳纳斯基斯',
#            '笑点',
#            '迫在眉睫',
#            '秘密',
#            '自我',
#            '实施',
#            '工商界',
#            '医院',
#            '欧盟',
#            'Cellular',
#            '软件',
#            '底特律',
#            '迈阿密',
#            '归功',
#            '通知',
#            '发射',
#            '产量',
#            '展望',
#            '另',
#            '工协',
#            '足以',
#            '川',
#            '次',
#            '标准值',
#            '事宜',
#            '取样',
#            '相信',
#            '面前',
#            '长久',
#            '发动',
#            '军',
#            '童话',
#            '配件',
#            '大王',
#            '屡',
#            '泥',
#            '鲜花',
#            '赖索托',
#            '保安局',
#            '大多',
#            '4',
#            '以期',
#            'Best',
#            '律师',
#            '瓜迪艾里',
#            '守卫',
#            '珠江',
#            '如',
#            '贫穷',
#            '1.5亿',
#            '趋',
#            '残缺',
#            '上次',
#            '毕业',
#            '3000万',
#            '参访',
#            '污水',
#            '犹太人',
#            '乘客',
#            '名宿',
#            '食物',
#            '院士',
#            '未',
#            '确保',
#            '蓝极速',
#            '3.0',
#            '策划',
#            '免于',
#            '他人',
#            '摄氏度',
#            '四十五万',
#            '纺织品',
#            '对付',
#            '3d',
#            '大举',
#            '技能',
#            '补偿',
#            '支持',
#            '水质',
#            '愿望',
#            '顺德市',
#            '11月',
#            '边疆',
#            '奇德',
#            '背后',
#            '事实',
#            '爱滋',
#            '成绩',
#            '大使馆',
#            '贵的',
#            '出人意料',
#            '奖',
#            '民众',
#            '浦东',
#            '意',
#            '充足',
#            '合资',
#            '爱尔兰',
#            '全权代表',
#            '九八年',
#            '希拉克',
#            '旅馆业',
#            '双管齐下',
#            '进',
#            '率先',
#            '私营',
#            '628',
#            '建成',
#            '4.45',
#            '玫',
#            '头衔',
#            '提醒',
#            '那个',
#            '妻子',
#            '素质',
#            '无照',
#            '对应',
#            '人民币',
#            '重伤',
#            '援外',
#            '斡旋',
#            '拒绝',
#            '自',
#            '60',
#            '胸前',
#            '余',
#            '核武',
#            '趋势',
#            'arm',
#            '为止',
#            '例如',
#            '地带',
#            '滑雪',
#            '使用者',
#            '而言',
#            '随时随地',
#            '自然保护区',
#            '打',
#            '高度',
#            '网络',
#            '规定',
#            '挺',
#            '再度',
#            '加拿大',
#            '历经',
#            '型式',
#            '协和',
#            '主席',
#            '遭遇',
#            '老',
#            '两百九十',
#            '硬件',
#            '马哈地',
#            '5196.1',
#            '贷款',
#            '走失',
#            '逢',
#            '适足',
#            '追平',
#            '开支',
#            '成本',
#            '埃及',
#            '经受',
#            '舷梯',
#            '痛苦',
#            '友好',
#            '制毒',
#            '缩放',
#            '2.9万',
#            '四',
#            '阻断',
#            '广州市',
#            '团体',
#            '明白',
#            '水文站',
#            '而后',
#            '能源',
#            '他们',
#            '不得而知',
#            '试图',
#            '卖淫',
#            '连续',
#            '盐',
#            '发达',
#            '乐于',
#            '上下',
#            '政协',
#            '0.1%',
#            '指责',
#            '泛',
#            '甩',
#            '五千万',
#            '右手',
#            '上海',
#            '其它',
#            '生变',
#            '联邦',
#            '游戏机',
#            '明确',
#            '联合',
#            '进一步',
#            '新泽西',
#            '艾丁顿',
#            '因而',
#            '61',
#            '法新社',
#            '责任感',
#            '毒贩',
#            '援助',
#            '学习',
#            '有史以来',
#            '任',
#            '展览',
#            '暴力',
#            '吸毒',
#            '周五',
#            '以往',
#            '不当',
#            '报界',
#            '惊人',
#            '称王',
#            '26万',
#            '缓和',
#            '救灾',
#            '侮辱',
#            '风暴',
#            '香港',
#            '恐惧',
#            '阿罗约',
#            '总裁',
#            '乘',
#            '严禁',
#            '如此',
#            '终于',
#            '汛期',
#            '即使',
#            '生',
#            '药品',
#            '纳洛福',
#            '动植物',
#            '会晤',
#            '开发计划署',
#            '讲话',
#            '供给',
#            '永远',
#            '此外',
#            '名',
#            '欢愉',
#            '化验',
#            '巴黎',
#            '首',
#            '恐怕',
#            '稍早',
#            '亚伯达省',
#            '事实上',
#            '150',
#            '1.5%',
#            '可是',
#            '总共',
#            '吉欧根',
#            '部门',
#            '库尔登',
#            '年内',
#            '主',
#            '观光业',
#            '公里',
#            '职网',
#            '意味',
#            '怪兽',
#            '但是',
#            '不断',
#            '制伏',
#            '格鲁吉亚',
#            '应急',
#            '机海战术',
#            '全场',
#            '铺路',
#            '瓦西里·博温',
#            '指挥部',
#            '饭店',
#            '项目',
#            '莱斯',
#            '此前',
#            '人文',
#            '十九',
#            '讯息',
#            '结构',
#            '谢',
#            '抗旱',
#            '头号',
#            '数千万',
#            '重要',
#            '建国',
#            '贾南德拉',
#            '漓江',
#            '超级',
#            '20',
#            '特定',
#            '爱国',
#            '程式',
#            '；',
#            ';',
#            '申请',
#            '大卫营',
#            '封山',
#            '警察局',
#            '九月',
#            '夜色',
#            '攻击者',
#            '投资额',
#            '送',
#            '起到',
#            '濒临',
#            '下去',
#            '体育',
#            '厂',
#            '凌虐',
#            ':',
#            '33',
#            '业者',
#            '莫三比克',
#            '除了',
#            '出租',
#            '境内',
#            '拜访',
#            '主政',
#            '同伴',
#            '国外',
#            '同事',
#            '罗森柏格',
#            '这么多',
#            '略',
#            '恶化',
#            '通讯',
#            '祖国',
#            '一下',
#            '称赞',
#            '江西',
#            '已经',
#            '覆盖率',
#            '胜仗',
#            '阿布·萨巴亚',
#            '创造',
#            '制造',
#            '屯垦区',
#            '21日',
#            '领军',
#            '共存',
#            '旅行',
#            '哥',
#            '曾',
#            '伊利瑟',
#            '挫败',
#            '15日',
#            '一系列',
#            '溜马队',
#            '此举',
#            '特卡乔夫',
#            '行径',
#            '假帐',
#            '9月',
#            '人选',
#            '酱',
#            '4899.13',
#            '大张旗鼓',
#            ...})

# %%
len(DataSet_vocab),len(DataSet_vocab_frozen)
# Out:
# (25206, 5259)

# %% [markdown]
# # BOW

# %%
# create two list for all chinese words and enligh words (one to one map)

words_ch = []
words_en = []

for s_ch, s_en in zip(DataSet_ch, DataSet_en):
    for w_ch, w_en in zip(s_ch, s_en):
        words_ch.append(w_ch)
        words_en.append(w_en)
        
for i in range(10):
    print(words_ch[i]+'->'+words_en[i])
# Out:
# 教区->archdiocese
# 财务->finance
# 委员会->council
# 认为->thinks
# ,->that
# 这项->this
# 协议->agreement
# 可能->may
# 使得->force
# 波士顿->boston

# %%
from collections import Counter, defaultdict, namedtuple, OrderedDict
# build a dict of chinese-english
def ch_en_dict(ch, en):
    d = defaultdict(lambda: defaultdict(int))
    for c, e in zip(ch, en):
        d[c][e] += 1
    return d

word_counts = ch_en_dict(words_ch, words_en)
word_counts
# Out:
# defaultdict(<function __main__.ch_en_dict.<locals>.<lambda>()>,
#             {'教区': defaultdict(int, {'archdiocese': 7}),
#              '财务': defaultdict(int, {'finance': 2, 'financial': 2}),
#              '委员会': defaultdict(int,
#                          {'council': 2,
#                           'committee': 1,
#                           'committees': 1,
#                           'None': 1,
#                           'commission': 6}),
#              '认为': defaultdict(int,
#                          {'thinks': 3,
#                           'think': 5,
#                           'opinion': 1,
#                           'considers': 1,
#                           'thought': 3,
#                           'agreed': 1,
#                           'held': 1,
#                           'holds': 1,
#                           'found': 1,
#                           'was believed that': 1,
#                           'it may be': 1,
#                           'gain a sense of': 1}),
#              ',': defaultdict(int,
#                          {'that': 153,
#                           'None': 541,
#                           ',': 484,
#                           '.': 140,
#                           ';': 13,
#                           ':': 4}),
#              '这项': defaultdict(int, {'this': 7, 'the': 9, 'None': 2}),
#              '协议': defaultdict(int,
#                          {'agreement': 13,
#                           'agreements': 3,
#                           'consultative': 1,
#                           'settlement': 3,
#                           'None': 2}),
#              '可能': defaultdict(int,
#                          {'may': 14,
#                           'possible': 4,
#                           'might': 2,
#                           'impossible': 1,
#                           'threatened': 1,
#                           'None': 6,
#                           'likely': 1,
#                           'can': 1,
#                           'likelihood': 1,
#                           'It may be': 1}),
#              '使得': defaultdict(int,
#                          {'force': 1,
#                           'None': 3,
#                           'throwing': 1,
#                           'forcing': 1,
#                           'sending': 1}),
#              '波士顿': defaultdict(int, {'boston': 6}),
#              '天主教会': defaultdict(int, {'catholic archdiocese': 1}),
#              '破产': defaultdict(int,
#                          {'bankruptcy': 3, 'bankrupt': 1, 'went bankrupt': 1}),
#              '因为': defaultdict(int,
#                          {'as': 2,
#                           'for': 3,
#                           'None': 1,
#                           'because of': 4,
#                           'because': 9,
#                           'due to': 1,
#                           'blame for': 1}),
#              '声称': defaultdict(int, {'alleged': 1, 'claiming': 1}),
#              '受到': defaultdict(int,
#                          {'None': 9,
#                           'drawn': 1,
#                           'deserves': 1,
#                           'were': 1,
#                           'suffered': 1,
#                           'getting': 1}),
#              '性': defaultdict(int,
#                          {'sexual': 3,
#                           'sex': 1,
#                           'sexually': 1,
#                           'None': 1,
#                           'pedophile': 1}),
#              '侵害': defaultdict(int,
#                          {'abuse': 2,
#                           'molestation': 1,
#                           'pedophile': 1,
#                           'None': 1}),
#              '的': defaultdict(int,
#                          {'of': 123,
#                           'None': 906,
#                           'his': 16,
#                           "'s": 40,
#                           'her': 6,
#                           "'": 6,
#                           'its': 2,
#                           'correspondingly': 1,
#                           'help': 1,
#                           'my': 3,
#                           'their': 6,
#                           'our': 6,
#                           'superheroes': 1,
#                           'perpetrators': 1,
#                           'violators': 1,
#                           'passers-by': 1,
#                           'victims': 1,
#                           'great': 1,
#                           'deal': 1,
#                           'when': 1,
#                           'entirely missed': 1,
#                           'with prices ranging from to': 1,
#                           'That is not the case': 1,
#                           'are in the range': 1,
#                           'Apple': 2,
#                           'the best': 1,
#                           'recent': 1,
#                           'for as little as': 1,
#                           'really': 1,
#                           'real': 2,
#                           'typical': 1,
#                           "Motorola's": 1,
#                           'high - interest': 1,
#                           'that have': 1,
#                           'increased': 1,
#                           'unique': 1,
#                           'has surely done a great job': 1,
#                           'in the Foot': 1,
#                           'Over the': 1,
#                           'luxury - oriented consumers': 1,
#                           'comfort': 1,
#                           'Where': 1,
#                           'nice': 1,
#                           'forced': 1,
#                           'as nice as it may be': 1,
#                           'pretty decent': 1,
#                           'the hidden': 1,
#                           'the integrated': 1,
#                           'it may be': 1,
#                           'The icing on the cake': 1,
#                           'has been paid for': 1,
#                           'extra': 3,
#                           'locked-in': 1,
#                           'during': 1,
#                           'aggressively': 1,
#                           'has a disadvantage in': 1,
#                           'planned': 1,
#                           'leaked': 1,
#                           'correct': 1,
#                           'be the megaseller needs': 1,
#                           'copy': 1,
#                           'premium': 1,
#                           'premium in a new category': 1,
#                           'needs': 1,
#                           'just': 1,
#                           'expensive': 1,
#                           'its own': 1,
#                           'in ways': 1,
#                           'groundbreaking': 1,
#                           'good': 1,
#                           'benefits': 1,
#                           'Imaginative': 2,
#                           'better': 1,
#                           'those': 1,
#                           'is empowering to': 1,
#                           'in': 1,
#                           'the beginning of': 1,
#                           'delicious': 1,
#                           'a lot of': 1,
#                           'communication': 1,
#                           'big bad': 1,
#                           'anger toward': 1,
#                           'children': 1,
#                           'to visit other worlds': 1,
#                           'of their own': 1,
#                           'Explosives': 1}),
#              '案子': defaultdict(int, {'cases': 1}),
#              '越来越': defaultdict(int, {'keep surfacing': 1}),
#              '多': defaultdict(int,
#                          {'keep surfacing': 1,
#                           'equal number': 1,
#                           'more': 9,
#                           'more than': 10,
#                           'how': 1,
#                           'over': 12,
#                           'a number of': 3,
#                           'many': 1,
#                           'about a dozen': 1,
#                           'up': 1,
#                           'several': 1,
#                           'multi-layered': 1,
#                           'in years': 1,
#                           'None': 3,
#                           'numerous': 1,
#                           'a series of': 2,
#                           'for years': 1,
#                           'multi-purpose': 1,
#                           'much': 1,
#                           'experiment with the variables': 1,
#                           'some': 1,
#                           'premium': 1,
#                           'a lot of': 1}),
#              '而且': defaultdict(int,
#                          {'and': 4,
#                           'furthermore': 1,
#                           'while': 1,
#                           'but also': 1}),
#              '「': defaultdict(int, {'"': 104, 'None': 11}),
#              '在': defaultdict(int,
#                          {'since': 2,
#                           'in': 163,
#                           'near': 1,
#                           'during': 14,
#                           'after': 20,
#                           'on': 26,
#                           'None': 64,
#                           'at': 45,
#                           'within': 4,
#                           'over': 4,
#                           'prior to': 7,
#                           'under': 5,
#                           'is': 3,
#                           'are': 2,
#                           'before': 3,
#                           'besides': 1,
#                           'once on': 1,
#                           'in front of': 1,
#                           'amidst': 1,
#                           'when': 3,
#                           'by': 3,
#                           'until': 1,
#                           'intended': 1,
#                           'on near': 1,
#                           'between': 1,
#                           'while': 1,
#                           'beneath': 1,
#                           'underneath': 1,
#                           'around': 1,
#                           'outside': 1,
#                           'be somewhere between and': 1,
#                           'which is a range': 1,
#                           'Where is': 1,
#                           'buying': 1,
#                           'add': 1,
#                           'in ways': 1,
#                           'of': 1,
#                           'are learning': 1}),
#              '促成': defaultdict(int, {'leading': 1, 'None': 1, 'help': 1}),
#              '程序': defaultdict(int,
#                          {'process': 1,
#                           'procedure': 1,
#                           'procedures': 1,
#                           'app': 1}),
#              '开始': defaultdict(int,
#                          {'started': 5,
#                           'None': 1,
#                           'begun': 1,
#                           'starts': 2,
#                           'starting': 1,
#                           'start': 2,
#                           'commenced': 1,
#                           'opening': 1,
#                           'begins': 1,
#                           'began': 1,
#                           'since': 1,
#                           'launched': 1,
#                           'initial': 1,
#                           'in the first place': 1}),
#              '后': defaultdict(int,
#                          {'since': 4,
#                           'after': 34,
#                           'ever since': 1,
#                           'None': 10,
#                           'in the wake of': 1,
#                           'once': 1,
#                           'in school': 1}),
#              '情况': defaultdict(int,
#                          {'situation': 3,
#                           'scenario': 1,
#                           'circumstances': 1,
#                           'circumstance': 1,
#                           'issue': 1,
#                           'None': 2}),
#              '已经': defaultdict(int,
#                          {'has': 8,
#                           'have': 6,
#                           'already': 8,
#                           'None': 5,
#                           'had': 1,
#                           'was': 1,
#                           'will': 1,
#                           'has been': 1}),
#              '有': defaultdict(int,
#                          {'None': 59,
#                           'is': 3,
#                           'available': 1,
#                           'are': 2,
#                           'having': 1,
#                           'have': 5,
#                           'had': 1,
#                           'necessary': 1,
#                           'has': 1,
#                           'offers': 1,
#                           'another': 2,
#                           'been': 1,
#                           'be': 2,
#                           'faulty': 1,
#                           'send': 1,
#                           'accomplish': 1,
#                           'able-bodied': 1,
#                           'skilled': 1,
#                           'taken in': 1,
#                           'include': 1,
#                           'what amount': 1,
#                           'carries': 1,
#                           'It was a very confident move by': 1,
#                           'there are': 1,
#                           'have to learn to play': 1,
#                           'in need': 1}),
#              '很': defaultdict(int,
#                          {'dramatically': 1,
#                           'deeply': 1,
#                           'very': 3,
#                           'None': 5,
#                           'strong': 1,
#                           'It was a very confident move by': 1,
#                           'as nice as it may be': 1,
#                           'a lot of': 1}),
#              '大': defaultdict(int,
#                          {'dramatically': 1,
#                           'largest': 8,
#                           'None': 10,
#                           'major': 5,
#                           'tons': 1,
#                           'huge': 2,
#                           'great': 2,
#                           'big': 2,
#                           'biggest': 1,
#                           'larger': 1,
#                           'large': 3,
#                           'little': 2,
#                           'plunged': 1,
#                           'second-biggest': 1,
#                           'most': 1,
#                           'greater': 1,
#                           'heavy': 1,
#                           'much-affected': 1,
#                           'high': 1,
#                           'dramatic': 1,
#                           'good Samaritans': 1}),
#              '变化': defaultdict(int, {'changed': 1, 'changes': 2}),
#              '」': defaultdict(int, {'"': 104, 'None': 12, '.': 1}),
#              '。': defaultdict(int,
#                          {'.': 859,
#                           'None': 11,
#                           ',': 3,
#                           '"': 1,
#                           '--': 1,
#                           ':': 1}),
#              '六十六': defaultdict(int, {'66-year-old': 1}),
#              '岁': defaultdict(int,
#                          {'66-year-old': 1,
#                           '10-year-old': 1,
#                           'None': 8,
#                           '75-year-old': 1,
#                           '32nd': 1,
#                           'aged': 1,
#                           '26-year-old': 1,
#                           '13-year-old': 2,
#                           '14-year-old': 2,
#                           '58-year-old': 2,
#                           'years': 1}),
#              '吉欧根': defaultdict(int, {'geoghan': 3}),
#              '一九九一年': defaultdict(int, {'1991': 1}),
#              '一': defaultdict(int,
#                          {'a': 83,
#                           'an': 18,
#                           'None': 53,
#                           'one': 11,
#                           'tons': 1,
#                           'one-day': 2,
#                           '3-1': 1,
#                           '6-1': 1,
#                           'first': 1,
#                           'january-march': 1,
#                           'other': 1,
#                           'one-week': 1,
#                           'another': 2,
#                           'scoreless': 1,
#                           'experiment with the variables': 1,
#                           'a different fight': 1,
#                           'in the first place': 1,
#                           'Next': 1,
#                           'By the way': 1,
#                           'to': 1}),
#              '名': defaultdict(int, {'None': 82, 'name': 2}),
#              '十': defaultdict(int,
#                          {'10-year-old': 1,
#                           '10': 6,
#                           '10-day': 1,
#                           'decade': 4,
#                           '100,000': 1,
#                           'dozens': 1,
#                           'Ten': 1}),
#              '男童': defaultdict(int, {'boy': 1}),
#              '最近': defaultdict(int,
#                          {'recently': 8,
#                           'just now': 1,
#                           'recent': 8,
#                           'None': 1,
#                           'soon': 1,
#                           'most recent': 1,
#                           'the recent': 1}),
#              '被': defaultdict(int,
#                          {'was': 5,
#                           'None': 17,
#                           'been': 4,
#                           'were': 3,
#                           'is': 1,
#                           'be': 2,
#                           'death': 1,
#                           'by': 12,
#                           'are': 1,
#                           'being': 1,
#                           'leaked': 1,
#                           'priced': 1,
#                           'to be left out': 1}),
#              '判处': defaultdict(int, {'sentenced': 3}),
#              '年': defaultdict(int,
#                          {'years': 26,
#                           'decades': 1,
#                           'year': 6,
#                           'decade': 4,
#                           '41-year-old': 1,
#                           'in years': 1,
#                           'six months': 1,
#                           'for years': 1,
#                           'annual': 2,
#                           '2011': 1,
#                           '2015': 1}),
#              '徒刑': defaultdict(int, {'imprisonment': 1}),
#              '已': defaultdict(int,
#                          {'None': 18,
#                           'has': 22,
#                           "'s": 1,
#                           'have': 11,
#                           'already': 12,
#                           'had': 2,
#                           'no longer': 1}),
#              '削去': defaultdict(int, {'defrocked': 1}),
#              '教士': defaultdict(int, {'priest': 4}),
#              '职务': defaultdict(int,
#                          {'None': 1,
#                           'position': 1,
#                           'office': 1,
#                           'positions': 1,
#                           'presidency': 1}),
#              '他': defaultdict(int,
#                          {'None': 4, 'his': 22, 'he': 79, 'him': 8, 'its': 1}),
#              '还': defaultdict(int,
#                          {'also': 19,
#                           'still': 3,
#                           'yet': 2,
#                           'None': 9,
#                           'and': 1,
#                           'just': 1,
#                           'has': 1,
#                           'as well': 1,
#                           'further': 1,
#                           'added': 1,
#                           'but also': 1,
#                           'in addition': 1,
#                           'were not shabby': 1}),
#              '面临': defaultdict(int,
#                          {'faces': 3,
#                           'confront': 1,
#                           'None': 1,
#                           'faced': 1,
#                           'facing': 1}),
#              '其他': defaultdict(int, {'other': 26, 'None': 2, 'others': 1}),
#              '刑事': defaultdict(int, {'criminal': 3}),
#              '审判': defaultdict(int, {'trials': 1, 'trial': 1}),
#              '和': defaultdict(int,
#                          {'and': 188,
#                           'with': 4,
#                           'None': 9,
#                           'or': 3,
#                           'greek-turkish': 1,
#                           'as well as': 2,
#                           'That is not the case': 1,
#                           'both and': 1,
#                           'compete with': 1,
#                           'to': 1}),
#              '数十': defaultdict(int, {'scores': 1}),
#              '件': defaultdict(int, {'None': 2}),
#              '民事': defaultdict(int, {'civil': 1}),
#              '官司': defaultdict(int, {'lawsuits': 1}),
#              '美': defaultdict(int,
#                          {'us': 7,
#                           'united states': 4,
#                           'america': 1,
#                           'filipino-us': 1,
#                           'us-china': 1,
#                           'eu-us': 2,
#                           'us-eu': 1,
#                           'as nice as it may be': 1}),
#              '印': defaultdict(int,
#                          {'india': 8,
#                           'None': 1,
#                           'india-pakistan': 4,
#                           'indian': 1}),
#              '五月': defaultdict(int, {'mid-may': 3, 'may': 7}),
#              '中': defaultdict(int,
#                          {'mid-may': 2,
#                           'None': 27,
#                           'at': 8,
#                           'in': 42,
#                           'during': 7,
#                           'medium': 1,
#                           'from': 1,
#                           'amidst': 1,
#                           'china': 3,
#                           'us-china': 1,
#                           'within': 1,
#                           'of': 1}),
#              '将': defaultdict(int,
#                          {'None': 41,
#                           'will': 96,
#                           'would': 6,
#                           'could': 1,
#                           'attribute': 1,
#                           'imminent': 1,
#                           'put': 1,
#                           'pull in tow': 1,
#                           'about': 1}),
#              '举行': defaultdict(int,
#                          {'conduct': 3,
#                           'conducted': 3,
#                           'upcoming': 1,
#                           'held': 22,
#                           'holds': 2,
#                           'hold': 9,
#                           'None': 9,
#                           'convene': 1,
#                           'holding': 1}),
#              '四十': defaultdict(int, {'4 decades': 1}),
#              '来': defaultdict(int,
#                          {'None': 28,
#                           'come over': 1,
#                           'comes': 1,
#                           'in terms of': 1,
#                           'since': 1,
#                           'invited': 1,
#                           'came': 1}),
#              '首次': defaultdict(int, {'first': 6, 'first time': 2}),
#              '联合': defaultdict(int, {'joint': 12}),
#              '军事': defaultdict(int, {'military': 16, 'None': 1}),
#              '演习': defaultdict(int, {'exercise': 7, 'exercises': 2}),
#              '(': defaultdict(int, {'(': 107, 'None': 3}),
#              '法新社': defaultdict(int, {'afp': 50}),
#              '新德里': defaultdict(int, {'new delhi': 6}),
#              '电': defaultdict(int, {'None': 97}),
#              ')': defaultdict(int, {')': 105, 'None': 5}),
#              '印度': defaultdict(int,
#                          {'india': 35,
#                           'indian': 11,
#                           'india-pakistan': 1,
#                           'india-controlled': 1,
#                           'None': 1}),
#              '美国': defaultdict(int,
#                          {'united states': 46,
#                           'us': 94,
#                           'american': 5,
#                           'abc': 1,
#                           'cbs': 1,
#                           'None': 4,
#                           'the united states of america': 1,
#                           'americans': 1,
#                           'unites states': 1}),
#              '三十九': defaultdict(int, {'39': 1}),
#              '为': defaultdict(int,
#                          {'None': 27,
#                           'for': 12,
#                           'did': 1,
#                           'be': 1,
#                           'on': 1,
#                           'in order to': 2,
#                           'to': 4,
#                           'as': 4,
#                           'targeting': 1,
#                           'being': 1,
#                           'aimed at': 1,
#                           'therefore': 1,
#                           'achieve': 1,
#                           'was': 6,
#                           'is': 2,
#                           'sports-based': 1,
#                           'towards': 1}),
#              '世界': defaultdict(int,
#                          {'world': 17,
#                           'wto': 3,
#                           'worldcom': 1,
#                           'world-renown': 1,
#                           'to visit other worlds': 1}),
#              '上': defaultdict(int,
#                          {'in': 11,
#                           'at': 12,
#                           'previous': 2,
#                           'onto': 1,
#                           'None': 6,
#                           'attend': 1,
#                           'on': 11,
#                           'last': 2,
#                           'went': 1,
#                           'market': 1,
#                           'it': 1,
#                           'to a certain degree': 1,
#                           'sort of': 1}),
#              '两': defaultdict(int,
#                          {'two': 41,
#                           'None': 14,
#                           '2-day': 2,
#                           '2': 1,
#                           'both': 1,
#                           'a pair of': 1,
#                           'second': 1}),
#              '个': defaultdict(int,
#                          {'None': 62,
#                           'months': 1,
#                           'an': 2,
#                           'a': 4,
#                           'what amount': 1}),
#              '最': defaultdict(int,
#                          {'largest': 7,
#                           'most': 8,
#                           'gravest': 1,
#                           'minimum': 1,
#                           'worst': 3,
#                           'biggest': 2,
#                           'best': 3,
#                           'poorest': 2,
#                           'worst-hit': 1,
#                           'fastest': 1,
#                           'lowest': 1,
#                           'chief': 1,
#                           'highest': 1,
#                           'sincerest': 1,
#                           'the best': 1,
#                           'The icing on the cake': 1}),
#              '民主': defaultdict(int, {'democracies': 1}),
#              '国家': defaultdict(int,
#                          {'democracies': 1,
#                           'national': 6,
#                           'None': 4,
#                           'nations': 14,
#                           'nbc': 1,
#                           'country': 3,
#                           'countries': 11,
#                           'states': 2,
#                           'state-sponsoring': 1,
#                           'state-sponsored': 1,
#                           'nation': 3,
#                           'president': 2,
#                           'asean': 1,
#                           'state': 2}),
#              '间': defaultdict(int,
#                          {'between': 5, 'in': 5, 'among': 1, 'None': 3}),
#              '合作': defaultdict(int,
#                          {'cooperation': 18,
#                           'work together': 3,
#                           'cooperate': 4,
#                           'cooperative': 2,
#                           'working': 1,
#                           'joint': 1,
#                           'to cooperate': 1}),
#              '关系': defaultdict(int,
#                          {'None': 7,
#                           'relations': 4,
#                           'relationship': 5,
#                           'partnership': 3,
#                           'tensions': 2,
#                           'relation': 1,
#                           'relationships': 1}),
#              '缔造': defaultdict(int, {'mark': 1}),
#              '里程碑': defaultdict(int, {'milestone': 1, 'landmark': 1}),
#              '国防部': defaultdict(int,
#                          {'ministry of national defense': 3, 'defense': 3}),
#              '说': defaultdict(int,
#                          {'said': 134,
#                           'None': 10,
#                           'say': 2,
#                           'according to': 3,
#                           'addressed': 1,
#                           'added': 4,
#                           'vows': 1,
#                           'speaking': 1,
#                           'saying': 4,
#                           'indicate': 1,
#                           'told': 1,
#                           'goes': 1,
#                           'says': 4,
#                           'more importantly': 1,
#                           'to a certain degree': 1,
#                           '" would "': 1,
#                           'have problems justifying': 1,
#                           'have argued that': 1}),
#              '支': defaultdict(int, {'None': 3}),
#              '精锐': defaultdict(int, {'elite': 1}),
#              '伞兵': defaultdict(int, {'paratroopers': 1}),
#              '旅': defaultdict(int,
#                          {'brigade': 1, 'travel': 5, 'trip': 1, 'journey': 1}),
#              '中旬': defaultdict(int, {'mid-may': 1}),
#              '与': defaultdict(int,
#                          {'with': 56,
#                           'and': 57,
#                           'india-pakistan': 1,
#                           'from': 1,
#                           'as well as': 2,
#                           'None': 10,
#                           'to': 1,
#                           'as': 1,
#                           'right against': 1,
#                           'contract from': 1,
#                           'alternative to': 1}),
#              '太平洋': defaultdict(int, {'pacific': 1, 'pacific ocean': 1}),
#              '美军': defaultdict(int,
#                          {'us': 2,
#                           'military personnel': 1,
#                           'united states': 1}),
#              '司令部': defaultdict(int, {'command': 1}),
#              '特种部队': defaultdict(int,
#                          {'special forces': 1, 'special force unit': 2}),
#              '闻名遐迩': defaultdict(int, {'renowned': 1}),
#              '泰姬': defaultdict(int, {'taj': 1}),
#              '马哈陵': defaultdict(int, {'mahal': 1}),
#              '附近': defaultdict(int,
#                          {'near': 3, 'nearby': 1, 'neighborhood': 2}),
#              '国': defaultdict(int,
#                          {'nations': 5,
#                           'None': 10,
#                           'countries': 6,
#                           'pakistan': 2,
#                           'state': 3,
#                           'pakistani': 1,
#                           'pakistanian': 1}),
#              '空军': defaultdict(int, {'air forces': 1, 'raf': 1}),
#              '给以': defaultdict(int, {'provide': 1}),
#              '支援': defaultdict(int, {'support': 1, 'supported': 1}),
#              '这': defaultdict(int,
#                          {'it': 2,
#                           'this': 25,
#                           'None': 18,
#                           'the': 30,
#                           'these': 7,
#                           'those': 1,
#                           'which': 1,
#                           'there are': 1,
#                           'that': 2,
#                           'this requirement': 1,
#                           'It': 2,
#                           'This': 1}),
#              '是': defaultdict(int,
#                          {'be': 9,
#                           'was': 5,
#                           'is': 53,
#                           'None': 53,
#                           'are': 13,
#                           "'m": 1,
#                           'were': 5,
#                           'been': 3,
#                           'especially': 4,
#                           'as': 3,
#                           'respectively': 1,
#                           "'s": 2,
#                           'being': 1,
#                           'represents': 1,
#                           'serves as': 1,
#                           'instead': 1,
#                           'because': 1,
#                           'since': 1,
#                           'will be': 1,
#                           "It's": 1,
#                           'which': 1,
#                           'there are': 1,
#                           '" would "': 1,
#                           "won't": 1,
#                           'tend to be': 1,
#                           'The bottom line :': 1,
#                           'is priced at': 1,
#                           'about': 1,
#                           'trump with': 1}),
#              '多次': defaultdict(int, {'many': 1}),
#              '第一': defaultdict(int,
#                          {'first': 13, 'top': 1, '1st': 2, 'top-seeded': 1}),
#              '次': defaultdict(int,
#                          {'None': 14,
#                           'time': 7,
#                           'first-time': 1,
#                           'times': 2,
#                           'several': 1}),
#              '冷战': defaultdict(int, {'cold war': 1}),
#              '时期': defaultdict(int, {'era': 1, 'period': 2, 'time': 1}),
#              '紧张': defaultdict(int,
#                          {'strained': 1, 'tensions': 13, 'tense': 1}),
#              '但': defaultdict(int,
#                          {'however': 14,
#                           'but': 15,
#                           'None': 10,
#                           'yet': 9,
#                           'though': 1,
#                           ',': 1}),
#              '自': defaultdict(int,
#                          {'since': 8, 'ever since': 1, 'on': 1, 'None': 1}),
#              '九一一': defaultdict(int, {'sept. 11': 8, 'september 11': 1}),
#              '纽约': defaultdict(int, {'new york': 6, 'nyse': 2}),
#              '华盛顿': defaultdict(int, {'washington': 17}),
#              '遭': defaultdict(int, {'None': 8, 'suffers': 1, 'was': 2}),
#              '恐怖分子': defaultdict(int, {'terrorist': 3, 'terrorists': 8}),
#              '攻击': defaultdict(int,
#                          {'attacks': 13,
#                           'attack': 8,
#                           'fires': 1,
#                           'penetrating': 1,
#                           'targets': 1,
#                           'actions': 2,
#                           'bomber': 1,
#                           'None': 2,
#                           'offensive': 1,
#                           'attacked': 1,
#                           'bombings': 1}),
#              '事件': defaultdict(int,
#                          {'None': 12,
#                           'event': 1,
#                           'things': 1,
#                           'incidents': 1,
#                           'incident': 3,
#                           'accident': 1,
#                           'attack': 1}),
#              '以来': defaultdict(int,
#                          {'since': 13,
#                           'ever': 1,
#                           'following': 1,
#                           'None': 6,
#                           'ever since': 1}),
#              '见': defaultdict(int,
#                          {'been': 1,
#                           'None': 1,
#                           'no': 1,
#                           'more on this below': 1}),
#              '大幅': defaultdict(int,
#                          {'dramatically': 1,
#                           'significantly': 1,
#                           'sweeping': 1,
#                           'sharp': 1}),
#              '改善': defaultdict(int,
#                          {'improved': 2,
#                           'improve': 3,
#                           'improvement': 2,
#                           'improvements': 1}),
#              '除': defaultdict(int, {'apart from': 2, 'None': 1}),
#              '海军': defaultdict(int, {'navy': 2, 'navies': 1}),
#              '印尼': defaultdict(int, {'indonesia': 1}),
#              '马来西亚': defaultdict(int, {'malaysia': 9, 'malaysian': 3}),
#              '之间': defaultdict(int,
#                          {'between': 11,
#                           'among': 1,
#                           'be somewhere between and': 1,
#                           'with': 1}),
#              '麻六甲': defaultdict(int, {'malacca': 1}),
#              '海峡': defaultdict(int, {'strait': 1}),
#              '外海': defaultdict(int, {'None': 1}),
#              '进行': defaultdict(int,
#                          {'None': 29,
#                           'conduct': 2,
#                           'went on': 1,
#                           'conducted': 2,
#                           'performed': 1,
#                           'hold': 2,
#                           'held': 2,
#                           'have': 1,
#                           'made': 1,
#                           'make': 1}),
#              '海上': defaultdict(int, {'sea': 1}),
#              '巡逻': defaultdict(int, {'patrolling': 2}),
#              '以防': defaultdict(int, {'so as to prevent': 1}),
#              '发生': defaultdict(int,
#                          {'None': 8,
#                           'took place': 4,
#                           'happen': 1,
#                           'likelihood': 1,
#                           'went up': 1,
#                           'had': 1,
#                           'been': 1,
#                           'hit': 1,
#                           'become': 1,
#                           'happens': 1}),
#              '海盗': defaultdict(int, {'piracy': 1}),
#              '行为': defaultdict(int,
#                          {'acts': 1, 'criminalizes': 1, 'None': 2, 'act': 1}),
#              '之外': defaultdict(int,
#                          {'apart from': 1,
#                           'None': 1,
#                           'besides': 1,
#                           'in addition to': 1}),
#              '近年': defaultdict(int, {'recent years': 2}),
#              '曾': defaultdict(int,
#                          {'has': 2,
#                           'None': 16,
#                           'once': 2,
#                           'having': 1,
#                           'zeng': 1,
#                           'for a time': 1}),
#              '英国': defaultdict(int,
#                          {'britain': 11,
#                           'british': 14,
#                           'raf': 1,
#                           'None': 2,
#                           'u.k.': 2}),
#              '、': defaultdict(int, {',': 115, 'None': 43, 'and': 4}),
#              '法国': defaultdict(int, {'france': 9, 'french': 17, 'None': 1}),
#              '日本': defaultdict(int, {'japan': 25, 'japanese': 3, 'None': 1}),
#              '发言人': defaultdict(int, {'spokesman': 6, 'spokeswoman': 1}),
#              ':': defaultdict(int,
#                          {':': 73, ',': 2, 'None': 2, 'that': 1, '0-2': 1}),
#              '即将': defaultdict(int,
#                          {'upcoming': 2,
#                           'will': 1,
#                           'will soon': 1,
#                           'is going to': 1,
#                           'right before': 1}),
#              '旨在': defaultdict(int,
#                          {'aims at': 1, 'aimed at': 1, 'aimed to': 1}),
#              '进一步': defaultdict(int,
#                          {'further': 12,
#                           'None': 2,
#                           'even': 1,
#                           'more': 1,
#                           'more importantly': 1}),
#              '提升': defaultdict(int, {'enhancing': 1, 'upgraded': 1}),
#              '上次': defaultdict(int, {'last time': 1}),
#              '一九六二年': defaultdict(int, {'1962': 1}),
#              '中国': defaultdict(int, {'china': 45, 'chinese': 16}),
#              '短暂': defaultdict(int, {'brief': 1}),
#              '边界': defaultdict(int, {'border': 11}),
#              '战争': defaultdict(int, {'war': 7, 'wars': 3}),
#              '之后': defaultdict(int, {'after': 11, 'later': 1, 'None': 2}),
#              '去年': defaultdict(int,
#                          {'last': 4,
#                           'last year': 23,
#                           'None': 1,
#                           'year ,': 1,
#                           'Last year': 1}),
#              '七月': defaultdict(int, {'july': 1}),
#              '大约': defaultdict(int, {'about': 4, 'None': 1, 'or': 1}),
#              '五十': defaultdict(int, {'50': 5, 'golden jubilee': 2, '50th': 2}),
#              '位': defaultdict(int, {'None': 30, 'Next': 1}),
#              '决策': defaultdict(int, {'policy makers': 2, 'decisions': 1}),
#              '人员': defaultdict(int,
#                          {'makers': 1,
#                           'personnel': 1,
#                           'None': 3,
#                           'staff': 2,
#                           'officers': 1,
#                           'employee': 3,
#                           'officials': 1,
#                           'employees': 1,
#                           'entourage': 1,
#                           'casualties': 1,
#                           'palestinians': 5,
#                           'crew': 1}),
#              '访问': defaultdict(int,
#                          {'visited': 1,
#                           'visits': 1,
#                           'visit': 12,
#                           'visiting': 1,
#                           'interview': 3,
#                           'pay a visit': 1,
#                           'tour': 1}),
#              '过': defaultdict(int,
#                          {'None': 7, 'huge': 1, 'survived': 1, 'said': 1}),
#              '同时': defaultdict(int,
#                          {'while': 5,
#                           'in the meantime': 2,
#                           'meanwhile': 1,
#                           'at the same time': 8,
#                           'meantime': 1,
#                           'simultaneously': 1,
#                           'and': 1}),
#              '方面': defaultdict(int,
#                          {'None': 9,
#                           'makers': 1,
#                           'democrats': 1,
#                           'respect': 1,
#                           'aspects': 1,
#                           'in many ways': 1,
#                           'has a disadvantage in': 1,
#                           'in ways': 2}),
#              '也': defaultdict(int,
#                          {'None': 13,
#                           'also': 33,
#                           'as well as': 3,
#                           'namely': 1,
#                           'too': 1,
#                           'as well': 1,
#                           'nor': 2,
#                           'yet': 1,
#                           'no longer': 1,
#                           'which': 1,
#                           'still': 1,
#                           'and': 1}),
#              '这么': defaultdict(int,
#                          {'equal number': 1, 'so': 1, 'the cost': 1}),
#              '人': defaultdict(int,
#                          {'people': 23,
#                           'None': 26,
#                           'muscovites': 1,
#                           'lives': 1,
#                           'toll': 1,
#                           'employees': 1,
#                           'arab': 1,
#                           'one': 1,
#                           'many': 1,
#                           'israeli': 1,
#                           'peoples': 1,
#                           'nobody': 2,
#                           'cast': 1,
#                           'inspiring': 1,
#                           'both': 1,
#                           'israelis': 4,
#                           'palestinian': 5,
#                           'palestinians': 7,
#                           'man': 1,
#                           'perpetrators': 1,
#                           'pledger': 1,
#                           'a soft start': 1,
#                           'filipinos': 1,
#                           'americans': 1,
#                           'satisfactory': 1,
#                           'attractive': 1,
#                           'victims': 1,
#                           'austrian': 1,
#                           'disappointing': 1,
#                           'Some': 1,
#                           'those': 1}),
#              '包括': defaultdict(int,
#                          {'including': 15,
#                           'included': 1,
#                           'None': 2,
#                           'include': 6,
#                           'composed of': 1,
#                           'excluding': 1}),
#              '瓦巴依': defaultdict(int, {'vajpayee': 2}),
#              '总理': defaultdict(int, {'prime minister': 14, 'premier': 1}),
#              '安全': defaultdict(int,
#                          {'security': 19,
#                           'secret': 1,
#                           'peace': 2,
#                           'safety': 4}),
#              '团队': defaultdict(int, {'team': 1}),
#              '成员': defaultdict(int, {'None': 2, 'members': 2, 'member': 2}),
#              '前往': defaultdict(int,
#                          {'paid to': 1,
#                           'fly to': 1,
#                           'went to': 1,
#                           'to': 1,
#                           'travel to': 1,
#                           'getting to': 1,
#                           'None': 1}),
#              '继': defaultdict(int,
#                          {'after': 3, 'in the wake of': 1, 'following': 2}),
#              '恐怖': defaultdict(int,
#                          {'terrorist': 14,
#                           'terrorism': 1,
#                           'anti-terrorist': 1}),
#              '以及': defaultdict(int,
#                          {'and': 24,
#                           'None': 2,
#                           'along with': 1,
#                           'as well as': 5,
#                           'or': 2}),
#              '十二月': defaultdict(int, {'december': 2}),
#              '国会': defaultdict(int,
#                          {'national parliament': 1,
#                           'congress': 2,
#                           'state duma': 2,
#                           'national assembly': 2,
#                           'congressmen': 1}),
#              '致使': defaultdict(int, {'led': 1, 'so that': 1}),
#              '巴基斯坦': defaultdict(int,
#                          {'pakistan': 17,
#                           'india-pakistan': 1,
#                           'pakistani': 7,
#                           'pakistan-controlled': 1,
#                           'pakistanis': 1}),
#              '呈现': defaultdict(int, {'None': 2}),
#              '情势': defaultdict(int, {'tensions': 6, 'situation': 4}),
#              '接触': defaultdict(int, {'contacts': 1, 'meet': 1}),
#              '增加': defaultdict(int,
#                          {'increased': 5,
#                           'increase': 12,
#                           'step up': 1,
#                           'rose': 1,
#                           'rise': 2,
#                           'newly-created': 1,
#                           'created': 1,
#                           'added': 1,
#                           'growing': 1,
#                           'higher': 1,
#                           'None': 1,
#                           'grown': 1,
#                           'up': 5}),
#              '外交官': defaultdict(int, {'diplomat': 1}),
#              '国防': defaultdict(int, {'national defense': 1, 'defense': 1}),
#              '于': defaultdict(int,
#                          {'in': 12,
#                           'at': 3,
#                           'on': 16,
#                           'california-based': 1,
#                           'None': 4,
#                           'from': 3,
#                           'to': 3,
#                           'of': 1,
#                           'never went beyond': 1,
#                           'attribute': 1,
#                           'over': 1,
#                           'after': 1,
#                           'end up with': 1}),
#              '二月': defaultdict(int, {'february': 2}),
#              '敲定': defaultdict(int,
#                          {'decided': 1,
#                           'made a deal': 1,
#                           'finalized': 1,
#                           'finalize': 1}),
#              '部分': defaultdict(int,
# ...
#              '最新': defaultdict(int, {'most recent': 4, 'latest': 2}),
#              '提议': defaultdict(int,
#                          {'proposed': 3,
#                           'proposal': 2,
#                           'None': 1,
#                           'recommendation': 1}),
#              '人道': defaultdict(int, {'humanitarian': 2}),
#              '援助': defaultdict(int,
#                          {'assistance': 5,
#                           'aid': 2,
#                           'assisting': 1,
#                           'aids': 1,
#                           'None': 1}),
#              '经由': defaultdict(int, {'through': 1}),
#              '民间': defaultdict(int,
#                          {'non-governmental': 1, 'civic': 3, 'None': 1}),
#              '机构': defaultdict(int,
#                          {'agencies': 4,
#                           'institutions': 1,
#                           'subdivision': 1,
#                           'agency': 1,
#                           'authority': 6,
#                           'institution': 4,
#                           'institute': 1}),
#              '直接': defaultdict(int, {'directly': 2, 'direct': 2}),
#              '人民': defaultdict(int, {'people': 9, 'popular': 1}),
#              '达成': defaultdict(int,
#                          {'reach': 6, 'achieve': 1, 'None': 1, 'reached': 7}),
#              '恢复': defaultdict(int,
#                          {'resuming': 1,
#                           'resumed': 1,
#                           'resume': 5,
#                           'resumption': 2,
#                           'reopen': 1}),
#              '通邮': defaultdict(int, {'mail service': 1}),
#              '以往': defaultdict(int, {'so far': 1, 'None': 1}),
#              '予以': defaultdict(int, {'None': 1}),
#              '拒绝': defaultdict(int, {'rejected': 1, 'refused': 1}),
#              '彻夜': defaultdict(int,
#                          {'overnight': 1,
#                           'throughout the night': 1,
#                           'throughout night': 1}),
#              '炮击': defaultdict(int, {'shelling': 4, 'shelled': 1}),
#              '丧生': defaultdict(int,
#                          {'death': 3,
#                           'dead': 3,
#                           'died': 2,
#                           'loss lives': 1,
#                           'loss': 1,
#                           'killed': 2,
#                           'claimed lives': 1}),
#              '人数': defaultdict(int,
#                          {'toll': 7,
#                           'None': 2,
#                           'numbers': 1,
#                           'unemployment': 1,
#                           'number': 2}),
#              '查摩': defaultdict(int, {'jammu': 3}),
#              '警方': defaultdict(int, {'police': 9}),
#              '争议': defaultdict(int,
#                          {'disputed': 2,
#                           'controversies': 1,
#                           'controversy': 2}),
#              '克什米尔': defaultdict(int, {'kashmir': 7}),
#              '导致': defaultdict(int,
#                          {'left': 1,
#                           'caused': 1,
#                           'resulting in': 1,
#                           'None': 1,
#                           'led to': 1,
#                           'making': 1,
#                           'contributed to': 1,
#                           'causing': 1,
#                           'cause': 1}),
#              '士兵': defaultdict(int, {'soldier': 4, 'soldiers': 6}),
#              '三': defaultdict(int,
#                          {'three': 17,
#                           '3-day': 1,
#                           '3-1': 1,
#                           '6-3': 1,
#                           'iii': 1,
#                           'None': 4}),
#              '平民': defaultdict(int, {'civilians': 3}),
#              '儿童': defaultdict(int,
#                          {'children': 4, 'None': 1, 'a preschooler': 1}),
#              '距': defaultdict(int, {'None': 1}),
#              '南部': defaultdict(int, {'southern': 5, 'south': 1}),
#              '冬宫': defaultdict(int, {'winter capital': 1}),
#              '以西': defaultdict(int, {'west of': 1}),
#              '七十五': defaultdict(int, {'75': 1, '75-year-old': 1}),
#              '公里': defaultdict(int, {'km': 4, 'kilometer': 1}),
#              '帕朗瓦拉': defaultdict(int, {'baramulla': 1}),
#              '消息': defaultdict(int, {'sources': 4, 'news': 6, 'None': 1}),
#              '军队': defaultdict(int, {'military': 2, 'troops': 5}),
#              '发射': defaultdict(int, {'bombarded': 1, 'launched': 1}),
#              '重': defaultdict(int, {'heavy': 1}),
#              '迫击炮': defaultdict(int, {'mortar fire': 1, 'mortar': 1}),
#              '火箭': defaultdict(int, {'rocket-propelled': 1}),
#              '推进': defaultdict(int, {'rocket-propelled': 1, 'promote': 1}),
#              '手榴弹': defaultdict(int, {'grenades': 1}),
#              '枚': defaultdict(int, {'None': 7}),
#              '击中': defaultdict(int, {'hit': 1, 'shot': 2}),
#              '栋': defaultdict(int, {'None': 3}),
#              '民宅': defaultdict(int, {'residential structure': 1}),
#              '炸': defaultdict(int, {'killing': 1}),
#              '死': defaultdict(int,
#                          {'killing': 1,
#                           'deaths': 1,
#                           'locked': 1,
#                           'died': 1,
#                           'killed': 4,
#                           'assassinated': 1}),
#              '成人': defaultdict(int, {'adult': 1}),
#              '同一': defaultdict(int, {'same': 3}),
#              '越界': defaultdict(int, {'cross-border': 3, 'cross': 1}),
#              '军人': defaultdict(int, {'soldier': 1, 'soldiers': 1}),
#              '此外': defaultdict(int, {'in addition': 8}),
#              '报导': defaultdict(int,
#                          {'reported': 3, 'report': 2, 'reports': 2}),
#              '靠近': defaultdict(int, {'near': 1}),
#              '彭琪': defaultdict(int, {'poonch': 1}),
#              '一带': defaultdict(int, {'area': 1}),
#              '沿着': defaultdict(int, {'along': 1}),
#              '分隔': defaultdict(int, {'separating': 1}),
#              '辖区': defaultdict(int,
#                          {'territories': 1,
#                           'directly under the central government': 1}),
#              '控制': defaultdict(int,
#                          {'control': 1,
#                           'pakistan-controlled': 1,
#                           'india-controlled': 1}),
#              '分界线': defaultdict(int, {'demarcation': 1}),
#              '爆发': defaultdict(int,
#                          {'came': 1,
#                           'breaking out': 1,
#                           'broke out': 4,
#                           'rock': 1,
#                           'None': 1,
#                           'brought to light': 2}),
#              '重炮': defaultdict(int, {'heavy artillery': 1}),
#              '今早': defaultdict(int, {'this morning': 1}),
#              '炮轰': defaultdict(int, {'shelling': 2, 'bombarded': 1}),
#              '十二': defaultdict(int, {'12': 5}),
#              '爱尔兰': defaultdict(int, {'irish': 7, 'ireland': 3}),
#              '足球队': defaultdict(int, {'soccer team': 3}),
#              '队长': defaultdict(int, {'captain': 3}),
#              '基恩': defaultdict(int, {'keane': 3}),
#              '宣布': defaultdict(int,
#                          {'announces': 3,
#                           'announced': 14,
#                           'announcement': 4,
#                           'announce': 1}),
#              '世界杯': defaultdict(int, {'world cup': 21}),
#              '退休': defaultdict(int, {'retire': 2, 'retired': 1}),
#              '都柏林': defaultdict(int, {'dublin': 2}),
#              '灵魂': defaultdict(int, {'heart and soul': 1}),
#              '人物': defaultdict(int,
#                          {'None': 1, 'superheroes': 1, 'person': 1}),
#              '罗伊基恩': defaultdict(int, {'roy keane': 1}),
#              '昨天': defaultdict(int, {'yesterday': 4}),
#              '威胁': defaultdict(int,
#                          {'threatened': 2, 'threat': 4, 'threats': 2}),
#              '退出': defaultdict(int, {'quit': 3}),
#              '代表队': defaultdict(int, {'representative team': 3}),
#              '曼彻斯特': defaultdict(int, {'manchester': 1}),
#              '联队': defaultdict(int, {'united': 1}),
#              '中场': defaultdict(int, {'midfielder': 1}),
#              '大将': defaultdict(int, {'midfielder': 1}),
#              '电视台': defaultdict(int,
#                          {'tv station': 3, 'tv': 1, 'television': 1}),
#              '感性': defaultdict(int, {'emotional': 1}),
#              '上述': defaultdict(int,
#                          {'above': 7,
#                           'above-described': 1,
#                           'mentioned above': 1,
#                           'above-mentioned': 1}),
#              '严厉': defaultdict(int, {'lashed': 1, 'tough': 1}),
#              '比赛': defaultdict(int,
#                          {'None': 5,
#                           'games': 2,
#                           'game': 4,
#                           'tournament': 1,
#                           'match': 1,
#                           'competitions': 1,
#                           'overtime': 1}),
#              '准备': defaultdict(int,
#                          {'preparation': 3,
#                           'preparing': 2,
#                           'going to': 1,
#                           'None': 3,
#                           'getting ready': 1,
#                           'prepare': 2,
#                           'were about to': 1,
#                           'prepared': 2}),
#              '工作': defaultdict(int,
#                          {'None': 5,
#                           'working': 2,
#                           'job': 6,
#                           'staff': 2,
#                           'employee': 3,
#                           'employees': 1,
#                           'stall': 1,
#                           'work': 1,
#                           'something': 1,
#                           'welfare': 1,
#                           'crew': 1}),
#              '不当': defaultdict(int,
#                          {'not making adequate': 1,
#                           'failing to make appropriate': 1,
#                           'inappropriate': 1}),
#              '塞班岛': defaultdict(int, {'saipan': 1}),
#              '集训': defaultdict(int, {'training': 2}),
#              '本周': defaultdict(int, {'this week': 4}),
#              '扬言': defaultdict(int,
#                          {'threatened': 2, 'pledges': 1, 'pledged': 1}),
#              '留下来': defaultdict(int, {'stay': 2}),
#              '队': defaultdict(int, {'team': 11, 'None': 3}),
#              '陷入': defaultdict(int, {'into': 1, 'throwing into': 1}),
#              '紊乱': defaultdict(int, {'confusion': 2}),
#              '背后': defaultdict(int, {'None': 1}),
#              '真正': defaultdict(int, {'real': 6, 'truly': 1, 'really': 1}),
#              '原因': defaultdict(int,
#                          {'reason': 2,
#                           'None': 1,
#                           'ground': 1,
#                           'caused': 1,
#                           'reasons': 1}),
#              '仍': defaultdict(int,
#                          {'remains': 1, 'still': 7, 'None': 2, 'remain': 1}),
#              '应该': defaultdict(int,
#                          {'deserves': 1,
#                           'should': 5,
#                           'would': 2,
#                           'will': 1,
#                           "shouldn't": 1,
#                           'for': 1}),
#              '指责': defaultdict(int, {'blame': 1, 'accused': 1}),
#              '这里': defaultdict(int, {'here': 2, 'this place': 1, 'None': 2}),
#              '想': defaultdict(int,
#                          {'None': 1,
#                           'want': 5,
#                           "'d like": 1,
#                           'think': 1,
#                           'To': 1}),
#              '踢': defaultdict(int, {'play': 2, 'struck': 2}),
#              '球': defaultdict(int, {'soccer': 2, 'goals': 1, 'basket': 1}),
#              '周围': defaultdict(int, {'around': 1}),
#              '假如': defaultdict(int, {'if': 4}),
#              '相同': defaultdict(int, {'common': 1, 'different': 1, 'same': 1}),
#              '那': defaultdict(int, {'there': 1, 'None': 3}),
#              '毫无': defaultdict(int, {'no': 1}),
#              '情形': defaultdict(int, {'None': 1, 'scenario': 1}),
#              '存在': defaultdict(int, {'going on': 1, 'exist': 2, 'None': 2}),
#              '段': defaultdict(int, {'None': 4}),
#              '一些': defaultdict(int, {'some': 4, 'None': 2, 'a handful of': 1}),
#              '问题': defaultdict(int,
#                          {'issues': 1,
#                           'problems': 7,
#                           'issue': 7,
#                           'None': 4,
#                           'problem': 2,
#                           'faulty': 3,
#                           'The problem': 1}),
#              '头': defaultdict(int, {'head': 1, 'first': 2, 'None': 2}),
#              '撞': defaultdict(int, {'bang': 1}),
#              '墙': defaultdict(int, {'wall': 1, 'shield': 1}),
#              '训练': defaultdict(int, {'training': 5}),
#              '各种': defaultdict(int, {'all kinds of': 1, 'various kinds': 3}),
#              '冰山': defaultdict(int, {'iceberg': 1}),
#              '一角': defaultdict(int, {'a tip': 1}),
#              '而已': defaultdict(int, {'None': 1}),
#              '你们': defaultdict(int, {'you': 1}),
#              '看见': defaultdict(int, {'seen': 1}),
#              '场地': defaultdict(int, {'pitch': 2}),
#              '自命不凡': defaultdict(int, {'self-conceited': 1}),
#              '安排': defaultdict(int,
#                          {'arrangements': 2, 'None': 1, 'arrange': 1}),
#              '离开': defaultdict(int, {'leaving': 1, 'left': 1}),
#              '机场': defaultdict(int, {'airport': 7, 'airports': 5}),
#              '通关': defaultdict(int, {'getting through the customs': 1}),
#              '堆': defaultdict(int, {'tons': 1}),
#              '抵达': defaultdict(int,
#                          {'arrives': 1,
#                           'arrived': 7,
#                           'arrive': 2,
#                           'arriving': 2}),
#              '历史性': defaultdict(int, {'historic': 3}),
#              '高峰': defaultdict(int, {'summit': 3, 'record': 1}),
#              '裁减': defaultdict(int, {'reduction': 3}),
#              '武器': defaultdict(int, {'arms': 4, 'weapons': 6}),
#              '新': defaultdict(int,
#                          {'new': 25,
#                           'newly-created': 1,
#                           'newly': 1,
#                           'newly-erected': 1,
#                           'None': 1}),
#              '宿敌': defaultdict(int, {'bitter foes': 1}),
#              '建立': defaultdict(int,
#                          {'shaping': 1,
#                           'establish': 3,
#                           'develop': 1,
#                           'established': 1,
#                           'create': 1}),
#              '二十一': defaultdict(int,
#                          {'21st-century': 1, '21-month-long': 1, '21': 2}),
#              '世纪': defaultdict(int,
#                          {'21st-century': 1, 'century': 2, '1930s': 1}),
#              '伙伴': defaultdict(int, {'partnership': 3}),
#              '隆重': defaultdict(int, {'grand': 1}),
#              '到访': defaultdict(int, {'visit': 1, 'visiting': 1}),
#              '整个': defaultdict(int, {'entire': 3, 'None': 1}),
#              '增强': defaultdict(int,
#                          {'stepped up': 1, 'enhance': 2, 'increased': 1}),
#              '家': defaultdict(int, {'None': 20}),
#              '报纸': defaultdict(int, {'newspaper': 1}),
#              '注意': defaultdict(int,
#                          {'watch': 2,
#                           'attention': 1,
#                           'None': 1,
#                           'watch out': 1,
#                           'monitor': 1,
#                           'be reminded that': 1}),
#              '单位': defaultdict(int, {'service': 1}),
#              '狙击手': defaultdict(int, {'snipers': 1}),
#              '自由派': defaultdict(int, {'liberal': 1}),
#              '议员': defaultdict(int,
#                          {'member': 2, 'members': 2, 'congressmen': 1}),
#              '哈卡马达': defaultdict(int, {'khakamada': 1}),
#              ...})

# %%
# now we pick up most most frequent english words for each chinese word
mfc_table = dict((ch_word, max(en_word.keys(), key=lambda key: en_word[key])) for ch_word, en_word in word_counts.items())
print(type(mfc_table))
mfc_table
# Out:
# <class 'dict'>
# {'教区': 'archdiocese',
#  '财务': 'finance',
#  '委员会': 'commission',
#  '认为': 'think',
#  ',': 'None',
#  '这项': 'the',
#  '协议': 'agreement',
#  '可能': 'may',
#  '使得': 'None',
#  '波士顿': 'boston',
#  '天主教会': 'catholic archdiocese',
#  '破产': 'bankruptcy',
#  '因为': 'because',
#  '声称': 'alleged',
#  '受到': 'None',
#  '性': 'sexual',
#  '侵害': 'abuse',
#  '的': 'None',
#  '案子': 'cases',
#  '越来越': 'keep surfacing',
#  '多': 'over',
#  '而且': 'and',
#  '「': '"',
#  '在': 'in',
#  '促成': 'leading',
#  '程序': 'process',
#  '开始': 'started',
#  '后': 'after',
#  '情况': 'situation',
#  '已经': 'has',
#  '有': 'None',
#  '很': 'None',
#  '大': 'None',
#  '变化': 'changes',
#  '」': '"',
#  '。': '.',
#  '六十六': '66-year-old',
#  '岁': 'None',
#  '吉欧根': 'geoghan',
#  '一九九一年': '1991',
#  '一': 'a',
#  '名': 'None',
#  '十': '10',
#  '男童': 'boy',
#  '最近': 'recently',
#  '被': 'None',
#  '判处': 'sentenced',
#  '年': 'years',
#  '徒刑': 'imprisonment',
#  '已': 'has',
#  '削去': 'defrocked',
#  '教士': 'priest',
#  '职务': 'None',
#  '他': 'he',
#  '还': 'also',
#  '面临': 'faces',
#  '其他': 'other',
#  '刑事': 'criminal',
#  '审判': 'trials',
#  '和': 'and',
#  '数十': 'scores',
#  '件': 'None',
#  '民事': 'civil',
#  '官司': 'lawsuits',
#  '美': 'us',
#  '印': 'india',
#  '五月': 'may',
#  '中': 'in',
#  '将': 'will',
#  '举行': 'held',
#  '四十': '4 decades',
#  '来': 'None',
#  '首次': 'first',
#  '联合': 'joint',
#  '军事': 'military',
#  '演习': 'exercise',
#  '(': '(',
#  '法新社': 'afp',
#  '新德里': 'new delhi',
#  '电': 'None',
#  ')': ')',
#  '印度': 'india',
#  '美国': 'us',
#  '三十九': '39',
#  '为': 'None',
#  '世界': 'world',
#  '上': 'at',
#  '两': 'two',
#  '个': 'None',
#  '最': 'most',
#  '民主': 'democracies',
#  '国家': 'nations',
#  '间': 'between',
#  '合作': 'cooperation',
#  '关系': 'None',
#  '缔造': 'mark',
#  '里程碑': 'milestone',
#  '国防部': 'ministry of national defense',
#  '说': 'said',
#  '支': 'None',
#  '精锐': 'elite',
#  '伞兵': 'paratroopers',
#  '旅': 'travel',
#  '中旬': 'mid-may',
#  '与': 'and',
#  '太平洋': 'pacific',
#  '美军': 'us',
#  '司令部': 'command',
#  '特种部队': 'special force unit',
#  '闻名遐迩': 'renowned',
#  '泰姬': 'taj',
#  '马哈陵': 'mahal',
#  '附近': 'near',
#  '国': 'None',
#  '空军': 'air forces',
#  '给以': 'provide',
#  '支援': 'support',
#  '这': 'the',
#  '是': 'is',
#  '多次': 'many',
#  '第一': 'first',
#  '次': 'None',
#  '冷战': 'cold war',
#  '时期': 'period',
#  '紧张': 'tensions',
#  '但': 'but',
#  '自': 'since',
#  '九一一': 'sept. 11',
#  '纽约': 'new york',
#  '华盛顿': 'washington',
#  '遭': 'None',
#  '恐怖分子': 'terrorists',
#  '攻击': 'attacks',
#  '事件': 'None',
#  '以来': 'since',
#  '见': 'been',
#  '大幅': 'dramatically',
#  '改善': 'improve',
#  '除': 'apart from',
#  '海军': 'navy',
#  '印尼': 'indonesia',
#  '马来西亚': 'malaysia',
#  '之间': 'between',
#  '麻六甲': 'malacca',
#  '海峡': 'strait',
#  '外海': 'None',
#  '进行': 'None',
#  '海上': 'sea',
#  '巡逻': 'patrolling',
#  '以防': 'so as to prevent',
#  '发生': 'None',
#  '海盗': 'piracy',
#  '行为': 'None',
#  '之外': 'apart from',
#  '近年': 'recent years',
#  '曾': 'None',
#  '英国': 'british',
#  '、': ',',
#  '法国': 'french',
#  '日本': 'japan',
#  '发言人': 'spokesman',
#  ':': ':',
#  '即将': 'upcoming',
#  '旨在': 'aims at',
#  '进一步': 'further',
#  '提升': 'enhancing',
#  '上次': 'last time',
#  '一九六二年': '1962',
#  '中国': 'china',
#  '短暂': 'brief',
#  '边界': 'border',
#  '战争': 'war',
#  '之后': 'after',
#  '去年': 'last year',
#  '七月': 'july',
#  '大约': 'about',
#  '五十': '50',
#  '位': 'None',
#  '决策': 'policy makers',
#  '人员': 'palestinians',
#  '访问': 'visit',
#  '过': 'None',
#  '同时': 'at the same time',
#  '方面': 'None',
#  '也': 'also',
#  '这么': 'equal number',
#  '人': 'None',
#  '包括': 'including',
#  '瓦巴依': 'vajpayee',
#  '总理': 'prime minister',
#  '安全': 'security',
#  '团队': 'team',
#  '成员': 'None',
#  '前往': 'paid to',
#  '继': 'after',
#  '恐怖': 'terrorist',
#  '以及': 'and',
#  '十二月': 'december',
#  '国会': 'congress',
#  '致使': 'led',
#  '巴基斯坦': 'pakistan',
#  '呈现': 'None',
#  '情势': 'tensions',
#  '接触': 'contacts',
#  '增加': 'increase',
#  '外交官': 'diplomat',
#  '国防': 'national defense',
#  '于': 'on',
#  '二月': 'february',
#  '敲定': 'decided',
#  '部分': 'some',
#  '为了': 'to',
#  '缓和': 'easing',
#  '因': 'None',
#  '强化': 'strengthening',
#  '所': 'None',
#  '引起': 'None',
#  '不安': 'discomfort',
#  '情绪': 'discomfort',
#  '南非': 'south african',
#  '太空': 'space',
#  '观光客': 'tourist',
#  '结束': 'over',
#  '之': 'None',
#  '返抵': 'back to',
#  '地球': 'earth',
#  '莫斯科': 'moscow',
#  '夏特沃斯': 'shuttleworth',
#  '五日': '5',
#  '搭乘': 'boarded',
#  '俄罗斯': 'russia',
#  '太空船': 'spacecraft',
#  '台北': 'taipei',
#  '时间': 'time',
#  '上午': 'morning',
#  '七时': '7:31',
#  '三十一分': '7:31',
#  '顺利': 'smooth',
#  '脱离': 'undocked',
#  '国际': 'international',
#  '太空站': 'space station',
#  '并': 'and',
#  '十一时': '11:51',
#  '五十一分': '11:51',
#  '降落': 'landed',
#  '中亚': 'central asia',
#  '哈萨克': 'kazakhstan',
#  '西北部': 'northwestern',
#  '草原': 'steppe',
#  '籍': 'None',
#  '狄托': 'tito',
#  '有史以来': 'in history',
#  '第二': 'second',
#  '付费': 'paying',
#  '都': 'None',
#  '支付': 'pay',
#  '两千万': '20 million',
#  '美元': 'us dollars',
#  '才': 'None',
#  '得以': 'chance',
#  '趟': 'None',
#  '四月': 'april',
#  '二十五日': '25',
#  '进入': 'entered',
#  '停留': 'stayed',
#  '天': 'days',
#  '期间': 'during',
#  '一连串': 'a series of',
#  '医学': 'medical',
#  '及': 'and',
#  '生物': 'biological',
#  '科技': 'tech',
#  '实验': 'experiments',
#  '一同': 'together',
#  '返回': 'returned',
#  '这次': 'this',
#  '一起': 'together',
#  '指挥官': 'commander',
#  '吉曾柯': 'gidzenko',
#  '义大利': 'italian',
#  '工程师': 'engineer',
#  '维托利': 'vittori',
#  '地面': 'terra firma',
#  '同伴': 'partners',
#  '先': 'None',
#  '接受': 'None',
#  '身体': 'physical',
#  '检查': 'exam',
#  '然后': 'before',
#  '直升机': 'helicopter',
#  '阿斯塔纳': 'astana',
#  '同一天': 'same day',
#  '转': 'transferred',
#  '往': 'to',
#  '首都': 'capital',
#  '今年': 'this year',
#  '二十八': '28',
#  '十分': 'very',
#  '富有': 'rich',
#  '电脑': 'tablet',
#  '资讯': 'information',
#  '商': 'businessman',
#  '付出': 'paid',
#  '旅行': 'travel',
#  '梦': 'dream',
#  '实现': 'fulfilling',
#  '人类': 'human history',
#  '首位': 'first',
#  '六十': '60',
#  '商人': 'businessman',
#  '专家': 'experts',
#  '稍早': 'earlier',
#  '指出': 'pointed out',
#  '较': 'over',
#  '更': 'more',
#  '能够': 'None',
#  '适应': 'suitable',
#  '当中': 'during',
#  '若干': 'a number of',
#  '科学': 'scientific',
#  '其中': 'None',
#  '爱滋': 'aids',
#  '病原': 'pathogens',
#  '研究': 'study',
#  '极大': 'great',
#  '关注': 'publicity',
#  '誉为': 'won the honor',
#  '曼德拉': 'mandela',
#  '从': 'from',
#  '监狱': 'prison',
#  '获释': 'release',
#  '重大': 'mass',
#  '新闻': 'news',
#  '政府': 'government',
#  '冷淡': 'not impressed',
#  '对待': 'None',
#  '卡斯楚': 'castro',
#  '向': 'None',
#  '卡特': 'carter',
#  '释出': 'None',
#  '善意': 'goodwill',
#  '姿态': 'stance',
#  '总统': 'president',
#  '布希': 'bush',
#  '对于': 'None',
#  '古巴': 'cuba',
#  '前': 'former',
#  '表达': 'extended',
#  '反应': 'response',
#  '正': 'is',
#  '共产': 'communist',
#  '岛国': 'island nation',
#  '展开': 'None',
#  '项': 'None',
#  '创下': 'making',
#  '表示': 'said',
#  '愿意': 'are willing to',
#  '让': 'None',
#  '随意': 'freely',
#  '会见': 'met',
#  '异议': 'dissidents',
#  '人士': 'official',
#  '所有': 'all',
#  '地区': 'region',
#  '指称': 'alleged',
#  '正在': 'is',
#  '制造': 'manufacturing',
#  '生物武器': 'biological weapons',
#  '要件': 'key components',
#  '实验室': 'labs',
#  '白宫': 'white house',
#  '国务院': 'state department',
#  '这些': 'these',
#  '建议': 'proposal',
#  '没有': 'not',
#  '意义': 'meaningless',
#  '凯塞尔': 'cassel',
#  '女士': 'ms.',
#  '私人': 'private',
#  '派去': 'sent',
#  '化学': 'chemical',
#  '或': 'or',
#  '设施': 'facilities',
#  '她': 'she',
#  '简短': 'brief',
#  '评论': 'remark',
#  '似乎': 'seem',
#  '呼应': 'echo',
#  '了': 'None',
#  '评论家': 'commentators',
#  '或是': 'neither nor',
#  '代表团': 'delegation',
#  '正确': 'proper',
#  '需': 'necessary',
#  '背景': 'background',
#  '坚称': 'insisted',
#  '官员': 'officials',
#  '作': 'made',
#  '简报': 'briefed',
#  '时': 'None',
#  '提到': 'mention',
#  '美方': 'united states',
#  '担心': 'concerned',
#  '计划': 'program',
#  '国务卿': 'secretary of state',
#  '鲍尔': 'powell',
#  '不': 'not',
#  '相信': 'believe',
#  '这个': 'this',
#  '说法': 'None',
#  '告诉': 'told',
#  '广播': 'abc',
#  '公司': 'None',
#  '电视网': 'network',
#  '我': 'i',
#  '知道': 'know',
#  '听取': 'was given',
#  '什么': 'what',
#  '确定': 'certain',
#  '我们': 'we',
#  '保留': 'reservation',
#  '拥有': 'None',
#  '生物战': 'biological warfare',
#  '能力': 'capability',
#  'napster': 'napster',
#  '执行长': 'ceo',
#  '希尔柏斯': 'hilbers',
#  '辞职': 'resign',
#  '旧金山': 'san francisco',
#  '一度': 'once',
#  '风靡': 'all-popular',
#  '网路': 'None',
#  '免费': 'free',
#  '下载/a': 'downloading',
#  '音乐/a': 'music',
#  '业者': 'company',
#  '该': 'the',
#  '立即': 'immediately',
#  '生效': 'effective',
#  '遗缺': 'None',
#  '由': 'None',
#  '何人': 'who',
#  '接替': 'replacement',
#  '目前': 'at present',
#  '不得而知': 'unknown',
#  '音乐': 'music',
#  '网站': 'website',
#  '法院': 'court',
#  '裁定': 'ruled',
#  '它': 'it',
#  '服务': 'service',
#  '造成': 'None',
#  '普遍': 'general',
#  '仿冒': 'copying',
#  '情事': 'copying',
#  '一直': 'None',
#  '关闭': 'closed',
#  '到': 'to',
#  '现在': 'now',
#  '许多': 'many',
#  '取而代之': 'taken its place',
#  '设': 'california-based',
#  '加州': 'california',
#  '红木': 'redwood',
#  '城': 'city',
#  '遗憾': 'regret',
#  '解决': 'solve',
#  '资金': 'funding',
#  '办法': 'solution',
#  '好': 'good',
#  '裨益': 'benefit',
#  '艺术界': 'artists',
#  '使用者': 'users',
#  '作业': 'service',
#  '又': 'again',
#  '未来': 'next',
#  '周': 'week',
#  '采取': 'take',
#  '措施': 'measures',
#  '撙节': 'cut',
#  '支出': 'spending',
#  '以前': 'once',
#  '德国': 'germany',
#  '媒体': 'media',
#  '巨擘': 'giant',
#  'bertelsmann': 'bertelsmann',
#  '执行人': 'executive officer',
#  '着手': 'started',
#  '帮助': 'help',
#  '经营': 'operation',
#  '困难': 'difficulties',
#  '裁决': 'ruling',
#  '架': 'None',
#  '权': 'framework',
#  '内': 'in',
#  '继续': 'continue',
#  '营运': 'operation',
#  '接': 'took',
#  '下': 'None',
#  '经合': 'oecd',
#  '组织部长': 'ministers examine',
#  '巴黎': 'paris',
#  '展望': 'outlook',
#  '经济': 'economic',
#  '主要': 'main',
#  '工业国': 'industrial nations',
#  '高级': 'senior',
#  '部长': 'minister',
#  '们': 'None',
#  '十五日': '15th',
#  '会议': 'meeting',
#  '他们': 'they',
#  '充满': 'Imaginative',
#  '希望': 'hope',
#  '远景': 'future',
#  '欧': 'eu-us',
#  '贸易': 'trade',
#  '争端': 'dispute',
#  '而': 'None',
#  '产生': 'caused',
#  '分裂': 'division',
#  '阴影': 'looming',
#  '发展': 'development',
#  '组织': 'wto',
#  '三十': '30',
#  '成员国': 'member nations',
#  '代表': 'representatives',
#  '关心': 'concern',
#  '贫穷': 'poor',
#  '缩短': 'abridge',
#  '差距': 'gap',
#  '冲突': 'conflict',
#  '但是': 'however',
#  '宏观': 'macroeconomics',
#  '讨论': 'discuss',
#  '欧盟': 'eu',
#  '摩擦': 'friction',
#  '升高': 'escalating',
#  '相形见绌': 'eclipsed',
#  '欧洲': 'europe',
#  '领袖': 'leaders',
#  '对': 'None',
#  '十三日': '13th',
#  '签署': 'signed',
#  '法案': 'bill',
#  '至': 'to',
#  '表': 'expressed',
#  '愤怒': 'indignation',
#  '法': 'None',
#  '允许': 'allow',
#  '农民': 'farmers',
#  '百分之七十': '70%',
#  '补助': 'subsidies',
#  '违背': 'violates',
#  '十一月': 'november',
#  '卡达': 'qatar',
#  '杜哈': 'doha',
#  '部长级': 'ministerial',
#  '就': 'None',
#  '终止': 'terminating',
#  '农业': 'farm',
#  '出口': 'export',
#  '承诺': 'pledge',
#  '比利时': 'belgian',
#  '维霍夫斯达': 'verhofstadt',
#  '开幕': 'opening ceremony',
#  '论坛': 'forum',
#  '高谈阔论': 'talk with eloquence',
#  '市场': 'market',
#  '自由化': 'liberalization',
#  '加以': 'None',
#  '贯彻': 'implement',
#  '虚伪': 'hypocritical',
#  '作法': 'None',
#  '期中': 'mid-term',
#  '选举': 'election',
#  '使': 'None',
#  '推动': 'promote',
#  '自由': 'free',
#  '步伐': 'efforts',
#  '趋': 'slow down',
#  '缓': 'slow down',
#  '经济学家': 'economists',
#  '分析师': 'analysts',
#  '讨好': 'woo',
#  '各': 'all',
#  '选区': 'constituencies',
#  '选民': 'voters',
#  '增设': 'additional imposed',
#  '障碍': 'barriers',
#  '长久': 'ever',
#  '促进': 'promotion',
#  '全球': 'global',
#  '华府': 'washington',
#  '智库': 'think tank',
#  '研究所': 'institute',
#  '萧特': 'schott',
#  '决意': 'determined',
#  '把': 'put',
#  '政治': 'political',
#  '目标': 'goal',
#  '放在': 'put',
#  '健全': 'sound',
#  '之上': 'above',
#  '屈服': 'succumbing',
#  '钢铁': 'steel',
#  '业': 'industry',
#  '工会': 'labor union',
#  '压力': 'pressures',
#  '针对': 'on',
#  '几': 'a few',
#  '供应': 'suppliers',
#  '来源': 'suppliers',
#  '--': 'None',
#  '联盟': 'coalition',
#  '巴西': 'brazil',
#  '某些': 'certain',
#  '产品': 'products',
#  '课征': 'levies',
#  '高': 'high',
#  '达': 'as as',
#  '百分之三十': '30%',
#  '关税': 'tariffs',
#  '接着': 'in addition',
#  '供': 'used',
#  '建材': 'building material',
#  '加拿大': 'canada',
#  '某种': 'certain kind',
#  '木材': 'lumber',
#  '百分之二十七': '27%',
#  '反倾销': 'anti-dumping',
#  '进口税': 'tariff',
#  '理由': 'ground',
#  '补贴': 'subsidies',
#  '这种': 'this',
#  '构成': 'constituted',
#  '倾销': 'dumping',
#  '尤': 'more',
#  '甚者': 'what aggravating',
#  '联邦': 'federal',
#  '颁布': 'promulgated',
#  '农产品': 'farm products',
#  '将近': 'nearly',
#  '百分之八十': '80%',
#  '根本': 'grossly',
#  '符合': 'violating',
#  '谈判': 'negotiations',
#  '坚持': 'insisted on',
#  '务必': 'None',
#  '以': 'israeli',
#  '易于': 'facilitate',
#  '打入': 'access into',
#  '相对': 'correspondingly',
#  '先进': 'developed',
#  '容易': 'easier',
#  '其': 'None',
#  '提供': 'provide',
#  '给': 'None',
#  '此': 'this',
#  '伤害': 'damage',
#  '远': 'far',
#  '超过': 'exceeded',
#  '接获': 'handling',
#  '预警': 'warnings',
#  '辩护': 'defend',
#  '急忙': 'scrambled',
#  '警告': 'warned',
#  '处理': 'process',
#  '方式': 'None',
#  '报告': 'report',
#  '欧萨玛.宾拉登': 'osama bin laden',
#  '指使': 'under',
#  '会': 'will',
#  '劫持': 'hijack',
#  '民航机': 'commercial airlines',
#  '国防部长': 'secretary of defense',
#  '伦斯斐': 'rumsfeld',
#  '今天': 'today',
#  '节目': 'show',
#  '应': 'should',
#  '就是': 'namely',
#  '全力': 'go all out',
#  '追击': 'pursue',
#  '对付': 'deal',
#  '包庇': 'harbor',
#  '随时随地': 'at any time',
#  '使用': 'None',
#  '任何': 'any',
#  '可行': 'available',
#  '手段': 'means',
#  '出击': 'attack',
#  '想要': 'None',
#  '日夜': 'at all times',
#  '全天候': 'at all times',
#  '保护': 'protection',
#  '地点': 'locations',
#  '实际上': 'practically',
#  '事': 'None',
#  '副': 'vice',
#  '钱尼': 'cheney',
#  '昨晚': 'last night',
#  '则': 'None',
#  '民主党': 'mdp',
#  '特别': 'especially',
#  '要': 'None',
#  '谨言慎行': 'cautious',
#  '不要': 'not',
#  '煽动': 'incendiary',
#  '词': 'remarks',
#  '寻求': 'seek',
#  '利益': 'interests',
#  '例如': 'such as',
#  '事先': 'advance',
#  '获得': 'None',
#  '情报': 'information',
#  '本': 'None',
#  '可以': 'can',
#  '阻止': 'prevented',
#  '血腥': 'bloody',
#  '之类': 'None',
#  '谈话': 'interview',
#  '晚间': 'night',
#  '承认': 'admitted',
#  '之前': 'prior to',
#  '曾经': 'had',
#  '指': 'None',
#  '遭到': 'was',
#  '抨击': 'fire',
#  '英航': 'british airways',
#  '出现': 'None',
#  '十五': '15',
#  '年度': 'annual',
#  '亏损': 'loss',
#  '伦敦': 'london',
#  '据': 'according to',
#  '航空': 'None',
#  '虽然': 'although',
#  '金额': 'amount',
#  '预期': 'expected',
#  '小': 'small',
#  '却': 'None',
#  '民营化': 'privatization',
#  '三月': 'march',
#  '底': 'end',
#  '为止': 'until',
#  '税前': 'pre-tax',
#  '二亿': '200',
#  '英镑': 'None',
#  '三亿二千万': '320 million',
#  '欧元': 'euros',
#  '二亿九千万': '290 million',
#  '重新': 'restated',
#  '修正': 'restated',
#  '利润': 'profit',
#  '一亿五千万': '150 million',
#  '仅': 'alone',
#  '第四': 'fourth',
#  '季': 'quarter',
#  '即': 'None',
#  '八千五百万': '85 million',
#  '六千五百万': '65 million',
#  '国营': 'state-owned',
#  '成绩': 'performance',
#  '佳': 'poor',
#  '归咎': 'blamed',
#  '不景气': 'slowdown',
#  '外国': 'foreign',
#  '裹足不前': 'kept away from',
#  '口蹄疫': 'foot-and-mouth disease',
#  '红利': 'dividend',
#  '因此': 'None',
#  '抵销': 'scrapped',
#  '总裁': 'governor',
#  '艾丁顿': 'eddington',
#  '仍然': 'still',
#  '疲弱': 'weak',
#  '快速': 'quick',
#  '果决': 'decisive',
#  '行动': 'actions',
#  '显示': 'shows',
#  '决心': 'determined',
#  '回复': 'return',
#  '可': 'can',
#  '获利': 'profitability',
#  '水准': 'levels',
#  '不过': 'however',
#  '结果': 'result',
#  '出乎': 'None',
#  '预料': 'expected',
#  '原来': 'None',
#  '股市': 'stock exchange',
#  '早盘': 'early trading session',
#  '股价': 'shares',
#  '上涨': 'rose',
#  '百分之二点六': '2.6%',
#  '达到': 'None',
#  '二四一点七五': '241.75',
#  '便士': 'pence',
#  '价位': 'price',
#  '前不久': 'shortly before',
#  '低': 'lower',
#  '百分之八': '8%',
#  '一九九七年': '1997',
#  '最高点': 'highest',
#  '七百六十': '760',
#  '几乎': 'almost',
#  '跌': 'down',
#  '解除': 'lift',
#  '禁运': 'embargo',
#  '如果': 'if',
#  '证明': 'proved',
#  '公正': 'fair',
#  '制度': 'system',
#  '改革': 'reform',
#  '唯有': 'None',
#  '长': 'None',
#  '四十一': '41-year-old',
#  '发表': 'None',
#  '演说': 'speech',
#  '称': 'said',
#  '只有': 'only',
#  '那个': 'then',
#  '时候': 'then',
#  '努力': 'efforts',
#  '禁令': 'embargo',
#  '只': 'only',
#  '帮': 'help',
#  '忙': 'help',
#  '吉米.卡特': 'jimmy carter',
#  '美洲': 'americas',
#  '唯一': 'only',
#  '共产主义': 'communist',
#  '呼吁': 'called for',
#  '当': 'when',
#  '四十八': '48',
#  '小时': 'hours',
#  '有关': 'relevant',
#  '最新': 'most recent',
#  '提议': 'proposed',
#  '人道': 'humanitarian',
#  '援助': 'assistance',
#  '经由': 'through',
#  '民间': 'civic',
#  '机构': 'authority',
#  '直接': 'directly',
#  '人民': 'people',
#  '达成': 'reached',
#  '恢复': 'resume',
#  '通邮': 'mail service',
#  '以往': 'so far',
#  '予以': 'None',
#  '拒绝': 'rejected',
#  '彻夜': 'overnight',
#  '炮击': 'shelling',
#  '丧生': 'death',
#  '人数': 'toll',
#  '查摩': 'jammu',
#  '警方': 'police',
#  '争议': 'disputed',
#  '克什米尔': 'kashmir',
#  '导致': 'left',
#  '士兵': 'soldiers',
#  '三': 'three',
#  '平民': 'civilians',
#  '儿童': 'children',
#  '距': 'None',
#  '南部': 'southern',
#  '冬宫': 'winter capital',
#  '以西': 'west of',
#  '七十五': '75',
#  '公里': 'km',
#  '帕朗瓦拉': 'baramulla',
#  '消息': 'news',
#  '军队': 'troops',
#  '发射': 'bombarded',
#  '重': 'heavy',
#  '迫击炮': 'mortar fire',
#  '火箭': 'rocket-propelled',
#  '推进': 'rocket-propelled',
#  '手榴弹': 'grenades',
#  '枚': 'None',
#  '击中': 'shot',
#  '栋': 'None',
#  '民宅': 'residential structure',
#  '炸': 'killing',
#  '死': 'killed',
#  '成人': 'adult',
#  '同一': 'same',
#  '越界': 'cross-border',
#  '军人': 'soldier',
#  '此外': 'in addition',
#  '报导': 'reported',
#  '靠近': 'near',
#  '彭琪': 'poonch',
#  '一带': 'area',
#  '沿着': 'along',
#  '分隔': 'separating',
#  '辖区': 'territories',
#  '控制': 'control',
#  '分界线': 'demarcation',
#  '爆发': 'broke out',
#  '重炮': 'heavy artillery',
#  '今早': 'this morning',
#  '炮轰': 'shelling',
#  '十二': '12',
#  '爱尔兰': 'irish',
#  '足球队': 'soccer team',
#  '队长': 'captain',
#  '基恩': 'keane',
#  '宣布': 'announced',
#  '世界杯': 'world cup',
#  '退休': 'retire',
#  '都柏林': 'dublin',
#  '灵魂': 'heart and soul',
#  '人物': 'None',
#  '罗伊基恩': 'roy keane',
#  '昨天': 'yesterday',
#  '威胁': 'threat',
#  '退出': 'quit',
#  '代表队': 'representative team',
#  '曼彻斯特': 'manchester',
#  '联队': 'united',
#  '中场': 'midfielder',
#  '大将': 'midfielder',
#  '电视台': 'tv station',
#  '感性': 'emotional',
#  '上述': 'above',
#  '严厉': 'lashed',
#  '比赛': 'None',
#  '准备': 'preparation',
#  '工作': 'job',
#  '不当': 'not making adequate',
#  '塞班岛': 'saipan',
#  '集训': 'training',
#  '本周': 'this week',
#  '扬言': 'threatened',
#  '留下来': 'stay',
#  '队': 'team',
#  '陷入': 'into',
#  '紊乱': 'confusion',
#  '背后': 'None',
#  '真正': 'real',
#  '原因': 'reason',
#  '仍': 'still',
#  '应该': 'should',
#  '指责': 'blame',
#  '这里': 'here',
#  '想': 'want',
#  '踢': 'play',
#  '球': 'soccer',
#  '周围': 'around',
#  '假如': 'if',
#  '相同': 'common',
#  '那': 'None',
#  '毫无': 'no',
#  '情形': 'None',
#  '存在': 'exist',
#  '段': 'None',
#  '一些': 'some',
#  '问题': 'problems',
#  '头': 'first',
#  '撞': 'bang',
#  '墙': 'wall',
#  '训练': 'training',
#  '各种': 'various kinds',
#  '冰山': 'iceberg',
#  '一角': 'a tip',
#  '而已': 'None',
#  '你们': 'you',
#  '看见': 'seen',
#  '场地': 'pitch',
#  '自命不凡': 'self-conceited',
#  '安排': 'arrangements',
#  '离开': 'leaving',
#  '机场': 'airport',
#  '通关': 'getting through the customs',
#  '堆': 'tons',
#  '抵达': 'arrived',
#  '历史性': 'historic',
#  '高峰': 'summit',
#  '裁减': 'reduction',
#  '武器': 'weapons',
#  '新': 'new',
#  '宿敌': 'bitter foes',
#  '建立': 'establish',
#  '二十一': '21',
#  '世纪': 'century',
#  '伙伴': 'partnership',
#  '隆重': 'grand',
#  '到访': 'visit',
#  '整个': 'entire',
#  '增强': 'enhance',
#  '家': 'None',
#  '报纸': 'newspaper',
#  '注意': 'watch',
#  '单位': 'service',
#  '狙击手': 'snipers',
#  '自由派': 'liberal',
#  '议员': 'member',
#  '哈卡马达': 'khakamada',
#  ...}

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
mfc_model = MFCTagger(mfc_table)

# %%
def replace_unknown(sequence):
    return [w if w in DataSet_vocab_frozen else 'nan' for w in sequence]
def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for sentence,es in zip(TestSet_ch,TestSet_en):
    #print("Sentence Key: {}\n".format(sentence))
    print("Sentence: {}\n".format(sentence))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(sentence, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(es)
    print("\n")
# Out:
# Sentence: ('目前', '，', '科学家', '们', '正在', '用', '三硝基', '甲苯', '（', '黄色炸药', '）', '饲养', '一', '群', '羊', '。')
#
# Predicted labels:
# -----------------
# ['at present', ',', 'scientists', 'None', 'is', 'learn', '<MISSING>', '<MISSING>', '(', '<MISSING>', ')', '<MISSING>', 'a', 'crowd', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'scientists', 'scientists', 'is feeding to', 'is feeding to', 'TNT', 'TNT', 'None', 'TNT', 'None', 'is feeding to', 'a flock of', 'a flock of', 'sheep', '.')
#
#
# Sentence: ('美国', '俄勒冈', '大学', '的', '兽医学', '教授', '莫里', '克雷格', '发现', '，', '反刍', '的', '食物', '的', '哺乳类', '动物', '能够', '有效', '的', '清理', '爆炸物', '污染', '的', '土壤', '。')
#
# Predicted labels:
# -----------------
# ['us', '<MISSING>', 'university', 'None', '<MISSING>', 'professor', '<MISSING>', '<MISSING>', 'found', ',', '<MISSING>', 'None', 'foods', 'None', '<MISSING>', 'None', 'None', 'effective', 'None', 'Clean Up', 'explosives', 'polluted', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'Oregon', 'State University', 'None', 'veterinary', 'scientist', 'Morrie', 'Craig', 'has found that', ',', 'cud-chewing', 'cud-chewing', 'cud-chewing', 'cud-chewing', 'mammals', 'mammals', 'can', 'efficiently', 'efficiently', 'clean up', 'explosives - contaminated', 'explosives - contaminated', 'explosives - contaminated', 'soil', ',')
#
#
# Sentence: ('在', '美国', '，', '军事', '训练', '产生', '的', '三硝基', '甲苯', '以及', '其他', '爆炸物', '以及', '一些', '老', '工厂', '的', '类似', '残留物', '共', '130', '万', '吨', '，')
#
# Predicted labels:
# -----------------
# ['in', 'us', ',', 'military', 'training', 'caused', 'None', '<MISSING>', '<MISSING>', 'and', 'other', 'explosives', 'and', 'some', 'old', '<MISSING>', 'None', 'copy alternative', '<MISSING>', 'total', '<MISSING>', 'million', 'tons', ',']
#
# Actual labels:
# --------------
# ('None', 'the U.S.', 'None', 'military', 'munitions training', 'from', 'from', 'TNT', 'TNT', 'and', 'other', 'explosives', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '1.3 million', '1.3 million', 'tons', 'None')
#
#
# Sentence: ('这些', '爆炸', '残留物', '已经', '在', '美国', '的', '土地', '上', '残留', '了', '几十', '年')
#
# Predicted labels:
# -----------------
# ['these', 'explosions', '<MISSING>', 'has', 'in', 'us', 'None', 'land', 'at', '<MISSING>', 'None', 'dozens', 'years']
#
# Actual labels:
# --------------
# ('the', 'remnants', 'remnants', 'remain for', 'in', 'None', 'None', 'the ground', 'in', 'remain for', 'remain for', 'decades', 'decades')
#
#
# Sentence: ('这些', '残留物', '并', '不', '会', '立即', '危害', '人类', '的', '健康', '，', '但是', '国防部', '官员', '表示', '，', '担忧', '这些', '残留物', '会', '渗', '到', '地下', '污染', '地下水', '或者', '毒害', '作物', '（', '以前', '发生', '过', '此类', '事件', '）', '。')
#
# Predicted labels:
# -----------------
# ['these', '<MISSING>', 'and', 'not', 'will', 'immediately', '<MISSING>', 'human history', 'None', 'health', ',', 'however', 'ministry of national defense', 'officials', 'said', ',', 'worry', 'these', '<MISSING>', 'will', '<MISSING>', 'to', '<MISSING>', 'polluted', '<MISSING>', 'or', '<MISSING>', '<MISSING>', '(', 'once', 'None', 'None', '<MISSING>', 'None', ')', '.']
#
# Actual labels:
# --------------
# ('This', 'residue', 'rarely', 'rarely', 'rarely', 'immediate', 'poses an threat', 'None', 'None', 'health', ',', 'but', 'the Department of Defense', 'officials', 'fear', 'fear', 'fear that', 'it', 'it', 'could', 'seep', 'into', 'None', 'None', 'groundwater', 'or', 'poison', 'plants', '(', 'before', 'has happened', 'has happened', 'which', 'which', ')', '.')
#
#
# Sentence: ('诸如', '燃烧', '土壤', '等', '传统', '清理', '技术', '不但', '昂贵', '而且', '耗时', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '<MISSING>', 'None', 'traditional', 'Clean Up', 'technology', '<MISSING>', 'high', 'and', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('such as', 'incinerating', 'the soil', 'None', 'Conventional', 'cleanup', 'techniques', 'None', 'are expensive', 'and', 'time-consuming', '.')
#
#
# Sentence: ('然而', '羊儿', '们', '可以', '免费', '做', '这项', '工作', '。')
#
# Predicted labels:
# -----------------
# ['However', '<MISSING>', 'None', 'can', 'free', 'do', 'the', 'job', '.']
#
# Actual labels:
# --------------
# ('None', 'Sheep', 'Sheep', 'will', 'for free', 'work', 'work', 'work', '.')
#
#
# Sentence: ('2004', '年', '，', '克雷格', '发现', '羊', '胃', '里', '助', '消化', '的', '细菌', '能够', '迅速', '将', '三硝基', '甲苯', '转化', '为', '一', '种', '无害', '的', '化合物', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'years', ',', '<MISSING>', 'found', '<MISSING>', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'None', '<MISSING>', 'None', 'promptly', 'will', '<MISSING>', '<MISSING>', 'None', 'None', 'a', 'None', '<MISSING>', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('2004', '2004', ',', 'Craig', 'discovered', "a sheep 's", 'stomach', 'in', 'help', 'digest cellulose', 'in', 'the bacteria', 'can', 'rapidly', 'convert into', 'TNT', 'TNT', 'convert into', 'convert into', 'a', 'a', 'harmless', 'harmless', 'compound', '.')
#
#
# Sentence: ('在', '近期', '的', '一些', '实验', '中', '，', '克雷格', '以及', '美国', '农业部', '的', '一些', '研究者', '们', '通过', '用', '三硝基', '甲苯', '饲养', '羊', '三', '周')
#
# Predicted labels:
# -----------------
# ['in', 'these days', 'None', 'some', 'experiments', 'in', ',', '<MISSING>', 'and', 'us', '<MISSING>', 'None', 'some', '<MISSING>', 'None', 'through', 'learn', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', 'three', 'week']
#
# Actual labels:
# --------------
# ('In', 'recent', 'recent', 'experiments', 'experiments', 'In', ',', 'he', 'and', 'the U.S. Department of Agriculture', 'the U.S. Department of Agriculture', 'None', 'None', 'researchers', 'researchers', 'None', 'fed for', 'TNT', 'TNT', 'fed for', 'sheep', 'three', 'weeks')
#
#
# Sentence: ('发现', '三硝基', '甲苯', '在', '羊', '体内', '分解', '的', '如此', '彻底', '，', '甚至', '在', '羊', '的', '粪便', '里', '没有', '任何', '残留', '，', '连', '类似', '相关', '的', '化合物', '都', '没有')
#
# Predicted labels:
# -----------------
# ['found', '<MISSING>', '<MISSING>', 'in', '<MISSING>', '<MISSING>', '<MISSING>', 'None', 'such', 'wipe out', ',', 'even', 'in', '<MISSING>', 'None', '<MISSING>', 'None', 'not', 'any', '<MISSING>', ',', '<MISSING>', 'copy alternative', 'sauce-related', 'None', '<MISSING>', 'None', 'not']
#
# Actual labels:
# --------------
# ('found that', 'it', 'it', 'None', 'None', 'None', 'broke down', 'None', 'so', 'completely', 'that', 'that', 'in', 'the animals', "'", 'feces', 'in', 'no', 'None', 'traces', 'or', 'None', 'None', 'related', 'related', 'compounds', 'no any', 'no any')
#
#
# Sentence: ('克雷格', '和', '他', '的', '同事', '们', '计划', '在', '被', '炸药', '污染', '的', '土地', '上', '种草', '以', '吸收', '爆炸物', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'and', 'he', 'None', 'co-workers', 'None', 'program', 'in', 'None', '<MISSING>', 'polluted', 'None', 'land', 'at', '<MISSING>', 'israeli', '<MISSING>', 'explosives', '.']
#
# Actual labels:
# --------------
# ('Craig', 'and', 'his', 'his', 'colleagues', 'colleagues', 'plan to', 'in', 'contaminated', 'TNT', 'contaminated', 'contaminated', 'soil', 'in', 'plant grasses', 'to', 'suck up', 'the explosives', '.')
#
#
# Sentence: ('在', '羊', '咀嚼', '的', '同时', '，', '羊', '消化道', '内', '的', '细菌', '就', '可以', '将', '残留', '的', '爆炸物', '分解', '。')
#
# Predicted labels:
# -----------------
# ['in', '<MISSING>', '<MISSING>', 'None', 'at the same time', ',', '<MISSING>', '<MISSING>', 'in', 'None', '<MISSING>', 'None', 'can', 'will', '<MISSING>', 'None', 'explosives', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('While', 'the sheep', 'munch away', 'While', 'While', ',', 'their', 'digestive tract', 'in', 'None', 'the bacteria', 'None', 'None', 'take care of', 'the rest', 'the rest', 'the rest', 'take care of', '.')
#
#
# Sentence: ('克雷格', '的', '实验室', '正在', '对', '来自', '军事', '基地', '的', '食草', '动物', '进行', '测试', '，')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'None', 'labs', 'is', 'None', 'None', 'military', 'al qaeda', 'None', '<MISSING>', 'None', 'None', '<MISSING>', ',']
#
# Actual labels:
# --------------
# ('Craig', "'s", 'lab', 'is testing', 'is testing', 'from', 'military', 'a base', 'None', 'on soil', 'the grazers', 'is testing', 'is testing', '.')
#
#
# Sentence: ('他', '估计', '20', '只', '的', '一', '群', '就', '可以', '在', '一个', '月', '内', '清理', '一', '英亩', '土地', '，', '在', '不到', '三', '年', '的', '时间', '内', '便', '可以', '彻底', '清除', '军事', '所', '用', '的', '爆炸', '残留物')
#
# Predicted labels:
# -----------------
# ['he', 'estimates', '20', 'only', 'None', 'a', 'crowd', 'None', 'can', 'in', 'a', 'months', 'in', 'Clean Up', 'a', '<MISSING>', 'land', ',', 'in', '<MISSING>', 'three', 'years', 'None', 'time', 'in', 'None', 'can', 'wipe out', '<MISSING>', 'military', 'None', 'learn', 'None', 'explosions', '<MISSING>']
#
# Actual labels:
# --------------
# ('He', 'estimates that', '20', '20', 'None', 'a flock of', 'a flock of', 'None', 'could', 'in', 'a', 'month', 'in', 'clear', 'an', 'acre of', 'grass', ', and', 'in', 'less than', 'three', 'years', 'in', 'in', 'in', 'None', 'None', 'completely', 'rid', 'None', 'None', 'None', 'None', 'munitions', 'residue')
#
#
# Sentence: ('克雷格', '指出', '，', '即使', '是', '吃', '了', '炸药', '的', '羊', '的', '羊肉', '被', '做成', '烤肉', '，', '也', '不', '会', '爆炸', '或者', '危害', '健康', '：')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'pointed out', ',', 'even', 'is', '<MISSING>', 'None', '<MISSING>', 'None', '<MISSING>', 'None', '<MISSING>', 'None', '<MISSING>', '<MISSING>', ',', 'also', 'not', 'will', 'explosions', 'or', '<MISSING>', 'health', ':']
#
# Actual labels:
# --------------
# ('Craig', 'points out', 'that', 'even if', 'None', 'TNT - eating', 'TNT - eating', 'TNT - eating', 'TNT - eating', 'sheep', "'s", 'meat', 'found its way onto a barbecue', 'found its way onto a barbecue', 'found its way onto a barbecue', ',', ',', 'never', 'could', 'explode', 'or', 'cause health problems', 'cause health problems', ':')
#
#
# Sentence: ('“', '摄取', '的', '炸药', '已经', '被', '分解', '成', '很', '小', '的', '分子', '，', '不', '可能', '形成', '和', '原', '化合物', '一样', '或者', '相似', '的', '东西', '。', '”')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', 'None', '<MISSING>', 'has', 'None', '<MISSING>', 'into', 'None', 'small', 'None', 'members', ',', 'not', 'may', 'reached', 'and', 'originally', '<MISSING>', 'like', 'or', 'alternative to', 'None', 'None', '.', '<MISSING>']
#
# Actual labels:
# --------------
# ('"', 'ingested', 'ingested', 'The TNT', 'None', 'is broken down', 'is broken down', 'is broken down into', 'small', 'small', 'small', 'molecules', 'None', 'are in no way similar to', 'are in no way similar to', 'None', 'None', 'original', 'the compound', 'are in no way similar to', 'are in no way similar to', 'are in no way similar to', 'None', 'None', '.', '"')
#
#
# Sentence: ('在', '上', '周五', '(', '2011', '年', '2', '月', '4', '日', ')', '的', '一个', '可能', '被', '称为', '“', '无人', '机', '的', '基蒂', '霍克', '时刻', '”', '中', '，', '一', '架', '实验性', '的', '无人机', '在', '空中', '飞行', '了', '29', '分钟', '，', '这', '架', '飞机', '不仅', '没有', '机上', '的', '飞行员', '，', '而且', '也', '没有', '远程', '操纵', '者', '。')
#
# Predicted labels:
# -----------------
# ['in', 'at', 'friday', '(', '2011', 'years', '2', 'months', 'four', 'one-day', ')', 'None', 'a', 'may', 'None', 'nicknamed', '<MISSING>', '<MISSING>', 'plane', 'None', '<MISSING>', '<MISSING>', 'moments', '<MISSING>', 'in', ',', 'a', 'None', '<MISSING>', 'None', '<MISSING>', 'in', 'in the air', 'flight', 'None', '<MISSING>', 'minutes', ',', 'the', 'None', 'aircraft', 'not only', 'not', '<MISSING>', 'None', '<MISSING>', ',', 'and', 'also', 'not', '<MISSING>', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('In', 'late', 'Friday', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'a', 'may be', 'None', 'None', 'None', 'an unmanned', 'aircraft', 'None', 'Kitty', 'Hawk', 'moment', 'None', 'In', 'None', 'an', 'an', 'experimental', 'experimental', 'drone', 'None', 'None', 'made a flight', 'None', '29', 'minute', ',', 'None', 'None', 'None', 'not only', 'lacking', 'onboard', 'onboard', 'an pilot', ',', 'None', 'None', 'None', 'one flying the vehicle remotely', 'one flying the vehicle remotely', 'one flying the vehicle remotely', '.')
#
#
# Sentence: ('“', '我们', '正', '在', '创造', '历史', '”', '，', '为', '美国', '海军', '建造', 'X-47B', '的', '诺斯罗普', '格鲁门', '公司', '航天', '系统', '部门', '负责', '该', '项目', '的', '副', '总裁', '兼', '产品', '经理', 'Janis', 'Pamiljans', '说', '，')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'we', 'is', 'in', 'create', 'history', '<MISSING>', ',', 'None', 'us', 'navy', '<MISSING>', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'agency', 'None', 'the', 'project', 'None', 'vice', 'governor', 'also', 'products', '<MISSING>', '<MISSING>', '<MISSING>', 'said', ',']
#
# Actual labels:
# --------------
# ('"', 'Such events are history in the making', 'Such events are history in the making', 'Such events are history in the making', 'Such events are history in the making', 'Such events are history in the making', '"', ',', 'for', 'the U.S.', 'Navy', 'built', 'the X-47B program', 'None', 'Northrop', 'Grumman', 'Grumman', 'Aerospace', 'Systems', 'None', 'None', 'None', 'None', 'None', 'vice', 'president', 'and', 'program', 'manager', 'Janis', 'Pamiljans', 'said', '.')
#
#
# Sentence: ('“', '我们', '已经', '超越', '了', '想', '在', '飞行器', '上', '所', '达到', '的', '目标', '！', '”')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'we', 'has', '<MISSING>', 'None', 'want', 'in', '<MISSING>', 'at', 'None', 'None', 'None', 'goal', '<MISSING>', '<MISSING>']
#
# Actual labels:
# --------------
# ('"', 'We', 'surpassed', 'surpassed', 'surpassed', 'wanted to', 'with', 'the flight', 'with', 'None', 'achieve', 'None', 'what', '.', '"')
#
#
# Sentence: ('这', '架', '采用', '蝠', '翼', '无', '尾', '布局', '的', 'X-47B', '是', '诺斯罗普', '格鲁门', '公司', '制造', '的', '两', '架', '演示', '机', '中', '的', '一', '架', '，', '在', '首飞', '上', '飞', '到', '了', '5000', '英尺', '的', '高空', '，', '并', '准确', '地', '降落', '在', '目标', '上', '。')
#
# Predicted labels:
# -----------------
# ['the', 'None', 'using', '<MISSING>', '<MISSING>', 'no', '<MISSING>', 'composition', 'None', '<MISSING>', 'is', '<MISSING>', '<MISSING>', 'None', 'manufacturing', 'None', 'two', 'None', '<MISSING>', 'plane', 'in', 'None', 'a', 'None', ',', 'in', '<MISSING>', 'at', 'to fly', 'to', 'None', '5,000', '<MISSING>', 'None', '<MISSING>', ',', 'and', '<MISSING>', 'None', 'landed', 'in', 'goal', 'at', '.']
#
# Actual labels:
# --------------
# ('The', 'The', 'None', 'bat', 'winged', 'less', 'tail', 'None', 'None', 'X-47B', ',', 'Northrop', 'Grumman', 'None', 'built', 'built', 'two', 'two', 'demonstrators', 'demonstrators', 'None', 'of', 'one', 'one', 'None', 'during', 'debut', 'during', 'flew', 'as high as', 'as high as', '5,000', 'feet', 'None', 'None', 'None', 'None', 'right', 'right', 'touched down', 'on', 'target', 'on', '.')
#
#
# Sentence: ('在', '随后', '召开', '的', '新闻', '发布会', '上', '，', '项目', '负责人', 'Jaime', 'Engdahl', '对', '媒体', '说', '：', '“', '我们', '的', '团队', '仍然', '在', '分析', '数据', '，', '但', '我', '可以', '告诉', '你', '，', '无人机', '的', '表现', '是', '无可', '挑剔', '的', '。')
#
# Predicted labels:
# -----------------
# ['in', 'shortly afterwards', 'None', 'None', 'news', '<MISSING>', 'at', ',', 'project', 'director', '<MISSING>', '<MISSING>', 'None', 'media', 'said', ':', '<MISSING>', 'we', 'None', 'team', 'still', 'in', 'analysis', 'data', ',', 'but', 'i', 'can', 'told', 'you', ',', '<MISSING>', 'None', 'performance', 'is', '<MISSING>', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '"', 'The', 'The', 'team', 'still', 'is analyzing', 'is analyzing', 'data', ',', 'but', 'I', 'will', 'tell', 'you', 'None', 'the air vehicle', 'None', 'performance', 'was', 'rock solid', 'rock solid', 'rock solid', '.')
#
#
# Sentence: ('它', '做到', '了', '我们', '所', '期望', '的', '事情', '。')
#
# Predicted labels:
# -----------------
# ['it', '<MISSING>', 'None', 'we', 'None', '<MISSING>', 'None', 'None', '.']
#
# Actual labels:
# --------------
# ('It', 'did', 'did', 'None', 'was', 'expected', 'what', 'what', '.')
#
#
# Sentence: ('从', '工程师', '那里', '得到', '的', '初步', '反馈', '表明', '试验', '机', '符合', '模型', '的', '空气', '动力学', '性能', '，', '并且', '导航', '和', '操纵', '都', '十分', '出色', '。')
#
# Predicted labels:
# -----------------
# ['from', 'engineer', 'there', 'None', 'None', '<MISSING>', '<MISSING>', 'shows', 'experimental', 'plane', 'violating', '<MISSING>', 'None', 'air', '<MISSING>', 'nuclear-capable', ',', 'and', '<MISSING>', 'and', '<MISSING>', 'None', 'very', 'excellent', '.']
#
# Actual labels:
# --------------
# ('from', 'the engineers', 'None', 'None', 'None', 'preliminary', 'The feedback', 'was that', 'it', 'it', 'matched', 'the model', 'None', 'aerodynamics', 'aerodynamics', 'performance', 'and', 'and', 'guidance', 'and', 'control', 'None', 'very', 'well', '.')
#
#
# Sentence: ('这', '是', '对于', '团队', '在', '过去', '几', '年', '的', '努力', '工作', '和', '他们', '在', '这', '一', '领域', '的', '专业', '知识', '的', '最', '好', '证明', '。', '”')
#
# Predicted labels:
# -----------------
# ['the', 'is', 'None', 'team', 'in', 'past', 'a few', 'years', 'None', 'efforts', 'job', 'and', 'they', 'in', 'the', 'a', 'fields', 'None', 'specializing', 'intellectual', 'None', 'most', 'good', 'proved', '.', '<MISSING>']
#
# Actual labels:
# --------------
# ('That', 'is', 'to', 'the teams', 'over', 'the last', 'few', 'years', 'None', 'hard', 'work', 'and', 'None', 'in', 'this', 'realm', 'realm', 'None', 'expertise', 'expertise', 'None', 'None', 'None', 'a testament', ',', '"')
#
#
# Sentence: ('在', '位于', '加州', '莫哈韦', '沙漠', '的', '爱德华', '空军', '基地', '，', 'X-47B', '完美', '的', '飞行', '和', '着陆', '向', '人们', '展示', '了', '由', '设计', '软件', '设计', '出', '的', '全自动', '无人', '驾驶', '飞机', '的', '精确性', '。')
#
# Predicted labels:
# -----------------
# ['in', 'located', 'california', '<MISSING>', 'desert', 'None', '<MISSING>', 'air forces', 'al qaeda', ',', '<MISSING>', 'grand', 'None', 'flight', 'and', '<MISSING>', 'None', 'people', '<MISSING>', 'None', 'None', 'generated', 'software', 'generated', 'exit', 'None', '<MISSING>', '<MISSING>', '<MISSING>', 'aircraft', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('in', 'in', "California 's", 'Mojave', 'Desert', 'in', 'Edwards', 'Air Force', 'Base', 'None', "X-47B 's", 'flawless', 'flawless', 'flight', 'and', 'landing back', 'None', 'None', 'demonstrated', 'demonstrated', 'None', 'None', 'software', 'design', 'None', 'None', 'fully automated', 'unmanned', 'unmanned', 'aircraft', 'unmanned', 'the accuracy', '.')
#
#
# Sentence: ('项目', '负责人', '指出', '，', '试飞', '增强', '了', '人们', '对', 'X-47B', '在', '接下来', '的', '航母', '测试', '中', '成功', '的', '信心', '。')
#
# Predicted labels:
# -----------------
# ['project', 'director', 'pointed out', ',', '<MISSING>', 'enhance', 'None', 'people', 'None', '<MISSING>', 'in', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'in', 'succeeded', 'None', 'confidence', '.']
#
# Actual labels:
# --------------
# ('program', 'managers', 'said', ',', 'The trial run', 'bolstered', 'bolstered', 'None', 'confidence', 'X-47B', 'None', 'follow-on', 'follow-on', 'an aircraft carrier', 'test flights', 'None', 'be successful', 'confidence', 'confidence', '.')
#
#
# Sentence: ('人们', '希望', 'X-47B', '在', '爱德华', '空军', '基地', '的', '试飞', '频率', '随着', '飞机', '能力', '的', '提升', '，', '能够', '达到', '每周', '一', '次', '。')
#
# Predicted labels:
# -----------------
# ['people', 'hope', '<MISSING>', 'in', '<MISSING>', 'air forces', 'al qaeda', 'None', '<MISSING>', '<MISSING>', 'with', 'aircraft', 'capability', 'None', 'enhancing', ',', 'None', 'None', '<MISSING>', 'a', 'None', '.']
#
# Actual labels:
# --------------
# ('are expected to', 'are expected to', 'None', 'None', 'Edwards', 'Air Force', 'Base', 'None', 'Flight', 'rates', 'as', 'the plane', 'capabilities', 'None', 'are expanded', 'None', 'None', 'None', 'per week', 'once', 'once', '.')
#
#
# Sentence: ('上', '周五', '试飞', '的', 'Air', 'Vehicle', '1', '（', '也', '被', '称为', 'AV-1', '）', '，', '将', '被', '转运', '到', '帕塔克森特', '河', '海军', '航空站', '，', '最终', '将', '在', '航空母舰', '上', '完成', '更', '多', '测试', '。')
#
# Predicted labels:
# -----------------
# ['at', 'friday', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'an', '(', 'also', 'None', 'nicknamed', '<MISSING>', ')', ',', 'will', 'None', '<MISSING>', 'to', '<MISSING>', '<MISSING>', 'navy', '<MISSING>', ',', 'final', 'will', 'in', '<MISSING>', 'at', 'completed', 'more', 'over', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('Friday', 'Friday', 'flew', 'which', 'Air', 'Vehicle', '1', ',', 'or', 'or', 'or', 'AV-1', ',', ',', 'will', 'be transferred to', 'be transferred to', 'to', 'Patuxent', 'River', 'Naval', 'Air Station', '.', 'and eventually', 'None', 'loaded onto', 'an aircraft carrier', 'loaded onto', 'None', 'additional', 'additional', 'testing', 'None')
#
#
# Sentence: ('AV-1', '的', '姊妹', '机', 'AV-2', '将', '在', '下', '个', '月', '转运', '到', '爱德华', '空军', '基地', '，', '并', '在', '那里', '进行', '滑跑', '测试', '和', '发动机', '工作', '测试', '，', '预计', '将', '在', '今年', '夏天', '完成', '首', '飞', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'None', '<MISSING>', 'plane', '<MISSING>', 'will', 'in', 'None', 'None', 'months', '<MISSING>', 'to', '<MISSING>', 'air forces', 'al qaeda', ',', 'and', 'in', 'there', 'None', '<MISSING>', '<MISSING>', 'and', 'engine', 'job', '<MISSING>', ',', 'estimated', 'will', 'in', 'this year', '<MISSING>', 'completed', 'first', 'to fly', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'Sistership', 'Sistership', 'AV-2', 'is due to', 'None', 'next', 'next', 'month', 'be transferred to', 'to', 'Edwards', 'AFB', 'AFB', 'None', 'None', 'None', 'None', 'for', 'taxi', 'tests', 'and', 'engine', 'runs', 'None', ', and', 'is expected to', 'None', 'None', 'this', 'summer', 'make', 'first', 'flight', '.')
#
#
# Sentence: ('X-47B', '将', '是', '第一', '架', '在', '航空母舰', '上', '起飞', '并', '降落', '的', '无人机', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'will', 'is', 'first', 'None', 'in', '<MISSING>', 'at', '<MISSING>', 'and', 'landed', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('The X-47B', 'will', 'be', 'the first', 'the first', 'aboard', 'an aircraft carrier', 'aboard', 'take off', 'and', 'land', 'None', 'unmanned jet aircraft', '.')
#
#
# Sentence: ('它', '的', '翼展', '为', '52', '英尺', '，', '长', '38', '英尺', '，', '是', '美国', '海军', '现役', '舰载', '机', 'F/A-18C', '大小', '的', '87%', '。')
#
# Predicted labels:
# -----------------
# ['it', 'None', '<MISSING>', 'None', '<MISSING>', '<MISSING>', ',', 'None', '<MISSING>', '<MISSING>', ',', 'is', 'us', 'navy', '<MISSING>', '<MISSING>', 'plane', '<MISSING>', 'size', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('the X-47B', 'None', 'wingspan', 'With', '52 -', '- foot', 'and', 'length of', '38', 'feet', ',', 'is', 'Navy', 'Navy', 'currently', 'operating aboard aircraft carriers', 'aircraft', 'F/A-18C', 'the size', 'of', '87 percent', '.')
#
#
# Sentence: ('“', '舰载', '机', '从', '有人', '驾驶', '到', '无人', '驾驶', '是', '一个', '巨大', '的', '转变', '。', '”', 'Engdahl', '说道', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', 'plane', 'from', 'someone', '<MISSING>', 'to', '<MISSING>', '<MISSING>', 'is', 'a', 'huge', 'None', 'moving', '.', '<MISSING>', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('"', 'on the carrier', 'None', 'None', 'manned', 'manned', 'to', 'unmanned', 'operation', 'None', 'None', 'big', 'big', 'paradigm shift', ',', '"', 'Engdahl', 'said', '.')
#
#
# Sentence: ('Engdahl', '是', '美国', '海军', '上校', '，', '说', '他', '参加', '这个', '项目', '的', '热情', '源于', '越战', '时', '，')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'is', 'us', 'navy', '<MISSING>', ',', 'said', 'he', 'attending', 'this', 'project', 'None', 'passion', '<MISSING>', '<MISSING>', 'None', ',']
#
# Actual labels:
# --------------
# ('Engdahl', 'None', 'in the U.S.', 'Navy', 'a captain', ',', 'says', 'his', 'joining', 'the', 'service', 'his', 'inspiration', 'came from', 'the Vietnam-era', 'the Vietnam-era', 'None')
#
#
# Sentence: ('有', '飞行员', '说', '任务', '中', '最', '艰难', '的', '部分', '是', '在', '航母', '上', '降落', '。')
#
# Predicted labels:
# -----------------
# ['None', '<MISSING>', 'said', 'mission', 'in', 'most', '<MISSING>', 'None', 'some', 'is', 'in', '<MISSING>', 'at', 'landed', '.']
#
# Actual labels:
# --------------
# ('who', 'pilots', 'said that', 'missions', 'of', 'the most', 'difficult', 'difficult', 'part', 'was', 'landing on', 'the carriers', 'landing on', 'landing on', '.')
#
#
# Sentence: ('Engdahl', '还', '说', '“', '这', '是', '海军', '无', '人', '验证', '机', '的', '第一', '次', '飞行', '，', '这', '可', '是', '大', '事儿', '，', '但', '仍然', '仅仅', '是', '这', '一', '项目', '的', '开始', '而已', '”', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'also', 'said', '<MISSING>', 'the', 'is', 'navy', 'no', 'None', '<MISSING>', 'plane', 'None', 'first', 'None', 'flight', ',', 'the', 'can', 'is', 'None', '<MISSING>', ',', 'but', 'still', 'only', 'is', 'the', 'a', 'project', 'None', 'started', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('Engdahl', 'None', 'said', '"', 'None', 'None', 'Navy', 'unmanned', 'unmanned', 'X-plane', 'a X-plane', 'of', 'First', 'First', 'flight', 'None', 'that', "'s", "'s", 'a huge deal', 'a huge deal', ',', 'but', 'None', 'just', "'s", 'this', 'this', 'program', 'to', 'one of the many firsts', 'just', '"', '.')
#
#
# Sentence: ('我们', '将', '见证', '更', '多', '的', '新', '面孔', '现身', '全明星', '舞台', '，', '尤其', '考虑', '到', '甜瓜', '马上', '即将', '东', '渡', '而', '姚', '明', '又', '再次', '报销', ',', '西部', '必', '将', '天下大乱', '。')
#
# Predicted labels:
# -----------------
# ['we', 'will', '<MISSING>', 'more', 'over', 'None', 'new', '<MISSING>', '<MISSING>', '<MISSING>', '<MISSING>', ',', 'especially', 'consideration', 'to', '<MISSING>', '<MISSING>', 'upcoming', 'eastern', '<MISSING>', 'None', 'yao', '<MISSING>', 'again', 'again', '<MISSING>', 'None', 'western', '<MISSING>', 'will', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'possibility', 'possibility', 'None', 'of a slew of', 'of a slew of', 'first-time', 'None', 'None', 'All-Stars', 'None', 'None', 'particularly', 'None', 'None', 'one current starter Carmelo Anthony', 'None', 'be', 'east', 'headed', 'None', 'Yao Ming', 'Ming', 'None', 'another', 'miss the game', 'None', 'the Western Conference', 'None', 'None', 'None', '.')
#
#
# Sentence: ('安东尼', '投奔', '篮网', '很', '有', '可能', '让', '家嫂', '在', '第二', '个', '前锋', '位置', '之', '争', '中', '突围', '，', '目前', '看来', '，', '腾出', '的', '这个', '位子', '非', '湖人', '二', '当家', '莫', '属', '了', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', 'nets', 'None', 'None', 'may', 'None', '<MISSING>', 'in', 'second', 'None', '<MISSING>', '<MISSING>', 'None', '<MISSING>', 'in', '<MISSING>', ',', 'at present', 'seems to be', ',', '<MISSING>', 'None', 'this', '<MISSING>', 'instead of', '<MISSING>', 'second', '<MISSING>', '<MISSING>', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ("Anthony 's", 'possible departure', 'New Jersey', 'None', 'would likely', 'would likely', 'result in', 'Pau Gasol him', 'None', 'the second', 'second', 'forward', 'spot', 'None', 'None', 'None', 'beating out', ',', 'None', 'None', 'None', 'freeing up', 'None', 'the reserve', 'slot', 'would likely go to', 'the Lakers', 'big man', 'big man', 'would likely go to', 'would likely go to', '.', '.')
#
#
# Sentence: ('斯特恩', '大人', '一', '句', '话', '，', '任何', '人', '都', '可能', '顶', '上', '姚', '明', '的', '首发', '位置', '，', '而', '教练', '们', '在', '选择', '替补', '球员', '时', '也', '有', '这种', '自由度', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', 'a', 'sentence', 'None', ',', 'any', 'None', 'None', 'may', '<MISSING>', 'at', 'yao', '<MISSING>', 'None', 'initial release', '<MISSING>', ',', 'None', 'coach', 'None', 'in', 'choice', '<MISSING>', 'soccer player', 'None', 'also', 'None', 'this', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('David Stern', 'David Stern', 'None', 'None', 'None', 'None', 'any', 'player', 'None', 'None', 'replace', 'replace', 'Yao', 'Yao', 'None', 'None', 'None', ',', 'and', 'the coaches who', 'coaches who', 'None', 'pick', 'backups', 'the backups', 'None', 'similar', 'have', 'flexibility', 'flexibility', ';')
#
#
# Sentence: ('虽然', '联盟', '定下', '规矩', '要', '选', '出', '双', '后卫', '，', '双', '前锋', '，', '一', '个', '中锋', '和', '两', '个', '任意', '位置')
#
# Predicted labels:
# -----------------
# ['although', 'coalition', 'has given as an zone', '<MISSING>', 'None', '<MISSING>', 'exit', 'pairs', '<MISSING>', ',', 'pairs', '<MISSING>', ',', 'a', 'None', '<MISSING>', 'and', 'two', 'None', '<MISSING>', '<MISSING>']
#
# Actual labels:
# --------------
# ('though', 'league', 'require', 'rules', 'to', 'pick', 'pick', 'two', 'guards', ',', 'two', 'forwards', ',', 'a', 'a', 'center', 'and', 'two', 'two', 'wild', 'cards')
#
#
# Sentence: ('但', '规则', '同样', '也', '指出', '教练', '能', '选择', '任何', '他们', '认为', '对', '球队', '化学', '反应', '有益', '的', '球员', '。')
#
# Predicted labels:
# -----------------
# ['but', '<MISSING>', 'None', 'also', 'pointed out', 'coach', 'None', 'choice', 'any', 'they', 'think', 'None', '<MISSING>', 'chemical', 'response', '<MISSING>', 'None', 'soccer player', '.']
#
# Actual labels:
# --------------
# ('None', 'those rules', 'same', 'None', 'give', 'coaches', 'give right to', 'designate', 'any', 'they', 'believe', 'benefit', 'None', 'the roster', 'the roster', 'benefit', 'benefit', 'player', '.')
#
#
# Sentence: ('因此', '，', '如果', '我们', '最终', '看到', '西部', '没', '有', '任何', '一', '位', '中锋', '现身', '，', '那', '也', '没', '什么', '可', '大惊小怪', '的', '。')
#
# Predicted labels:
# -----------------
# ['None', ',', 'if', 'we', 'final', 'seen', 'western', 'not', 'None', 'any', 'a', 'None', '<MISSING>', '<MISSING>', ',', 'None', 'also', 'not', 'what', 'can', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('Therefore', ',', 'possible', 'None', 'None', 'None', 'the Western Conference', "won't", "won't", "won't a single", 'a', 'a', 'center', 'include', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('让我们', '先', '不要', '理会', '甜瓜', '和', '家嫂', '的', '那', '档子', '事', '，', '就', '先', '把', '这', '第二', '个', '前锋', '位置', '空', '出来', '吧', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'None', 'not', 'ignored', '<MISSING>', 'and', '<MISSING>', 'None', 'None', '<MISSING>', 'None', ',', 'None', 'None', 'put', 'the', 'second', 'None', '<MISSING>', '<MISSING>', '<MISSING>', 'leaked', 'None', '.']
#
# Actual labels:
# --------------
# ("Let's", 'None', 'for a second', 'put on hold', 'Carmelo/Gasol', 'Carmelo/Gasol', 'Carmelo/Gasol', 'None', 'None', 'None', 'the thing', 'and', 'and', 'None', 'leave', 'that', 'second', 'second', 'starting forward', 'spot', 'blank', 'blank', '.', '.')
#
#
# Sentence: ('这样', '呢', '，', '我', '觉得', '首先', '下面', '六', '位', '球员', '已经', '锁定', '了', '2011年', '全明星', '大', '名单', '：')
#
# Predicted labels:
# -----------------
# ['None', 'None', ',', 'i', '<MISSING>', '<MISSING>', '<MISSING>', '6-1', 'None', 'soccer player', 'has', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'None', 'list', ':']
#
# Actual labels:
# --------------
# ('In that scenario', 'None', ',', 'I', 'consider', 'None', 'the following', 'six', 'six', 'players', "'d", 'locks', 'locks', 'None', 'All-Star', '12 slots', 'slots', ':')
#
#
# Sentence: ('1', '.')
#
# Predicted labels:
# -----------------
# ['an', '<MISSING>']
#
# Actual labels:
# --------------
# ('1', '.')
#
#
# Sentence: ('科比', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ':']
#
# Actual labels:
# --------------
# ('Kobe Bryant', ':')
#
#
# Sentence: ('将', '出任', '先', '发', '后卫', '。')
#
# Predicted labels:
# -----------------
# ['will', '<MISSING>', 'None', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('Will', 'be voted in as', 'starter', 'starter', 'starter', '.')
#
#
# Sentence: ('2', '.')
#
# Predicted labels:
# -----------------
# ['2', '<MISSING>']
#
# Actual labels:
# --------------
# ('2', '.')
#
#
# Sentence: ('保罗', '：')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ':']
#
# Actual labels:
# --------------
# ('Chris Paul', ':')
#
#
# Sentence: ('杜兰特', '：')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ':']
#
# Actual labels:
# --------------
# ('Kevin Durant', ':')
#
#
# Sentence: ('强劲', '势头', '领先', '前锋', '票', '选', '。')
#
# Predicted labels:
# -----------------
# ['robust', '<MISSING>', 'lead', '<MISSING>', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('strong', 'margin', 'Leading', 'forwards', 'None', 'None', '.')
#
#
# Sentence: ('4', '.')
#
# Predicted labels:
# -----------------
# ['four', '<MISSING>']
#
# Actual labels:
# --------------
# ('4', '.')
#
#
# Sentence: ('吉诺比利', '：')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ':']
#
# Actual labels:
# --------------
# ('Manu Ginobili', ':')
#
#
# Sentence: ('本', '季', '最', '佳', '球队', '的', '最', '佳', '球员', '，', '球队', '大', '脑', '，', '马', '刺', '攻防', '两', '端', '无处不在', '，', '实至名归', '。')
#
# Predicted labels:
# -----------------
# ['None', 'quarter', 'most', 'poor', '<MISSING>', 'None', 'most', 'poor', 'soccer player', ',', '<MISSING>', 'None', '<MISSING>', ',', '<MISSING>', '<MISSING>', '<MISSING>', 'two', '<MISSING>', '<MISSING>', ',', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'the best', 'best', 'team', "'s been", 'the best', 'best', 'player', ',', 'None', 'record-wise', 'record-wise', ', and', 'None', 'None', 'None', 'both ends', 'ends', 'None', 'None', 'None', '.')
#
#
# Sentence: ('5', '.')
#
# Predicted labels:
# -----------------
# ['five', '<MISSING>']
#
# Actual labels:
# --------------
# ('5', '.')
#
#
# Sentence: ('诺维斯基', '：')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ':']
#
# Actual labels:
# --------------
# ('Dirk Nowitzki', ':')
#
#
# Sentence: ('众多', 'MVP', '评选', '的', '大', '热门', '，', '毫', '无', '悬念', '。', '6', '.')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '<MISSING>', 'None', 'None', '<MISSING>', ',', '<MISSING>', 'no', '<MISSING>', '.', 'six', '<MISSING>']
#
# Actual labels:
# --------------
# ('a lot', 'MVP', 'ballots', 'of', 'The front-runner', 'The front-runner', ', and', 'deservedly', 'deservedly', 'deservedly', '.', '6', '.')
#
#
# Sentence: ('德隆', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ':']
#
# Actual labels:
# --------------
# ('Deron Williams', ':')
#
#
# Sentence: ('在', '爵士', '体系', '中', '比', '以往', '担当', '了', '更', '多', '的', '得分', '任务', '，', '场', '均', '走', '上', '罚球', '线', '多', '达', '七', '次', '。')
#
# Predicted labels:
# -----------------
# ['in', '<MISSING>', 'system', 'in', 'than', 'so far', '<MISSING>', 'None', 'more', 'over', 'None', 'None', 'mission', ',', 'None', 'None', 'onto', 'at', '<MISSING>', '<MISSING>', 'over', 'as as', 'seven', 'None', '.']
#
# Actual labels:
# --------------
# ('in', 'Utah', 'Utah', 'in', 'than', 'ever before', 'shouldering', "'s shouldering", 'more', 'more', 'of', 'scoring', 'load', ', and', 'per game', 'per', 'getting', "'s getting", 'line', 'the line', 'more than', 'more than', 'seven', 'times', '.')
#
#
# Sentence: ('身体', '和', '技术', '都', '能', '摇摆', '到', '分位', '，', '防守', '上', '的', '出众', '表现', '使', '其', '在', '这', '张', '名单', '中', '干掉', '纳什', '。')
#
# Predicted labels:
# -----------------
# ['physical', 'and', 'technology', 'None', 'None', '<MISSING>', 'to', '<MISSING>', ',', '<MISSING>', 'at', 'None', '<MISSING>', 'performance', 'None', 'None', 'in', 'the', 'zhang', 'list', 'in', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('the size', 'and', 'flexibility', 'None', 'to', 'shift', 'to', 'shooting guard', ', and', 'defensively', 'None', 'None', 'enough', 'None', 'to', 'None', 'on', 'my', 'my', 'ballot', 'on', 'jump above', 'Steve Nash', '.')
#
#
# Sentence: ('以上', '都', '是', '板上定钉', '的', '了', '，', '西部', '剩下', '的', '六', '个', '位置', '我', '觉得', '至少', '将', '有', '20', '位', '球员', '有', '能力', '来', '竞争', '。')
#
# Predicted labels:
# -----------------
# ['over', 'None', 'is', '<MISSING>', 'None', 'None', ',', 'western', 'there are just a few things', 'None', '6-1', 'None', '<MISSING>', 'i', '<MISSING>', 'at least', 'will', 'None', '20', 'None', 'soccer player', 'None', 'capability', 'None', 'compete with', '.']
#
# Actual labels:
# --------------
# ('Those', 'are', 'are', 'sure', 'sure', '.', '.', 'the West', 'the remaining', 'remaining', 'six', 'six', 'spots', 'by my count', 'by my count', 'None', 'leaves', 'leaves', '20', '20', 'players', 'None', 'None', 'for', 'competing', '.')
#
#
# Sentence: ('这', '20', '名', '球员', '中', '，', '14', '人', '已经', '当选', '过', '全', '明星', '。')
#
# Predicted labels:
# -----------------
# ['the', '20', 'None', 'soccer player', 'in', ',', '14-year-old', 'None', 'has', '<MISSING>', 'None', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('those', '20', '20', 'players', 'Of', ',', '14', '14', 'have', 'made', 'made', 'an All-Star', 'an All-Star', '.')
#
#
# Sentence: ('让', '我们', '按', '身高', '和', '技术', '特点', '而', '非', '官方', '位置', '来', '给', '他们', '排', '排序', '，', '大胆', '预测', '一下', '今年', '的', '最终', '阵容', '，', '其中', '可能', '迎来', '全明星', '处女秀', '的', '球员', '用', '斜体', '标', '出', '。')
#
# Predicted labels:
# -----------------
# ['None', 'we', 'in accordance with', '<MISSING>', 'and', 'technology', 'characteristic', 'None', 'instead of', 'official', '<MISSING>', 'None', 'None', 'they', '<MISSING>', '<MISSING>', ',', '<MISSING>', 'predict', 'be reminded that', 'this year', 'None', 'final', '<MISSING>', ',', 'None', 'may', '<MISSING>', '<MISSING>', '<MISSING>', 'None', 'soccer player', 'learn', '<MISSING>', '<MISSING>', 'exit', '.']
#
# Actual labels:
# --------------
# ('Let', "'s", 'by', 'size', 'and', 'skill', 'skill', 'rather than', 'rather than', 'official', 'position', 'None', 'None', 'them', 'divide', 'divide up', 'to', 'better', 'get', 'get', 'None', 'of', 'realities', 'roster', ',', 'None', 'potential', 'with', 'None', 'first-timers', 'None', 'None', 'in', 'italics', 'italics', 'italics', '.')
#
#
# Sentence: ('（', '按', '名字', '首', '字母', '排', '序', '）')
#
# Predicted labels:
# -----------------
# ['(', 'in accordance with', 'names', 'first', 'letters', '<MISSING>', '<MISSING>', ')']
#
# Actual labels:
# --------------
# ('(', 'in', 'None', 'alphabetical', 'alphabetical order', 'Lists', 'Lists', ')')
#
#
# Sentence: ('内线', '球员', '大家', '也', '看到', '了', '，', '这', '个', '位置', '真的', '很', '拥挤', '，', '这', '也', '就', '意味着', '更', '多', '表现', '不俗', '的', '球员', '将', '会', '与', '洛杉矶', '全明星', '无', '缘', '了', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'soccer player', 'it', 'also', 'seen', 'None', ',', 'the', 'None', '<MISSING>', 'It was a very confident move by', 'None', '<MISSING>', ',', 'the', 'also', 'None', 'mean', 'more', 'over', 'performance', '<MISSING>', 'None', 'soccer player', 'will', 'will', 'and', 'los angeles', '<MISSING>', 'no', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('POST', 'PLAYERS', "you'll", 'None', 'see', 'see', ',', 'this', 'this', 'group', 'is', 'very', 'crowded', ',', 'which', 'None', 'None', 'means', 'a bunch of', 'a bunch of', 'None', 'deserving', 'deserving', 'guys', "aren't going", "aren't going", "aren't going to make it", 'None', 'None', "aren't going to make it", "aren't going to make it", 'None', '.')
#
#
# Sentence: ('阿德里尔奇', '(', '球员', '效率', '值', 'PER', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '(', 'soccer player', '<MISSING>', 'in meantime', '<MISSING>', ':']
#
# Actual labels:
# --------------
# ('LaMarcus Aldridge', '(', 'Player', 'Efficiency', 'Rating', 'Player Efficiency Rating', ':')
#
#
# Sentence: ('20.68', '?', '28th', 'in', 'NBA', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '?', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('20.68', 'None', '28th', 'in', 'NBA', ')', ':')
#
#
# Sentence: ('阿德里尔奇', '打', '出', '了', '生涯', '最佳', '表现', '，', '正', '在', '越来越', '多', '的', '获得', '罚球', '并', '冲击', '内线', '，', '而', '当', '他', '不', '在', '场上', '时', '开拓者', '攻防', '两', '端', '都', '尽', '显', '疲软', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'killed', 'exit', 'None', 'career', 'best', 'performance', ',', 'is', 'in', 'keep surfacing', 'over', 'None', 'None', '<MISSING>', 'and', '<MISSING>', '<MISSING>', ',', 'None', 'when', 'he', 'not', 'in', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'two', '<MISSING>', 'None', 'None', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('Aldridge', 'having', 'having', 'is', 'his season', 'best', 'None', '.', "'s", "'s", 'more', 'more', 'more', "'s getting", 'the line', 'and', 'attacking', 'the rim', ',', 'and', 'when', 'Aldridge', 'sits', 'sits', 'sits', 'when', 'Portland', 'None', 'both', 'ends', 'both', 'None', 'None', 'dies', '.')
#
#
# Sentence: ('超出', '期待', '的', '表现', '令', '他', '成为', '全', '明星', '更', '有力', '的', '竞争者', '，', '考虑', '到', '队伍', '目前', '的', '困境', '，', '更', '会', '给', '他', '加', '分', '不', '少', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', 'None', 'performance', 'None', 'he', 'become', '<MISSING>', '<MISSING>', 'more', '<MISSING>', 'None', '<MISSING>', ',', 'consideration', 'to', 'team', 'at present', 'None', 'None', ',', 'more', 'will', 'None', 'he', 'None', 'points', 'not', 'smaller', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'None', 'None', 'None', 'None', 'All-Star', 'All-Star', 'better', 'better', 'better', 'candidate', ',', 'given', 'given', 'team', 'None', 'None', 'context', 'None', 'especially', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None')
#
#
# Sentence: ('邓肯', '(', 'PER', '21.60', '22nd', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Tim Duncan', '(', 'PER', '21.60', '22nd', ')', ':')
#
#
# Sentence: ('我们', '很', '难', '将', '一', '名', '场', '均', '不到', '30', '分钟', '的', '球员', '送', '到', '洛杉矶', '，', '而', '邓肯', '或许', '更', '乐意', '在', '职业', '生涯', '末', '段', '能', '多多', '休息', '。')
#
# Predicted labels:
# -----------------
# ['we', 'None', 'difficult', 'will', 'a', 'None', 'None', 'None', '<MISSING>', '1930s', 'minutes', 'None', 'soccer player', 'sent', 'to', 'los angeles', ',', 'None', '<MISSING>', 'might', 'more', '<MISSING>', 'in', 'professional', 'career', '<MISSING>', 'None', 'None', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'hard', 'hard', 'to', 'a', 'a', 'game', 'per', 'fewer than', '30', 'minutes', 'None', 'player', 'send', 'to', 'the All-Star Game', ',', 'and', 'Duncan', 'might', 'be', 'interested in', 'at', 'career', 'career', 'point', 'point', 'None', 'resting', 'resting', '.')
#
#
# Sentence: ('但', '他', '在', '马', '刺', '攻击', '端', '的', '挡拆', '技巧', '仍然', '犀利', '无比', '，', '而', '队伍', '还', '指望', '他', '在', '季后赛', '中', '的', '稳定', '发挥', '。')
#
# Predicted labels:
# -----------------
# ['but', 'he', 'in', '<MISSING>', '<MISSING>', 'attacks', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'still', '<MISSING>', '<MISSING>', ',', 'None', 'team', 'also', '<MISSING>', 'he', 'in', 'playoffs', 'in', 'None', 'stabilization', 'played', '.']
#
# Actual labels:
# --------------
# ('But', 'his', 'None', 'None', 'None', 'None', 'None', 'None', 'pick-and-roll', 'skill', 'remains', 'crucial', 'crucial', ',', 'and', 'the team', 'None', 'lean on', 'his', 'in', 'the playoffs', 'in', 'None', 'None', 'None', '.')
#
#
# Sentence: ('同时', '，', '他', '在', '马刺队', '的', '防守', '端', '的', '中流砥柱', '作用', '依然', '无', '人', '撼动', '。')
#
# Predicted labels:
# -----------------
# ['at the same time', ',', 'he', 'in', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'None', '<MISSING>', 'role', 'None', 'no', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('And', 'And', 'he', 'None', 'the Spurs', 'of', 'defense', 'the back line', 'None', 'None', 'None', 'is', 'as solid as ever', 'as solid as ever', 'as solid as ever', '.')
#
#
# Sentence: ('保罗', '加索尔', '(', 'PER', '23.56', '11th', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Paul', 'Gasol', '(', 'PER', '23.56', '11th', ')', ':')
#
#
# Sentence: ('因为', '肌腱', '的', '酸痛', '，', '过去', '三', '周', '里', '保罗', '的', '表现', '有', '点', '退步', '，', '但', '他', '仍然', '是', '那个', '高', '效率', '低', '失误', '的', '进攻', '利器', '，', '在', '湖人', '的', '三角', '进攻', '中', '扮演', '着', '内线', '轴心', '。')
#
# Predicted labels:
# -----------------
# ['because', '<MISSING>', 'None', '<MISSING>', ',', 'past', 'three', 'week', 'None', '<MISSING>', 'None', 'performance', 'None', 'points', '<MISSING>', ',', 'but', 'he', 'still', 'is', 'then', 'high', '<MISSING>', 'lower', 'faults', 'None', '<MISSING>', '<MISSING>', ',', 'in', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'in', 'play pretend', 'None', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('because of', 'hamstring', 'None', 'sore', ',', 'the last', 'three', 'three weeks', 'over', "He's", 'None', 'None', 'a step', 'a step', 'back', ',', 'but', "he's", 'still', "he's", 'the', 'high-efficiency', 'high-efficiency', 'low-turnover', 'low-turnover', 'None', 'skill', 'machine', 'that', 'None', 'the Lakers', 'of', 'triangle', 'offense', 'None', 'serves as', 'None', 'None', 'the hub', '.')
#
#
# Sentence: ('考虑', '到', '这', '是', '一', '次', '洛杉矶', '当地', '的', '全明星', '，', '相信', '他', '会', '入选', '的', '。')
#
# Predicted labels:
# -----------------
# ['consideration', 'to', 'the', 'is', 'a', 'None', 'los angeles', 'local', 'None', '<MISSING>', ',', 'believe', 'he', 'will', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'with', 'None', 'None', 'Los Angeles', 'None', 'None', 'the game', ',', 'None', 'He', "'s", 'getting in', 'None', 'None')
#
#
# Sentence: ('布雷克', '格里芬', '(', 'PER', '22.89', '15th', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Blake', 'Griffin', '(', 'PER', '22.89', '15th', ')', ':')
#
#
# Sentence: ('虽然', '作为', '新秀', '入选', '正', '赛', '还是', '有', '些', '难度', '，', '但', '给力芬', '已经', '准备', '好', '参加', '扣篮', '大赛', '了', '，', '而且', '他', '的', '表现', '比', '大家', '预想', '的', '可', '要', '劲', '爆', '多', '了', '。')
#
# Predicted labels:
# -----------------
# ['although', 'as', '<MISSING>', '<MISSING>', 'is', 'None', 'still', 'None', 'some', '<MISSING>', ',', 'but', '<MISSING>', 'has', 'preparation', 'good', 'attending', '<MISSING>', '<MISSING>', 'None', ',', 'and', 'he', 'None', 'performance', 'than', 'it', '<MISSING>', 'None', 'can', 'None', '<MISSING>', 'None', 'over', 'None', '.']
#
# Actual labels:
# --------------
# ('None', 'as', 'a rookie', 'make it', 'None', 'None', 'None', 'tough', 'None', 'tough', ',', 'but', "Griffin's", 'already', 'None', 'None', 'for', 'dunk', 'contest', 'None', ',', 'and', "he's", 'None', 'None', 'None', 'most folks', 'realize', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('即使', '没有', '开发', '出', '什么', '低位', '和', '左手', '技术', '，', '他', '依然', '能', '取得', '52%', '的', '命中率', '，', '平均', '一', '场', '比赛', '8', '次', '走', '上', '罚球', '线', '的', '同时', '他', '也', '成为', '了', '联盟', '最', '顶尖', '的', '篮板', '手', '之一', '（', '无论', '是', '进攻', '还', '是', '防守', '篮板', '）', '。')
#
# Predicted labels:
# -----------------
# ['even', 'not', 'developed', 'exit', 'what', '<MISSING>', 'and', '<MISSING>', 'technology', ',', 'he', 'None', 'None', 'achieved', '<MISSING>', 'None', '<MISSING>', ',', 'average', 'a', 'None', 'None', '8', 'None', 'onto', 'at', '<MISSING>', '<MISSING>', 'None', 'at the same time', 'he', 'also', 'become', 'None', 'coalition', 'most', '<MISSING>', 'None', '<MISSING>', '<MISSING>', 'one of', '(', 'None', 'is', '<MISSING>', 'also', 'is', '<MISSING>', '<MISSING>', ')', '.']
#
# Actual labels:
# --------------
# ('None', 'without', 'None', 'None', 'None', 'refined post game', 'or', 'left hand', 'left hand', 'None', "he's", 'None', 'None', 'None', '52 percent', 'None', 'shooting', ',', 'per', 'per', 'per', 'game', 'eight', 'times', 'getting to', 'getting to', 'the line', 'the line', 'None', 'and', "he's", 'None', 'been', "he's", 'None', 'best', 'best', 'None', 'rebounders', 'rebounders', 'one of', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('防守', '端', '他', '的', '位置', '感', '还', '不', '是', '很', '强', '，', '仍', '需', '学习', '如何', '应对', '挡拆', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', 'he', 'None', '<MISSING>', '<MISSING>', 'also', 'not', 'is', 'None', 'quarterfinals', ',', 'still', 'necessary', 'learn', 'how', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('defense', 'None', "He's", 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', ', and', 'still', 'None', 'learning', 'to', 'guard', 'the pick-and-roll', '.')
#
#
# Sentence: ('但是', '保证', '篮板', '也', '是', '防守', '的', '重要', '一', '部分', '，', '而', '快', '船队', '也', '因此', '悄悄', '挤', '进', '了', '防守', '篮板', '前', '十', '位', '。')
#
# Predicted labels:
# -----------------
# ['however', 'vowing', '<MISSING>', 'also', 'is', '<MISSING>', 'None', 'important', 'a', 'some', ',', 'None', 'fastest', '<MISSING>', 'also', 'None', '<MISSING>', '<MISSING>', 'entered', 'None', '<MISSING>', '<MISSING>', 'former', '10', 'None', '.']
#
# Actual labels:
# --------------
# ('But', 'securing', 'rebounds', 'None', 'is', 'defense', 'of', 'big', 'a', 'part', ',', 'and', 'the Clippers', 'the Clippers', 'None', 'None', 'None', 'inching', 'inching', 'toward', 'defensive', 'rebounding', 'the top', 'the 10', '10', 'None')
#
#
# Sentence: ('榜单', '中', '算是', '一', '名', '超', '有', '人气', '的', '候选人', '了', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'in', 'will', 'a', 'None', '<MISSING>', 'None', '<MISSING>', 'None', 'candidate', 'None', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'A', 'A', 'None', 'None', 'None', 'None', 'candidate', 'None', '.')
#
#
# Sentence: ('艾尔', '杰佛森', '(', 'PER', '18.02', '，', '53rd', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '(', '<MISSING>', '<MISSING>', ',', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Al', 'Jefferson', '(', 'PER', '18.02', ',', '53rd', ')', ':')
#
#
# Sentence: ('完美', '地', '适应', '了', '新', '的', '队友', '和', '体系', '，', '但', '离', '全明星', '还', '稍', '有', '差距', '--', '尤其', '在', '犹他', '前锋线', '已经', '有', '了', '另', '一个', '强力', '竞争者', '的', '前提', '下', '。')
#
# Predicted labels:
# -----------------
# ['grand', 'None', 'suitable', 'None', 'new', 'None', '<MISSING>', 'and', 'system', ',', 'but', '<MISSING>', '<MISSING>', 'also', '<MISSING>', 'None', 'gap', 'None', 'especially', 'in', '<MISSING>', '<MISSING>', 'has', 'None', 'None', 'another', 'a', 'strong', '<MISSING>', 'None', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('nice', 'nice', 'adjusting to', 'None', 'None', 'None', 'team', 'and', 'system', ',', 'but', 'to', 'All-Star', 'None', 'None', 'not enough', 'not enough', '—', 'especially', 'when on', "Utah's", 'front line', 'None', "there's", 'None', 'a', 'a', 'superior', 'candidate', 'None', 'when', 'when', 'None')
#
#
# Sentence: ('凯文', '拉夫', '(', 'PER', '24.38', '5th', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Kevin', 'Love', '(', 'PER', '24.38', '5th', ')', ':')
#
#
# Sentence: ('他', '对', '挡拆', '的', '防守', '以及', '相关', '技术', '有点', '不', '尽如人意', '，', '而且', '当', '拉夫', '先生', '坐', '上', '板凳', '席', '时', '似乎', '森林狼', '的', '防守', '更', '严实', '些', '。')
#
# Predicted labels:
# -----------------
# ['he', 'None', '<MISSING>', 'None', '<MISSING>', 'and', 'sauce-related', 'technology', 'somewhat', 'not', '<MISSING>', ',', 'and', 'when', '<MISSING>', 'mr.', 'seated', 'at', '<MISSING>', '<MISSING>', 'None', 'seem', '<MISSING>', 'None', '<MISSING>', 'more', '<MISSING>', 'some', '.']
#
# Actual labels:
# --------------
# ('His', 'on', 'the pick-and-roll', 'None', 'defense', 'and', 'otherwise', 'None', 'is', 'a bit of a mess', 'a bit of a mess', ',', 'and', 'None', 'Love', 'Love', 'heads', 'heads to', 'the bench', 'None', 'None', 'None', 'the Wolves', 'None', 'None', 'much stingier', 'stingier', 'None', '.')
#
#
# Sentence: ('但', '这', '足', '以', '让', '人们', '无视', '他', '领导', '的', '队伍', '正', '在', '联盟', '垫底', '的', '事实', '吗', '？')
#
# Predicted labels:
# -----------------
# ['but', 'the', '<MISSING>', 'israeli', 'None', 'people', '<MISSING>', 'he', 'leader', 'None', 'team', 'is', 'in', 'coalition', '<MISSING>', 'None', 'facts', '<MISSING>', '?']
#
# Actual labels:
# --------------
# ('None', 'that', 'be enough', 'to', 'to', 'None', 'overcome', 'None', 'None', 'None', 'team', 'playing for', 'playing for', "league's", 'the worst', 'of', 'the stigma', '?', '?')
#
#
# Sentence: ('保罗', '米尔萨普', '(', 'PER', '21.36', '23rd', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Paul', 'Millsap', '(', 'PER', '21.36', '23rd', ')', ':')
#
#
# Sentence: ('爱神', '？', '阿德里尔奇', '？', '还', '是', '米尔萨普', '？')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '?', '<MISSING>', '?', 'also', 'is', '<MISSING>', '?']
#
# Actual labels:
# --------------
# ('Love', 'None', 'Aldridge', 'None', 'None', 'and', 'Millsap', '?')
#
#
# Sentence: ('恭喜', '你', '有', '得', '选', '了', '！')
#
# Predicted labels:
# -----------------
# ['<MISSING>', 'you', 'None', 'None', '<MISSING>', 'None', '<MISSING>']
#
# Actual labels:
# --------------
# ('Good luck', 'Good luck', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('虽然', '随着', '本', '季', '上场', '时间', '的', '增长', '，', '米尔萨普', '的', '进攻', '篮板', '并没有', '保持', '超高', '水准', '，')
#
# Predicted labels:
# -----------------
# ['although', 'with', 'None', 'quarter', '<MISSING>', 'time', 'None', 'up', ',', '<MISSING>', 'None', '<MISSING>', '<MISSING>', '<MISSING>', 'maintained', '<MISSING>', 'levels', ',']
#
# Actual labels:
# --------------
# ('None', 'as', 'None', 'None', 'None', 'minutes', 'None', 'have jumped', ',', 'Millsap', 'None', 'offensive', 'rebounder', "hasn't been able to", 'remain', 'off-the-charts', 'off-the-charts', ',')
#
#
# Sentence: ('但', '他', '55%', '的', '命中率', '与', '稳定', '的', '中', '投', '以及', '本', '季', '犹他', '内线', '防守', '核心', '的', '表现', '还', '是', '不容', '小视', '。')
#
# Predicted labels:
# -----------------
# ['but', 'he', '<MISSING>', 'None', '<MISSING>', 'and', 'stabilization', 'None', 'in', '<MISSING>', 'and', 'None', 'quarter', '<MISSING>', '<MISSING>', '<MISSING>', 'core', 'None', 'performance', 'also', 'is', '<MISSING>', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('but', 'he', '55 percent', 'None', "'s shooting", ',', 'stroking', 'None', 'the mid-range', 'jumper', 'and', 'this', 'season', "Utah's", 'interior', 'defender', 'defender', 'None', 'None', 'None', 'None', 'best', 'best', '.')
#
#
# Sentence: ('哥们', '，', '值得', '细细', '斟酌', '啊', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', ',', 'worth', '<MISSING>', '<MISSING>', 'None', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'Worth', 'None', 'None', 'None', '.')
#
#
# Sentence: ('内内', '(', 'PER', '20.73', '27th', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Nene', '(', 'PER', '20.73', '27th', ')', ':')
#
#
# Sentence: ('一', '名', '永远', '被', '人', '低估', '的', '球员', '，', '本', '季', '交出', '了', '生涯', '的', '代表作', '。')
#
# Predicted labels:
# -----------------
# ['a', 'None', 'never', 'None', 'None', '<MISSING>', 'None', 'soccer player', ',', 'None', 'quarter', '<MISSING>', 'None', 'career', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'Perpetually', 'underrated', 'None', 'underrated', 'None', 'None', 'and', 'season', 'season', 'having', 'having', 'career', 'of', 'the best', '.')
#
#
# Sentence: ('随着', '伤病', '一', '次次', '摧毁', '掘金', '的', '前锋', '线', '，', '巴西', '人', '在', '攻防', '两', '端', '承担', '了', '更', '多', '的', '责任', '，', '而且', '还', '能', '以', '63', '%', '的', '命中率', '领', '跑', '联盟', '。')
#
# Predicted labels:
# -----------------
# ['with', '<MISSING>', 'a', '<MISSING>', 'destruction', '<MISSING>', 'None', '<MISSING>', '<MISSING>', ',', 'brazil', 'None', 'in', '<MISSING>', 'two', '<MISSING>', 'sustain', 'None', 'more', 'over', 'None', 'responsibility', ',', 'and', 'also', 'None', 'israeli', '<MISSING>', '<MISSING>', 'None', '<MISSING>', '<MISSING>', '<MISSING>', 'coalition', '.']
#
# Actual labels:
# --------------
# ('as', 'injuries', 'have', 'have', 'decimated', 'Denver', 'None', 'front', 'line', ',', 'None', 'None', 'None', 'None', 'both ends', 'ends', 'carry', 'None', 'a huge', 'a huge', 'huge', 'burden', ',', 'and', "'s 's 's", "'s 's 's", 'in', '63', 'percent', 'percent', 'field-goal percentage', 'leading', 'leading', 'the league', '.')
#
#
# Sentence: ('哦', '对了', '，', '他', '在', '这', '份', '名单', '中', '可能', '以', '中锋', '身份', '出现', '哦', '。')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', ',', 'he', 'in', 'the', 'None', 'list', 'in', 'may', 'israeli', '<MISSING>', '<MISSING>', 'None', '<MISSING>', '.']
#
# Actual labels:
# --------------
# ('None', 'A small plus', ':', 'He', 'None', 'the', 'the', 'ballot', 'None', 'actually', 'as', 'a center', 'center', "'s listed", 'None', '.')
#
#
# Sentence: ('扎克', '兰道夫', '(', 'PER', '21.81', '20th', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Zach', 'Randolph', '(', 'PER', '21.81', '20th', ')', ':')
#
#
# Sentence: ('去年', '已经', '进', '过', '全明星', '了', '，', '今年', '的', '表现', '依然', '出色', '。')
#
# Predicted labels:
# -----------------
# ['last year', 'has', 'entered', 'None', '<MISSING>', 'None', ',', 'this year', 'None', 'performance', 'None', 'excellent', '.']
#
# Actual labels:
# --------------
# ('last year', 'None', 'made', 'made', 'it', 'None', ',', 'this season', 'None', "'s playing", 'at least', 'well', '.')
#
#
# Sentence: ('斯科拉', '(', 'PER', '19.20', '43rd', ')', ':')
#
# Predicted labels:
# -----------------
# ['<MISSING>', '(', '<MISSING>', '<MISSING>', '<MISSING>', ')', ':']
#
# Actual labels:
# --------------
# ('Luis Scola', '(', 'PER', '19.20', '43rd', ')', ':')

# %%
def accuracy(X, Y, model):
    correct = total_predictions = 0
    # The model.viterbi call in simplify_decoding will return None if the HMM
    # raises an error (for example, if a test sentence contains a word that
    # is out of vocabulary for the training set). Any exception counts the
    # full sentence as an error (which makes this a conservative estimate).
    for ch_sentence, en_sentence in zip(X, Y):
        try:
            most_likely_tags = simplify_decoding(ch_sentence, model)
            for p, t in zip(most_likely_tags, en_sentence):
                if(p.find(t)!=-1):
                    correct += 1
        except:
            pass
        total_predictions += len(ch_sentence)    
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(DataSet_ch, DataSet_en, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))
# Out:
# training accuracy mfc_model: 68.37%

# %%
mfc_testing_acc = accuracy(TestSet_ch, TestSet_en, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# testing accuracy mfc_model: 22.48%

# %% [markdown]
# # HMM

# %%
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution

# creat Hidden Markov Model for tanslator
hmm_model = HiddenMarkovModel(name="base-hmm-translator")

# %%
# create two list for all chinese words and enligh words (one to one map)

words_ch = []
words_en = []

for s_ch, s_en in zip(DataSet_ch, DataSet_en):
    for w_ch, w_en in zip(s_ch, s_en):
        words_ch.append(w_ch)
        words_en.append(w_en)
        
for i in range(10):
    print(words_ch[i]+'->'+words_en[i])
# Out:
# 教区->archdiocese
# 财务->finance
# 委员会->council
# 认为->thinks
# ,->that
# 这项->this
# 协议->agreement
# 可能->may
# 使得->force
# 波士顿->boston

# %%
len(words_ch),len(words_en)
# Out:
# (25206, 25206)

# %%
# First, let's see how many English words we have in our corpus
def unigram_counts(sequences):
    return Counter(sequences)

en_unigram = unigram_counts(words_en)
en_unigram
# Out:
# Counter({'archdiocese': 7,
#          'finance': 2,
#          'council': 3,
#          'thinks': 3,
#          'that': 158,
#          'this': 86,
#          'agreement': 14,
#          'may': 42,
#          'force': 2,
#          'boston': 6,
#          'catholic archdiocese': 1,
#          'bankruptcy': 3,
#          'None': 4259,
#          'as': 28,
#          'alleged': 5,
#          'sexual': 3,
#          'abuse': 3,
#          'of': 129,
#          'cases': 5,
#          'keep surfacing': 2,
#          ',': 668,
#          'and': 365,
#          '"': 310,
#          'since': 40,
#          'leading': 2,
#          'process': 7,
#          'started': 7,
#          'situation': 13,
#          'has': 36,
#          'dramatically': 6,
#          'changed': 1,
#          '.': 1009,
#          '66-year-old': 2,
#          'geoghan': 3,
#          'for': 36,
#          'in': 270,
#          '1991': 1,
#          'molestation': 1,
#          'a': 117,
#          '10-year-old': 2,
#          'boy': 2,
#          'recently': 14,
#          'was': 24,
#          'sentenced': 6,
#          '10': 15,
#          'years': 27,
#          'imprisonment': 1,
#          'defrocked': 1,
#          'priest': 4,
#          'also': 58,
#          'faces': 3,
#          'other': 32,
#          'criminal': 5,
#          'trials': 2,
#          'scores': 1,
#          'civil': 1,
#          'lawsuits': 1,
#          'us': 107,
#          'india': 43,
#          'mid-may': 6,
#          'conduct': 5,
#          '4 decades': 1,
#          'decades': 1,
#          'first': 33,
#          'joint': 20,
#          'military': 32,
#          'exercise': 7,
#          '(': 113,
#          'afp': 50,
#          'new delhi': 6,
#          ')': 111,
#          'united states': 54,
#          'will': 117,
#          '39': 1,
#          'world': 23,
#          'two': 41,
#          'largest': 15,
#          'democracies': 2,
#          'between': 17,
#          'cooperation': 18,
#          'mark': 1,
#          'milestone': 1,
#          'ministry of national defense': 3,
#          'said': 173,
#          'an': 28,
#          'elite': 1,
#          'indian': 12,
#          'paratroopers': 1,
#          'brigade': 1,
#          'with': 79,
#          'pacific': 1,
#          'command': 1,
#          'special forces': 1,
#          'near': 5,
#          'renowned': 1,
#          'taj': 1,
#          'mahal': 1,
#          'nations': 23,
#          'air forces': 1,
#          'provide': 7,
#          'support': 9,
#          'it': 19,
#          'be': 16,
#          'conducted': 5,
#          'many': 19,
#          'exercises': 2,
#          'during': 29,
#          'cold war': 1,
#          'era': 1,
#          'relations': 4,
#          'strained': 1,
#          'however': 35,
#          'sept. 11': 9,
#          'new york': 6,
#          'washington': 21,
#          'terrorist': 18,
#          'attacks': 16,
#          'been': 14,
#          'improved': 5,
#          'apart from': 6,
#          'navy': 2,
#          'indonesia': 3,
#          'malaysia': 9,
#          'malacca': 1,
#          'strait': 1,
#          'sea': 2,
#          'patrolling': 2,
#          'so as to prevent': 1,
#          'piracy': 1,
#          'acts': 1,
#          'recent years': 3,
#          'britain': 11,
#          'france': 9,
#          'japan': 26,
#          'spokesman': 6,
#          ':': 81,
#          'upcoming': 3,
#          'aims at': 1,
#          'further': 15,
#          'enhancing': 2,
#          'last time': 1,
#          'after': 76,
#          '1962': 1,
#          'china': 48,
#          'brief': 2,
#          'border': 14,
#          'war': 7,
#          'year': 9,
#          'last': 11,
#          'july': 3,
#          'about': 33,
#          '50': 5,
#          'policy makers': 2,
#          'makers': 3,
#          'visited': 2,
#          'while': 21,
#          'equal number': 2,
#          'people': 49,
#          'including': 27,
#          'vajpayee': 2,
#          'prime minister': 16,
#          'his': 40,
#          'national': 15,
#          'security': 20,
#          'team': 15,
#          'paid to': 1,
#          'visits': 2,
#          'december': 6,
#          'national parliament': 1,
#          'attack': 10,
#          'led': 3,
#          'pakistan': 25,
#          'tensions': 24,
#          'contacts': 1,
#          'increased': 9,
#          'diplomat': 1,
#          'national defense': 1,
#          'february': 3,
#          'decided': 9,
#          'partly': 1,
#          'wanted': 4,
#          'ease': 2,
#          'over': 47,
#          'relationship': 5,
#          'strengthening': 1,
#          'discomfort': 2,
#          'south african': 2,
#          'space': 14,
#          'tourist': 5,
#          'travel': 12,
#          'back to': 2,
#          'earth': 3,
#          'moscow': 6,
#          'shuttleworth': 8,
#          '5th': 1,
#          'he': 82,
#          'boarded': 2,
#          'russian': 16,
#          'spacecraft': 4,
#          'at': 79,
#          'taipei': 1,
#          'time': 12,
#          'a.m.': 1,
#          '7:31': 2,
#          'smoothly': 1,
#          'undocked': 1,
#          'international': 23,
#          'space station': 2,
#          '11:51': 2,
#          'successfully': 4,
#          'landed': 2,
#          'on': 94,
#          'central asia': 1,
#          'kazakhstan': 3,
#          'northwestern': 3,
#          'steppe': 1,
#          'is': 82,
#          'american': 6,
#          'tito': 4,
#          'in history': 1,
#          'second': 21,
#          'paying': 5,
#          'both': 15,
#          'paid': 4,
#          '20 million': 8,
#          'us dollars': 36,
#          'chance': 2,
#          'april': 10,
#          '25': 6,
#          'enter': 1,
#          'stayed': 2,
#          'days': 6,
#          'a series of': 9,
#          'medical': 3,
#          'biological': 3,
#          'science': 2,
#          'experiments': 2,
#          'together': 6,
#          'returning': 1,
#          'are': 23,
#          'him': 10,
#          'entered': 8,
#          'commander': 1,
#          'gidzenko': 1,
#          'italian': 3,
#          'engineer': 1,
#          'vittori': 1,
#          'terra firma': 1,
#          'partners': 1,
#          'be given': 1,
#          'physical': 2,
#          'exam': 1,
#          'before': 14,
#          'boarding': 1,
#          'helicopter': 1,
#          'fly to': 1,
#          'astana': 1,
#          'same day': 3,
#          'transferred': 1,
#          'to': 105,
#          'capital': 14,
#          'this year': 26,
#          'just': 8,
#          '28': 7,
#          'very': 8,
#          'wealthy': 1,
#          'computer': 3,
#          'information': 10,
#          'businessman': 2,
#          'trip': 4,
#          '10-day': 2,
#          'dream': 1,
#          'fulfilling': 1,
#          'human history': 1,
#          '60': 6,
#          'last year': 23,
#          'went on': 2,
#          'specialists': 1,
#          'earlier': 9,
#          'pointed out': 16,
#          'than': 10,
#          'more': 34,
#          'suitable': 2,
#          'a number of': 6,
#          'scientific': 2,
#          'aids': 2,
#          'pathogens': 1,
#          'study': 6,
#          'south africa': 1,
#          'drawn': 2,
#          'great': 13,
#          'publicity': 1,
#          'won the honor': 1,
#          'mandela': 1,
#          'from': 36,
#          'prison': 1,
#          'release': 2,
#          'most': 14,
#          'important': 7,
#          'news': 12,
#          'event': 3,
#          'government': 67,
#          'not impressed': 2,
#          'castro': 4,
#          'carter': 7,
#          'goodwill': 2,
#          'stance': 3,
#          'president': 76,
#          'bush': 35,
#          "'s": 44,
#          'administration': 8,
#          'cuban': 3,
#          'former': 11,
#          'extended': 2,
#          'communist': 2,
#          'island nation': 1,
#          'cuba': 13,
#          'making': 7,
#          'landmark': 1,
#          'visit': 16,
#          'expressed': 8,
#          'willingness': 1,
#          'allow': 4,
#          'freely': 1,
#          'meet': 10,
#          'dissidents': 2,
#          'all': 22,
#          'areas': 7,
#          'manufacturing': 3,
#          'biological weapon': 1,
#          'key components': 1,
#          'labs': 3,
#          'white house': 6,
#          'state department': 3,
#          'these': 16,
#          'proposals': 1,
#          'meaningless': 2,
#          'spokeswoman': 1,
#          'cassel': 1,
#          'private citizen': 1,
#          'visiting': 5,
#          'not': 44,
#          'sent': 4,
#          'inspect': 1,
#          'possible': 4,
#          'chemical': 3,
#          'or': 28,
#          'biological weapons': 2,
#          'facilities': 7,
#          'her': 16,
#          'remark': 2,
#          'seems': 2,
#          'echo': 1,
#          'commentators': 1,
#          'response': 5,
#          'neither nor': 3,
#          'delegation': 7,
#          'members': 14,
#          'proper': 2,
#          'inspection': 4,
#          'necessary': 5,
#          'background': 1,
#          'insisted': 3,
#          'officials': 19,
#          'briefed': 2,
#          'no': 17,
#          'mention': 1,
#          'concern': 2,
#          'plan': 7,
#          'but': 25,
#          'secretary of state': 4,
#          'powell': 5,
#          'indicated': 13,
#          'believe': 3,
#          'told': 8,
#          'abc': 3,
#          'network': 3,
#          'i': 21,
#          "n't": 7,
#          'know': 3,
#          'was given': 1,
#          'what': 4,
#          'briefing': 2,
#          'certain': 3,
#          'we': 36,
#          'reservation': 2,
#          'our': 14,
#          'belief': 3,
#          'possesses': 2,
#          'biological warfare': 1,
#          'research': 2,
#          'capabilities': 1,
#          'napster': 8,
#          'ceo': 2,
#          'hilbers': 4,
#          'resigns': 1,
#          'san francisco': 4,
#          'once': 9,
#          'all-popular': 1,
#          'free': 9,
#          'downloading': 1,
#          'music': 3,
#          'company': 27,
#          'chief executive': 2,
#          'resigned': 1,
#          'immediately': 4,
#          'effective': 7,
#          "'": 6,
#          'who': 10,
#          'replacement': 1,
#          'at present': 15,
#          'still': 18,
#          'unknown': 1,
#          'website': 4,
#          'ever since': 4,
#          'court': 15,
#          'ruled': 2,
#          'its': 7,
#          'service': 9,
#          'given rise to': 1,
#          'wide-spread': 2,
#          'copying': 2,
#          'remained': 3,
#          'closed': 6,
#          'today': 28,
#          'shut down': 2,
#          'websites': 1,
#          'taken its place': 1,
#          'california-based': 3,
#          'redwood': 1,
#          'city': 5,
#          'stated': 1,
#          'deeply': 2,
#          'regret': 1,
#          'yet': 18,
#          'funding': 1,
#          'solution': 3,
#          'would': 14,
#          'enable': 2,
#          'launch': 4,
#          'benefit': 3,
#          'artists': 2,
#          'users': 1,
#          'say': 2,
#          'coming': 2,
#          'week': 11,
#          'take': 17,
#          'measures': 12,
#          'cut': 3,
#          'expenses': 3,
#          'german': 1,
#          'media': 7,
#          'giant': 4,
#          'bertelsmann': 2,
#          'executive officer': 1,
#          'help': 13,
#          'struggling': 3,
#          'within': 7,
#          'ruling': 9,
#          'framework': 3,
#          'continue': 6,
#          'operation': 17,
#          'took': 3,
#          'position': 5,
#          'oecd': 1,
#          'ministers examine': 1,
#          'paris': 8,
#          'outlook': 1,
#          'economy': 18,
#          'major': 17,
#          'industrial nations': 1,
#          'senior': 7,
#          'ministers': 5,
#          '15th': 3,
#          '2-day': 4,
#          'meeting': 17,
#          'they': 25,
#          'examine': 1,
#          'promising': 2,
#          'future': 3,
#          'as well as': 13,
#          'confront': 1,
#          'europe': 7,
#          'by': 47,
#          'trade': 24,
#          'dispute': 11,
#          'caused': 10,
#          'division': 1,
#          'looming': 1,
#          'economic': 25,
#          'development': 14,
#          'organization': 7,
#          '30': 5,
#          'member nations': 2,
#          'representatives': 3,
#          'rich': 2,
#          'poor': 11,
#          'abridge': 1,
#          'gap': 1,
#          'arising': 2,
#          'conflict': 7,
#          'macroeconomics': 2,
#          'discussion': 5,
#          'european union': 1,
#          'friction': 1,
#          'escalating': 2,
#          'eclipsed': 1,
#          'european': 8,
#          'leaders': 16,
#          '13th': 2,
#          'signed': 7,
#          'bill': 4,
#          'indignation': 1,
#          'next': 3,
#          'decade': 8,
#          'farmers': 1,
#          'increase': 17,
#          '70%': 3,
#          'subsidies': 8,
#          'eu': 28,
#          'think': 6,
#          'the': 79,
#          'violates': 1,
#          'november': 3,
#          'qatar': 2,
#          'doha': 3,
#          'held': 28,
#          'wto': 23,
#          'ministerial': 2,
#          'conference': 14,
#          'terminating': 1,
#          'export': 7,
#          'made': 10,
#          'promise': 2,
#          'belgian': 1,
#          'verhofstadt': 1,
#          'prior to': 14,
#          'opening ceremony': 1,
#          'forum': 3,
#          'talk with eloquence': 1,
#          'market': 25,
#          'liberalization': 2,
#          'fail to': 2,
#          'implement': 6,
#          'hypocritical': 1,
#          'mid-term': 2,
#          'election': 5,
#          'promote': 6,
#          'efforts': 5,
#          'slow down': 4,
#          'economists': 2,
#          'analysts': 5,
#          'woo': 1,
#          'constituencies': 1,
#          'voters': 1,
#          'additional imposed': 1,
#          'barriers': 3,
#          'ever': 2,
#          'ongoing': 1,
#          'global': 7,
#          'think tank': 2,
#          'economics': 2,
#          'institute': 5,
#          'economist': 2,
#          'schott': 3,
#          'determined': 3,
#          'put': 4,
#          'political': 16,
#          'goal': 4,
#          'promoting': 3,
#          'sound': 2,
#          'above': 15,
#          'succumbing': 1,
#          'steel': 11,
#          'industry': 2,
#          'labor union': 2,
#          'pressures': 1,
#          'suppliers': 2,
#          'russia': 13,
#          'brazil': 5,
#          'products': 10,
#          'levies': 1,
#          'high': 15,
#          'as as': 6,
#          '30%': 2,
#          'tariff': 2,
#          'in addition': 13,
#          'used': 2,
#          'building material': 1,
#          'canada': 7,
#          'certain kind': 1,
#          'lumber': 2,
#          'imposes': 1,
#          '27%': 1,
#          'anti-dumping': 1,
#          'ground': 3,
#          'canadian': 1,
#          'constituted': 1,
#          'dumping': 1,
#          'what aggravating': 1,
#          'federal': 6,
#          'promulgated': 2,
#          'farm': 5,
#          'farm products': 6,
#          'nearly': 8,
#          '80%': 3,
#          'grossly': 1,
#          'violating': 2,
#          'negotiations': 3,
#          'insisted on': 1,
#          'so as to': 8,
#          'facilitate': 2,
#          'access into': 1,
#          'markets': 4,
#          'correspondingly': 2,
#          'under': 17,
#          'developed': 4,
#          'easier': 4,
#          'their': 18,
#          'services': 4,
#          'damage': 3,
#          'far': 3,
#          'surpassed': 2,
#          'imposing': 1,
#          'tariffs imports': 1,
#          'measure': 1,
#          'brought': 2,
#          'handling': 2,
#          'warnings': 2,
#          'defend': 2,
#          'scrambled': 1,
#          'reports': 7,
#          'included': 1,
#          'osama bin laden': 1,
#          'terrorists': 8,
#          'might': 3,
#          'hijack': 2,
#          'commercial airlines': 1,
#          'secretary of defense': 1,
#          'rumsfeld': 7,
#          'nbc': 3,
#          'show': 9,
#          'did': 1,
#          'should': 10,
#          'namely': 2,
#          'go all out': 1,
#          'pursue': 1,
#          'organizations': 1,
#          'do everything in his power': 1,
#          'deal': 5,
#          'harbor': 1,
#          'at any time': 1,
#          'any': 11,
#          'available': 3,
#          'means': 1,
#          'at all times': 2,
#          'protect': 1,
#          'locations': 1,
#          'practically': 1,
#          'impossible': 2,
#          'vice': 11,
#          'cheney': 1,
#          'last night': 4,
#          'on the other hand': 2,
#          'warned': 5,
#          'democrats': 2,
#          'extra': 9,
#          'cautious': 1,
#          'incendiary': 1,
#          'remarks': 1,
#          'seek': 5,
#          'interests': 3,
#          'such as': 21,
#          'advance': 1,
#          'received': 3,
#          'have': 27,
#          'could': 4,
#          'prevented': 1,
#          'bloody': 1,
#          'night': 4,
#          'admitted': 5,
#          'had': 8,
#          'warning': 2,
#          'commercial airplanes': 1,
#          'came under': 1,
#          'fire': 2,
#          'british airways': 7,
#          'posts': 1,
#          '15': 7,
#          'annual': 10,
#          'loss': 6,
#          'london': 9,
#          'as by': 1,
#          'british': 17,
#          'airways': 2,
#          'reported': 9,
#          'although': 10,
#          'amount': 1,
#          'expected': 10,
#          'smaller': 3,
#          'posted': 1,
#          'ago': 9,
#          'privatization': 2,
#          'march': 9,
#          'end': 8,
#          'ended': 3,
#          'previous': 5,
#          'pre-tax': 1,
#          '200': 4,
#          'million': 5,
#          '320 million': 1,
#          'euros': 6,
#          '290 million': 1,
#          'preceding': 1,
#          'restated': 2,
#          'profit': 1,
#          '150 million': 3,
#          'alone': 4,
#          'fourth': 4,
#          'quarter': 9,
#          'lost': 4,
#          '85 million': 1,
#          '65 million': 1,
#          'state-owned': 4,
#          'performance': 5,
#          'blamed': 1,
#          'slowdown': 1,
#          'kept': 1,
#          'foreign': 12,
#          'tourists': 4,
#          'kept away from': 1,
#          'foot-and-mouth disease': 1,
#          'dividend': 1,
#          'thus': 1,
#          'scrapped': 1,
#          'airline': 4,
#          'eddington': 1,
#          'remain': 3,
#          'weak': 1,
#          'taken': 8,
#          'quick': 2,
#          'decisive': 1,
#          'actions': 15,
#          'shown': 3,
#          'business': 7,
#          'return': 1,
#          'acceptable': 4,
#          'profitability': 1,
#          'levels': 1,
#          'result': 3,
#          'expectation': 1,
#          'lose': 2,
#          'even': 11,
#          'stock market': 2,
#          'early trading session': 1,
#          'ba': 1,
#          'shares': 6,
#          'rose': 6,
#          '2.6%': 2,
#          '241.75': 1,
#          'pence': 2,
#          'price': 13,
#          'september 11': 1,
#          'shortly before': 1,
#          'down': 5,
#          '8%': 1,
#          ';': 18,
#          'compared': 1,
#          '1997': 3,
#          'highest': 7,
#          '760': 1,
#          'almost': 4,
#          'holds': 4,
#          'elections': 5,
#          'lift': 3,
#          'embargo': 4,
#          'only if': 1,
#          'can': 24,
#          'proved': 2,
#          'fair': 3,
#          'promotes': 3,
#          'system': 8,
#          'reform': 3,
#          '41-year-old': 2,
#          'against': 8,
#          'speech': 7,
#          'only': 12,
#          'till': 2,
#          'then': 5,
#          'congress': 3,
#          'work': 3,
#          'remove': 3,
#          'jimmy carter': 1,
#          'went to': 1,
#          'americas': 1,
#          'country': 7,
#          'called for': 5,
#          'returned': 3,
#          'merely': 2,
#          '48': 1,
#          'hours': 5,
#          'most recent': 5,
#          'proposed': 5,
#          'step up': 2,
#          'humanitarian': 2,
#          'assistance': 9,
#          'through': 10,
#          'non-governmental': 1,
#          'agencies': 6,
#          'directly': 2,
#          'reach': 11,
#          'agreements': 4,
#          'resuming': 2,
#          'countries': 17,
#          'direct': 2,
#          'mail service': 1,
#          'hold': 13,
#          'so far': 6,
#          'consistently': 1,
#          'rejected': 1,
#          'india-pakistan': 11,
#          'overnight': 1,
#          'shelling': 6,
#          'death': 17,
#          'toll': 8,
#          'jammu': 3,
#          'police': 13,
#          'disputed': 4,
#          'kashmir': 7,
#          'area': 14,
#          'left': 3,
#          'one': 18,
#          'soldier': 5,
#          'three': 32,
#          'civilians': 3,
#          'dead': 7,
#          'children': 15,
#          'took place': 4,
#          'southern': 9,
#          'winter capital': 1,
#          'west of': 1,
#          '75': 1,
#          'km': 4,
#          'baramulla': 1,
#          'sources': 8,
#          'pakistani': 10,
#          'throughout the night': 1,
#          'bombarded': 2,
#          'heavy': 2,
#          'mortar fire': 1,
#          'rocket-propelled': 2,
#          'grenades': 1,
#          'mortar': 1,
#          'hit': 5,
#          'residential structure': 1,
#          'killing': 10,
#          'adult': 1,
#          'same': 6,
#          'cross-border': 3,
#          'died': 5,
#          'poonch': 1,
#          'along': 2,
#          'separating': 1,
#          'territories': 2,
#          'control': 3,
#          'demarcation': 1,
#          'throughout night': 1,
#          'came': 2,
#          'heavy artillery': 1,
#          'fires': 1,
#          'in the meantime': 3,
#          'official': 22,
#          'this morning': 1,
#          'resumed': 3,
#          'pakistan-controlled': 2,
#          'pakistanis': 1,
#          'rise': 6,
#          '12': 8,
#          'irish': 7,
#          'soccer team': 3,
#          'captain': 3,
#          'keane': 3,
#          'announces': 5,
#          'world cup': 21,
#          'retire': 2,
#          'dublin': 2,
#          'heart and soul': 1,
#          'roy keane': 1,
#          'announced': 17,
#          'whereas': 1,
#          'yesterday': 4,
#          'threatened': 5,
#          'quit': 3,
#          'representative team': 3,
#          'manchester': 1,
#          'united': 1,
#          'midfielder': 2,
#          'tv station': 3,
#          'emotional': 1,
#          'interview': 6,
#          'announcement': 6,
#          'lashed': 2,
#          'ireland': 3,
#          'preparation': 3,
#          'not making adequate': 1,
#          'currently': 8,
#          'pacific ocean': 1,
#          'saipan': 1,
#          'training': 8,
#          'this week': 4,
#          'a few': 6,
#          'later': 2,
#          'again': 13,
#          'offered': 4,
#          'stay': 2,
#          'throwing': 2,
#          'into': 6,
#          'confusion': 2,
#          'real': 9,
#          'reason': 2,
#          'remains': 1,
#          'mystery': 1,
#          'failing to make appropriate': 1,
#          'deserves': 2,
#          'blame': 1,
#          'come over': 1,
#          'here': 9,
#          'play': 6,
#          'well': 3,
#          'soccer': 9,
#          'hope': 10,
#          'around': 4,
#          'too': 2,
#          'want': 7,
#          'if': 20,
#          'common': 5,
#          'there': 2,
#          'point': 1,
#          'furthermore': 1,
#          'going on': 1,
#          'regarding': 3,
#          'some': 12,
#          'issues': 3,
#          'my': 7,
#          'head': 3,
#          "'d like": 1,
#          'bang': 1,
#          'wall': 1,
#          'all kinds of': 3,
#          'problems': 7,
#          'iceberg': 1,
#          'a tip': 1,
#          'you': 13,
#          'seen': 4,
#          'pitch': 2,
#          "'m": 1,
#          'self-conceited': 1,
#          'arrangements': 2,
#          'leaving': 1,
#          'airport': 7,
#          'when': 23,
#          'getting through the customs': 1,
#          'tons': 6,
#          'arrives': 1,
#          'historic': 3,
#          'summit': 14,
#          'arrived': 9,
#          'reduction': 3,
#          'arms': 4,
#          'new': 27,
#          'were': 12,
#          'bitter foes': 1,
#          'shaping': 1,
#          '21st-century': 2,
#          'partnership': 6,
#          'grand': 3,
#          'preparing': 2,
#          'entire': 3,
#          'stepped up': 2,
#          'newspaper': 1,
#          'cautions': 1,
#          'muscovites': 2,
#          'watch': 2,
#          'secret': 3,
#          'snipers': 1,
#          'liberal': 1,
#          'state duma': 2,
#          'member': 4,
#          'khakamada': 1,
#          'ms.': 2,
#          'optimistic': 1,
#          'not only': 5,
#          'because of': 4,
#          'expect': 3,
#          'sign': 8,
#          'documents': 2,
#          'mutual': 3,
#          'finally': 4,
#          'unfolding': 1,
#          'she': 15,
#          ...})

# %%
# see which english word followed by other english words
def bigram_counts(sequences):
    return Counter(sequences)
# !!
words_en_bi = [(words_en[i], words_en[i+1]) for i in range(0,len(words_en)-2,1)]
en_bigram = bigram_counts(words_en_bi)
en_bigram
# Out:
# Counter({('archdiocese', 'finance'): 2,
#          ('finance', 'council'): 2,
#          ('council', 'thinks'): 1,
#          ('thinks', 'that'): 3,
#          ('that', 'this'): 2,
#          ('this', 'agreement'): 1,
#          ('agreement', 'may'): 1,
#          ('may', 'force'): 1,
#          ('force', 'boston'): 1,
#          ('boston', 'catholic archdiocese'): 1,
#          ('catholic archdiocese', 'bankruptcy'): 1,
#          ('bankruptcy', 'None'): 2,
#          ('None', 'as'): 3,
#          ('as', 'alleged'): 1,
#          ('alleged', 'None'): 3,
#          ('None', 'sexual'): 1,
#          ('sexual', 'abuse'): 2,
#          ('abuse', 'of'): 1,
#          ('of', 'cases'): 1,
#          ('cases', 'keep surfacing'): 1,
#          ('keep surfacing', 'keep surfacing'): 1,
#          ('keep surfacing', ','): 1,
#          (',', 'and'): 6,
#          ('and', '"'): 1,
#          ('"', 'since'): 1,
#          ('since', 'leading'): 1,
#          ('leading', 'agreement'): 1,
#          ('agreement', 'None'): 2,
#          ('None', 'process'): 2,
#          ('process', 'started'): 1,
#          ('started', 'since'): 1,
#          ('since', 'situation'): 1,
#          ('situation', 'has'): 1,
#          ('has', 'None'): 2,
#          ('None', 'dramatically'): 1,
#          ('dramatically', 'dramatically'): 1,
#          ('dramatically', 'changed'): 1,
#          ('changed', '"'): 1,
#          ('"', '.'): 32,
#          ('.', '66-year-old'): 1,
#          ('66-year-old', '66-year-old'): 1,
#          ('66-year-old', 'None'): 1,
#          ('None', 'geoghan'): 2,
#          ('geoghan', 'for'): 1,
#          ('for', 'in'): 2,
#          ('in', '1991'): 1,
#          ('1991', 'sexual'): 1,
#          ('sexual', 'molestation'): 1,
#          ('molestation', 'a'): 1,
#          ('a', 'None'): 59,
#          ('None', '10-year-old'): 1,
#          ('10-year-old', '10-year-old'): 1,
#          ('10-year-old', 'boy'): 1,
#          ('boy', 'None'): 1,
#          ('None', 'recently'): 3,
#          ('recently', 'was'): 1,
#          ('was', 'sentenced'): 1,
#          ('sentenced', '10'): 1,
#          ('10', 'years'): 5,
#          ('years', 'imprisonment'): 1,
#          ('imprisonment', '.'): 1,
#          ('.', 'None'): 68,
#          ('None', 'None'): 722,
#          ('None', 'defrocked'): 1,
#          ('defrocked', 'priest'): 1,
#          ('priest', 'None'): 1,
#          ('None', 'also'): 6,
#          ('also', 'faces'): 1,
#          ('faces', 'other'): 1,
#          ('other', 'criminal'): 2,
#          ('criminal', 'trials'): 1,
#          ('trials', 'and'): 1,
#          ('and', 'scores'): 1,
#          ('scores', 'None'): 1,
#          ('None', 'civil'): 1,
#          ('civil', 'lawsuits'): 1,
#          ('lawsuits', '.'): 1,
#          ('.', 'us'): 19,
#          ('us', 'india'): 1,
#          ('india', 'mid-may'): 1,
#          ('mid-may', 'mid-may'): 3,
#          ('mid-may', 'None'): 2,
#          ('None', 'conduct'): 2,
#          ('conduct', '4 decades'): 1,
#          ('4 decades', 'decades'): 1,
#          ('decades', 'None'): 1,
#          ('None', 'first'): 9,
#          ('first', 'joint'): 2,
#          ('joint', 'military'): 5,
#          ('military', 'exercise'): 5,
#          ('exercise', '('): 1,
#          ('(', 'afp'): 48,
#          ('afp', 'new delhi'): 1,
#          ('new delhi', 'None'): 1,
#          ('None', ')'): 48,
#          (')', 'india'): 1,
#          ('india', 'and'): 8,
#          ('and', 'united states'): 2,
#          ('united states', 'will'): 3,
#          ('will', 'conduct'): 1,
#          ('conduct', '39'): 1,
#          ('39', 'years'): 1,
#          ('years', 'None'): 12,
#          ('exercise', 'None'): 4,
#          ('None', 'world'): 4,
#          ('world', 'in'): 2,
#          ('in', 'two'): 2,
#          ('two', 'None'): 22,
#          ('None', 'largest'): 2,
#          ('largest', 'largest'): 7,
#          ('largest', 'None'): 5,
#          ('None', 'democracies'): 1,
#          ('democracies', 'democracies'): 1,
#          ('democracies', 'between'): 1,
#          ('between', 'None'): 10,
#          ('None', 'cooperation'): 3,
#          ('cooperation', 'None'): 11,
#          ('None', 'mark'): 1,
#          ('mark', 'milestone'): 1,
#          ('milestone', '.'): 1,
#          ('.', 'ministry of national defense'): 2,
#          ('ministry of national defense', 'said'): 2,
#          ('said', 'that'): 64,
#          ('that', 'an'): 1,
#          ('an', 'None'): 18,
#          ('None', 'elite'): 1,
#          ('elite', 'None'): 1,
#          ('None', 'indian'): 2,
#          ('indian', 'paratroopers'): 1,
#          ('paratroopers', 'brigade'): 1,
#          ('brigade', 'mid-may'): 1,
#          ('mid-may', 'will'): 1,
#          ('will', 'with'): 8,
#          ('with', 'pacific'): 1,
#          ('pacific', 'us'): 1,
#          ('us', 'command'): 1,
#          ('command', 'of'): 1,
#          ('of', 'special forces'): 1,
#          ('special forces', 'near'): 1,
#          ('near', 'renowned'): 1,
#          ('renowned', 'None'): 1,
#          ('None', 'taj'): 1,
#          ('taj', 'mahal'): 1,
#          ('mahal', 'near'): 1,
#          ('near', 'conduct'): 1,
#          ('conduct', 'joint'): 1,
#          ('exercise', '.'): 1,
#          ('.', 'two'): 5,
#          ('two', 'nations'): 3,
#          ('nations', 'None'): 4,
#          ('None', 'air forces'): 1,
#          ('air forces', 'will'): 1,
#          ('will', 'provide'): 1,
#          ('provide', 'support'): 1,
#          ('support', '.'): 4,
#          ('said', 'None'): 35,
#          ('None', 'it'): 4,
#          ('it', 'be'): 1,
#          ('be', 'two'): 1,
#          ('nations', 'will'): 1,
#          ('will', 'conducted'): 1,
#          ('conducted', 'None'): 2,
#          ('None', 'many'): 8,
#          ('many', 'military'): 1,
#          ('military', 'exercises'): 1,
#          ('exercises', 'None'): 1,
#          ('None', 'of'): 9,
#          ('of', 'first'): 1,
#          ('first', 'None'): 9,
#          ('None', '.'): 96,
#          ('.', 'united states'): 1,
#          ('united states', 'india'): 2,
#          ('india', 'None'): 10,
#          ('None', 'during'): 3,
#          ('during', 'cold war'): 1,
#          ('cold war', 'era'): 1,
#          ('era', 'relations'): 1,
#          ('relations', 'strained'): 1,
#          ('strained', '.'): 1,
#          ('.', 'however'): 29,
#          ('however', 'since'): 1,
#          ('since', 'sept. 11'): 1,
#          ('sept. 11', 'new york'): 1,
#          ('new york', 'and'): 1,
#          ('and', 'washington'): 1,
#          ('washington', 'None'): 13,
#          ('None', 'terrorist'): 6,
#          ('terrorist', 'attacks'): 11,
#          ('attacks', 'None'): 8,
#          ('None', 'since'): 1,
#          ('since', 'None'): 9,
#          ('None', 'has'): 3,
#          ('has', 'been'): 3,
#          ('been', 'dramatically'): 1,
#          ('dramatically', 'improved'): 1,
#          ('improved', '.'): 2,
#          ('.', 'apart from'): 2,
#          ('apart from', 'with'): 1,
#          ('with', 'us'): 4,
#          ('us', 'navy'): 2,
#          ('navy', 'in'): 1,
#          ('in', 'indonesia'): 1,
#          ('indonesia', 'and'): 1,
#          ('and', 'malaysia'): 2,
#          ('malaysia', 'between'): 1,
#          ('None', 'malacca'): 1,
#          ('malacca', 'strait'): 1,
#          ('strait', 'None'): 1,
#          ('None', 'sea'): 1,
#          ('sea', 'patrolling'): 1,
#          ('patrolling', 'so as to prevent'): 1,
#          ('so as to prevent', 'None'): 1,
#          ('None', 'piracy'): 1,
#          ('piracy', 'acts'): 1,
#          ('acts', 'apart from'): 1,
#          ('apart from', ','): 3,
#          (',', 'india'): 3,
#          ('india', 'recent years'): 1,
#          ('recent years', 'has'): 1,
#          ('has', 'with'): 2,
#          ('with', 'britain'): 1,
#          ('britain', ','): 2,
#          (',', 'france'): 6,
#          ('france', 'and'): 1,
#          ('and', 'japan'): 6,
#          ('japan', 'conducted'): 1,
#          ('conducted', 'joint'): 2,
#          ('joint', 'exercises'): 1,
#          ('exercises', '.'): 1,
#          ('.', 'india'): 3,
#          ('india', 'ministry of national defense'): 1,
#          ('ministry of national defense', 'spokesman'): 1,
#          ('spokesman', 'said'): 2,
#          ('said', ':'): 54,
#          (':', '"'): 71,
#          ('"', 'upcoming'): 1,
#          ('upcoming', 'upcoming'): 1,
#          ('upcoming', 'None'): 1,
#          ('None', 'exercise'): 2,
#          ('exercise', 'aims at'): 1,
#          ('aims at', 'further'): 1,
#          ('further', 'enhancing'): 1,
#          ('enhancing', 'india'): 1,
#          ('united states', 'None'): 11,
#          ('None', 'military'): 5,
#          ('military', 'cooperation'): 1,
#          ('.', '"'): 73,
#          ('"', 'last time'): 1,
#          ('last time', 'india'): 1,
#          ('india', 'with'): 1,
#          ('with', 'united states'): 5,
#          ('united states', 'conducted'): 1,
#          ('None', 'was'): 7,
#          ('was', 'after'): 1,
#          ('after', '1962'): 1,
#          ('1962', 'india'): 1,
#          ('and', 'china'): 3,
#          ('china', 'None'): 3,
#          ('None', 'brief'): 1,
#          ('brief', 'border'): 1,
#          ('border', 'war'): 1,
#          ('war', 'after'): 1,
#          ('after', 'a'): 3,
#          ('a', 'year'): 4,
#          ('year', '.'): 1,
#          ('.', 'since'): 7,
#          ('since', 'last'): 1,
#          ('last', 'july'): 1,
#          ('july', 'since'): 1,
#          ('since', ','): 5,
#          (',', 'about'): 4,
#          ('about', 'None'): 8,
#          ('None', '50'): 2,
#          ('50', 'None'): 2,
#          ('None', 'us'): 14,
#          ('us', 'policy makers'): 1,
#          ('policy makers', 'makers'): 2,
#          ('makers', 'visited'): 1,
#          ('visited', 'None'): 2,
#          ('None', 'india'): 9,
#          ('None', 'while'): 13,
#          ('while', 'india'): 1,
#          ('None', 'equal number'): 1,
#          ('equal number', 'equal number'): 1,
#          ('equal number', 'people'): 1,
#          ('people', ','): 2,
#          (',', 'including'): 10,
#          ('including', 'vajpayee'): 1,
#          ('vajpayee', 'prime minister'): 1,
#          ('prime minister', 'and'): 2,
#          ('and', 'his'): 2,
#          ('his', 'his'): 15,
#          ('his', 'national'): 1,
#          ('national', 'security'): 6,
#          ('security', 'team'): 1,
#          ('team', 'None'): 4,
#          ('None', ','): 51,
#          (',', 'paid to'): 1,
#          ('paid to', 'washington'): 1,
#          ('washington', 'visits'): 1,
#          ('visits', '.'): 1,
#          ('.', 'after'): 9,
#          ('after', 'sept. 11'): 1,
#          ('sept. 11', 'terrorist'): 4,
#          ('and', 'last'): 1,
#          ('last', 'december'): 1,
#          ('december', 'new delhi'): 1,
#          ('new delhi', 'national parliament'): 1,
#          ('national parliament', 'None'): 1,
#          ('None', 'attack'): 6,
#          ('attack', 'led'): 1,
#          ('led', 'india'): 1,
#          ('and', 'pakistan'): 4,
#          ('pakistan', 'None'): 4,
#          ('military', 'tensions'): 1,
#          ('tensions', 'tensions'): 11,
#          ('tensions', 'after'): 1,
#          ('after', ','): 15,
#          (',', 'united states'): 3,
#          ('india', 'between'): 3,
#          ('None', 'contacts'): 1,
#          ('contacts', 'increased'): 1,
#          ('increased', '.'): 3,
#          ('.', 'diplomat'): 1,
#          ('diplomat', 'said'): 1,
#          ('that', 'united states'): 4,
#          ('None', 'national defense'): 1,
#          ('national defense', 'policy makers'): 1,
#          ('makers', 'in'): 1,
#          ('in', 'february'): 1,
#          ('february', 'in'): 1,
#          ('in', 'decided'): 1,
#          ('decided', 'mid-may'): 1,
#          ('None', 'partly'): 1,
#          ('partly', 'also'): 1,
#          ('also', 'wanted'): 1,
#          ('wanted', 'ease'): 1,
#          ('ease', 'new delhi'): 1,
#          ('new delhi', 'over'): 1,
#          ('over', 'united states'): 1,
#          ('united states', 'and'): 4,
#          ('pakistan', 'relationship'): 1,
#          ('relationship', 'strengthening'): 1,
#          ('strengthening', 'None'): 1,
#          ('None', 'discomfort'): 1,
#          ('discomfort', 'discomfort'): 1,
#          ('discomfort', '.'): 1,
#          ('.', 'south african'): 1,
#          ('south african', 'space'): 2,
#          ('space', 'tourist'): 4,
#          ('tourist', 'None'): 1,
#          ('None', 'space'): 6,
#          ('space', 'None'): 7,
#          ('None', 'travel'): 5,
#          ('travel', 'back to'): 1,
#          ('back to', 'earth'): 2,
#          ('earth', '('): 1,
#          ('afp', 'moscow'): 2,
#          ('moscow', 'None'): 3,
#          (')', 'south african'): 1,
#          ('tourist', 'shuttleworth'): 1,
#          ('shuttleworth', '5th'): 1,
#          ('5th', 'back to'): 1,
#          ('earth', '.'): 1,
#          ('.', 'he'): 40,
#          ('he', 'None'): 8,
#          ('None', 'boarded'): 1,
#          ('boarded', 'None'): 1,
#          ('None', 'russian'): 8,
#          ('russian', 'spacecraft'): 3,
#          ('spacecraft', 'at'): 1,
#          ('at', 'taipei'): 1,
#          ('taipei', 'time'): 1,
#          ('time', 'a.m.'): 1,
#          ('a.m.', '7:31'): 1,
#          ('7:31', '7:31'): 1,
#          ('7:31', 'smoothly'): 1,
#          ('smoothly', 'undocked'): 1,
#          ('undocked', 'international'): 1,
#          ('international', 'space station'): 2,
#          ('space station', 'None'): 1,
#          ('None', 'and'): 54,
#          ('and', 'at'): 1,
#          ('at', '11:51'): 1,
#          ('11:51', '11:51'): 1,
#          ('11:51', 'successfully'): 1,
#          ('successfully', 'landed'): 1,
#          ('landed', 'on'): 1,
#          ('on', 'central asia'): 1,
#          ('central asia', 'kazakhstan'): 1,
#          ('kazakhstan', 'northwestern'): 1,
#          ('northwestern', 'None'): 1,
#          ('None', 'steppe'): 1,
#          ('steppe', '.'): 1,
#          ('.', 'shuttleworth'): 3,
#          ('shuttleworth', 'is'): 2,
#          ('is', 'after'): 1,
#          ('after', 'american'): 1,
#          ('american', 'None'): 1,
#          ('None', 'tito'): 1,
#          ('tito', 'after'): 1,
#          ('after', 'None'): 10,
#          ('None', 'in history'): 1,
#          ('in history', 'second'): 1,
#          ('second', 'None'): 7,
#          ('None', 'paying'): 2,
#          ('paying', 'None'): 3,
#          ('tourist', '.'): 1,
#          ('he', 'and'): 1,
#          ('and', 'tito'): 1,
#          ('tito', 'both'): 1,
#          ('both', 'paid'): 1,
#          ('paid', '20 million'): 2,
#          ('20 million', 'us dollars'): 6,
#          ('us dollars', 'None'): 7,
#          ('None', 'chance'): 1,
#          ('chance', 'None'): 1,
#          ('travel', '.'): 2,
#          ('shuttleworth', 'None'): 2,
#          ('None', 'on'): 20,
#          ('on', 'april'): 1,
#          ('april', '25'): 1,
#          ('25', 'boarded'): 1,
#          ('boarded', 'russian'): 1,
#          ('spacecraft', 'enter'): 1,
#          ('enter', 'space'): 1,
#          ('None', 'stayed'): 2,
#          ('stayed', 'None'): 2,
#          ('None', '10'): 2,
#          ('10', 'days'): 1,
#          ('days', 'None'): 2,
#          ('conduct', 'a series of'): 2,
#          ('a series of', 'medical'): 1,
#          ('medical', 'and'): 1,
#          ('and', 'biological'): 1,
#          ('biological', 'science'): 1,
#          ('science', 'experiments'): 1,
#          ('experiments', '.'): 1,
#          ('.', 'with'): 1,
#          ('with', 'shuttleworth'): 1,
#          ('shuttleworth', 'together'): 1,
#          ('together', 'returning'): 1,
#          ('returning', 'earth'): 1,
#          ('earth', 'None'): 1,
#          ('None', 'are'): 5,
#          ('are', 'None'): 6,
#          ('None', 'with'): 13,
#          ('with', 'him'): 1,
#          ('him', 'None'): 4,
#          ('None', 'entered'): 1,
#          ('entered', 'space'): 1,
#          ('spacecraft', 'commander'): 1,
#          ('commander', 'gidzenko'): 1,
#          ('gidzenko', 'and'): 1,
#          ('and', 'italian'): 1,
#          ('italian', 'engineer'): 1,
#          ('engineer', 'vittori'): 1,
#          ('vittori', '.'): 1,
#          ('.', 'spacecraft'): 1,
#          ('spacecraft', 'landed'): 1,
#          ('landed', 'terra firma'): 1,
#          ('terra firma', 'after'): 1,
#          (',', 'shuttleworth'): 1,
#          ('shuttleworth', 'and'): 1,
#          ('and', 'two'): 1,
#          ('None', 'partners'): 1,
#          ('partners', 'will'): 1,
#          ('will', 'first'): 1,
#          ('first', 'be given'): 1,
#          ('be given', 'physical'): 1,
#          ('physical', 'exam'): 1,
#          ('exam', 'None'): 1,
#          ('None', 'before'): 2,
#          ('before', 'boarding'): 1,
#          ('boarding', 'helicopter'): 1,
#          ('helicopter', 'fly to'): 1,
#          ('fly to', 'kazakhstan'): 1,
#          ('kazakhstan', 'None'): 1,
#          ('None', 'astana'): 1,
#          ('astana', 'None'): 1,
#          ('on', 'same day'): 1,
#          ('same day', 'transferred'): 1,
#          ('transferred', 'to'): 1,
#          ('to', 'russian'): 1,
#          ('russian', 'capital'): 2,
#          ('capital', 'moscow'): 1,
#          ('moscow', '.'): 1,
#          ('.', 'this year'): 4,
#          ('this year', 'just'): 1,
#          ('just', '28'): 1,
#          ('28', 'None'): 7,
#          ('None', 'shuttleworth'): 1,
#          ('is', 'a'): 4,
#          ('None', 'very'): 4,
#          ('very', 'wealthy'): 1,
#          ('wealthy', 'None'): 1,
#          ('None', 'computer'): 1,
#          ('computer', 'information'): 1,
#          ('information', 'businessman'): 1,
#          ('businessman', '.'): 1,
#          ('he', 'for'): 1,
#          ('for', 'this'): 3,
#          ('this', 'None'): 32,
#          ('None', 'trip'): 2,
#          ('trip', 'paid'): 1,
#          ('us dollars', ','): 8,
#          (',', '10-day'): 1,
#          ('10-day', '10-day'): 1,
#          ('10-day', 'None'): 1,
#          ('space', 'travel'): 3,
#          ('travel', 'dream'): 1,
#          ('dream', 'None'): 1,
#          ('None', 'fulfilling'): 1,
#          ('fulfilling', '.'): 1,
#          ('.', 'human history'): 1,
#          ('human history', 'first'): 1,
#          ('first', 'space'): 1,
#          ('tourist', 'is'): 1,
#          ('is', 'this year'): 1,
#          ('this year', '60'): 1,
#          ('60', 'None'): 3,
#          ('None', 'businessman'): 1,
#          ('businessman', 'tito'): 1,
#          ('tito', '.'): 1,
#          ('None', 'last year'): 4,
#          ('last year', 'april'): 1,
#          ('april', 'went on'): 1,
#          ('went on', 'paying'): 1,
#          ('paying', 'space'): 1,
#          ('travel', 'None'): 2,
#          ('russian', 'medical'): 1,
#          ('medical', 'specialists'): 1,
#          ('specialists', 'earlier'): 1,
#          ('earlier', 'pointed out'): 1,
#          ('pointed out', 'that'): 15,
#          ('that', 'shuttleworth'): 1,
#          ('shuttleworth', 'than'): 1,
#          ('than', 'tito'): 1,
#          ('tito', 'more'): 1,
#          ('more', 'None'): 8,
#          ('None', 'suitable'): 1,
#          ('suitable', 'space'): 1,
#          ('he', 'during'): 2,
#          ('during', 'this'): 3,
#          ('this', 'space'): 1,
#          ('travel', 'during'): 1,
#          ('during', 'None'): 4,
#          ('None', 'at'): 13,
#          ('at', 'international'): 1,
#          ('space station', 'conducted'): 1,
#          ('conducted', 'a number of'): 1,
#          ('a number of', 'scientific'): 1,
#          ('scientific', 'experiments'): 1,
#          ('experiments', ','): 1,
#          ('including', 'including'): 6,
#          ('including', 'aids'): 1,
#          ('aids', 'pathogens'): 1,
#          ('pathogens', 'study'): 1,
#          ('study', '.'): 1,
#          ('travel', 'in'): 1,
#          ('in', 'south africa'): 1,
#          ('south africa', 'drawn'): 1,
#          ('drawn', 'great'): 1,
#          ('great', 'None'): 4,
#          ('None', 'publicity'): 1,
#          ('publicity', 'None'): 1,
#          ('and', 'None'): 19,
#          ('None', 'won the honor'): 1,
#          ('won the honor', 'since'): 1,
#          ('since', 'mandela'): 1,
#          ('mandela', 'from'): 1,
#          ('from', 'prison'): 1,
#          ('prison', 'release'): 1,
#          ('release', 'since'): 1,
#          ('None', 'most'): 5,
#          ('most', 'important'): 1,
#          ('important', 'None'): 5,
#          ('None', 'news'): 5,
#          ('news', 'event'): 1,
#          ('event', '.'): 3,
#          ('us', 'government'): 10,
#          ('government', 'not impressed'): 1,
#          ('not impressed', 'None'): 2,
#          ('None', 'castro'): 1,
#          ('castro', 'to'): 2,
#          ('to', 'carter'): 1,
#          ('carter', 'None'): 1,
#          ('None', 'goodwill'): 2,
#          ('goodwill', 'stance'): 2,
#          ('stance', '('): 1,
#          ('afp', 'washington'): 11,
#          (')', 'us'): 13,
#          ('us', 'president'): 10,
#          ('president', 'bush'): 7,
#          ('bush', "'s"): 2,
#          ("'s", 'administration'): 1,
#          ('administration', 'None'): 2,
#          ('None', 'cuban'): 1,
#          ('cuban', 'president'): 1,
#          ('president', 'castro'): 1,
#          ('to', 'former'): 1,
#          ('former', 'us'): 2,
#          ('president', 'carter'): 1,
#          ('carter', 'extended'): 1,
#          ('extended', 'None'): 1,
#          ('stance', 'None'): 2,
#          ('None', 'not impressed'): 1,
#          ('None', 'is'): 19,
#          ('is', 'None'): 8,
#          ('None', 'communist'): 1,
#          ('communist', 'island nation'): 1,
#          ('island nation', 'cuba'): 1,
#          ('cuba', 'None'): 6,
#          ('None', 'a'): 24,
#          ('None', 'making'): 1,
#          ('making', 'landmark'): 1,
#          ('landmark', 'None'): 1,
#          ('None', 'visit'): 2,
#          ('visit', '.'): 5,
#          ('.', 'castro'): 1,
#          ('castro', 'expressed'): 1,
#          ('expressed', 'willingness'): 1,
#          ('willingness', 'allow'): 1,
#          ('allow', 'carter'): 1,
#          ('carter', 'freely'): 1,
#          ('freely', 'meet'): 1,
#          ('meet', 'dissidents'): 1,
#          ('dissidents', 'dissidents'): 1,
#          ('dissidents', 'and'): 1,
#          ('and', 'visit'): 1,
#          ('visit', 'all'): 1,
#          ('all', 'areas'): 1,
#          ('areas', ','): 2,
#          ('including', 'washington'): 1,
#          ('washington', 'alleged'): 1,
#          ('alleged', 'are'): 1,
#          ('are', 'manufacturing'): 1,
#          ('manufacturing', 'biological weapon'): 1,
#          ('biological weapon', 'key components'): 1,
#          ('key components', 'None'): 1,
#          ('None', 'labs'): 2,
#          ('labs', '.'): 1,
#          ('.', 'white house'): 1,
#          ('white house', 'and'): 1,
#          ('and', 'state department'): 1,
#          ('state department', 'said'): 1,
#          ('None', 'these'): 3,
#          ('these', 'proposals'): 1,
#          ('proposals', 'meaningless'): 1,
#          ('meaningless', 'meaningless'): 1,
#          ('meaningless', '.'): 1,
#          ('.', 'state department'): 1,
#          ('state department', 'spokeswoman'): 1,
#          ('spokeswoman', 'cassel'): 1,
#          ('cassel', 'None'): 1,
#          ('None', 'said'): 17,
#          ('"', 'carter'): 1,
#          ('carter', 'president'): 2,
#          ('president', 'is'): 2,
#          ('None', 'cuba'): 1,
#          ('None', 'private citizen'): 1,
#          ('private citizen', 'visiting'): 1,
#          ('visiting', '.'): 1,
#          ('None', 'not'): 16,
#          ('not', 'been'): 1,
#          ('been', 'sent'): 2,
#          ('sent', 'inspect'): 1,
#          ('inspect', 'possible'): 1,
#          ('possible', 'None'): 4,
#          ('None', 'chemical'): 1,
#          ('chemical', 'or'): 1,
#          ('or', 'biological weapons'): 1,
#          ('biological weapons', 'facilities'): 1,
#          ('facilities', '.'): 3,
#          ('"', 'her'): 1,
#          ('her', 'her'): 6,
#          ('her', 'brief'): 1,
#          ('brief', 'remark'): 1,
#          ('remark', 'seems'): 1,
#          ('seems', 'echo'): 1,
#          ('echo', 'None'): 1,
#          ('None', 'other'): 5,
#          ('other', 'commentators'): 1,
#          ('commentators', 'of'): 1,
#          ('of', 'response'): 1,
#          ('response', 'None'): 1,
#          ('None', 'pointed out'): 2,
#          ('that', 'carter'): 1,
#          ('carter', 'neither nor'): 1,
#          ('neither nor', 'his'): 1,
#          ('his', 'delegation'): 1,
#          ('delegation', 'other'): 1,
#          ('other', 'members'): 1,
#          ('members', 'neither nor'): 1,
#          ('neither nor', 'neither nor'): 1,
#          ('neither nor', 'proper'): 1,
#          ('proper', 'inspection'): 1,
#          ('inspection', 'labs'): 1,
#          ('labs', 'necessary'): 1,
#          ('necessary', 'necessary'): 2,
#          ('necessary', 'None'): 2,
#          ('None', 'science'): 1,
#          ('science', 'background'): 1,
#          ('background', '.'): 1,
#          ('.', 'carter'): 1,
#          ('carter', 'insisted'): 1,
#          ('insisted', 'that'): 3,
#          ('that', 'government'): 1,
#          ('government', 'officials'): 2,
#          ('officials', 'None'): 5,
#          ('None', 'he'): 11,
#          ('he', 'briefed'): 1,
#          ('briefed', 'briefed'): 1,
#          ('briefed', 'while'): 1,
#          ('while', 'None'): 4,
#          ('None', 'no'): 6,
#          ('no', 'mention'): 1,
#          ('mention', 'us'): 1,
#          ('us', 'concern'): 1,
#          ('concern', 'cuba'): 1,
#          ('cuba', "'s"): 1,
#          ("'s", 'biological weapons'): 1,
#          ('biological weapons', 'plan'): 1,
#          ('plan', ','): 2,
#          (',', 'but'): 21,
#          ('but', 'us'): 2,
#          ('us', 'secretary of state'): 3,
#          ('secretary of state', 'powell'): 3,
#          ('powell', 'indicated'): 1,
#          ('indicated', 'he'): 1,
#          ('he', 'not'): 1,
#          ('not', 'believe'): 1,
#          ('believe', 'this'): 1,
#          ('.', 'powell'): 1,
#          ('powell', 'told'): 1,
#          ('told', 'abc'): 1,
#          ('abc', 'abc'): 2,
#          ('abc', 'network'): 1,
#          ('network', 'None'): 2,
#          ('None', ':'): 5,
#          ('"', 'i'): 6,
#          ('i', "n't"): 1,
#          ("n't", 'know'): 1,
#          ('know', 'carter'): 1,
#          ('president', 'was given'): 1,
#          ('was given', 'None'): 1,
#          ('None', 'what'): 1,
#          ('what', 'briefing'): 1,
#          ('briefing', '.'): 1,
#          ('.', 'i'): 4,
#          ('i', 'certain'): 1,
#          ('certain', 'we'): 1,
#          ('we', 'no'): 1,
#          ('no', 'reservation'): 1,
#          ('reservation', 'None'): 1,
#          ('None', 'our'): 2,
#          ('our', 'belief'): 1,
#          ('belief', 'cuba'): 1,
#          ('cuba', 'possesses'): 1,
#          ('possesses', 'biological warfare'): 1,
#          ('biological warfare', 'None'): 1,
#          ('None', 'research'): 1,
#          ('research', 'capabilities'): 1,
#          ('capabilities', '.'): 1,
#          ('"', 'napster'): 1,
#          ('napster', 'ceo'): 2,
#          ('ceo', 'hilbers'): 1,
#          ('hilbers', 'resigns'): 1,
#          ('resigns', '('): 1,
#          ('afp', 'san francisco'): 2,
#          ('san francisco', 'None'): 1,
#          ('None', 'once'): 2,
#          ('once', 'all-popular'): 1,
#          ('all-popular', 'None'): 1,
#          ('None', 'free'): 2,
#          ('free', 'downloading'): 1,
#          ('downloading', 'music'): 1,
#          ('music', 'company'): 1,
#          ('company', 'napster'): 1,
#          ('napster', 'said'): 1,
#          ('that', 'None'): 12,
#          ('None', 'chief executive'): 1,
#          ('chief executive', 'hilbers'): 1,
#          ('hilbers', 'resigned'): 1,
#          ('resigned', ','): 1,
#          (',', 'None'): 78,
#          ('None', 'immediately'): 2,
#          ('immediately', 'effective'): 1,
#          ('effective', '.'): 1,
#          ('.', 'hilbers'): 1,
#          ('hilbers', "'"): 1,
#          ("'", 'None'): 1,
#          ('None', 'will'): 16,
#          ('will', 'None'): 19,
#          ('None', 'who'): 1,
#          ('who', 'replacement'): 1,
#          ('replacement', 'None'): 1,
#          ('None', 'at present'): 1,
#          ('at present', 'still'): 2,
#          ('still', 'unknown'): 1,
#          ('unknown', '.'): 1,
#          ('.', 'napster'): 2,
#          ('napster', 'music'): 2,
#          ('music', 'website'): 2,
#          ('website', 'ever since'): 1,
#          ('ever since', 'last year'): 1,
#          ('last year', 'court'): 1,
#          ('court', 'ruled'): 2,
#          ('ruled', 'its'): 1,
#          ('its', 'its'): 2,
#          ('its', 'service'): 1,
#          ('service', 'given rise to'): 1,
#          ('given rise to', 'wide-spread'): 1,
#          ('wide-spread', 'copying'): 1,
#          ('copying', 'copying'): 1,
#          ('copying', 'ever since'): 1,
#          ('ever since', 'remained'): 1,
#          ('remained', 'closed'): 1,
#          ('closed', 'None'): 3,
#          ('None', 'today'): 4,
#          ('today', '.'): 1,
#          ('website', 'shut down'): 1,
#          ('shut down', 'after'): 1,
#          ('many', 'other'): 1,
#          ('other', 'websites'): 1,
#          ('websites', 'taken its place'): 1,
#          ('taken its place', '.'): 1,
#          ('.', 'california-based'): 1,
#          ('california-based', 'california-based'): 2,
#          ('california-based', 'redwood'): 1,
#          ('redwood', 'city'): 1,
#          ('city', 'None'): 2,
#          ('None', 'napster'): 2,
#          ('napster', 'None'): 1,
#          ('None', 'stated'): 1,
#          ('stated', ':'): 1,
#          ('"', 'we'): 8,
#          ('we', 'deeply'): 1,
#          ('deeply', 'regret'): 1,
#          ('regret', 'yet'): 1,
#          ('yet', "n't"): 1,
#          ("n't", 'None'): 3,
#          ('None', 'funding'): 1,
#          ('funding', 'None'): 1,
#          ('None', 'solution'): 1,
#          ('solution', 'None'): 1,
#          ('None', 'would'): 5,
#          ('would', 'enable'): 1,
#          ('enable', 'napster'): 1,
#          ('napster', 'launch'): 1,
#          ('launch', 'benefit'): 1,
#          ('benefit', 'artists'): 1,
#          ('artists', 'artists'): 1,
#          ('artists', 'and'): 1,
#          ('and', 'website'): 1,
#          ('website', 'users'): 1,
#          ('users', 'None'): 1,
#          ('None', 'service'): 2,
#          ('service', 'service'): 1,
#          ('service', '.'): 2,
#          ('"', 'it'): 1,
#          ('it', 'went on'): 1,
#          ('went on', 'say'): 1,
#          ('say', ':'): 1,
#          ('we', 'will'): 6,
#          ('will', 'in'): 9,
#          ('in', 'coming'): 1,
#          ('coming', 'None'): 1,
#          ('None', 'week'): 3,
#          ('week', 'take'): 1,
#          ('take', 'measures'): 1,
#          ('measures', 'None'): 7,
#          ('None', 'further'): 7,
#          ('further', 'cut'): 1,
#          ('cut', 'expenses'): 1,
#          ('expenses', '.'): 1,
#          ('"', 'once'): 1,
#          ('once', 'None'): 2,
#          ('None', 'german'): 1,
#          ('german', 'media'): 1,
#          ('media', 'giant'): 2,
#          ('giant', 'bertelsmann'): 1,
#          ('bertelsmann', 'None'): 1,
#          ('None', 'executive officer'): 1,
#          ('executive officer', 'None'): 1,
#          ('None', 'hilbers'): 1,
#          ('hilbers', ','): 1,
#          (',', 'at'): 3,
#          ('at', 'bertelsmann'): 1,
#          ('bertelsmann', 'started'): 1,
#          ('started', 'help'): 1,
#          ('help', 'struggling'): 1,
#          ('struggling', 'struggling'): 1,
#          ('struggling', 'None'): 1,
#          ('napster', 'within'): 1,
#          ('within', 'court'): 1,
#          ('court', 'ruling'): 1,
#          ('ruling', 'None'): 4,
#          ('None', 'framework'): 2,
#          ('framework', 'framework'): 1,
#          ('framework', 'within'): 1,
#          ('within', 'continue'): 1,
#          ('continue', 'operation'): 1,
#          ('operation', 'time'): 1,
#          ('time', 'None'): 2,
#          ('None', 'took'): 1,
#          ('took', 'took'): 1,
#          ('took', 'napster'): 1,
#          ('ceo', 'position'): 1,
#          ('position', '.'): 3,
#          ('.', 'oecd'): 1,
#          ('oecd', 'ministers examine'): 1,
#          ('ministers examine', 'in'): 1,
#          ('in', 'paris'): 2,
#          ('paris', 'outlook'): 1,
#          ('outlook', 'world'): 1,
#          ('world', 'economy'): 1,
#          ('economy', '('): 1,
#          ('afp', 'paris'): 2,
#          ('paris', 'None'): 3,
#          (')', 'world'): 2,
#          ('world', 'major'): 1,
#          ('major', 'industrial nations'): 1,
#          ('industrial nations', 'None'): 1,
#          ('None', 'senior'): 3,
#          ('senior', 'ministers'): 1,
#          ('ministers', 'None'): 2,
#          ('None', '15th'): 1,
#          ('15th', 'in'): 1,
#          ('None', '2-day'): 1,
#          ('2-day', '2-day'): 2,
#          ('2-day', 'meeting'): 2,
#          ('meeting', '.'): 4,
#          ('.', 'they'): 8,
#          ('they', 'will'): 2,
#          ('will', 'examine'): 1,
#          ('examine', 'promising'): 1,
#          ('promising', 'promising'): 1,
#          ('promising', 'of'): 1,
#          ('of', 'economy'): 2,
#          ('economy', 'future'): 1,
#          ('future', 'None'): 3,
#          ('None', 'as well as'): 3,
#          ('as well as', 'confront'): 1,
#          ('confront', 'united states'): 1,
#          ('united states', 'europe'): 1,
#          ('europe', 'between'): 1,
#          ('between', 'by'): 1,
#          ('by', 'trade'): 1,
#          ('trade', 'dispute'): 5,
#          ('dispute', 'None'): 3,
#          ('None', 'caused'): 4,
#          ('caused', 'None'): 3,
#          ('None', 'division'): 1,
#          ('division', 'looming'): 1,
#          ('looming', '.'): 1,
#          ('.', 'economic'): 1,
#          ('economic', 'cooperation'): 1,
#          ('cooperation', 'and'): 1,
#          ('and', 'development'): 1,
#          ('development', 'organization'): 1,
#          ('organization', '30'): 1,
#          ('30', 'None'): 3,
#          ('None', 'member nations'): 1,
#          ('member nations', 'None'): 1,
#          ('None', 'representatives'): 2,
#          ('representatives', 'also'): 1,
#          ('also', 'will'): 10,
#          ('will', 'concern'): 1,
#          ('concern', 'rich'): 1,
#          ('rich', 'None'): 1,
#          ('and', 'poor'): 1,
#          ('poor', 'nations'): 3,
#          ('nations', 'between'): 1,
#          ('None', 'abridge'): 1,
#          ('abridge', 'gap'): 1,
#          ('gap', 'None'): 1,
#          ('None', 'arising'): 2,
#          ('arising', 'None'): 2,
#          ('None', 'conflict'): 1,
#          ('conflict', '.'): 1,
#          ('however', ','): 7,
#          (',', 'macroeconomics'): 1,
#          ('macroeconomics', 'macroeconomics'): 1,
#          ('macroeconomics', 'None'): 1,
#          ('None', 'discussion'): 3,
#          ('discussion', 'may'): 1,
#          ('may', 'by'): 2,
#          ('by', 'united states'): 1,
#          ('and', 'european union'): 1,
#          ('european union', 'between'): 1,
#          ('between', 'trade'): 1,
#          ('trade', 'friction'): 1,
#          ('friction', 'None'): 1,
#          ('None', 'escalating'): 2,
#          ('escalating', 'None'): 1,
#          ('None', 'eclipsed'): 1,
#          ('eclipsed', '.'): 1,
#          ('.', 'european'): 3,
#          ('european', 'nations'): 3,
#          ...})

# %%
# which english words we use in the beginnig of the sentence?
def starting_counts(sequences):
    return Counter(sequences)

start_en_words = [i[0] for i in DataSet_en]
en_words_starts = starting_counts(start_en_words)
en_words_starts
# Out:
# Counter({'archdiocese': 2,
#          '66-year-old': 1,
#          'None': 48,
#          'us': 22,
#          '(': 50,
#          'ministry of national defense': 2,
#          'two': 5,
#          'united states': 1,
#          'apart from': 2,
#          'india': 3,
#          'last time': 1,
#          'since': 7,
#          'after': 8,
#          'diplomat': 1,
#          'south african': 1,
#          'shuttleworth': 3,
#          'he': 41,
#          'with': 1,
#          'spacecraft': 1,
#          'this year': 4,
#          'human history': 1,
#          'russian': 1,
#          'castro': 1,
#          'white house': 1,
#          'state department': 1,
#          'her': 1,
#          'carter': 1,
#          'powell': 1,
#          'our': 1,
#          'napster': 3,
#          'hilbers': 1,
#          'california-based': 1,
#          'it': 3,
#          'once': 1,
#          'oecd': 1,
#          'economic': 1,
#          'however': 23,
#          'european': 3,
#          'eu': 4,
#          'belgian': 1,
#          'mid-term': 1,
#          'washington': 1,
#          'in addition': 10,
#          'schott': 2,
#          'at': 7,
#          'correspondingly': 1,
#          'secretary of defense': 1,
#          'british airways': 2,
#          'in': 13,
#          'alone': 1,
#          'former': 4,
#          'airline': 1,
#          'this': 13,
#          'bush': 10,
#          'so far': 2,
#          'india-pakistan': 1,
#          'shelling': 1,
#          'police': 3,
#          'in the meantime': 2,
#          'irish': 2,
#          'the': 25,
#          'keane': 2,
#          'from': 2,
#          'training': 1,
#          'while': 1,
#          'liberal': 1,
#          'she': 4,
#          'reduction': 1,
#          'state duma': 1,
#          'pakistan': 6,
#          'announcement': 1,
#          'yesterday': 1,
#          'in meantime': 1,
#          'musharraf': 1,
#          'we': 2,
#          'nobody': 1,
#          'japanese': 1,
#          'located': 4,
#          'declined to': 1,
#          'now': 1,
#          '1932': 1,
#          'fifa': 2,
#          'japan': 3,
#          'according to': 15,
#          'having': 1,
#          'by': 4,
#          'pakistani': 1,
#          'international': 3,
#          'saltanov': 1,
#          'putin': 1,
#          'un': 1,
#          'they': 7,
#          'argentina': 1,
#          'cta': 1,
#          'argentine': 1,
#          'capital': 1,
#          'italian': 1,
#          'scajola': 2,
#          'attending': 1,
#          'recently': 1,
#          'weakland': 1,
#          'marcoux': 1,
#          'aer lingus': 4,
#          'at this moment': 1,
#          'through': 1,
#          'before': 1,
#          'who': 3,
#          'tuberculosis': 1,
#          'fbi': 2,
#          'but': 2,
#          'good people': 1,
#          'like': 1,
#          'austin': 1,
#          'jennifer lopez': 1,
#          'next': 1,
#          'columbia': 1,
#          'about': 1,
#          '"': 5,
#          'to': 1,
#          'britain': 3,
#          'a': 3,
#          'queen': 4,
#          'british': 2,
#          'blair': 1,
#          'reynolds': 1,
#          'ruling': 1,
#          'some time earlier': 1,
#          'this case': 1,
#          'in the future': 1,
#          '1998': 1,
#          'lockyer': 1,
#          'labor department': 1,
#          'unemployment rate': 1,
#          'analysts': 2,
#          'naroff': 1,
#          'job': 1,
#          'mubarak': 4,
#          'last': 1,
#          'costa': 3,
#          'conference': 2,
#          'game': 1,
#          'ferrero': 1,
#          '26-year-old': 1,
#          'rumsfeld': 5,
#          'g8': 2,
#          'kananaskis': 1,
#          'attending the meeting': 1,
#          'canada': 1,
#          'ex-duchess': 1,
#          'universal': 1,
#          'fergie': 1,
#          'at present': 6,
#          'bank of japan': 2,
#          'masaru hayami': 2,
#          'meanwhile': 4,
#          'although': 2,
#          'local': 1,
#          'reformists': 1,
#          'during': 5,
#          'kim': 2,
#          'chong wa dae': 2,
#          'expected': 1,
#          'south korean': 1,
#          'south korea': 3,
#          'south and north koreas': 1,
#          'marriott': 2,
#          'english': 1,
#          'in the world': 1,
#          'reported': 3,
#          'senior': 1,
#          'jerusalem': 1,
#          'public': 2,
#          'palestinian': 3,
#          'israel': 2,
#          'beijing': 2,
#          'media': 1,
#          'victims': 1,
#          'reports': 1,
#          'above': 1,
#          'statement': 5,
#          'montreal': 1,
#          'january-march': 1,
#          'current account': 1,
#          'guatieri': 1,
#          'israel-arab': 1,
#          'israeli': 6,
#          'these': 2,
#          'five': 1,
#          'afp': 1,
#          'military': 2,
#          'jenin': 1,
#          'dawn': 1,
#          'qureshi': 2,
#          'tensions': 1,
#          'if': 1,
#          'china': 5,
#          'ministry of civil affairs': 1,
#          'liu': 1,
#          'some': 1,
#          'umno': 2,
#          'yaakob': 2,
#          'mahathir': 3,
#          'when': 2,
#          'serves both as': 1,
#          'abdullah': 1,
#          'san francisco': 1,
#          'long': 1,
#          '9th': 1,
#          'an': 2,
#          'his': 1,
#          'judge': 1,
#          'controversial': 1,
#          'pledger': 1,
#          'america': 1,
#          'scientists': 1,
#          'afghan': 1,
#          'xinhua news agency': 50,
#          'ghani': 3,
#          'nepal': 1,
#          'gyanendra': 1,
#          'deuba': 1,
#          'nepali': 1,
#          'therefore': 2,
#          'moreover': 1,
#          'given': 1,
#          'contributed to': 1,
#          'both parties': 1,
#          'both': 1,
#          'chris patten': 2,
#          'earlier': 2,
#          'indian': 1,
#          'closely following': 1,
#          'soon after that': 1,
#          'reeker': 1,
#          'europe': 1,
#          'consequently': 1,
#          'venezuelan': 2,
#          'learned': 1,
#          'cabello': 1,
#          'colombian': 2,
#          'venezuela': 2,
#          'pele': 5,
#          'as': 3,
#          'amusement park': 1,
#          'because': 1,
#          'after the accident': 1,
#          'involved in the accident': 1,
#          'accident': 1,
#          'honda': 3,
#          'recalled': 1,
#          'ignition': 1,
#          'four': 1,
#          'chile': 2,
#          'lagos': 1,
#          'brazil': 1,
#          'ricciardone': 1,
#          'last year': 4,
#          'currently': 4,
#          'year ,': 1,
#          'south koreas': 1,
#          'lee': 1,
#          'activities': 3,
#          'both sides': 2,
#          'on the other hand': 1,
#          'marisabel rodriguez de chavez': 1,
#          'hong kong': 3,
#          'negative equity': 2,
#          'survey': 2,
#          'in addition to': 1,
#          'boeing': 1,
#          'us-china': 1,
#          'industry insiders': 1,
#          'reportedly': 1,
#          'in response to': 1,
#          'jiang': 2,
#          'st. petersburg': 1,
#          'afterwards': 1,
#          'sochi': 1,
#          '8th': 1,
#          'romania': 1,
#          'workers': 1,
#          'based on': 1,
#          'being': 1,
#          'reinforcement': 1,
#          'above-mentioned': 1,
#          'incomes': 1,
#          'romanian': 1,
#          'philippines': 1,
#          'arroyo': 1,
#          'philippine': 2,
#          'heat wave': 1,
#          'report': 7,
#          'maiduguri': 1,
#          'kida': 2,
#          'though': 1,
#          'even': 1,
#          'nyse': 1,
#          'dow jones': 1,
#          'on the day': 1,
#          'new york': 2,
#          'last week': 1,
#          'under': 2,
#          'french': 4,
#          'lamour': 2,
#          'i': 1,
#          'three': 1,
#          'two sides': 1,
#          'gaza': 1,
#          'riga': 1,
#          'sas': 1,
#          'hotel': 1,
#          'chinese': 1,
#          'gourmet': 1,
#          'chilean': 1,
#          'today': 1,
#          'polloni': 1,
#          'guilin': 1,
#          'center': 1,
#          'tourists': 1,
#          'reporter': 1,
#          'water transport': 1,
#          'all': 1,
#          'this month': 2,
#          'fossett': 1,
#          'due to': 1,
#          'guangdong': 2,
#          'new': 1,
#          '- -': 1,
#          'hong kong macau': 1,
#          'russia': 1,
#          'macau': 1,
#          'entire year': 1,
#          'swim beaches': 1,
#          'sewage': 1,
#          '2001': 1,
#          'austrian': 2,
#          'confiscated': 1,
#          'lower austria': 1,
#          '2000': 1,
#          'greece': 1,
#          'alexandroupolis': 1,
#          'ding': 3,
#          'presentation': 1,
#          'xinjiang university': 1,
#          'moftec': 1,
#          'an min': 1,
#          'taiwan': 1,
#          'chang': 1,
#          'visiting': 1,
#          'mt. helan': 1,
#          'south north': 1,
#          'foreign': 1,
#          '2002': 1,
#          'nigerien': 2,
#          'niger': 1,
#          'measures': 1,
#          'at the same time': 1,
#          'tokyo': 1,
#          'nakatani': 1,
#          'host and guest': 1,
#          'tian': 1,
#          'hope': 1,
#          'in order to': 2,
#          'opiyo': 2,
#          'heinz': 2,
#          'transaction': 1,
#          'guangzhou': 3,
#          'believes': 1,
#          'asia-pacific region': 1,
#          'guangdong province': 1,
#          'for example': 2,
#          'of course': 2,
#          'palestine': 1,
#          'january': 1,
#          'panama': 1,
#          'legislative': 1,
#          'panamanian': 1,
#          'hamas': 1,
#          'at the time': 1,
#          'nets': 1,
#          'detroit': 1,
#          'pistons': 1,
#          'miller': 1,
#          'boston': 2,
#          'you': 3,
#          'deal': 1,
#          'Ten': 1,
#          'Last year': 1,
#          'So': 1,
#          'seems to be': 1,
#          'Samsung': 2,
#          'these days': 1,
#          'Now': 1,
#          'If': 4,
#          'people': 1,
#          'the Value': 1,
#          'Value': 1,
#          'in the end': 1,
#          'You': 3,
#          'Usability': 1,
#          'entertainment factor which': 1,
#          '2011': 1,
#          'However': 3,
#          'Even if': 1,
#          'in many ways': 1,
#          'HP': 1,
#          'Shooting': 1,
#          'weekend': 1,
#          'Apple': 2,
#          'I': 4,
#          '" would "': 1,
#          'But': 1,
#          'No matter': 1,
#          'Expensive enough that': 1,
#          '900': 1,
#          'that': 1,
#          'The icing on the cake': 1,
#          'to get': 1,
#          'Why': 1,
#          'Admittedly': 1,
#          'Some': 1,
#          'Steve Jobs': 1,
#          'It may be': 1,
#          'The bottom line :': 1,
#          '32': 1,
#          'Conclusion': 1,
#          'please': 1,
#          'its': 1,
#          'It': 3,
#          'By the way': 1,
#          'Honeycomb': 1,
#          'To': 1,
#          'As': 2,
#          'Develop': 1,
#          'Playing': 2,
#          'Imaginative': 2,
#          'Build': 1,
#          'Young children': 1,
#          'Imagining': 1,
#          'It helps': 1,
#          'Boost': 1,
#          'Using': 1,
#          'in school': 1,
#          'Practice': 1,
#          'Kids who': 1,
#          'This': 1,
#          'Work out': 1,
#          'children': 1,
#          'When': 1,
#          'To encourage': 1,
#          'Books': 1,
#          'Scientists': 1})

# %%
# which english word we end with?

def ending_counts(sequences):    
    return Counter(sequences)

end_en_words = [i[len(i)-1] for i in DataSet_en]
en_words_ends = ending_counts(end_en_words)
en_words_ends
# Out:
# Counter({'.': 790,
#          'exercise': 1,
#          '"': 71,
#          'earth': 1,
#          'None': 18,
#          'stance': 1,
#          'resigns': 1,
#          'economy': 1,
#          'slow down': 1,
#          'defend': 1,
#          'loss': 1,
#          'embargo': 1,
#          'rose': 1,
#          'retire': 1,
#          'summit': 1,
#          'missile': 1,
#          'bankrupt': 1,
#          'speech': 1,
#          'protests': 1,
#          'police force': 1,
#          'loss lives': 1,
#          'apology': 1,
#          'future hangs in the air': 1,
#          'progress': 1,
#          'actions': 2,
#          'superhero': 1,
#          'golden jubilee': 1,
#          'fined': 1,
#          'slow': 1,
#          'key': 1,
#          'claims crown': 1,
#          'weapons': 1,
#          'situation': 1,
#          'show': 1,
#          'benefit enormously': 1,
#          'obstacles': 1,
#          'talks': 1,
#          'hotels': 1,
#          'arrested': 1,
#          'shaking': 1,
#          'towns': 1,
#          'dead': 2,
#          'escalates': 1,
#          'missing': 1,
#          'succeed': 1,
#          'unconstitutional': 1,
#          'tough penalties': 1,
#          'pledge': 1,
#          'parliament': 1,
#          'accelerating': 1,
#          'relationship': 1,
#          'meet': 1,
#          'ups and downs': 1,
#          'asylum': 1,
#          'autobiography': 1,
#          'underneath': 1,
#          ',': 4,
#          'cars': 1,
#          'farm': 1,
#          'leaders': 1,
#          'announcement': 1,
#          'divorce': 1,
#          'results': 2,
#          'company': 1,
#          'visit': 1,
#          'relieve concerns': 1,
#          'software': 1,
#          'asg': 1,
#          'slip': 1,
#          'lemerre': 1,
#          'killed': 1,
#          'week': 1,
#          'cooperate': 1,
#          'closed': 1,
#          'program': 1,
#          'measures': 1,
#          'travel': 1,
#          'requirements': 1,
#          ':': 5,
#          'crisis': 1,
#          'cases': 1,
#          'tide of immigrants': 1,
#          'professor': 1,
#          'people': 1,
#          'precious pool': 1,
#          'rise': 1,
#          'declaration': 1,
#          'death': 1,
#          'president': 1,
#          'companies': 1,
#          'diversified': 1,
#          'cease-fire': 1,
#          'rises': 1,
#          'slide': 1,
#          'assassinated': 1,
#          'pulled out': 1,
#          '?': 6,
#          'a tab': 1,
#          'in the Foot': 1,
#          '--': 1,
#          'value': 1,
#          'Next': 1,
#          'skills': 2,
#          'self-confidence': 1,
#          'growth': 1,
#          'fears': 1,
#          'Residue': 1})

# %%
# count chinese words that associated to each english word, and we can get emission probabilities 
# (given english words, the probability of observing certain chinese words)
def pair_counts(en_w, ch_w):
    d = defaultdict(lambda: defaultdict(int))
    for en, ch in zip(en_w, ch_w):
        d[en][ch] += 1
    return d

en_ch_count = pair_counts(words_en, words_ch)
en_ch_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'archdiocese': defaultdict(int, {'教区': 7}),
#              'finance': defaultdict(int, {'财务': 2}),
#              'council': defaultdict(int, {'委员会': 2, '理事会': 1}),
#              'thinks': defaultdict(int, {'认为': 3}),
#              'that': defaultdict(int,
#                          {',': 153, ':': 1, '这': 2, '款': 1, '，': 1}),
#              'this': defaultdict(int,
#                          {'这项': 7,
#                           '这': 25,
#                           '这次': 6,
#                           '这个': 14,
#                           '此': 17,
#                           '这种': 7,
#                           '这部': 1,
#                           '这家': 3,
#                           '今天': 2,
#                           '本': 1,
#                           '此次': 1,
#                           '它': 2}),
#              'agreement': defaultdict(int, {'协议': 13, '协定': 1}),
#              'may': defaultdict(int,
#                          {'可能': 14,
#                           '会': 2,
#                           '五月': 7,
#                           '五月份': 1,
#                           '5月': 14,
#                           '5月份': 2,
#                           '可': 1,
#                           '将会': 1}),
#              'force': defaultdict(int, {'使得': 1, '迫使': 1}),
#              'boston': defaultdict(int, {'波士顿': 6}),
#              'catholic archdiocese': defaultdict(int, {'天主教会': 1}),
#              'bankruptcy': defaultdict(int, {'破产': 3}),
#              'None': defaultdict(int,
#                          {',': 541,
#                           '受到': 9,
#                           '的': 906,
#                           '有': 59,
#                           '名': 82,
#                           '已': 18,
#                           '被': 17,
#                           '职务': 1,
#                           '他': 4,
#                           '件': 2,
#                           '将': 41,
#                           '来': 28,
#                           '电': 97,
#                           '为': 27,
#                           '个': 62,
#                           '关系': 7,
#                           '支': 3,
#                           '中': 27,
#                           '次': 14,
#                           '两': 14,
#                           '国': 10,
#                           '遭': 8,
#                           '事件': 12,
#                           '外海': 1,
#                           '进行': 29,
#                           '发生': 8,
#                           '位': 30,
#                           '过': 7,
#                           '方面': 9,
#                           '也': 13,
#                           '成员': 2,
#                           '呈现': 2,
#                           '、': 43,
#                           '所': 19,
#                           '引起': 3,
#                           '结束': 2,
#                           '之': 24,
#                           '大': 10,
#                           '籍': 1,
#                           '才': 9,
#                           '一': 53,
#                           '趟': 2,
#                           '是': 53,
#                           '并': 17,
#                           '在': 64,
#                           '太空': 1,
#                           '期间': 2,
#                           '这次': 1,
#                           '一起': 2,
#                           '岁': 8,
#                           '得以': 1,
#                           '。': 11,
#                           '能够': 3,
#                           '曾': 16,
#                           '这': 18,
#                           '对待': 1,
#                           '释出': 1,
#                           '对于': 3,
#                           '反应': 1,
#                           '卡特': 1,
#                           '展开': 6,
#                           '项': 27,
#                           '女士': 1,
#                           '了': 111,
#                           '评论家': 1,
#                           '说法': 1,
#                           '说': 10,
#                           ')': 5,
#                           '网路': 1,
#                           '该': 6,
#                           '公司': 27,
#                           '遗缺': 1,
#                           '由': 14,
#                           '到': 11,
#                           '网站': 1,
#                           '解决': 3,
#                           '们': 8,
#                           '但': 10,
#                           '而': 34,
#                           '国家': 4,
#                           '至': 1,
#                           '法': 2,
#                           '对': 26,
#                           '农业': 1,
#                           '加以': 1,
#                           '作法': 3,
#                           '使': 9,
#                           '为了': 1,
#                           '使得': 3,
#                           '「': 11,
#                           '」': 12,
#                           '目标': 1,
#                           '钢铁': 1,
#                           '下': 6,
#                           '--': 5,
#                           '因为': 1,
#                           '这种': 2,
#                           '务必': 1,
#                           '更': 2,
#                           '给': 4,
#                           '接获': 1,
#                           '方式': 3,
#                           '会': 11,
#                           '想要': 1,
#                           '事': 3,
#                           '要': 15,
#                           '之类': 1,
#                           '谈话': 1,
#                           '指': 2,
#                           '开始': 1,
#                           '却': 8,
#                           '后': 10,
#                           '英镑': 3,
#                           '即': 1,
#                           '就': 26,
#                           '让': 5,
#                           '出乎': 1,
#                           '之外': 1,
#                           '市场': 2,
#                           '原来': 1,
#                           '预期': 1,
#                           '较': 2,
#                           '不': 2,
#                           '唯有': 1,
#                           '其': 7,
#                           '长': 1,
#                           '达': 2,
#                           '发表': 7,
#                           '此': 6,
#                           '予以': 1,
#                           '行动': 10,
#                           '距': 1,
#                           '其中': 10,
#                           '枚': 7,
#                           '栋': 3,
#                           '据': 14,
#                           '地区': 6,
#                           '人': 26,
#                           '人物': 1,
#                           '比赛': 5,
#                           '工作': 5,
#                           '背后': 1,
#                           '想': 1,
#                           '我们': 3,
#                           '情形': 1,
#                           '段': 4,
#                           '都': 26,
#                           '而已': 1,
#                           '以及': 2,
#                           '安排': 1,
#                           '家': 20,
#                           '之后': 2,
#                           '他们': 4,
#                           '双方': 6,
#                           '历经': 1,
#                           '直到': 1,
#                           '获致': 1,
#                           '声浪': 1,
#                           '因此': 4,
#                           '型': 1,
#                           '射程': 1,
#                           '足球': 1,
#                           '国内': 3,
#                           '等': 16,
#                           '从': 5,
#                           '过去': 1,
#                           '一直': 6,
#                           '尚': 1,
#                           '造成': 9,
#                           '它': 7,
#                           '印': 1,
#                           '巴': 1,
#                           '要求': 2,
#                           '时': 19,
#                           '有所': 3,
#                           '拥有': 5,
#                           '进入': 1,
#                           '紧锣密鼓': 1,
#                           '阶段': 1,
#                           '肩负': 1,
#                           '印度': 1,
#                           '危机': 2,
#                           '组织': 2,
#                           '正': 2,
#                           '境内': 2,
#                           '面临': 1,
#                           '-': 3,
#                           '上': 6,
#                           '能': 7,
#                           '条': 3,
#                           '阿根廷': 1,
#                           '包括': 2,
#                           '设': 1,
#                           '路障': 1,
#                           '活动': 7,
#                           '困境': 2,
#                           '把': 1,
#                           '群众': 1,
#                           '召开': 3,
#                           '先行': 1,
#                           '事宜': 3,
#                           '有意': 1,
#                           '入会': 2,
#                           '于': 4,
#                           '研究': 1,
#                           '与': 10,
#                           '国际': 1,
#                           '接受': 6,
#                           '那么': 2,
#                           '倒': 1,
#                           '相互': 1,
#                           '争取': 1,
#                           '彼此': 1,
#                           '针对': 2,
#                           '提议': 1,
#                           '导致': 1,
#                           '人数': 2,
#                           '机密': 1,
#                           '透露': 1,
#                           '和': 9,
#                           '可能': 6,
#                           '出': 7,
#                           '甫': 1,
#                           '起': 9,
#                           '意': 1,
#                           '向': 15,
#                           '还': 9,
#                           '趁': 2,
#                           '之际': 2,
#                           '(': 3,
#                           'aer': 1,
#                           'lingus': 1,
#                           '设法': 1,
#                           '道': 2,
#                           '航空': 4,
#                           '举行': 9,
#                           '看': 1,
#                           '因': 7,
#                           '受': 3,
#                           '员工': 1,
#                           '亏损': 1,
#                           '约': 3,
#                           '讨论': 1,
#                           '份': 8,
#                           '内容': 2,
#                           '表示': 2,
#                           '散播': 1,
#                           '先': 2,
#                           '方案': 1,
#                           '策略': 1,
#                           '实施': 2,
#                           '这些': 1,
#                           '着': 9,
#                           '用品': 1,
#                           '用': 1,
#                           ':': 2,
#                           '令': 3,
#                           '注意': 1,
#                           '自然': 1,
#                           '几乎': 2,
#                           '女': 4,
#                           '出品': 1,
#                           'shrink': 1,
#                           '除': 1,
#                           '担任': 2,
#                           '外': 1,
#                           '身兼': 1,
#                           '当': 1,
#                           '担纲': 1,
#                           '她': 3,
#                           '则': 5,
#                           '进一步': 2,
#                           '构想': 1,
#                           '剧情': 1,
#                           '神奇': 1,
#                           '庆贺': 1,
#                           '庆祝': 2,
#                           '给予': 3,
#                           '很': 5,
#                           '架': 3,
#                           '划': 1,
#                           '无论': 2,
#                           '来说': 3,
#                           '可以': 5,
#                           '一番': 1,
#                           '今年': 2,
#                           '稍早': 1,
#                           '绝': 1,
#                           '英国': 2,
#                           '各项': 1,
#                           '情': 1,
#                           '判决': 1,
#                           '阅读': 1,
#                           '不准': 1,
#                           '如今': 1,
#                           '丝毫': 1,
#                           '提出': 2,
#                           '必须': 3,
#                           '须': 1,
#                           '负担': 1,
#                           '不得': 1,
#                           '占': 1,
#                           '行为': 2,
#                           '非常': 2,
#                           '显现': 1,
#                           '过程': 2,
#                           '降': 1,
#                           '比率': 1,
#                           '原先': 1,
#                           '虽然': 3,
#                           '促成': 1,
#                           '承诺': 1,
#                           '九日': 1,
#                           '团': 1,
#                           '问题': 4,
#                           '一个': 3,
#                           '达成': 1,
#                           '以': 13,
#                           '座': 5,
#                           '赛': 5,
#                           '同': 2,
#                           '一度': 1,
#                           '无奈': 1,
#                           '发': 2,
#                           '最后': 2,
#                           '饮恨': 1,
#                           '称臣': 1,
#                           '战': 2,
#                           '冠军': 1,
#                           '近': 2,
#                           '杀进': 1,
#                           '前': 1,
#                           '一路': 1,
#                           '番': 1,
#                           '进军': 1,
#                           '抱': 1,
#                           '得': 2,
#                           '表现': 1,
#                           '美国': 4,
#                           '准备': 3,
#                           '那些': 1,
#                           '谁': 1,
#                           '那': 3,
#                           '系': 1,
#                           '根本': 1,
#                           '来自': 3,
#                           '主要': 2,
#                           '秘境': 1,
#                           '局势': 1,
#                           '肯定': 1,
#                           '布希': 1,
#                           '符合': 1,
#                           '条件': 1,
#                           '届时': 1,
#                           '自': 1,
#                           '有着': 1,
#                           '头': 2,
#                           '媒体': 1,
#                           '集团': 1,
#                           '具': 2,
#                           '发展': 1,
#                           '专': 1,
#                           '晋级': 1,
#                           '强': 1,
#                           '趋势': 2,
#                           '该行': 1,
#                           '遭遇': 1,
#                           '影响': 2,
#                           '路': 1,
#                           '日益': 1,
#                           '另': 2,
#                           '已经': 5,
#                           '超乎': 1,
#                           '主管': 1,
#                           '增': 1,
#                           'marriott': 1,
#                           'hotel': 1,
#                           '话': 2,
#                           '而言': 1,
#                           '指出': 1,
#                           '旅馆': 1,
#                           '迄': 1,
#                           '生意': 1,
#                           '决定': 2,
#                           '巴勒斯坦': 2,
#                           '辆': 16,
#                           '发动': 2,
#                           '间': 3,
#                           '范围': 1,
#                           '攻击': 2,
#                           '案': 6,
#                           '大约': 1,
#                           '暂时': 1,
#                           ';': 2,
#                           '火灾': 1,
#                           '姓': 5,
#                           '北京': 1,
#                           '死者': 1,
#                           '加': 1,
#                           '又': 5,
#                           '创': 2,
#                           '价位': 1,
#                           '约旦河': 8,
#                           '遭到': 2,
#                           '自杀': 1,
#                           '炸弹': 1,
#                           '所为': 1,
#                           '处': 4,
#                           '行径': 1,
#                           '共': 1,
#                           '以来': 6,
#                           '以致': 1,
#                           '军方': 1,
#                           '买': 2,
#                           '东西': 1,
#                           '同样': 2,
#                           '见': 1,
#                           '最近': 1,
#                           '变成': 1,
#                           '人员': 3,
#                           '恐怕': 2,
#                           '采取': 1,
#                           '程度': 1,
#                           '至今': 1,
#                           '获得': 2,
#                           '还有': 1,
#                           '出现': 4,
#                           '省': 1,
#                           '县市': 1,
#                           '接替': 1,
#                           '放弃': 1,
#                           '联盟': 1,
#                           '国民': 2,
#                           '举国': 1,
#                           '再': 4,
#                           '时间': 2,
#                           '情事': 1,
#                           '皆': 2,
#                           '措施': 2,
#                           '爆发': 1,
#                           '演变': 1,
#                           '成': 1,
#                           '日渐': 1,
#                           '迅速': 1,
#                           '不过': 1,
#                           '保证': 1,
#                           '构成': 1,
#                           '做出': 3,
#                           '提供': 2,
#                           '管理': 1,
#                           '年度': 1,
#                           '援助': 1,
#                           '此举': 1,
#                           '政府': 4,
#                           '仍': 2,
#                           '届': 3,
#                           '预定': 1,
#                           '期限': 2,
#                           '内': 5,
#                           '尼泊尔': 1,
#                           '贾南德拉': 1,
#                           '速度': 2,
#                           '负责': 2,
#                           '十分': 2,
#                           '幅度': 1,
#                           '时候': 1,
#                           '买房': 2,
#                           '供': 1,
#                           '不断': 1,
#                           '正在': 2,
#                           '现象': 1,
#                           '去年': 1,
#                           '原因': 1,
#                           '银行': 2,
#                           '目前': 2,
#                           '照': 1,
#                           '下去': 1,
#                           '地': 8,
#                           '各个': 1,
#                           '委员会': 1,
#                           '经': 1,
#                           '股市': 2,
#                           '走势': 1,
#                           '企业': 1,
#                           '《': 2,
#                           '》': 1,
#                           '种': 6,
#                           '股票': 4,
#                           '收盘': 3,
#                           '微': 1,
#                           '幅': 2,
#                           '点': 6,
#                           '带来': 1,
#                           '过渡': 1,
#                           '自己': 7,
#                           '广大': 1,
#                           '自传': 1,
#                           '本': 4,
#                           '通过': 2,
#                           '勇气': 1,
#                           '棵': 1,
#                           '场': 2,
#                           '巴西': 1,
#                           '"': 18,
#                           '那里': 1,
#                           '受伤': 1,
#                           '汽车': 2,
#                           '一些': 2,
#                           '它们': 2,
#                           '数量': 3,
#                           '排名': 1,
#                           '事务': 1,
#                           '本国': 1,
#                           '智利': 2,
#                           '合': 1,
#                           '民族': 1,
#                           '收到': 1,
#                           '当事人': 1,
#                           '应': 2,
#                           '任': 1,
#                           '业务': 1,
#                           '宗': 4,
#                           '住宅': 2,
#                           '比': 2,
#                           '另外': 1,
#                           '三': 4,
#                           '方': 2,
#                           '维修': 1,
#                           '均': 1,
#                           '类': 3,
#                           '有关': 4,
#                           '产量': 1,
#                           '存在': 2,
#                           '需要': 1,
#                           '档次': 1,
#                           '成员国': 1,
#                           '元首': 1,
#                           '乘': 1,
#                           '驻': 1,
#                           '江': 1,
#                           '泽民': 1,
#                           '主席': 1,
#                           '夫妇': 1,
#                           '相望': 1,
#                           '国务院': 1,
#                           '博物馆': 1,
#                           '人们': 1,
#                           '户': 1,
#                           '建筑物': 1,
#                           '依然': 1,
#                           '总是': 1,
#                           '情不自禁': 1,
#                           '一样': 1,
#                           '住': 1,
#                           '交': 1,
#                           '几': 3,
#                           '转化': 1,
#                           '制造': 1,
#                           '里': 3,
#                           '使用': 2,
#                           '估计': 1,
#                           '发出': 2,
#                           '多': 3,
#                           '信仰': 1,
#                           '状态': 1,
#                           '逢': 1,
#                           '支持': 1,
#                           '30': 1,
#                           '价格': 3,
#                           '指数': 1,
#                           '行情': 1,
#                           '转': 1,
#                           '数字': 1,
#                           '出局': 1,
#                           '去': 1,
#                           '迎接': 2,
#                           '面对': 1,
#                           '队': 3,
#                           '尽': 1,
#                           '般': 1,
#                           '项目': 2,
#                           '军': 3,
#                           '儿童': 1,
#                           '军事': 1,
#                           '这里': 2,
#                           '性': 1,
#                           '水平': 3,
#                           '纷纷': 1,
#                           '生命': 1,
#                           '了解': 1,
#                           '办理': 1,
#                           '手续': 1,
#                           '桂林': 1,
#                           '官兵': 1,
#                           '赶赴': 1,
#                           '做': 2,
#                           '好': 2,
#                           '待': 1,
#                           '航线': 1,
#                           '获': 1,
#                           '便': 1,
#                           '情况': 2,
#                           '初': 1,
#                           '双管齐下': 1,
#                           '似乎': 1,
#                           '行驶': 8,
#                           '者': 3,
#                           '准予': 1,
#                           '商户': 2,
#                           '增加': 1,
#                           '——': 3,
#                           '办': 1,
#                           '实业': 1,
#                           '每': 1,
#                           '人士': 2,
#                           '金额': 1,
#                           '达到': 3,
#                           '人民币': 1,
#                           '如果': 1,
#                           '规定': 1,
#                           '执行': 1,
#                           '人口': 1,
#                           '组成': 2,
#                           '家庭': 1,
#                           '日前': 1,
#                           '显示': 1,
#                           '面积': 1,
#                           '量': 1,
#                           '人次': 1,
#                           '连续': 1,
#                           '片': 1,
#                           '部门': 3,
#                           '受聘': 1,
#                           '我': 2,
#                           '各族': 1,
#                           '领导': 1,
#                           '从事': 1,
#                           '部长': 1,
#                           '所在': 1,
#                           '持': 1,
#                           '态度': 1,
#                           '这个': 2,
#                           '民间': 1,
#                           '为期': 2,
#                           '动物': 1,
#                           '居': 1,
#                           '阻挡': 1,
#                           '生态': 1,
#                           '工程': 1,
#                           '封山': 1,
#                           '资源': 1,
#                           '得到': 3,
#                           '只': 1,
#                           '消息': 1,
#                           '尼日尔': 1,
#                           '地位': 1,
#                           '从而': 1,
#                           '排列': 1,
#                           '及': 1,
#                           '其他': 2,
#                           '日本': 1,
#                           '教': 1,
#                           '口': 1,
#                           '案件': 1,
#                           '田': 1,
#                           '聪明': 1,
#                           '事情': 1,
#                           '留下': 1,
#                           '新华社': 1,
#                           '值得': 1,
#                           '前往': 1,
#                           '逐步': 1,
#                           '转变': 1,
#                           '以往': 1,
#                           '新建': 1,
#                           '改建': 1,
#                           '采用': 1,
#                           '制': 1,
#                           '致': 1,
#                           '促使': 1,
#                           '实现': 1,
#                           '领土': 1,
#                           '法国': 1,
#                           '状况': 1,
#                           '走向': 1,
#                           '由于': 1,
#                           '按': 1,
#                           '社会': 1,
#                           '身': 1,
#                           '靠': 1,
#                           '中的': 1,
#                           '个人': 1,
#                           '得分': 1,
#                           '名列': 2,
#                           '爆': 1,
#                           '冷门': 1,
#                           '终了': 1,
#                           '加赛': 1,
#                           '终于': 1,
#                           '差': 1,
#                           '天主教': 1,
#                           '侵害': 1,
#                           '检视': 1,
#                           '这项': 2,
#                           '和解': 1,
#                           '协议': 2,
#                           '赔偿': 1,
#                           '？': 1,
#                           '，': 18,
#                           '但是': 1,
#                           '遍': 1,
#                           '购买': 2,
#                           '所有': 1,
#                           '确实': 3,
#                           '其实': 1,
#                           '够': 1,
#                           '怎么': 1,
#                           '呢': 2,
#                           '啊': 1,
#                           'TM': 1,
#                           '贵': 1,
#                           '吧': 1,
#                           '产品': 2,
#                           '或': 1,
#                           '类似': 1,
#                           '没有': 1,
#                           '大概': 1,
#                           '这样': 1,
#                           '打': 1,
#                           '典型': 1,
#                           '本身': 1,
#                           '什么': 1,
#                           '整个': 1,
#                           '台': 1,
#                           '随': 1,
#                           '流逝': 1,
#                           '也许': 1,
#                           '可': 1,
#                           '为止': 1,
#                           '孩子': 1,
#                           '将来': 1,
#                           '乐于': 1,
#                           '积极': 1,
#                           '无论是': 1,
#                           '堆起': 1,
#                           '形象思维': 1,
#                           '发挥': 1,
#                           '新': 1,
#                           '发现': 1,
#                           '---': 1}),
#              'as': defaultdict(int,
#                          {'因为': 2,
#                           '作': 1,
#                           '由于': 5,
#                           '作为': 4,
#                           '身': 1,
#                           '为': 4,
#                           '是': 3,
#                           '因': 1,
#                           '如': 2,
#                           '与': 1,
#                           '按': 1,
#                           '据': 3}),
#              'alleged': defaultdict(int, {'声称': 1, '指称': 2, '自称': 2}),
#              'sexual': defaultdict(int, {'性': 3}),
#              'abuse': defaultdict(int, {'侵害': 2, '滥用': 1}),
#              'of': defaultdict(int,
#                          {'的': 123,
#                           '于': 1,
#                           '之': 1,
#                           '因': 1,
#                           '向': 1,
#                           '在': 1,
#                           '中': 1}),
#              'cases': defaultdict(int, {'案子': 1, '病例': 2, '案件': 2}),
#              'keep surfacing': defaultdict(int, {'越来越': 1, '多': 1}),
#              ',': defaultdict(int,
#                          {',': 484,
#                           '、': 115,
#                           ':': 2,
#                           '--': 1,
#                           '。': 3,
#                           ';': 2,
#                           '，': 59,
#                           '那么': 1,
#                           '但': 1}),
#              'and': defaultdict(int,
#                          {'而且': 4,
#                           '和': 188,
#                           '与': 57,
#                           '以及': 24,
#                           '并': 38,
#                           '及': 16,
#                           '至': 1,
#                           '或': 1,
#                           '还': 1,
#                           '又': 2,
#                           '加上': 3,
#                           '并且': 4,
#                           '、': 4,
#                           '暨': 1,
#                           '同': 1,
#                           '同时': 1,
#                           '而': 2,
#                           '，': 15,
#                           '就': 1,
#                           '也': 1}),
#              '"': defaultdict(int,
#                          {'「': 104,
#                           '」': 104,
#                           '。': 1,
#                           '"': 86,
#                           '》': 8,
#                           '《': 7}),
#              'since': defaultdict(int,
#                          {'在': 2,
#                           '后': 4,
#                           '自': 8,
#                           '以来': 13,
#                           '由于': 3,
#                           '因': 1,
#                           '自从': 2,
#                           '起': 1,
#                           '从': 3,
#                           '来': 1,
#                           '开始': 1,
#                           '是': 1}),
#              'leading': defaultdict(int, {'促成': 1, '主导': 1}),
#              'process': defaultdict(int, {'程序': 1, '进程': 1, '过程': 2, '处理': 3}),
#              'started': defaultdict(int, {'开始': 5, '着手': 1, '起': 1}),
#              'situation': defaultdict(int,
#                          {'情况': 3, '情势': 4, '局势': 2, '形势': 4}),
#              'has': defaultdict(int,
#                          {'已经': 8,
#                           '已': 22,
#                           '曾': 2,
#                           '有': 1,
#                           '开设': 1,
#                           '还': 1,
#                           '原本': 1}),
#              'dramatically': defaultdict(int,
#                          {'很': 1,
#                           '大': 1,
#                           '大幅': 1,
#                           '显著': 1,
#                           '大大': 1,
#                           '大幅度': 1}),
#              'changed': defaultdict(int, {'变化': 1}),
#              '.': defaultdict(int,
#                          {'。': 859, ',': 140, ';': 7, '」': 1, '；': 1, '，': 1}),
#              '66-year-old': defaultdict(int, {'六十六': 1, '岁': 1}),
#              'geoghan': defaultdict(int, {'吉欧根': 3}),
#              'for': defaultdict(int,
#                          {'因为': 3,
#                           '为': 12,
#                           '对': 7,
#                           '因': 2,
#                           '针对': 1,
#                           '以': 1,
#                           '用于': 3,
#                           '寻求': 1,
#                           '由于': 1,
#                           '给': 1,
#                           '购买': 1,
#                           '应该': 1,
#                           '买': 1,
#                           '到': 1}),
#              'in': defaultdict(int,
#                          {'在': 163,
#                           '上': 11,
#                           '于': 12,
#                           '间': 5,
#                           '中': 42,
#                           '到': 2,
#                           '时': 8,
#                           '地处': 1,
#                           '内': 6,
#                           '以': 3,
#                           '处于': 1,
#                           '为了': 1,
#                           '对': 4,
#                           '当中': 1,
#                           '下': 1,
#                           '驻': 3,
#                           '身着': 1,
#                           '里': 3,
#                           '的': 1,
#                           '用': 1}),
#              '1991': defaultdict(int, {'一九九一年': 1}),
#              'molestation': defaultdict(int, {'侵害': 1}),
#              'a': defaultdict(int,
#                          {'一': 83,
#                           '一个': 21,
#                           '个': 4,
#                           '台': 4,
#                           '款': 3,
#                           '种': 1,
#                           '这个': 1}),
#              '10-year-old': defaultdict(int, {'十': 1, '岁': 1}),
#              'boy': defaultdict(int, {'男童': 1, '男孩': 1}),
#              'recently': defaultdict(int,
#                          {'最近': 8, '近来': 2, '近日': 2, '日前': 2}),
#              'was': defaultdict(int,
#                          {'被': 5,
#                           '是': 5,
#                           '遭': 2,
#                           '已经': 1,
#                           '遭到': 4,
#                           '为': 6,
#                           '堪称': 1}),
#              'sentenced': defaultdict(int, {'判处': 3, '判': 3}),
#              '10': defaultdict(int, {'十': 6, '十日': 1, '10': 6, '10日': 2}),
#              'years': defaultdict(int, {'年': 26, '岁': 1}),
#              'imprisonment': defaultdict(int, {'徒刑': 1}),
#              'defrocked': defaultdict(int, {'削去': 1}),
#              'priest': defaultdict(int, {'教士': 4}),
#              'also': defaultdict(int,
#                          {'还': 19, '也': 33, '又': 3, '并': 2, '兼': 1}),
#              'faces': defaultdict(int, {'面临': 3}),
#              'other': defaultdict(int, {'其他': 26, '其它': 4, '另外': 1, '一': 1}),
#              'criminal': defaultdict(int, {'刑事': 3, '犯罪': 2}),
#              'trials': defaultdict(int, {'审判': 1, '考验': 1}),
#              'scores': defaultdict(int, {'数十': 1}),
#              'civil': defaultdict(int, {'民事': 1}),
#              'lawsuits': defaultdict(int, {'官司': 1}),
#              'us': defaultdict(int,
#                          {'美': 7,
#                           '美军': 2,
#                           '美国': 94,
#                           '美方': 1,
#                           '我们': 1,
#                           '美属': 1,
#                           '全美': 1}),
#              'india': defaultdict(int, {'印': 8, '印度': 35}),
#              'mid-may': defaultdict(int, {'五月': 3, '中': 2, '中旬': 1}),
#              'conduct': defaultdict(int, {'举行': 3, '进行': 2}),
#              '4 decades': defaultdict(int, {'四十': 1}),
#              'decades': defaultdict(int, {'年': 1}),
#              'first': defaultdict(int,
#                          {'首次': 6,
#                           '第一': 13,
#                           '先': 1,
#                           '首位': 1,
#                           '前': 1,
#                           '头': 2,
#                           '一': 1,
#                           '首': 7,
#                           '第1': 1}),
#              'joint': defaultdict(int, {'联合': 12, '共同': 5, '联手': 2, '合作': 1}),
#              'military': defaultdict(int,
#                          {'军事': 16, '军队': 2, '军': 6, '军方': 7, '武装': 1}),
#              'exercise': defaultdict(int, {'演习': 7}),
#              '(': defaultdict(int, {'(': 107, '（': 6}),
#              'afp': defaultdict(int, {'法新社': 50}),
#              'new delhi': defaultdict(int, {'新德里': 6}),
#              ')': defaultdict(int, {')': 105, '）': 6}),
#              'united states': defaultdict(int,
#                          {'美国': 46, '美': 4, '美方': 2, '华府': 1, '美军': 1}),
#              'will': defaultdict(int,
#                          {'将': 96,
#                           '会': 13,
#                           '即将': 1,
#                           '就': 1,
#                           '能够': 1,
#                           '能': 1,
#                           '应该': 1,
#                           '算是': 1,
#                           '已经': 1,
#                           '必将': 1}),
#              '39': defaultdict(int, {'三十九': 1}),
#              'world': defaultdict(int, {'世界': 17, '全球': 4, '全世界': 2}),
#              'two': defaultdict(int, {'两': 41}),
#              'largest': defaultdict(int, {'最': 7, '大': 8}),
#              'democracies': defaultdict(int, {'民主': 1, '国家': 1}),
#              'between': defaultdict(int, {'间': 5, '之间': 11, '在': 1}),
#              'cooperation': defaultdict(int, {'合作': 18}),
#              'mark': defaultdict(int, {'缔造': 1}),
#              'milestone': defaultdict(int, {'里程碑': 1}),
#              'ministry of national defense': defaultdict(int, {'国防部': 3}),
#              'said': defaultdict(int,
#                          {'说': 134,
#                           '表示': 28,
#                           '称': 8,
#                           '指': 1,
#                           '曾经': 1,
#                           '过': 1}),
#              'an': defaultdict(int,
#                          {'一': 18, '一个': 4, '安': 3, '1': 1, '个': 2}),
#              'elite': defaultdict(int, {'精锐': 1}),
#              'indian': defaultdict(int, {'印度': 11, '印': 1}),
#              'paratroopers': defaultdict(int, {'伞兵': 1}),
#              'brigade': defaultdict(int, {'旅': 1}),
#              'with': defaultdict(int,
#                          {'与': 56,
#                           '和': 4,
#                           '把': 1,
#                           '具有': 1,
#                           '拥有': 2,
#                           '对': 2,
#                           '由于': 1,
#                           '向': 4,
#                           '以': 2,
#                           '患有': 1,
#                           '随着': 2,
#                           '持有': 1,
#                           '一起': 1,
#                           '之间': 1}),
#              'pacific': defaultdict(int, {'太平洋': 1}),
#              'command': defaultdict(int, {'司令部': 1}),
#              'special forces': defaultdict(int, {'特种部队': 1}),
#              'near': defaultdict(int, {'在': 1, '附近': 3, '靠近': 1}),
#              'renowned': defaultdict(int, {'闻名遐迩': 1}),
#              'taj': defaultdict(int, {'泰姬': 1}),
#              'mahal': defaultdict(int, {'马哈陵': 1}),
#              'nations': defaultdict(int,
#                          {'国': 5, '国家': 14, '各国': 2, '会员国': 2}),
#              'air forces': defaultdict(int, {'空军': 1}),
#              'provide': defaultdict(int, {'给以': 1, '提供': 6}),
#              'support': defaultdict(int, {'支援': 1, '支持': 8}),
#              'it': defaultdict(int,
#                          {'这': 2,
#                           '它': 13,
#                           '大家': 1,
#                           '电脑': 1,
#                           '上': 1,
#                           'Google': 1}),
#              'be': defaultdict(int,
#                          {'是': 9, '为': 1, '兼任': 1, '被': 2, '有': 2, '成为': 1}),
#              'conducted': defaultdict(int, {'举行': 3, '进行': 2}),
#              'many': defaultdict(int,
#                          {'多次': 1, '许多': 14, '人': 1, '多': 1, '很多': 2}),
#              'exercises': defaultdict(int, {'演习': 2}),
#              'during': defaultdict(int,
#                          {'在': 14,
#                           '当中': 1,
#                           '中': 7,
#                           '期间': 3,
#                           '内': 2,
#                           '的': 1,
#                           '过程': 1}),
#              'cold war': defaultdict(int, {'冷战': 1}),
#              'era': defaultdict(int, {'时期': 1}),
#              'relations': defaultdict(int, {'关系': 4}),
#              'strained': defaultdict(int, {'紧张': 1}),
#              'however': defaultdict(int,
#                          {'但': 14,
#                           '但是': 7,
#                           '不过': 10,
#                           '则': 1,
#                           '而': 2,
#                           '然而': 1}),
#              'sept. 11': defaultdict(int, {'九一一': 8, '9·11': 1}),
#              'new york': defaultdict(int, {'纽约': 6}),
#              'washington': defaultdict(int, {'华盛顿': 17, '华府': 4}),
#              'terrorist': defaultdict(int, {'恐怖分子': 3, '恐怖': 14, '恐怖主义': 1}),
#              'attacks': defaultdict(int, {'攻击': 13, '袭击': 3}),
#              'been': defaultdict(int,
#                          {'见': 1,
#                           '被': 4,
#                           '遭到': 2,
#                           '是': 3,
#                           '发生': 1,
#                           '有': 1,
#                           '正在': 1,
#                           '得到': 1}),
#              'improved': defaultdict(int, {'改善': 2, '改进': 2, '了': 1}),
#              'apart from': defaultdict(int,
#                          {'除': 2, '之外': 1, '除了': 1, '外': 2}),
#              'navy': defaultdict(int, {'海军': 2}),
#              'indonesia': defaultdict(int, {'印尼': 1, '印度尼西亚': 2}),
#              'malaysia': defaultdict(int, {'马来西亚': 9}),
#              'malacca': defaultdict(int, {'麻六甲': 1}),
#              'strait': defaultdict(int, {'海峡': 1}),
#              'sea': defaultdict(int, {'海上': 1, '海': 1}),
#              'patrolling': defaultdict(int, {'巡逻': 2}),
#              'so as to prevent': defaultdict(int, {'以防': 1}),
#              'piracy': defaultdict(int, {'海盗': 1}),
#              'acts': defaultdict(int, {'行为': 1}),
#              'recent years': defaultdict(int, {'近年': 2, '近年来': 1}),
#              'britain': defaultdict(int, {'英国': 11}),
#              'france': defaultdict(int, {'法国': 9}),
#              'japan': defaultdict(int, {'日本': 25, '日': 1}),
#              'spokesman': defaultdict(int, {'发言人': 6}),
#              ':': defaultdict(int, {':': 73, ',': 4, '：': 3, '。': 1}),
#              'upcoming': defaultdict(int, {'即将': 2, '举行': 1}),
#              'aims at': defaultdict(int, {'旨在': 1}),
#              'further': defaultdict(int, {'进一步': 12, '又': 1, '还': 1, '再次': 1}),
#              'enhancing': defaultdict(int, {'提升': 1, '提高': 1}),
#              'last time': defaultdict(int, {'上次': 1}),
#              'after': defaultdict(int,
#                          {'在': 20,
#                           '之后': 11,
#                           '继': 3,
#                           '后': 34,
#                           '当': 1,
#                           '经过': 5,
#                           '于': 1,
#                           '经': 1}),
#              '1962': defaultdict(int, {'一九六二年': 1}),
#              'china': defaultdict(int, {'中国': 45, '中': 3}),
#              'brief': defaultdict(int, {'短暂': 1, '简短': 1}),
#              'border': defaultdict(int, {'边界': 11, '边防': 2, '边境': 1}),
#              'war': defaultdict(int, {'战争': 7}),
#              'year': defaultdict(int, {'年': 6, '年度': 2, '今年': 1}),
#              'last': defaultdict(int, {'去年': 4, '过去': 2, '上': 2, '最后': 3}),
#              'july': defaultdict(int, {'七月': 1, '7月': 2}),
#              'about': defaultdict(int,
#                          {'大约': 4,
#                           '约': 21,
#                           '有关': 1,
#                           '至于': 1,
#                           '左右': 2,
#                           '对': 1,
#                           '大概': 1,
#                           '将': 1,
#                           '是': 1}),
#              '50': defaultdict(int, {'五十': 5}),
#              'policy makers': defaultdict(int, {'决策': 2}),
#              'makers': defaultdict(int, {'人员': 1, '方面': 1, '业者': 1}),
#              'visited': defaultdict(int, {'访问': 1, '参观': 1}),
#              'while': defaultdict(int,
#                          {'同时': 5,
#                           '时': 4,
#                           '时间': 1,
#                           '当': 2,
#                           '值': 1,
#                           '之际': 1,
#                           '而且': 1,
#                           '而': 4,
#                           '当时': 1,
#                           '在': 1}),
#              'equal number': defaultdict(int, {'这么': 1, '多': 1}),
#              'people': defaultdict(int,
#                          {'人': 23,
#                           '人民': 9,
#                           '民众': 2,
#                           '群众': 1,
#                           '全国': 1,
#                           '人们': 4,
#                           '人口': 2,
#                           '百姓': 1,
#                           '人士': 3,
#                           '居民': 1,
#                           '消费者': 1,
#                           '顾客': 1}),
#              'including': defaultdict(int,
#                          {'包括': 15,
#                           '其中': 5,
#                           '在内': 3,
#                           '不': 1,
#                           '例外': 1,
#                           '含': 2}),
#              'vajpayee': defaultdict(int, {'瓦巴依': 2}),
#              'prime minister': defaultdict(int, {'总理': 14, '首相': 2}),
#              'his': defaultdict(int, {'他': 22, '的': 16, '其': 2}),
#              'national': defaultdict(int,
#                          {'国家': 6, '全国': 5, '国家级': 3, '民族': 1}),
#              'security': defaultdict(int, {'安全': 19, '措施': 1}),
#              'team': defaultdict(int,
#                          {'团队': 1, '队': 11, '队伍': 1, '全体': 1, '队员': 1}),
#              'paid to': defaultdict(int, {'前往': 1}),
#              'visits': defaultdict(int, {'访问': 1, '参观': 1}),
#              'december': defaultdict(int, {'十二月': 2, '12月': 4}),
#              'national parliament': defaultdict(int, {'国会': 1}),
#              'attack': defaultdict(int, {'攻击': 8, '出击': 1, '事件': 1}),
#              'led': defaultdict(int, {'致使': 1, '为首': 1, '领军': 1}),
#              'pakistan': defaultdict(int, {'巴基斯坦': 17, '巴': 6, '国': 2}),
#              'tensions': defaultdict(int,
#                          {'紧张': 13, '情势': 6, '关系': 2, '局面': 1, '局势': 2}),
#              'contacts': defaultdict(int, {'接触': 1}),
#              'increased': defaultdict(int,
#                          {'增加': 5, '上升': 1, '增长': 1, '增强': 1, '的': 1}),
#              'diplomat': defaultdict(int, {'外交官': 1}),
#              'national defense': defaultdict(int, {'国防': 1}),
#              'february': defaultdict(int, {'二月': 2, '2月份': 1}),
#              'decided': defaultdict(int, {'敲定': 1, '决定': 8}),
#              'partly': defaultdict(int, {'部分': 1}),
#              'wanted': defaultdict(int, {'为了': 1, '要': 1, '要求': 1, '通缉': 1}),
#              'ease': defaultdict(int, {'缓和': 1, '缓解': 1}),
#              'over': defaultdict(int,
#                          {'因': 2,
#                           '在': 4,
#                           '内': 3,
#                           '对': 4,
#                           '以上': 5,
#                           '多': 12,
#                           '于': 1,
#                           '较': 3,
#                           '结束': 3,
#                           '逾': 1,
#                           '就': 2,
#                           '比': 7}),
#              'relationship': defaultdict(int, {'关系': 5}),
#              'strengthening': defaultdict(int, {'强化': 1}),
#              'discomfort': defaultdict(int, {'不安': 1, '情绪': 1}),
#              'south african': defaultdict(int, {'南非': 2}),
#              'space': defaultdict(int, {'太空': 14}),
#              'tourist': defaultdict(int, {'观光客': 4, '旅游': 1}),
#              'travel': defaultdict(int, {'旅': 5, '旅行': 5, '旅游': 2}),
#              'back to': defaultdict(int, {'返抵': 2}),
#              'earth': defaultdict(int, {'地球': 3}),
#              'moscow': defaultdict(int, {'莫斯科': 5, '俄罗斯': 1}),
#              'shuttleworth': defaultdict(int, {'夏特沃斯': 8}),
#              '5th': defaultdict(int, {'五日': 1}),
#              'he': defaultdict(int, {'他': 79, '自己': 1, '何': 1, '怪兽': 1}),
#              'boarded': defaultdict(int, {'搭乘': 2}),
#              'russian': defaultdict(int, {'俄罗斯': 9, '俄方': 1, '俄': 6}),
#              'spacecraft': defaultdict(int, {'太空船': 4}),
#              'at': defaultdict(int,
# ...
#              '8%': defaultdict(int, {'百分之八': 1}),
#              ';': defaultdict(int, {',': 13, ';': 5}),
#              'compared': defaultdict(int, {'较': 1}),
#              '1997': defaultdict(int, {'一九九七年': 2, '1997年': 1}),
#              'highest': defaultdict(int,
#                          {'最高点': 1, '最高': 3, '最': 1, '崇高': 1, '首': 1}),
#              '760': defaultdict(int, {'七百六十': 1}),
#              'almost': defaultdict(int, {'几乎': 3, '险些': 1}),
#              'holds': defaultdict(int, {'举行': 2, '具有': 1, '认为': 1}),
#              'elections': defaultdict(int, {'选举': 5}),
#              'lift': defaultdict(int, {'解除': 3}),
#              'embargo': defaultdict(int, {'禁运': 3, '禁令': 1}),
#              'only if': defaultdict(int, {'如果': 1}),
#              'can': defaultdict(int,
#                          {'可': 5, '可以': 7, '会': 1, '能': 7, '可能': 1, '能够': 3}),
#              'proved': defaultdict(int, {'证明': 2}),
#              'fair': defaultdict(int, {'公正': 3}),
#              'promotes': defaultdict(int, {'推动': 1, '促进': 1, '推出': 1}),
#              'system': defaultdict(int,
#                          {'制度': 2, '制': 2, '体系': 1, '机制': 2, '体制': 1}),
#              'reform': defaultdict(int, {'改革': 2, '改造': 1}),
#              '41-year-old': defaultdict(int, {'四十一': 1, '年': 1}),
#              'against': defaultdict(int, {'针对': 2, '反': 1, '对': 4, '反对': 1}),
#              'speech': defaultdict(int, {'演说': 5, '致词': 1, '演讲': 1}),
#              'only': defaultdict(int,
#                          {'只有': 3, '只': 3, '唯一': 2, '仅': 3, '仅仅': 1}),
#              'till': defaultdict(int, {'到': 2}),
#              'then': defaultdict(int,
#                          {'那个': 1, '时候': 1, '就': 1, '然后': 1, '那么': 1}),
#              'congress': defaultdict(int, {'国会': 2, '大会': 1}),
#              'work': defaultdict(int, {'努力': 2, '工作': 1}),
#              'remove': defaultdict(int, {'解除': 1, '取消': 1, '消除': 1}),
#              'jimmy carter': defaultdict(int, {'吉米.卡特': 1}),
#              'went to': defaultdict(int, {'前往': 1}),
#              'americas': defaultdict(int, {'美洲': 1}),
#              'country': defaultdict(int, {'国家': 3, '全国': 4}),
#              'called for': defaultdict(int, {'呼吁': 5}),
#              'returned': defaultdict(int, {'返回': 3}),
#              'merely': defaultdict(int, {'仅': 1, '只': 1}),
#              '48': defaultdict(int, {'四十八': 1}),
#              'hours': defaultdict(int, {'小时': 5}),
#              'most recent': defaultdict(int, {'最新': 4, '最近': 1}),
#              'proposed': defaultdict(int, {'提议': 3, '建议': 1, '拟议': 1}),
#              'step up': defaultdict(int, {'增加': 1, '加强': 1}),
#              'humanitarian': defaultdict(int, {'人道': 2}),
#              'assistance': defaultdict(int,
#                          {'援助': 5, '协助': 2, '帮助': 1, '协作': 1}),
#              'through': defaultdict(int,
#                          {'经由': 1, '至': 1, '直到': 1, '经': 1, '通过': 5, '经过': 1}),
#              'non-governmental': defaultdict(int, {'民间': 1}),
#              'agencies': defaultdict(int, {'机构': 4, '部门': 2}),
#              'directly': defaultdict(int, {'直接': 2}),
#              'reach': defaultdict(int, {'达成': 6, '达': 3, '达到': 2}),
#              'agreements': defaultdict(int, {'协议': 3, '文件': 1}),
#              'resuming': defaultdict(int, {'重新': 1, '恢复': 1}),
#              'countries': defaultdict(int, {'国': 6, '国家': 11}),
#              'direct': defaultdict(int, {'直接': 2}),
#              'mail service': defaultdict(int, {'通邮': 1}),
#              'hold': defaultdict(int, {'举行': 9, '进行': 2, '举办': 1, '停靠': 1}),
#              'so far': defaultdict(int,
#                          {'以往': 1, '目前': 1, '迄今': 2, '至今': 1, '此前': 1}),
#              'consistently': defaultdict(int, {'一直': 1}),
#              'rejected': defaultdict(int, {'拒绝': 1}),
#              'india-pakistan': defaultdict(int,
#                          {'印度': 1, '与': 1, '巴基斯坦': 1, '印': 4, '巴': 4}),
#              'overnight': defaultdict(int, {'彻夜': 1}),
#              'shelling': defaultdict(int, {'炮击': 4, '炮轰': 2}),
#              'death': defaultdict(int,
#                          {'丧生': 3,
#                           '死亡': 5,
#                           '遇害': 1,
#                           '被': 1,
#                           '杀': 1,
#                           '身亡': 1,
#                           '死刑': 5}),
#              'toll': defaultdict(int, {'人数': 7, '人': 1}),
#              'jammu': defaultdict(int, {'查摩': 3}),
#              'police': defaultdict(int, {'警方': 9, '警察': 1, '警察局': 2, '警务': 1}),
#              'disputed': defaultdict(int, {'引起': 1, '争议': 2, '争执': 1}),
#              'kashmir': defaultdict(int, {'克什米尔': 7}),
#              'area': defaultdict(int, {'地区': 10, '一带': 1, '面积': 2, '土地': 1}),
#              'left': defaultdict(int, {'导致': 1, '让': 1, '离开': 1}),
#              'one': defaultdict(int, {'一': 11, '人': 1, '一个': 5, '1': 1}),
#              'soldier': defaultdict(int, {'士兵': 4, '军人': 1}),
#              'three': defaultdict(int, {'三': 17, '3': 15}),
#              'civilians': defaultdict(int, {'平民': 3}),
#              'dead': defaultdict(int, {'丧生': 3, '死亡': 4}),
#              'children': defaultdict(int,
#                          {'儿童': 4,
#                           '孩子': 7,
#                           '子女': 1,
#                           '孩子们': 1,
#                           '他们': 1,
#                           '的': 1}),
#              'took place': defaultdict(int, {'发生': 4}),
#              'southern': defaultdict(int, {'南部': 5, '南方': 3, '南端': 1}),
#              'winter capital': defaultdict(int, {'冬宫': 1}),
#              'west of': defaultdict(int, {'以西': 1}),
#              '75': defaultdict(int, {'七十五': 1}),
#              'km': defaultdict(int, {'公里': 4}),
#              'baramulla': defaultdict(int, {'帕朗瓦拉': 1}),
#              'sources': defaultdict(int, {'消息': 4, '人士': 3, '信息': 1}),
#              'pakistani': defaultdict(int, {'巴基斯坦': 7, '巴': 2, '国': 1}),
#              'throughout the night': defaultdict(int, {'彻夜': 1}),
#              'bombarded': defaultdict(int, {'发射': 1, '炮轰': 1}),
#              'heavy': defaultdict(int, {'重': 1, '大': 1}),
#              'mortar fire': defaultdict(int, {'迫击炮': 1}),
#              'rocket-propelled': defaultdict(int, {'火箭': 1, '推进': 1}),
#              'grenades': defaultdict(int, {'手榴弹': 1}),
#              'mortar': defaultdict(int, {'迫击炮': 1}),
#              'hit': defaultdict(int,
#                          {'击中': 1, '发生': 1, '水灾': 1, '受灾': 1, '袭击': 1}),
#              'residential structure': defaultdict(int, {'民宅': 1}),
#              'killing': defaultdict(int,
#                          {'炸': 1, '死': 1, '死亡': 3, '造成': 2, '杀人': 1, '杀害': 2}),
#              'adult': defaultdict(int, {'成人': 1}),
#              'same': defaultdict(int, {'同一': 3, '同样': 1, '同': 1, '相同': 1}),
#              'cross-border': defaultdict(int, {'越界': 3}),
#              'died': defaultdict(int, {'丧生': 2, '丧命': 1, '死': 1, '死亡': 1}),
#              'poonch': defaultdict(int, {'彭琪': 1}),
#              'along': defaultdict(int, {'沿着': 1, '沿': 1}),
#              'separating': defaultdict(int, {'分隔': 1}),
#              'territories': defaultdict(int, {'辖区': 1, '土地': 1}),
#              'control': defaultdict(int, {'控制': 1, '把持': 1, '管制': 1}),
#              'demarcation': defaultdict(int, {'分界线': 1}),
#              'throughout night': defaultdict(int, {'彻夜': 1}),
#              'came': defaultdict(int, {'爆发': 1, '来': 1}),
#              'heavy artillery': defaultdict(int, {'重炮': 1}),
#              'fires': defaultdict(int, {'攻击': 1}),
#              'in the meantime': defaultdict(int, {'同时': 2, '期间': 1}),
#              'official': defaultdict(int,
#                          {'官员': 9, '官方': 3, '干部': 1, '正式': 4, '人士': 5}),
#              'this morning': defaultdict(int, {'今早': 1}),
#              'resumed': defaultdict(int, {'恢复': 1, '重新': 1, '履行': 1}),
#              'pakistan-controlled': defaultdict(int, {'巴基斯坦': 1, '控制': 1}),
#              'pakistanis': defaultdict(int, {'巴基斯坦': 1}),
#              'rise': defaultdict(int,
#                          {'增加': 2, '升高': 1, '上升': 1, '增长': 1, '提高': 1}),
#              '12': defaultdict(int, {'十二': 5, '12日': 1, '12': 2}),
#              'irish': defaultdict(int, {'爱尔兰': 7}),
#              'soccer team': defaultdict(int, {'足球队': 3}),
#              'captain': defaultdict(int, {'队长': 3}),
#              'keane': defaultdict(int, {'基恩': 3}),
#              'announces': defaultdict(int, {'宣布': 3, '发布': 1, '公布': 1}),
#              'world cup': defaultdict(int, {'世界杯': 21}),
#              'retire': defaultdict(int, {'退休': 2}),
#              'dublin': defaultdict(int, {'都柏林': 2}),
#              'heart and soul': defaultdict(int, {'灵魂': 1}),
#              'roy keane': defaultdict(int, {'罗伊基恩': 1}),
#              'announced': defaultdict(int, {'宣布': 14, '公布': 2, '发表': 1}),
#              'whereas': defaultdict(int, {'而': 1}),
#              'yesterday': defaultdict(int, {'昨天': 4}),
#              'threatened': defaultdict(int, {'威胁': 2, '扬言': 2, '可能': 1}),
#              'quit': defaultdict(int, {'退出': 3}),
#              'representative team': defaultdict(int, {'代表队': 3}),
#              'manchester': defaultdict(int, {'曼彻斯特': 1}),
#              'united': defaultdict(int, {'联队': 1}),
#              'midfielder': defaultdict(int, {'中场': 1, '大将': 1}),
#              'tv station': defaultdict(int, {'电视台': 3}),
#              'emotional': defaultdict(int, {'感性': 1}),
#              'interview': defaultdict(int, {'访问': 3, '谈话': 2, '采访': 1}),
#              'announcement': defaultdict(int, {'宣布': 4, '声明': 1, '发表': 1}),
#              'lashed': defaultdict(int, {'严厉': 1, '抨击': 1}),
#              'ireland': defaultdict(int, {'爱尔兰': 3}),
#              'preparation': defaultdict(int, {'准备': 3}),
#              'not making adequate': defaultdict(int, {'不当': 1}),
#              'currently': defaultdict(int, {'目前': 7, '正': 1}),
#              'pacific ocean': defaultdict(int, {'太平洋': 1}),
#              'saipan': defaultdict(int, {'塞班岛': 1}),
#              'training': defaultdict(int, {'集训': 2, '训练': 5, '培养': 1}),
#              'this week': defaultdict(int, {'本周': 4}),
#              'a few': defaultdict(int, {'几': 5, '数': 1}),
#              'later': defaultdict(int, {'之后': 1, '晚': 1}),
#              'again': defaultdict(int, {'又': 6, '再度': 4, '再次': 1, '再': 2}),
#              'offered': defaultdict(int, {'表示': 2, '悬赏': 2}),
#              'stay': defaultdict(int, {'留下来': 2}),
#              'throwing': defaultdict(int, {'使得': 1, '使': 1}),
#              'into': defaultdict(int,
#                          {'陷入': 1, '成': 1, '进入': 1, '至': 1, '成为': 1, '到': 1}),
#              'confusion': defaultdict(int, {'紊乱': 2}),
#              'real': defaultdict(int, {'真正': 6, '非常': 1, '的': 2}),
#              'reason': defaultdict(int, {'原因': 2}),
#              'remains': defaultdict(int, {'仍': 1}),
#              'mystery': defaultdict(int, {'不得而知': 1}),
#              'failing to make appropriate': defaultdict(int, {'不当': 1}),
#              'deserves': defaultdict(int, {'应该': 1, '受到': 1}),
#              'blame': defaultdict(int, {'指责': 1}),
#              'come over': defaultdict(int, {'来': 1}),
#              'here': defaultdict(int, {'这里': 2, '此间': 4, '此地': 3}),
#              'play': defaultdict(int, {'踢': 2, '饰演': 1, '模仿': 1, '游戏': 2}),
#              'well': defaultdict(int, {'好': 2, '相当': 1}),
#              'soccer': defaultdict(int, {'球': 2, '足球': 6, '足坛': 1}),
#              'hope': defaultdict(int, {'希望': 10}),
#              'around': defaultdict(int, {'周围': 1, '环行': 1, '在': 1, '上下': 1}),
#              'too': defaultdict(int, {'也': 1, '太': 1}),
#              'want': defaultdict(int, {'想': 5, '欲': 1, '希望': 1}),
#              'if': defaultdict(int,
#                          {'假如': 4,
#                           '如': 1,
#                           '如果': 11,
#                           '假设': 1,
#                           '的话': 1,
#                           '若是': 1,
#                           '能否': 1}),
#              'common': defaultdict(int, {'相同': 1, '共同': 3, '普遍': 1}),
#              'there': defaultdict(int, {'那': 1, '那里': 1}),
#              'point': defaultdict(int, {'理由': 1}),
#              'furthermore': defaultdict(int, {'而且': 1}),
#              'going on': defaultdict(int, {'存在': 1}),
#              'regarding': defaultdict(int, {'有关': 2, '就': 1}),
#              'some': defaultdict(int,
#                          {'一些': 4,
#                           '部分': 2,
#                           '某些': 2,
#                           '些': 1,
#                           '有的': 1,
#                           '更': 1,
#                           '多': 1}),
#              'issues': defaultdict(int, {'问题': 1, '议题': 1, '事项': 1}),
#              'my': defaultdict(int, {'我': 4, '的': 3}),
#              'head': defaultdict(int, {'头': 1, '头部': 1, '率': 1}),
#              "'d like": defaultdict(int, {'想': 1}),
#              'bang': defaultdict(int, {'撞': 1}),
#              'wall': defaultdict(int, {'墙': 1}),
#              'all kinds of': defaultdict(int, {'各种': 1, '各': 1, '各项': 1}),
#              'problems': defaultdict(int, {'问题': 7}),
#              'iceberg': defaultdict(int, {'冰山': 1}),
#              'a tip': defaultdict(int, {'一角': 1}),
#              'you': defaultdict(int, {'你们': 1, '诸位': 1, '你': 11}),
#              'seen': defaultdict(int, {'看见': 1, '看到': 1, '得到': 1, '见到': 1}),
#              'pitch': defaultdict(int, {'场地': 2}),
#              "'m": defaultdict(int, {'是': 1}),
#              'self-conceited': defaultdict(int, {'自命不凡': 1}),
#              'arrangements': defaultdict(int, {'安排': 2}),
#              'leaving': defaultdict(int, {'离开': 1}),
#              'airport': defaultdict(int, {'机场': 7}),
#              'when': defaultdict(int,
#                          {'时': 11, '在': 3, '之际': 2, '当': 5, '的': 1, '时候': 1}),
#              'getting through the customs': defaultdict(int, {'通关': 1}),
#              'tons': defaultdict(int, {'一': 1, '大': 1, '堆': 1, '吨': 3}),
#              'arrives': defaultdict(int, {'抵达': 1}),
#              'historic': defaultdict(int, {'历史性': 3}),
#              'summit': defaultdict(int, {'高峰': 3, '会议': 5, '高峰会': 3, '首脑': 3}),
#              'arrived': defaultdict(int, {'抵达': 7, '来临': 1, '诞生': 1}),
#              'reduction': defaultdict(int, {'裁减': 3}),
#              'arms': defaultdict(int, {'武器': 4}),
#              'new': defaultdict(int, {'新': 25, '惊奇': 1, '新任': 1}),
#              'were': defaultdict(int,
#                          {'是': 5, '系': 1, '受': 1, '被': 3, '受到': 1, '正': 1}),
#              'bitter foes': defaultdict(int, {'宿敌': 1}),
#              'shaping': defaultdict(int, {'建立': 1}),
#              '21st-century': defaultdict(int, {'二十一': 1, '世纪': 1}),
#              'partnership': defaultdict(int, {'伙伴': 3, '关系': 3}),
#              'grand': defaultdict(int, {'隆重': 1, '盛大': 1, '完美': 1}),
#              'preparing': defaultdict(int, {'准备': 2}),
#              'entire': defaultdict(int, {'整个': 3}),
#              'stepped up': defaultdict(int, {'增强': 1, '加强': 1}),
#              'newspaper': defaultdict(int, {'报纸': 1}),
#              'cautions': defaultdict(int, {'警告': 1}),
#              'muscovites': defaultdict(int, {'莫斯科': 1, '人': 1}),
#              'watch': defaultdict(int, {'注意': 2}),
#              'secret': defaultdict(int, {'安全': 1, '秘密': 2}),
#              'snipers': defaultdict(int, {'狙击手': 1}),
#              'liberal': defaultdict(int, {'自由派': 1}),
#              'state duma': defaultdict(int, {'国会': 2}),
#              'member': defaultdict(int, {'议员': 2, '成员': 2}),
#              'khakamada': defaultdict(int, {'哈卡马达': 1}),
#              'ms.': defaultdict(int, {'女士': 2}),
#              'optimistic': defaultdict(int, {'乐观': 1}),
#              'not only': defaultdict(int, {'不仅': 3, '除了': 1, '外': 1}),
#              'because of': defaultdict(int, {'因为': 4}),
#              'expect': defaultdict(int, {'预期': 3}),
#              'sign': defaultdict(int, {'签署': 3, '迹象': 4, '标志': 1}),
#              'documents': defaultdict(int, {'文件': 2}),
#              'mutual': defaultdict(int, {'共同': 1, '双方': 1, '相互': 1}),
#              'finally': defaultdict(int, {'终于': 2, '最后': 2}),
#              'unfolding': defaultdict(int, {'展开': 1}),
#              'she': defaultdict(int, {'她': 15}),
#              ...})

# %%
# yielding the distribution of chinese words (per english word), calculate emission probability
  
to_pass_states = []
for en, ch in en_ch_count.items():
    total = float(sum(ch.values()))
    distribution = {word: count/total for word, count in ch.items()}
    en_emissions = DiscreteDistribution(distribution)
    en_state = State(en_emissions, name=en)
    to_pass_states.append(en_state)

# %%
distribution
# Out:
# {'残渣': 1.0}

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6559\u533a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "archdiocese",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8d22\u52a1" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "finance",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u59d4\u5458\u4f1a" : 0.6666666666666666,
#                  "\u7406\u4e8b\u4f1a" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "council",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8ba4\u4e3a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "thinks",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "," : 0.9683544303797469,
#                  ":" : 0.006329113924050633,
#                  "\u8fd9" : 0.012658227848101266,
#                  "\u6b3e" : 0.006329113924050633,
#                  "\uff0c" : 0.006329113924050633
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "that",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8fd9\u9879" : 0.08139534883720931,
#                  "\u8fd9" : 0.29069767441860467,
#                  "\u8fd9\u6b21" : 0.06976744186046512,
#                  "\u8fd9\u4e2a" : 0.16279069767441862,
#                  "\u6b64" : 0.19767441860465115,
#                  "\u8fd9\u79cd" : 0.08139534883720931,
#                  "\u8fd9\u90e8" : 0.011627906976744186,
#                  "\u8fd9\u5bb6" : 0.03488372093023256,
#                  "\u4eca\u5929" : 0.023255813953488372,
#                  "\u672c" : 0.011627906976744186,
#                  "\u6b64\u6b21" : 0.011627906976744186,
#                  "\u5b83" : 0.023255813953488372
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u534f\u8bae" : 0.9285714285714286,
#                  "\u534f\u5b9a" : 0.07142857142857142
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "agreement",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u53ef\u80fd" : 0.3333333333333333,
#                  "\u4f1a" : 0.047619047619047616,
#                  "\u4e94\u6708" : 0.16666666666666666,
#                  "\u4e94\u6708\u4efd" : 0.023809523809523808,
#                  "5\u6708" : 0.3333333333333333,
#                  "5\u6708\u4efd" : 0.047619047619047616,
#                  "\u53ef" : 0.023809523809523808,
#                  "\u5c06\u4f1a" : 0.023809523809523808
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "may",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4f7f\u5f97" : 0.5,
#                  "\u8feb\u4f7f" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "force",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6ce2\u58eb\u987f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "boston",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5929\u4e3b\u6559\u4f1a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "catholic archdiocese",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7834\u4ea7" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bankruptcy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "," : 0.12702512326837287,
#                  "\u53d7\u5230" : 0.002113172106128199,
#                  "\u7684" : 0.21272599201690537,
#                  "\u6709" : 0.01385301714017375,
#                  "\u540d" : 0.019253345855834703,
#                  "\u5df2" : 0.004226344212256398,
#                  "\u88ab" : 0.0039915473115754874,
#                  "\u804c\u52a1" : 0.00023479690068091102,
#                  "\u4ed6" : 0.0009391876027236441,
#                  "\u4ef6" : 0.00046959380136182204,
#                  "\u5c06" : 0.009626672927917352,
#                  "\u6765" : 0.006574313219065508,
#                  "\u7535" : 0.022775299366048368,
#                  "\u4e3a" : 0.006339516318384597,
#                  "\u4e2a" : 0.014557407842216482,
#                  "\u5173\u7cfb" : 0.001643578304766377,
#                  "\u652f" : 0.000704390702042733,
#                  "\u4e2d" : 0.006339516318384597,
#                  "\u6b21" : 0.003287156609532754,
#                  "\u4e24" : 0.003287156609532754,
#                  "\u56fd" : 0.0023479690068091102,
#                  "\u906d" : 0.0018783752054472881,
#                  "\u4e8b\u4ef6" : 0.002817562808170932,
#                  "\u5916\u6d77" : 0.00023479690068091102,
#                  "\u8fdb\u884c" : 0.0068091101197464195,
#                  "\u53d1\u751f" : 0.0018783752054472881,
#                  "\u4f4d" : 0.00704390702042733,
#                  "\u8fc7" : 0.001643578304766377,
#                  "\u65b9\u9762" : 0.002113172106128199,
#                  "\u4e5f" : 0.0030523597088518433,
#                  "\u6210\u5458" : 0.00046959380136182204,
#                  "\u5448\u73b0" : 0.00046959380136182204,
#                  "\u3001" : 0.010096266729279173,
#                  "\u6240" : 0.004461141112937309,
#                  "\u5f15\u8d77" : 0.000704390702042733,
#                  "\u7ed3\u675f" : 0.00046959380136182204,
#                  "\u4e4b" : 0.005635125616341864,
#                  "\u5927" : 0.0023479690068091102,
#                  "\u7c4d" : 0.00023479690068091102,
#                  "\u624d" : 0.002113172106128199,
#                  "\u4e00" : 0.012444235736088284,
#                  "\u8d9f" : 0.00046959380136182204,
#                  "\u662f" : 0.012444235736088284,
#                  "\u5e76" : 0.0039915473115754874,
#                  "\u5728" : 0.015027001643578305,
#                  "\u592a\u7a7a" : 0.00023479690068091102,
#                  "\u671f\u95f4" : 0.00046959380136182204,
#                  "\u8fd9\u6b21" : 0.00023479690068091102,
#                  "\u4e00\u8d77" : 0.00046959380136182204,
#                  "\u5c81" : 0.0018783752054472881,
#                  "\u5f97\u4ee5" : 0.00023479690068091102,
#                  "\u3002" : 0.002582765907490021,
#                  "\u80fd\u591f" : 0.000704390702042733,
#                  "\u66fe" : 0.0037567504108945763,
#                  "\u8fd9" : 0.004226344212256398,
#                  "\u5bf9\u5f85" : 0.00023479690068091102,
#                  "\u91ca\u51fa" : 0.00023479690068091102,
#                  "\u5bf9\u4e8e" : 0.000704390702042733,
#                  "\u53cd\u5e94" : 0.00023479690068091102,
#                  "\u5361\u7279" : 0.00023479690068091102,
#                  "\u5c55\u5f00" : 0.001408781404085466,
#                  "\u9879" : 0.006339516318384597,
#                  "\u5973\u58eb" : 0.00023479690068091102,
#                  "\u4e86" : 0.02606245597558112,
#                  "\u8bc4\u8bba\u5bb6" : 0.00023479690068091102,
#                  "\u8bf4\u6cd5" : 0.00023479690068091102,
#                  "\u8bf4" : 0.0023479690068091102,
#                  ")" : 0.0011739845034045551,
#                  "\u7f51\u8def" : 0.00023479690068091102,
#                  "\u8be5" : 0.001408781404085466,
#                  "\u516c\u53f8" : 0.006339516318384597,
#                  "\u9057\u7f3a" : 0.00023479690068091102,
#                  "\u7531" : 0.003287156609532754,
#                  "\u5230" : 0.002582765907490021,
#                  "\u7f51\u7ad9" : 0.00023479690068091102,
#                  "\u89e3\u51b3" : 0.000704390702042733,
#                  "\u4eec" : 0.0018783752054472881,
#                  "\u4f46" : 0.0023479690068091102,
#                  "\u800c" : 0.007983094623150975,
#                  "\u56fd\u5bb6" : 0.0009391876027236441,
#                  "\u81f3" : 0.00023479690068091102,
#                  "\u6cd5" : 0.00046959380136182204,
#                  "\u5bf9" : 0.0061047194177036865,
#                  "\u519c\u4e1a" : 0.00023479690068091102,
#                  "\u52a0\u4ee5" : 0.00023479690068091102,
#                  "\u4f5c\u6cd5" : 0.000704390702042733,
#                  "\u4f7f" : 0.002113172106128199,
#                  "\u4e3a\u4e86" : 0.00023479690068091102,
#                  "\u4f7f\u5f97" : 0.000704390702042733,
#                  "\u300c" : 0.002582765907490021,
#                  "\u300d" : 0.002817562808170932,
#                  "\u76ee\u6807" : 0.00023479690068091102,
#                  "\u94a2\u94c1" : 0.00023479690068091102,
#                  "\u4e0b" : 0.001408781404085466,
#                  "--" : 0.0011739845034045551,
#                  "\u56e0\u4e3a" : 0.00023479690068091102,
#                  "\u8fd9\u79cd" : 0.00046959380136182204,
#                  "\u52a1\u5fc5" : 0.00023479690068091102,
#                  "\u66f4" : 0.00046959380136182204,
#                  "\u7ed9" : 0.0009391876027236441,
#                  "\u63a5\u83b7" : 0.00023479690068091102,
#                  "\u65b9\u5f0f" : 0.000704390702042733,
#                  "\u4f1a" : 0.002582765907490021,
#                  "\u60f3\u8981" : 0.00023479690068091102,
#                  "\u4e8b" : 0.000704390702042733,
#                  "\u8981" : 0.003521953510213665,
#                  "\u4e4b\u7c7b" : 0.00023479690068091102,
#                  "\u8c08\u8bdd" : 0.00023479690068091102,
#                  "\u6307" : 0.00046959380136182204,
#                  "\u5f00\u59cb" : 0.00023479690068091102,
#                  "\u5374" : 0.0018783752054472881,
#                  "\u540e" : 0.0023479690068091102,
#                  "\u82f1\u9551" : 0.000704390702042733,
#                  "\u5373" : 0.00023479690068091102,
#                  "\u5c31" : 0.0061047194177036865,
#                  "\u8ba9" : 0.0011739845034045551,
#                  "\u51fa\u4e4e" : 0.00023479690068091102,
#                  "\u4e4b\u5916" : 0.00023479690068091102,
#                  "\u5e02\u573a" : 0.00046959380136182204,
#                  "\u539f\u6765" : 0.00023479690068091102,
#                  "\u9884\u671f" : 0.00023479690068091102,
#                  "\u8f83" : 0.00046959380136182204,
#                  "\u4e0d" : 0.00046959380136182204,
#                  "\u552f\u6709" : 0.00023479690068091102,
#                  "\u5176" : 0.001643578304766377,
#                  "\u957f" : 0.00023479690068091102,
#                  "\u8fbe" : 0.00046959380136182204,
#                  "\u53d1\u8868" : 0.001643578304766377,
#                  "\u6b64" : 0.001408781404085466,
#                  "\u4e88\u4ee5" : 0.00023479690068091102,
#                  "\u884c\u52a8" : 0.0023479690068091102,
#                  "\u8ddd" : 0.00023479690068091102,
#                  "\u5176\u4e2d" : 0.0023479690068091102,
#                  "\u679a" : 0.001643578304766377,
#                  "\u680b" : 0.000704390702042733,
#                  "\u636e" : 0.003287156609532754,
#                  "\u5730\u533a" : 0.001408781404085466,
#                  "\u4eba" : 0.0061047194177036865,
#                  "\u4eba\u7269" : 0.00023479690068091102,
#                  "\u6bd4\u8d5b" : 0.0011739845034045551,
#                  "\u5de5\u4f5c" : 0.0011739845034045551,
#                  "\u80cc\u540e" : 0.00023479690068091102,
#                  "\u60f3" : 0.00023479690068091102,
#                  "\u6211\u4eec" : 0.000704390702042733,
#                  "\u60c5\u5f62" : 0.00023479690068091102,
#                  "\u6bb5" : 0.0009391876027236441,
#                  "\u90fd" : 0.0061047194177036865,
#                  "\u800c\u5df2" : 0.00023479690068091102,
#                  "\u4ee5\u53ca" : 0.00046959380136182204,
#                  "\u5b89\u6392" : 0.00023479690068091102,
#                  "\u5bb6" : 0.0046959380136182205,
#                  "\u4e4b\u540e" : 0.00046959380136182204,
#                  "\u4ed6\u4eec" : 0.0009391876027236441,
#                  "\u53cc\u65b9" : 0.001408781404085466,
#                  "\u5386\u7ecf" : 0.00023479690068091102,
#                  "\u76f4\u5230" : 0.00023479690068091102,
#                  "\u83b7\u81f4" : 0.00023479690068091102,
#                  "\u58f0\u6d6a" : 0.00023479690068091102,
#                  "\u56e0\u6b64" : 0.0009391876027236441,
#                  "\u578b" : 0.00023479690068091102,
#                  "\u5c04\u7a0b" : 0.00023479690068091102,
#                  "\u8db3\u7403" : 0.00023479690068091102,
#                  "\u56fd\u5185" : 0.000704390702042733,
#                  "\u7b49" : 0.0037567504108945763,
#                  "\u4ece" : 0.0011739845034045551,
#                  "\u8fc7\u53bb" : 0.00023479690068091102,
#                  "\u4e00\u76f4" : 0.001408781404085466,
#                  "\u5c1a" : 0.00023479690068091102,
#                  "\u9020\u6210" : 0.002113172106128199,
#                  "\u5b83" : 0.001643578304766377,
#                  "\u5370" : 0.00023479690068091102,
#                  "\u5df4" : 0.00023479690068091102,
#                  "\u8981\u6c42" : 0.00046959380136182204,
#                  "\u65f6" : 0.004461141112937309,
#                  "\u6709\u6240" : 0.000704390702042733,
#                  "\u62e5\u6709" : 0.0011739845034045551,
#                  "\u8fdb\u5165" : 0.00023479690068091102,
#                  "\u7d27\u9523\u5bc6\u9f13" : 0.00023479690068091102,
#                  "\u9636\u6bb5" : 0.00023479690068091102,
#                  "\u80a9\u8d1f" : 0.00023479690068091102,
#                  "\u5370\u5ea6" : 0.00023479690068091102,
#                  "\u5371\u673a" : 0.00046959380136182204,
#                  "\u7ec4\u7ec7" : 0.00046959380136182204,
#                  "\u6b63" : 0.00046959380136182204,
#                  "\u5883\u5185" : 0.00046959380136182204,
#                  "\u9762\u4e34" : 0.00023479690068091102,
#                  "-" : 0.000704390702042733,
#                  "\u4e0a" : 0.001408781404085466,
#                  "\u80fd" : 0.001643578304766377,
#                  "\u6761" : 0.000704390702042733,
#                  "\u963f\u6839\u5ef7" : 0.00023479690068091102,
#                  "\u5305\u62ec" : 0.00046959380136182204,
#                  "\u8bbe" : 0.00023479690068091102,
#                  "\u8def\u969c" : 0.00023479690068091102,
#                  "\u6d3b\u52a8" : 0.001643578304766377,
#                  "\u56f0\u5883" : 0.00046959380136182204,
#                  "\u628a" : 0.00023479690068091102,
#                  "\u7fa4\u4f17" : 0.00023479690068091102,
#                  "\u53ec\u5f00" : 0.000704390702042733,
#                  "\u5148\u884c" : 0.00023479690068091102,
#                  "\u4e8b\u5b9c" : 0.000704390702042733,
#                  "\u6709\u610f" : 0.00023479690068091102,
#                  "\u5165\u4f1a" : 0.00046959380136182204,
#                  "\u4e8e" : 0.0009391876027236441,
#                  "\u7814\u7a76" : 0.00023479690068091102,
#                  "\u4e0e" : 0.0023479690068091102,
#                  "\u56fd\u9645" : 0.00023479690068091102,
#                  "\u63a5\u53d7" : 0.001408781404085466,
#                  "\u90a3\u4e48" : 0.00046959380136182204,
#                  "\u5012" : 0.00023479690068091102,
#                  "\u76f8\u4e92" : 0.00023479690068091102,
#                  "\u4e89\u53d6" : 0.00023479690068091102,
#                  "\u5f7c\u6b64" : 0.00023479690068091102,
#                  "\u9488\u5bf9" : 0.00046959380136182204,
#                  "\u63d0\u8bae" : 0.00023479690068091102,
#                  "\u5bfc\u81f4" : 0.00023479690068091102,
#                  "\u4eba\u6570" : 0.00046959380136182204,
#                  "\u673a\u5bc6" : 0.00023479690068091102,
#                  "\u900f\u9732" : 0.00023479690068091102,
#                  "\u548c" : 0.002113172106128199,
#                  "\u53ef\u80fd" : 0.001408781404085466,
#                  "\u51fa" : 0.001643578304766377,
#                  "\u752b" : 0.00023479690068091102,
#                  "\u8d77" : 0.002113172106128199,
#                  "\u610f" : 0.00023479690068091102,
#                  "\u5411" : 0.003521953510213665,
#                  "\u8fd8" : 0.002113172106128199,
#                  "\u8d81" : 0.00046959380136182204,
#                  "\u4e4b\u9645" : 0.00046959380136182204,
#                  "(" : 0.000704390702042733,
#                  "aer" : 0.00023479690068091102,
#                  "lingus" : 0.00023479690068091102,
#                  "\u8bbe\u6cd5" : 0.00023479690068091102,
#                  "\u9053" : 0.00046959380136182204,
#                  "\u822a\u7a7a" : 0.0009391876027236441,
#                  "\u4e3e\u884c" : 0.002113172106128199,
#                  "\u770b" : 0.00023479690068091102,
#                  "\u56e0" : 0.001643578304766377,
#                  "\u53d7" : 0.000704390702042733,
#                  "\u5458\u5de5" : 0.00023479690068091102,
#                  "\u4e8f\u635f" : 0.00023479690068091102,
#                  "\u7ea6" : 0.000704390702042733,
#                  "\u8ba8\u8bba" : 0.00023479690068091102,
#                  "\u4efd" : 0.0018783752054472881,
#                  "\u5185\u5bb9" : 0.00046959380136182204,
#                  "\u8868\u793a" : 0.00046959380136182204,
#                  "\u6563\u64ad" : 0.00023479690068091102,
#                  "\u5148" : 0.00046959380136182204,
#                  "\u65b9\u6848" : 0.00023479690068091102,
#                  "\u7b56\u7565" : 0.00023479690068091102,
#                  "\u5b9e\u65bd" : 0.00046959380136182204,
#                  "\u8fd9\u4e9b" : 0.00023479690068091102,
#                  "\u7740" : 0.002113172106128199,
#                  "\u7528\u54c1" : 0.00023479690068091102,
#                  "\u7528" : 0.00023479690068091102,
#                  ":" : 0.00046959380136182204,
#                  "\u4ee4" : 0.000704390702042733,
#                  "\u6ce8\u610f" : 0.00023479690068091102,
#                  "\u81ea\u7136" : 0.00023479690068091102,
#                  "\u51e0\u4e4e" : 0.00046959380136182204,
#                  "\u5973" : 0.0009391876027236441,
#                  "\u51fa\u54c1" : 0.00023479690068091102,
#                  "shrink" : 0.00023479690068091102,
#                  "\u9664" : 0.00023479690068091102,
#                  "\u62c5\u4efb" : 0.00046959380136182204,
#                  "\u5916" : 0.00023479690068091102,
#                  "\u8eab\u517c" : 0.00023479690068091102,
#                  "\u5f53" : 0.00023479690068091102,
#                  "\u62c5\u7eb2" : 0.00023479690068091102,
#                  "\u5979" : 0.000704390702042733,
#                  "\u5219" : 0.0011739845034045551,
#                  "\u8fdb\u4e00\u6b65" : 0.00046959380136182204,
#                  "\u6784\u60f3" : 0.00023479690068091102,
#                  "\u5267\u60c5" : 0.00023479690068091102,
#                  "\u795e\u5947" : 0.00023479690068091102,
#                  "\u5e86\u8d3a" : 0.00023479690068091102,
#                  "\u5e86\u795d" : 0.00046959380136182204,
#                  "\u7ed9\u4e88" : 0.000704390702042733,
#                  "\u5f88" : 0.0011739845034045551,
#                  "\u67b6" : 0.000704390702042733,
#                  "\u5212" : 0.00023479690068091102,
#                  "\u65e0\u8bba" : 0.00046959380136182204,
#                  "\u6765\u8bf4" : 0.000704390702042733,
#                  "\u53ef\u4ee5" : 0.0011739845034045551,
#                  "\u4e00\u756a" : 0.00023479690068091102,
#                  "\u4eca\u5e74" : 0.00046959380136182204,
#                  "\u7a0d\u65e9" : 0.00023479690068091102,
#                  "\u7edd" : 0.00023479690068091102,
#                  "\u82f1\u56fd" : 0.00046959380136182204,
#                  "\u5404\u9879" : 0.00023479690068091102,
#                  "\u60c5" : 0.00023479690068091102,
#                  "\u5224\u51b3" : 0.00023479690068091102,
#                  "\u9605\u8bfb" : 0.00023479690068091102,
#                  "\u4e0d\u51c6" : 0.00023479690068091102,
#                  "\u5982\u4eca" : 0.00023479690068091102,
#                  "\u4e1d\u6beb" : 0.00023479690068091102,
#                  "\u63d0\u51fa" : 0.00046959380136182204,
#                  "\u5fc5\u987b" : 0.000704390702042733,
#                  "\u987b" : 0.00023479690068091102,
#                  "\u8d1f\u62c5" : 0.00023479690068091102,
#                  "\u4e0d\u5f97" : 0.00023479690068091102,
#                  "\u5360" : 0.00023479690068091102,
#                  "\u884c\u4e3a" : 0.00046959380136182204,
#                  "\u975e\u5e38" : 0.00046959380136182204,
#                  "\u663e\u73b0" : 0.00023479690068091102,
#                  "\u8fc7\u7a0b" : 0.00046959380136182204,
#                  "\u964d" : 0.00023479690068091102,
#                  "\u6bd4\u7387" : 0.00023479690068091102,
#                  "\u539f\u5148" : 0.00023479690068091102,
#                  "\u867d\u7136" : 0.000704390702042733,
#                  "\u4fc3\u6210" : 0.00023479690068091102,
#                  "\u627f\u8bfa" : 0.00023479690068091102,
#                  "\u4e5d\u65e5" : 0.00023479690068091102,
#                  "\u56e2" : 0.00023479690068091102,
#                  "\u95ee\u9898" : 0.0009391876027236441,
#                  "\u4e00\u4e2a" : 0.000704390702042733,
#                  "\u8fbe\u6210" : 0.00023479690068091102,
#                  "\u4ee5" : 0.0030523597088518433,
#                  "\u5ea7" : 0.0011739845034045551,
#                  "\u8d5b" : 0.0011739845034045551,
#                  "\u540c" : 0.00046959380136182204,
#                  "\u4e00\u5ea6" : 0.00023479690068091102,
#                  "\u65e0\u5948" : 0.00023479690068091102,
#                  "\u53d1" : 0.00046959380136182204,
#                  "\u6700\u540e" : 0.00046959380136182204,
#                  "\u996e\u6068" : 0.00023479690068091102,
#                  "\u79f0\u81e3" : 0.00023479690068091102,
#                  "\u6218" : 0.00046959380136182204,
#                  "\u51a0\u519b" : 0.00023479690068091102,
#                  "\u8fd1" : 0.00046959380136182204,
#                  "\u6740\u8fdb" : 0.00023479690068091102,
#                  "\u524d" : 0.00023479690068091102,
#                  "\u4e00\u8def" : 0.00023479690068091102,
#                  "\u756a" : 0.00023479690068091102,
#                  "\u8fdb\u519b" : 0.00023479690068091102,
#                  "\u62b1" : 0.00023479690068091102,
#                  "\u5f97" : 0.00046959380136182204,
#                  "\u8868\u73b0" : 0.00023479690068091102,
#                  "\u7f8e\u56fd" : 0.0009391876027236441,
#                  "\u51c6\u5907" : 0.000704390702042733,
#                  "\u90a3\u4e9b" : 0.00023479690068091102,
#                  "\u8c01" : 0.00023479690068091102,
#                  "\u90a3" : 0.000704390702042733,
#                  "\u7cfb" : 0.00023479690068091102,
#                  "\u6839\u672c" : 0.00023479690068091102,
#                  "\u6765\u81ea" : 0.000704390702042733,
#                  "\u4e3b\u8981" : 0.00046959380136182204,
#                  "\u79d8\u5883" : 0.00023479690068091102,
#                  "\u5c40\u52bf" : 0.00023479690068091102,
#                  "\u80af\u5b9a" : 0.00023479690068091102,
#                  "\u5e03\u5e0c" : 0.00023479690068091102,
#                  "\u7b26\u5408" : 0.00023479690068091102,
#                  "\u6761\u4ef6" : 0.00023479690068091102,
#                  "\u5c4a\u65f6" : 0.00023479690068091102,
#                  "\u81ea" : 0.00023479690068091102,
#                  "\u6709\u7740" : 0.00023479690068091102,
#                  "\u5934" : 0.00046959380136182204,
#                  "\u5a92\u4f53" : 0.00023479690068091102,
#                  "\u96c6\u56e2" : 0.00023479690068091102,
#                  "\u5177" : 0.00046959380136182204,
#                  "\u53d1\u5c55" : 0.00023479690068091102,
#                  "\u4e13" : 0.00023479690068091102,
#                  "\u664b\u7ea7" : 0.00023479690068091102,
#                  "\u5f3a" : 0.00023479690068091102,
#                  "\u8d8b\u52bf" : 0.00046959380136182204,
#                  "\u8be5\u884c" : 0.00023479690068091102,
#                  "\u906d\u9047" : 0.00023479690068091102,
#                  "\u5f71\u54cd" : 0.00046959380136182204,
#                  "\u8def" : 0.00023479690068091102,
#                  "\u65e5\u76ca" : 0.00023479690068091102,
#                  "\u53e6" : 0.00046959380136182204,
#                  "\u5df2\u7ecf" : 0.0011739845034045551,
#                  "\u8d85\u4e4e" : 0.00023479690068091102,
#                  "\u4e3b\u7ba1" : 0.00023479690068091102,
#                  "\u589e" : 0.00023479690068091102,
#                  "marriott" : 0.00023479690068091102,
#                  "hotel" : 0.00023479690068091102,
#                  "\u8bdd" : 0.00046959380136182204,
#                  "\u800c\u8a00" : 0.00023479690068091102,
#                  "\u6307\u51fa" : 0.00023479690068091102,
#                  "\u65c5\u9986" : 0.00023479690068091102,
#                  "\u8fc4" : 0.00023479690068091102,
#                  "\u751f\u610f" : 0.00023479690068091102,
#                  "\u51b3\u5b9a" : 0.00046959380136182204,
#                  "\u5df4\u52d2\u65af\u5766" : 0.00046959380136182204,
#                  "\u8f86" : 0.0037567504108945763,
#                  "\u53d1\u52a8" : 0.00046959380136182204,
#                  "\u95f4" : 0.000704390702042733,
#                  "\u8303\u56f4" : 0.00023479690068091102,
#                  "\u653b\u51fb" : 0.00046959380136182204,
#                  "\u6848" : 0.001408781404085466,
#                  "\u5927\u7ea6" : 0.00023479690068091102,
#                  "\u6682\u65f6" : 0.00023479690068091102,
#                  ";" : 0.00046959380136182204,
#                  "\u706b\u707e" : 0.00023479690068091102,
#                  "\u59d3" : 0.0011739845034045551,
#                  "\u5317\u4eac" : 0.00023479690068091102,
#                  "\u6b7b\u8005" : 0.00023479690068091102,
#                  "\u52a0" : 0.00023479690068091102,
#                  "\u53c8" : 0.0011739845034045551,
#                  "\u521b" : 0.00046959380136182204,
#                  "\u4ef7\u4f4d" : 0.00023479690068091102,
#                  "\u7ea6\u65e6\u6cb3" : 0.0018783752054472881,
#                  "\u906d\u5230" : 0.00046959380136182204,
#                  "\u81ea\u6740" : 0.00023479690068091102,
#                  "\u70b8\u5f39" : 0.00023479690068091102,
#                  "\u6240\u4e3a" : 0.00023479690068091102,
#                  "\u5904" : 0.0009391876027236441,
#                  "\u884c\u5f84" : 0.00023479690068091102,
#                  "\u5171" : 0.00023479690068091102,
#                  "\u4ee5\u6765" : 0.001408781404085466,
#                  "\u4ee5\u81f4" : 0.00023479690068091102,
#                  "\u519b\u65b9" : 0.00023479690068091102,
#                  "\u4e70" : 0.00046959380136182204,
#                  "\u4e1c\u897f" : 0.00023479690068091102,
#                  "\u540c\u6837" : 0.00046959380136182204,
#                  "\u89c1" : 0.00023479690068091102,
#                  "\u6700\u8fd1" : 0.00023479690068091102,
#                  "\u53d8\u6210" : 0.00023479690068091102,
#                  "\u4eba\u5458" : 0.000704390702042733,
#                  "\u6050\u6015" : 0.00046959380136182204,
#                  "\u91c7\u53d6" : 0.00023479690068091102,
#                  "\u7a0b\u5ea6" : 0.00023479690068091102,
#                  "\u81f3\u4eca" : 0.00023479690068091102,
#                  "\u83b7\u5f97" : 0.00046959380136182204,
#                  "\u8fd8\u6709" : 0.00023479690068091102,
#                  "\u51fa\u73b0" : 0.0009391876027236441,
#                  "\u7701" : 0.00023479690068091102,
#                  "\u53bf\u5e02" : 0.00023479690068091102,
#                  "\u63a5\u66ff" : 0.00023479690068091102,
#                  "\u653e\u5f03" : 0.00023479690068091102,
#                  "\u8054\u76df" : 0.00023479690068091102,
#                  "\u56fd\u6c11" : 0.00046959380136182204,
#                  "\u4e3e\u56fd" : 0.00023479690068091102,
#                  "\u518d" : 0.0009391876027236441,
#                  "\u65f6\u95f4" : 0.00046959380136182204,
#                  "\u60c5\u4e8b" : 0.00023479690068091102,
#                  "\u7686" : 0.00046959380136182204,
#                  "\u63aa\u65bd" : 0.00046959380136182204,
#                  "\u7206\u53d1" : 0.00023479690068091102,
#                  "\u6f14\u53d8" : 0.00023479690068091102,
#                  "\u6210" : 0.00023479690068091102,
#                  "\u65e5\u6e10" : 0.00023479690068091102,
#                  "\u8fc5\u901f" : 0.00023479690068091102,
#                  "\u4e0d\u8fc7" : 0.00023479690068091102,
#                  "\u4fdd\u8bc1" : 0.00023479690068091102,
#                  "\u6784\u6210" : 0.00023479690068091102,
#                  "\u505a\u51fa" : 0.000704390702042733,
#                  "\u63d0\u4f9b" : 0.00046959380136182204,
#                  "\u7ba1\u7406" : 0.00023479690068091102,
#                  "\u5e74\u5ea6" : 0.00023479690068091102,
#                  "\u63f4\u52a9" : 0.00023479690068091102,
#                  "\u6b64\u4e3e" : 0.00023479690068091102,
#                  "\u653f\u5e9c" : 0.0009391876027236441,
#                  "\u4ecd" : 0.00046959380136182204,
#                  "\u5c4a" : 0.000704390702042733,
#                  "\u9884\u5b9a" : 0.00023479690068091102,
#                  "\u671f\u9650" : 0.00046959380136182204,
#                  "\u5185" : 0.0011739845034045551,
#                  "\u5c3c\u6cca\u5c14" : 0.00023479690068091102,
#                  "\u8d3e\u5357\u5fb7\u62c9" : 0.00023479690068091102,
#                  "\u901f\u5ea6" : 0.00046959380136182204,
#                  "\u8d1f\u8d23" : 0.00046959380136182204,
#                  "\u5341\u5206" : 0.00046959380136182204,
#                  "\u5e45\u5ea6" : 0.00023479690068091102,
#                  "\u65f6\u5019" : 0.00023479690068091102,
#                  "\u4e70\u623f" : 0.00046959380136182204,
#                  "\u4f9b" : 0.00023479690068091102,
#                  "\u4e0d\u65ad" : 0.00023479690068091102,
#                  "\u6b63\u5728" : 0.00046959380136182204,
#                  "\u73b0\u8c61" : 0.00023479690068091102,
#                  "\u53bb\u5e74" : 0.00023479690068091102,
#                  "\u539f\u56e0" : 0.00023479690068091102,
#                  "\u94f6\u884c" : 0.00046959380136182204,
#                  "\u76ee\u524d" : 0.00046959380136182204,
#                  "\u7167" : 0.00023479690068091102,
#                  "\u4e0b\u53bb" : 0.00023479690068091102,
#                  "\u5730" : 0.0018783752054472881,
#                  "\u5404\u4e2a" : 0.00023479690068091102,
#                  "\u59d4\u5458\u4f1a" : 0.00023479690068091102,
#                  "\u7ecf" : 0.00023479690068091102,
#                  "\u80a1\u5e02" : 0.00046959380136182204,
#                  "\u8d70\u52bf" : 0.00023479690068091102,
#                  "\u4f01\u4e1a" : 0.00023479690068091102,
#                  "\u300a" : 0.00046959380136182204,
#                  "\u300b" : 0.00023479690068091102,
#                  "\u79cd" : 0.001408781404085466,
#                  "\u80a1\u7968" : 0.0009391876027236441,
#                  "\u6536\u76d8" : 0.000704390702042733,
#                  "\u5fae" : 0.00023479690068091102,
#                  "\u5e45" : 0.00046959380136182204,
#                  "\u70b9" : 0.001408781404085466,
#                  "\u5e26\u6765" : 0.00023479690068091102,
#                  "\u8fc7\u6e21" : 0.00023479690068091102,
#                  "\u81ea\u5df1" : 0.001643578304766377,
#                  "\u5e7f\u5927" : 0.00023479690068091102,
#                  "\u81ea\u4f20" : 0.00023479690068091102,
#                  "\u672c" : 0.0009391876027236441,
#                  "\u901a\u8fc7" : 0.00046959380136182204,
#                  "\u52c7\u6c14" : 0.00023479690068091102,
#                  "\u68f5" : 0.00023479690068091102,
#                  "\u573a" : 0.00046959380136182204,
#                  "\u5df4\u897f" : 0.00023479690068091102,
#                  "\"" : 0.004226344212256398,
#                  "\u90a3\u91cc" : 0.00023479690068091102,
#                  "\u53d7\u4f24" : 0.00023479690068091102,
#                  "\u6c7d\u8f66" : 0.00046959380136182204,
#                  "\u4e00\u4e9b" : 0.00046959380136182204,
#                  "\u5b83\u4eec" : 0.00046959380136182204,
#                  "\u6570\u91cf" : 0.000704390702042733,
#                  "\u6392\u540d" : 0.00023479690068091102,
#                  "\u4e8b\u52a1" : 0.00023479690068091102,
#                  "\u672c\u56fd" : 0.00023479690068091102,
#                  "\u667a\u5229" : 0.00046959380136182204,
#                  "\u5408" : 0.00023479690068091102,
#                  "\u6c11\u65cf" : 0.00023479690068091102,
#                  "\u6536\u5230" : 0.00023479690068091102,
#                  "\u5f53\u4e8b\u4eba" : 0.00023479690068091102,
#                  "\u5e94" : 0.00046959380136182204,
#                  "\u4efb" : 0.00023479690068091102,
#                  "\u4e1a\u52a1" : 0.00023479690068091102,
#                  "\u5b97" : 0.0009391876027236441,
#                  "\u4f4f\u5b85" : 0.00046959380136182204,
#                  "\u6bd4" : 0.00046959380136182204,
#                  "\u53e6\u5916" : 0.00023479690068091102,
#                  "\u4e09" : 0.0009391876027236441,
#                  "\u65b9" : 0.00046959380136182204,
#                  "\u7ef4\u4fee" : 0.00023479690068091102,
#                  "\u5747" : 0.00023479690068091102,
#                  "\u7c7b" : 0.000704390702042733,
#                  "\u6709\u5173" : 0.0009391876027236441,
#                  "\u4ea7\u91cf" : 0.00023479690068091102,
#                  "\u5b58\u5728" : 0.00046959380136182204,
#                  "\u9700\u8981" : 0.00023479690068091102,
#                  "\u6863\u6b21" : 0.00023479690068091102,
#                  "\u6210\u5458\u56fd" : 0.00023479690068091102,
#                  "\u5143\u9996" : 0.00023479690068091102,
#                  "\u4e58" : 0.00023479690068091102,
#                  "\u9a7b" : 0.00023479690068091102,
#                  "\u6c5f" : 0.00023479690068091102,
#                  "\u6cfd\u6c11" : 0.00023479690068091102,
#                  "\u4e3b\u5e2d" : 0.00023479690068091102,
#                  "\u592b\u5987" : 0.00023479690068091102,
#                  "\u76f8\u671b" : 0.00023479690068091102,
#                  "\u56fd\u52a1\u9662" : 0.00023479690068091102,
#                  "\u535a\u7269\u9986" : 0.00023479690068091102,
#                  "\u4eba\u4eec" : 0.00023479690068091102,
#                  "\u6237" : 0.00023479690068091102,
#                  "\u5efa\u7b51\u7269" : 0.00023479690068091102,
#                  "\u4f9d\u7136" : 0.00023479690068091102,
#                  "\u603b\u662f" : 0.00023479690068091102,
#                  "\u60c5\u4e0d\u81ea\u7981" : 0.00023479690068091102,
#                  "\u4e00\u6837" : 0.00023479690068091102,
#                  "\u4f4f" : 0.00023479690068091102,
#                  "\u4ea4" : 0.00023479690068091102,
#                  "\u51e0" : 0.000704390702042733,
#                  "\u8f6c\u5316" : 0.00023479690068091102,
#                  "\u5236\u9020" : 0.00023479690068091102,
#                  "\u91cc" : 0.000704390702042733,
#                  "\u4f7f\u7528" : 0.00046959380136182204,
#                  "\u4f30\u8ba1" : 0.00023479690068091102,
#                  "\u53d1\u51fa" : 0.00046959380136182204,
#                  "\u591a" : 0.000704390702042733,
#                  "\u4fe1\u4ef0" : 0.00023479690068091102,
#                  "\u72b6\u6001" : 0.00023479690068091102,
#                  "\u9022" : 0.00023479690068091102,
#                  "\u652f\u6301" : 0.00023479690068091102,
#                  "30" : 0.00023479690068091102,
#                  "\u4ef7\u683c" : 0.000704390702042733,
#                  "\u6307\u6570" : 0.00023479690068091102,
#                  "\u884c\u60c5" : 0.00023479690068091102,
#                  "\u8f6c" : 0.00023479690068091102,
#                  "\u6570\u5b57" : 0.00023479690068091102,
#                  "\u51fa\u5c40" : 0.00023479690068091102,
#                  "\u53bb" : 0.00023479690068091102,
#                  "\u8fce\u63a5" : 0.00046959380136182204,
#                  "\u9762\u5bf9" : 0.00023479690068091102,
#                  "\u961f" : 0.000704390702042733,
#                  "\u5c3d" : 0.00023479690068091102,
#                  "\u822c" : 0.00023479690068091102,
#                  "\u9879\u76ee" : 0.00046959380136182204,
#                  "\u519b" : 0.000704390702042733,
#                  "\u513f\u7ae5" : 0.00023479690068091102,
#                  "\u519b\u4e8b" : 0.00023479690068091102,
#                  "\u8fd9\u91cc" : 0.00046959380136182204,
#                  "\u6027" : 0.00023479690068091102,
#                  "\u6c34\u5e73" : 0.000704390702042733,
#                  "\u7eb7\u7eb7" : 0.00023479690068091102,
#                  "\u751f\u547d" : 0.00023479690068091102,
#                  "\u4e86\u89e3" : 0.00023479690068091102,
#                  "\u529e\u7406" : 0.00023479690068091102,
#                  "\u624b\u7eed" : 0.00023479690068091102,
#                  "\u6842\u6797" : 0.00023479690068091102,
#                  "\u5b98\u5175" : 0.00023479690068091102,
#                  "\u8d76\u8d74" : 0.00023479690068091102,
#                  "\u505a" : 0.00046959380136182204,
#                  "\u597d" : 0.00046959380136182204,
#                  "\u5f85" : 0.00023479690068091102,
#                  "\u822a\u7ebf" : 0.00023479690068091102,
#                  "\u83b7" : 0.00023479690068091102,
#                  "\u4fbf" : 0.00023479690068091102,
#                  "\u60c5\u51b5" : 0.00046959380136182204,
#                  "\u521d" : 0.00023479690068091102,
#                  "\u53cc\u7ba1\u9f50\u4e0b" : 0.00023479690068091102,
#                  "\u4f3c\u4e4e" : 0.00023479690068091102,
#                  "\u884c\u9a76" : 0.0018783752054472881,
#                  "\u8005" : 0.000704390702042733,
#                  "\u51c6\u4e88" : 0.00023479690068091102,
#                  "\u5546\u6237" : 0.00046959380136182204,
#                  "\u589e\u52a0" : 0.00023479690068091102,
#                  "\u2014\u2014" : 0.000704390702042733,
#                  "\u529e" : 0.00023479690068091102,
#                  "\u5b9e\u4e1a" : 0.00023479690068091102,
#                  "\u6bcf" : 0.00023479690068091102,
#                  "\u4eba\u58eb" : 0.00046959380136182204,
#                  "\u91d1\u989d" : 0.00023479690068091102,
#                  "\u8fbe\u5230" : 0.000704390702042733,
#                  "\u4eba\u6c11\u5e01" : 0.00023479690068091102,
#                  "\u5982\u679c" : 0.00023479690068091102,
#                  "\u89c4\u5b9a" : 0.00023479690068091102,
#                  "\u6267\u884c" : 0.00023479690068091102,
#                  "\u4eba\u53e3" : 0.00023479690068091102,
#                  "\u7ec4\u6210" : 0.00046959380136182204,
#                  "\u5bb6\u5ead" : 0.00023479690068091102,
#                  "\u65e5\u524d" : 0.00023479690068091102,
#                  "\u663e\u793a" : 0.00023479690068091102,
#                  "\u9762\u79ef" : 0.00023479690068091102,
#                  "\u91cf" : 0.00023479690068091102,
#                  "\u4eba\u6b21" : 0.00023479690068091102,
#                  "\u8fde\u7eed" : 0.00023479690068091102,
#                  "\u7247" : 0.00023479690068091102,
#                  "\u90e8\u95e8" : 0.000704390702042733,
#                  "\u53d7\u8058" : 0.00023479690068091102,
#                  "\u6211" : 0.00046959380136182204,
#                  "\u5404\u65cf" : 0.00023479690068091102,
#                  "\u9886\u5bfc" : 0.00023479690068091102,
#                  "\u4ece\u4e8b" : 0.00023479690068091102,
#                  "\u90e8\u957f" : 0.00023479690068091102,
#                  "\u6240\u5728" : 0.00023479690068091102,
#                  "\u6301" : 0.00023479690068091102,
#                  "\u6001\u5ea6" : 0.00023479690068091102,
#                  "\u8fd9\u4e2a" : 0.00046959380136182204,
#                  "\u6c11\u95f4" : 0.00023479690068091102,
#                  "\u4e3a\u671f" : 0.00046959380136182204,
#                  "\u52a8\u7269" : 0.00023479690068091102,
#                  "\u5c45" : 0.00023479690068091102,
#                  "\u963b\u6321" : 0.00023479690068091102,
#                  "\u751f\u6001" : 0.00023479690068091102,
#                  "\u5de5\u7a0b" : 0.00023479690068091102,
#                  "\u5c01\u5c71" : 0.00023479690068091102,
#                  "\u8d44\u6e90" : 0.00023479690068091102,
#                  "\u5f97\u5230" : 0.000704390702042733,
#                  "\u53ea" : 0.00023479690068091102,
#                  "\u6d88\u606f" : 0.00023479690068091102,
#                  "\u5c3c\u65e5\u5c14" : 0.00023479690068091102,
#                  "\u5730\u4f4d" : 0.00023479690068091102,
#                  "\u4ece\u800c" : 0.00023479690068091102,
#                  "\u6392\u5217" : 0.00023479690068091102,
#                  "\u53ca" : 0.00023479690068091102,
#                  "\u5176\u4ed6" : 0.00046959380136182204,
#                  "\u65e5\u672c" : 0.00023479690068091102,
#                  "\u6559" : 0.00023479690068091102,
#                  "\u53e3" : 0.00023479690068091102,
#                  "\u6848\u4ef6" : 0.00023479690068091102,
#                  "\u7530" : 0.00023479690068091102,
#                  "\u806a\u660e" : 0.00023479690068091102,
#                  "\u4e8b\u60c5" : 0.00023479690068091102,
#                  "\u7559\u4e0b" : 0.00023479690068091102,
#                  "\u65b0\u534e\u793e" : 0.00023479690068091102,
#                  "\u503c\u5f97" : 0.00023479690068091102,
#                  "\u524d\u5f80" : 0.00023479690068091102,
#                  "\u9010\u6b65" : 0.00023479690068091102,
#                  "\u8f6c\u53d8" : 0.00023479690068091102,
#                  "\u4ee5\u5f80" : 0.00023479690068091102,
#                  "\u65b0\u5efa" : 0.00023479690068091102,
#                  "\u6539\u5efa" : 0.00023479690068091102,
#                  "\u91c7\u7528" : 0.00023479690068091102,
#                  "\u5236" : 0.00023479690068091102,
#                  "\u81f4" : 0.00023479690068091102,
#                  "\u4fc3\u4f7f" : 0.00023479690068091102,
#                  "\u5b9e\u73b0" : 0.00023479690068091102,
#                  "\u9886\u571f" : 0.00023479690068091102,
#                  "\u6cd5\u56fd" : 0.00023479690068091102,
#                  "\u72b6\u51b5" : 0.00023479690068091102,
#                  "\u8d70\u5411" : 0.00023479690068091102,
#                  "\u7531\u4e8e" : 0.00023479690068091102,
#                  "\u6309" : 0.00023479690068091102,
#                  "\u793e\u4f1a" : 0.00023479690068091102,
#                  "\u8eab" : 0.00023479690068091102,
#                  "\u9760" : 0.00023479690068091102,
#                  "\u4e2d\u7684" : 0.00023479690068091102,
#                  "\u4e2a\u4eba" : 0.00023479690068091102,
#                  "\u5f97\u5206" : 0.00023479690068091102,
#                  "\u540d\u5217" : 0.00046959380136182204,
#                  "\u7206" : 0.00023479690068091102,
#                  "\u51b7\u95e8" : 0.00023479690068091102,
#                  "\u7ec8\u4e86" : 0.00023479690068091102,
#                  "\u52a0\u8d5b" : 0.00023479690068091102,
#                  "\u7ec8\u4e8e" : 0.00023479690068091102,
#                  "\u5dee" : 0.00023479690068091102,
#                  "\u5929\u4e3b\u6559" : 0.00023479690068091102,
#                  "\u4fb5\u5bb3" : 0.00023479690068091102,
#                  "\u68c0\u89c6" : 0.00023479690068091102,
#                  "\u8fd9\u9879" : 0.00046959380136182204,
#                  "\u548c\u89e3" : 0.00023479690068091102,
#                  "\u534f\u8bae" : 0.00046959380136182204,
#                  "\u8d54\u507f" : 0.00023479690068091102,
#                  "\uff1f" : 0.00023479690068091102,
#                  "\uff0c" : 0.004226344212256398,
#                  "\u4f46\u662f" : 0.00023479690068091102,
#                  "\u904d" : 0.00023479690068091102,
#                  "\u8d2d\u4e70" : 0.00046959380136182204,
#                  "\u6240\u6709" : 0.00023479690068091102,
#                  "\u786e\u5b9e" : 0.000704390702042733,
#                  "\u5176\u5b9e" : 0.00023479690068091102,
#                  "\u591f" : 0.00023479690068091102,
#                  "\u600e\u4e48" : 0.00023479690068091102,
#                  "\u5462" : 0.00046959380136182204,
#                  "\u554a" : 0.00023479690068091102,
#                  "TM" : 0.00023479690068091102,
#                  "\u8d35" : 0.00023479690068091102,
#                  "\u5427" : 0.00023479690068091102,
#                  "\u4ea7\u54c1" : 0.00046959380136182204,
#                  "\u6216" : 0.00023479690068091102,
#                  "\u7c7b\u4f3c" : 0.00023479690068091102,
#                  "\u6ca1\u6709" : 0.00023479690068091102,
#                  "\u5927\u6982" : 0.00023479690068091102,
#                  "\u8fd9\u6837" : 0.00023479690068091102,
#                  "\u6253" : 0.00023479690068091102,
#                  "\u5178\u578b" : 0.00023479690068091102,
#                  "\u672c\u8eab" : 0.00023479690068091102,
#                  "\u4ec0\u4e48" : 0.00023479690068091102,
#                  "\u6574\u4e2a" : 0.00023479690068091102,
#                  "\u53f0" : 0.00023479690068091102,
#                  "\u968f" : 0.00023479690068091102,
#                  "\u6d41\u901d" : 0.00023479690068091102,
#                  "\u4e5f\u8bb8" : 0.00023479690068091102,
#                  "\u53ef" : 0.00023479690068091102,
#                  "\u4e3a\u6b62" : 0.00023479690068091102,
#                  "\u5b69\u5b50" : 0.00023479690068091102,
#                  "\u5c06\u6765" : 0.00023479690068091102,
#                  "\u4e50\u4e8e" : 0.00023479690068091102,
#                  "\u79ef\u6781" : 0.00023479690068091102,
#                  "\u65e0\u8bba\u662f" : 0.00023479690068091102,
#                  "\u5806\u8d77" : 0.00023479690068091102,
#                  "\u5f62\u8c61\u601d\u7ef4" : 0.00023479690068091102,
#                  "\u53d1\u6325" : 0.00023479690068091102,
#                  "\u65b0" : 0.00023479690068091102,
#                  "\u53d1\u73b0" : 0.00023479690068091102,
#                  "---" : 0.00023479690068091102
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "None",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u56e0\u4e3a" : 0.07142857142857142,
#                  "\u4f5c" : 0.03571428571428571,
#                  "\u7531\u4e8e" : 0.17857142857142858,
#                  "\u4f5c\u4e3a" : 0.14285714285714285,
#                  "\u8eab" : 0.03571428571428571,
# ...
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "leaving",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u673a\u573a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "airport",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u65f6" : 0.4782608695652174,
#                  "\u5728" : 0.13043478260869565,
#                  "\u4e4b\u9645" : 0.08695652173913043,
#                  "\u5f53" : 0.21739130434782608,
#                  "\u7684" : 0.043478260869565216,
#                  "\u65f6\u5019" : 0.043478260869565216
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "when",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u901a\u5173" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "getting through the customs",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e00" : 0.16666666666666666,
#                  "\u5927" : 0.16666666666666666,
#                  "\u5806" : 0.16666666666666666,
#                  "\u5428" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "tons",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u62b5\u8fbe" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "arrives",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5386\u53f2\u6027" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "historic",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u9ad8\u5cf0" : 0.21428571428571427,
#                  "\u4f1a\u8bae" : 0.35714285714285715,
#                  "\u9ad8\u5cf0\u4f1a" : 0.21428571428571427,
#                  "\u9996\u8111" : 0.21428571428571427
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "summit",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u62b5\u8fbe" : 0.7777777777777778,
#                  "\u6765\u4e34" : 0.1111111111111111,
#                  "\u8bde\u751f" : 0.1111111111111111
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "arrived",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u88c1\u51cf" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "reduction",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6b66\u5668" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "arms",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u65b0" : 0.9259259259259259,
#                  "\u60ca\u5947" : 0.037037037037037035,
#                  "\u65b0\u4efb" : 0.037037037037037035
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "new",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u662f" : 0.4166666666666667,
#                  "\u7cfb" : 0.08333333333333333,
#                  "\u53d7" : 0.08333333333333333,
#                  "\u88ab" : 0.25,
#                  "\u53d7\u5230" : 0.08333333333333333,
#                  "\u6b63" : 0.08333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "were",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5bbf\u654c" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "bitter foes",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5efa\u7acb" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "shaping",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e8c\u5341\u4e00" : 0.5,
#                  "\u4e16\u7eaa" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "21st-century",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4f19\u4f34" : 0.5,
#                  "\u5173\u7cfb" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "partnership",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u9686\u91cd" : 0.3333333333333333,
#                  "\u76db\u5927" : 0.3333333333333333,
#                  "\u5b8c\u7f8e" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "grand",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u51c6\u5907" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "preparing",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6574\u4e2a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "entire",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u589e\u5f3a" : 0.5,
#                  "\u52a0\u5f3a" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "stepped up",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u62a5\u7eb8" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "newspaper",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8b66\u544a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "cautions",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u83ab\u65af\u79d1" : 0.5,
#                  "\u4eba" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "muscovites",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6ce8\u610f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "watch",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5b89\u5168" : 0.3333333333333333,
#                  "\u79d8\u5bc6" : 0.6666666666666666
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "secret",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u72d9\u51fb\u624b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "snipers",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u81ea\u7531\u6d3e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "liberal",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u56fd\u4f1a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "state duma",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u8bae\u5458" : 0.5,
#                  "\u6210\u5458" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "member",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u54c8\u5361\u9a6c\u8fbe" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "khakamada",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5973\u58eb" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "ms.",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e50\u89c2" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "optimistic",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u4e0d\u4ec5" : 0.6,
#                  "\u9664\u4e86" : 0.2,
#                  "\u5916" : 0.2
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "not only",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u56e0\u4e3a" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "because of",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u9884\u671f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "expect",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7b7e\u7f72" : 0.375,
#                  "\u8ff9\u8c61" : 0.5,
#                  "\u6807\u5fd7" : 0.125
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sign",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u6587\u4ef6" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "documents",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5171\u540c" : 0.3333333333333333,
#                  "\u53cc\u65b9" : 0.3333333333333333,
#                  "\u76f8\u4e92" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mutual",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u7ec8\u4e8e" : 0.5,
#                  "\u6700\u540e" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "finally",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5c55\u5f00" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "unfolding",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u5979" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "she",
#      "weight" : 1.0
#  }, ...]

# %%
# validation-----we should have state for each english word, the number should be same
len(to_pass_states),len(en_unigram)
# Out:
# (5677, 5677)

# %%
type(to_pass_states[0])
# Out:
# pomegranate.base.State

# %%
# add states to our model
hmm_model.add_states(to_pass_states)

# %%
# add start probability
start_prob={}

# for tag in tags:
#     start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

# for tag_state in to_pass_states :
#     hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])  
    

for en in words_en:
    start_prob[en] = en_words_starts[en]/ sum(en_words_starts.values()) 

#for en in words_en:
#    start_prob[en] = en_words_starts[en]/ en_unigram[en]

for en_state in to_pass_states:
    hmm_model.add_transition(hmm_model.start, en_state, start_prob[en_state.name])

# %%
# !!! try not to add end probability !!!!
# add end probability

end_prob={}

# for tag in tags:
#     end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
# for tag_state in to_pass_states :
#     hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])
    
for en in words_en:
     end_prob[en] = en_words_ends[en]/ sum(en_words_ends.values()) 

#for en in words_en:
#    end_prob[en] = en_words_ends[en]/ en_unigram[en]

for en_state in to_pass_states:
    hmm_model.add_transition(en_state, hmm_model.end, end_prob[en_state.name])

# %%
# add transition probability
transition_prob_pair={}

# for key in tag_bigrams.keys():
#     transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
# for tag_state in to_pass_states:
#     for next_tag_state in to_pass_states:
#         hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])


for en in en_bigram.keys():
    transition_prob_pair[en] = en_bigram.get(en)/ en_unigram[en[0]]

for en_state in to_pass_states:
    for next_en_state in to_pass_states:
        if (en_state.name, next_en_state.name) in transition_prob_pair.keys():
            hmm_model.add_transition(en_state, next_en_state, transition_prob_pair[(en_state.name, next_en_state.name)])
#         else:
#             #!! if path no exits(there is no one english word to another english word due the the limited data size)
#             hmm_model.add_transition(en_state, next_en_state, 0)

# %%
transition_prob_pair
# Out:
# {('archdiocese', 'finance'): 0.2857142857142857,
#  ('finance', 'council'): 1.0,
#  ('council', 'thinks'): 0.3333333333333333,
#  ('thinks', 'that'): 1.0,
#  ('that', 'this'): 0.012658227848101266,
#  ('this', 'agreement'): 0.011627906976744186,
#  ('agreement', 'may'): 0.07142857142857142,
#  ('may', 'force'): 0.023809523809523808,
#  ('force', 'boston'): 0.5,
#  ('boston', 'catholic archdiocese'): 0.16666666666666666,
#  ('catholic archdiocese', 'bankruptcy'): 1.0,
#  ('bankruptcy', 'None'): 0.6666666666666666,
#  ('None', 'as'): 0.000704390702042733,
#  ('as', 'alleged'): 0.03571428571428571,
#  ('alleged', 'None'): 0.6,
#  ('None', 'sexual'): 0.00023479690068091102,
#  ('sexual', 'abuse'): 0.6666666666666666,
#  ('abuse', 'of'): 0.3333333333333333,
#  ('of', 'cases'): 0.007751937984496124,
#  ('cases', 'keep surfacing'): 0.2,
#  ('keep surfacing', 'keep surfacing'): 0.5,
#  ('keep surfacing', ','): 0.5,
#  (',', 'and'): 0.008982035928143712,
#  ('and', '"'): 0.0027397260273972603,
#  ('"', 'since'): 0.0032258064516129032,
#  ('since', 'leading'): 0.025,
#  ('leading', 'agreement'): 0.5,
#  ('agreement', 'None'): 0.14285714285714285,
#  ('None', 'process'): 0.00046959380136182204,
#  ('process', 'started'): 0.14285714285714285,
#  ('started', 'since'): 0.14285714285714285,
#  ('since', 'situation'): 0.025,
#  ('situation', 'has'): 0.07692307692307693,
#  ('has', 'None'): 0.05555555555555555,
#  ('None', 'dramatically'): 0.00023479690068091102,
#  ('dramatically', 'dramatically'): 0.16666666666666666,
#  ('dramatically', 'changed'): 0.16666666666666666,
#  ('changed', '"'): 1.0,
#  ('"', '.'): 0.1032258064516129,
#  ('.', '66-year-old'): 0.0009910802775024777,
#  ('66-year-old', '66-year-old'): 0.5,
#  ('66-year-old', 'None'): 0.5,
#  ('None', 'geoghan'): 0.00046959380136182204,
#  ('geoghan', 'for'): 0.3333333333333333,
#  ('for', 'in'): 0.05555555555555555,
#  ('in', '1991'): 0.003703703703703704,
#  ('1991', 'sexual'): 1.0,
#  ('sexual', 'molestation'): 0.3333333333333333,
#  ('molestation', 'a'): 1.0,
#  ('a', 'None'): 0.5042735042735043,
#  ('None', '10-year-old'): 0.00023479690068091102,
#  ('10-year-old', '10-year-old'): 0.5,
#  ('10-year-old', 'boy'): 0.5,
#  ('boy', 'None'): 0.5,
#  ('None', 'recently'): 0.000704390702042733,
#  ('recently', 'was'): 0.07142857142857142,
#  ('was', 'sentenced'): 0.041666666666666664,
#  ('sentenced', '10'): 0.16666666666666666,
#  ('10', 'years'): 0.3333333333333333,
#  ('years', 'imprisonment'): 0.037037037037037035,
#  ('imprisonment', '.'): 1.0,
#  ('.', 'None'): 0.06739345887016848,
#  ('None', 'None'): 0.16952336229161774,
#  ('None', 'defrocked'): 0.00023479690068091102,
#  ('defrocked', 'priest'): 1.0,
#  ('priest', 'None'): 0.25,
#  ('None', 'also'): 0.001408781404085466,
#  ('also', 'faces'): 0.017241379310344827,
#  ('faces', 'other'): 0.3333333333333333,
#  ('other', 'criminal'): 0.0625,
#  ('criminal', 'trials'): 0.2,
#  ('trials', 'and'): 0.5,
#  ('and', 'scores'): 0.0027397260273972603,
#  ('scores', 'None'): 1.0,
#  ('None', 'civil'): 0.00023479690068091102,
#  ('civil', 'lawsuits'): 1.0,
#  ('lawsuits', '.'): 1.0,
#  ('.', 'us'): 0.018830525272547076,
#  ('us', 'india'): 0.009345794392523364,
#  ('india', 'mid-may'): 0.023255813953488372,
#  ('mid-may', 'mid-may'): 0.5,
#  ('mid-may', 'None'): 0.3333333333333333,
#  ('None', 'conduct'): 0.00046959380136182204,
#  ('conduct', '4 decades'): 0.2,
#  ('4 decades', 'decades'): 1.0,
#  ('decades', 'None'): 1.0,
#  ('None', 'first'): 0.002113172106128199,
#  ('first', 'joint'): 0.06060606060606061,
#  ('joint', 'military'): 0.25,
#  ('military', 'exercise'): 0.15625,
#  ('exercise', '('): 0.14285714285714285,
#  ('(', 'afp'): 0.4247787610619469,
#  ('afp', 'new delhi'): 0.02,
#  ('new delhi', 'None'): 0.16666666666666666,
#  ('None', ')'): 0.011270251232683728,
#  (')', 'india'): 0.009009009009009009,
#  ('india', 'and'): 0.18604651162790697,
#  ('and', 'united states'): 0.005479452054794521,
#  ('united states', 'will'): 0.05555555555555555,
#  ('will', 'conduct'): 0.008547008547008548,
#  ('conduct', '39'): 0.2,
#  ('39', 'years'): 1.0,
#  ('years', 'None'): 0.4444444444444444,
#  ('exercise', 'None'): 0.5714285714285714,
#  ('None', 'world'): 0.0009391876027236441,
#  ('world', 'in'): 0.08695652173913043,
#  ('in', 'two'): 0.007407407407407408,
#  ('two', 'None'): 0.5365853658536586,
#  ('None', 'largest'): 0.00046959380136182204,
#  ('largest', 'largest'): 0.4666666666666667,
#  ('largest', 'None'): 0.3333333333333333,
#  ('None', 'democracies'): 0.00023479690068091102,
#  ('democracies', 'democracies'): 0.5,
#  ('democracies', 'between'): 0.5,
#  ('between', 'None'): 0.5882352941176471,
#  ('None', 'cooperation'): 0.000704390702042733,
#  ('cooperation', 'None'): 0.6111111111111112,
#  ('None', 'mark'): 0.00023479690068091102,
#  ('mark', 'milestone'): 1.0,
#  ('milestone', '.'): 1.0,
#  ('.', 'ministry of national defense'): 0.0019821605550049554,
#  ('ministry of national defense', 'said'): 0.6666666666666666,
#  ('said', 'that'): 0.3699421965317919,
#  ('that', 'an'): 0.006329113924050633,
#  ('an', 'None'): 0.6428571428571429,
#  ('None', 'elite'): 0.00023479690068091102,
#  ('elite', 'None'): 1.0,
#  ('None', 'indian'): 0.00046959380136182204,
#  ('indian', 'paratroopers'): 0.08333333333333333,
#  ('paratroopers', 'brigade'): 1.0,
#  ('brigade', 'mid-may'): 1.0,
#  ('mid-may', 'will'): 0.16666666666666666,
#  ('will', 'with'): 0.06837606837606838,
#  ('with', 'pacific'): 0.012658227848101266,
#  ('pacific', 'us'): 1.0,
#  ('us', 'command'): 0.009345794392523364,
#  ('command', 'of'): 1.0,
#  ('of', 'special forces'): 0.007751937984496124,
#  ('special forces', 'near'): 1.0,
#  ('near', 'renowned'): 0.2,
#  ('renowned', 'None'): 1.0,
#  ('None', 'taj'): 0.00023479690068091102,
#  ('taj', 'mahal'): 1.0,
#  ('mahal', 'near'): 1.0,
#  ('near', 'conduct'): 0.2,
#  ('conduct', 'joint'): 0.2,
#  ('exercise', '.'): 0.14285714285714285,
#  ('.', 'two'): 0.004955401387512388,
#  ('two', 'nations'): 0.07317073170731707,
#  ('nations', 'None'): 0.17391304347826086,
#  ('None', 'air forces'): 0.00023479690068091102,
#  ('air forces', 'will'): 1.0,
#  ('will', 'provide'): 0.008547008547008548,
#  ('provide', 'support'): 0.14285714285714285,
#  ('support', '.'): 0.4444444444444444,
#  ('said', 'None'): 0.2023121387283237,
#  ('None', 'it'): 0.0009391876027236441,
#  ('it', 'be'): 0.05263157894736842,
#  ('be', 'two'): 0.0625,
#  ('nations', 'will'): 0.043478260869565216,
#  ('will', 'conducted'): 0.008547008547008548,
#  ('conducted', 'None'): 0.4,
#  ('None', 'many'): 0.0018783752054472881,
#  ('many', 'military'): 0.05263157894736842,
#  ('military', 'exercises'): 0.03125,
#  ('exercises', 'None'): 0.5,
#  ('None', 'of'): 0.002113172106128199,
#  ('of', 'first'): 0.007751937984496124,
#  ('first', 'None'): 0.2727272727272727,
#  ('None', '.'): 0.022540502465367457,
#  ('.', 'united states'): 0.0009910802775024777,
#  ('united states', 'india'): 0.037037037037037035,
#  ('india', 'None'): 0.23255813953488372,
#  ('None', 'during'): 0.000704390702042733,
#  ('during', 'cold war'): 0.034482758620689655,
#  ('cold war', 'era'): 1.0,
#  ('era', 'relations'): 1.0,
#  ('relations', 'strained'): 0.25,
#  ('strained', '.'): 1.0,
#  ('.', 'however'): 0.028741328047571853,
#  ('however', 'since'): 0.02857142857142857,
#  ('since', 'sept. 11'): 0.025,
#  ('sept. 11', 'new york'): 0.1111111111111111,
#  ('new york', 'and'): 0.16666666666666666,
#  ('and', 'washington'): 0.0027397260273972603,
#  ('washington', 'None'): 0.6190476190476191,
#  ('None', 'terrorist'): 0.001408781404085466,
#  ('terrorist', 'attacks'): 0.6111111111111112,
#  ('attacks', 'None'): 0.5,
#  ('None', 'since'): 0.00023479690068091102,
#  ('since', 'None'): 0.225,
#  ('None', 'has'): 0.000704390702042733,
#  ('has', 'been'): 0.08333333333333333,
#  ('been', 'dramatically'): 0.07142857142857142,
#  ('dramatically', 'improved'): 0.16666666666666666,
#  ('improved', '.'): 0.4,
#  ('.', 'apart from'): 0.0019821605550049554,
#  ('apart from', 'with'): 0.16666666666666666,
#  ('with', 'us'): 0.05063291139240506,
#  ('us', 'navy'): 0.018691588785046728,
#  ('navy', 'in'): 0.5,
#  ('in', 'indonesia'): 0.003703703703703704,
#  ('indonesia', 'and'): 0.3333333333333333,
#  ('and', 'malaysia'): 0.005479452054794521,
#  ('malaysia', 'between'): 0.1111111111111111,
#  ('None', 'malacca'): 0.00023479690068091102,
#  ('malacca', 'strait'): 1.0,
#  ('strait', 'None'): 1.0,
#  ('None', 'sea'): 0.00023479690068091102,
#  ('sea', 'patrolling'): 0.5,
#  ('patrolling', 'so as to prevent'): 0.5,
#  ('so as to prevent', 'None'): 1.0,
#  ('None', 'piracy'): 0.00023479690068091102,
#  ('piracy', 'acts'): 1.0,
#  ('acts', 'apart from'): 1.0,
#  ('apart from', ','): 0.5,
#  (',', 'india'): 0.004491017964071856,
#  ('india', 'recent years'): 0.023255813953488372,
#  ('recent years', 'has'): 0.3333333333333333,
#  ('has', 'with'): 0.05555555555555555,
#  ('with', 'britain'): 0.012658227848101266,
#  ('britain', ','): 0.18181818181818182,
#  (',', 'france'): 0.008982035928143712,
#  ('france', 'and'): 0.1111111111111111,
#  ('and', 'japan'): 0.01643835616438356,
#  ('japan', 'conducted'): 0.038461538461538464,
#  ('conducted', 'joint'): 0.4,
#  ('joint', 'exercises'): 0.05,
#  ('exercises', '.'): 0.5,
#  ('.', 'india'): 0.002973240832507433,
#  ('india', 'ministry of national defense'): 0.023255813953488372,
#  ('ministry of national defense', 'spokesman'): 0.3333333333333333,
#  ('spokesman', 'said'): 0.3333333333333333,
#  ('said', ':'): 0.31213872832369943,
#  (':', '"'): 0.8765432098765432,
#  ('"', 'upcoming'): 0.0032258064516129032,
#  ('upcoming', 'upcoming'): 0.3333333333333333,
#  ('upcoming', 'None'): 0.3333333333333333,
#  ('None', 'exercise'): 0.00046959380136182204,
#  ('exercise', 'aims at'): 0.14285714285714285,
#  ('aims at', 'further'): 1.0,
#  ('further', 'enhancing'): 0.06666666666666667,
#  ('enhancing', 'india'): 0.5,
#  ('united states', 'None'): 0.2037037037037037,
#  ('None', 'military'): 0.0011739845034045551,
#  ('military', 'cooperation'): 0.03125,
#  ('.', '"'): 0.07234886025768088,
#  ('"', 'last time'): 0.0032258064516129032,
#  ('last time', 'india'): 1.0,
#  ('india', 'with'): 0.023255813953488372,
#  ('with', 'united states'): 0.06329113924050633,
#  ('united states', 'conducted'): 0.018518518518518517,
#  ('None', 'was'): 0.001643578304766377,
#  ('was', 'after'): 0.041666666666666664,
#  ('after', '1962'): 0.013157894736842105,
#  ('1962', 'india'): 1.0,
#  ('and', 'china'): 0.00821917808219178,
#  ('china', 'None'): 0.0625,
#  ('None', 'brief'): 0.00023479690068091102,
#  ('brief', 'border'): 0.5,
#  ('border', 'war'): 0.07142857142857142,
#  ('war', 'after'): 0.14285714285714285,
#  ('after', 'a'): 0.039473684210526314,
#  ('a', 'year'): 0.03418803418803419,
#  ('year', '.'): 0.1111111111111111,
#  ('.', 'since'): 0.006937561942517344,
#  ('since', 'last'): 0.025,
#  ('last', 'july'): 0.09090909090909091,
#  ('july', 'since'): 0.3333333333333333,
#  ('since', ','): 0.125,
#  (',', 'about'): 0.005988023952095809,
#  ('about', 'None'): 0.24242424242424243,
#  ('None', '50'): 0.00046959380136182204,
#  ('50', 'None'): 0.4,
#  ('None', 'us'): 0.003287156609532754,
#  ('us', 'policy makers'): 0.009345794392523364,
#  ('policy makers', 'makers'): 1.0,
#  ('makers', 'visited'): 0.3333333333333333,
#  ('visited', 'None'): 1.0,
#  ('None', 'india'): 0.002113172106128199,
#  ('None', 'while'): 0.0030523597088518433,
#  ('while', 'india'): 0.047619047619047616,
#  ('None', 'equal number'): 0.00023479690068091102,
#  ('equal number', 'equal number'): 0.5,
#  ('equal number', 'people'): 0.5,
#  ('people', ','): 0.04081632653061224,
#  (',', 'including'): 0.014970059880239521,
#  ('including', 'vajpayee'): 0.037037037037037035,
#  ('vajpayee', 'prime minister'): 0.5,
#  ('prime minister', 'and'): 0.125,
#  ('and', 'his'): 0.005479452054794521,
#  ('his', 'his'): 0.375,
#  ('his', 'national'): 0.025,
#  ('national', 'security'): 0.4,
#  ('security', 'team'): 0.05,
#  ('team', 'None'): 0.26666666666666666,
#  ('None', ','): 0.011974641934726462,
#  (',', 'paid to'): 0.0014970059880239522,
#  ('paid to', 'washington'): 1.0,
#  ('washington', 'visits'): 0.047619047619047616,
#  ('visits', '.'): 0.5,
#  ('.', 'after'): 0.008919722497522299,
#  ('after', 'sept. 11'): 0.013157894736842105,
#  ('sept. 11', 'terrorist'): 0.4444444444444444,
#  ('and', 'last'): 0.0027397260273972603,
#  ('last', 'december'): 0.09090909090909091,
#  ('december', 'new delhi'): 0.16666666666666666,
#  ('new delhi', 'national parliament'): 0.16666666666666666,
#  ('national parliament', 'None'): 1.0,
#  ('None', 'attack'): 0.001408781404085466,
#  ('attack', 'led'): 0.1,
#  ('led', 'india'): 0.3333333333333333,
#  ('and', 'pakistan'): 0.010958904109589041,
#  ('pakistan', 'None'): 0.16,
#  ('military', 'tensions'): 0.03125,
#  ('tensions', 'tensions'): 0.4583333333333333,
#  ('tensions', 'after'): 0.041666666666666664,
#  ('after', ','): 0.19736842105263158,
#  (',', 'united states'): 0.004491017964071856,
#  ('india', 'between'): 0.06976744186046512,
#  ('None', 'contacts'): 0.00023479690068091102,
#  ('contacts', 'increased'): 1.0,
#  ('increased', '.'): 0.3333333333333333,
#  ('.', 'diplomat'): 0.0009910802775024777,
#  ('diplomat', 'said'): 1.0,
#  ('that', 'united states'): 0.02531645569620253,
#  ('None', 'national defense'): 0.00023479690068091102,
#  ('national defense', 'policy makers'): 1.0,
#  ('makers', 'in'): 0.3333333333333333,
#  ('in', 'february'): 0.003703703703703704,
#  ('february', 'in'): 0.3333333333333333,
#  ('in', 'decided'): 0.003703703703703704,
#  ('decided', 'mid-may'): 0.1111111111111111,
#  ('None', 'partly'): 0.00023479690068091102,
#  ('partly', 'also'): 1.0,
#  ('also', 'wanted'): 0.017241379310344827,
#  ('wanted', 'ease'): 0.25,
#  ('ease', 'new delhi'): 0.5,
#  ('new delhi', 'over'): 0.16666666666666666,
#  ('over', 'united states'): 0.02127659574468085,
#  ('united states', 'and'): 0.07407407407407407,
#  ('pakistan', 'relationship'): 0.04,
#  ('relationship', 'strengthening'): 0.2,
#  ('strengthening', 'None'): 1.0,
#  ('None', 'discomfort'): 0.00023479690068091102,
#  ('discomfort', 'discomfort'): 0.5,
#  ('discomfort', '.'): 0.5,
#  ('.', 'south african'): 0.0009910802775024777,
#  ('south african', 'space'): 1.0,
#  ('space', 'tourist'): 0.2857142857142857,
#  ('tourist', 'None'): 0.2,
#  ('None', 'space'): 0.001408781404085466,
#  ('space', 'None'): 0.5,
#  ('None', 'travel'): 0.0011739845034045551,
#  ('travel', 'back to'): 0.08333333333333333,
#  ('back to', 'earth'): 1.0,
#  ('earth', '('): 0.3333333333333333,
#  ('afp', 'moscow'): 0.04,
#  ('moscow', 'None'): 0.5,
#  (')', 'south african'): 0.009009009009009009,
#  ('tourist', 'shuttleworth'): 0.2,
#  ('shuttleworth', '5th'): 0.125,
#  ('5th', 'back to'): 1.0,
#  ('earth', '.'): 0.3333333333333333,
#  ('.', 'he'): 0.03964321110009911,
#  ('he', 'None'): 0.0975609756097561,
#  ('None', 'boarded'): 0.00023479690068091102,
#  ('boarded', 'None'): 0.5,
#  ('None', 'russian'): 0.0018783752054472881,
#  ('russian', 'spacecraft'): 0.1875,
#  ('spacecraft', 'at'): 0.25,
#  ('at', 'taipei'): 0.012658227848101266,
#  ('taipei', 'time'): 1.0,
#  ('time', 'a.m.'): 0.08333333333333333,
#  ('a.m.', '7:31'): 1.0,
#  ('7:31', '7:31'): 0.5,
#  ('7:31', 'smoothly'): 0.5,
#  ('smoothly', 'undocked'): 1.0,
#  ('undocked', 'international'): 1.0,
#  ('international', 'space station'): 0.08695652173913043,
#  ('space station', 'None'): 0.5,
#  ('None', 'and'): 0.012679032636769194,
#  ('and', 'at'): 0.0027397260273972603,
#  ('at', '11:51'): 0.012658227848101266,
#  ('11:51', '11:51'): 0.5,
#  ('11:51', 'successfully'): 0.5,
#  ('successfully', 'landed'): 0.25,
#  ('landed', 'on'): 0.5,
#  ('on', 'central asia'): 0.010638297872340425,
#  ('central asia', 'kazakhstan'): 1.0,
#  ('kazakhstan', 'northwestern'): 0.3333333333333333,
#  ('northwestern', 'None'): 0.3333333333333333,
#  ('None', 'steppe'): 0.00023479690068091102,
#  ('steppe', '.'): 1.0,
#  ('.', 'shuttleworth'): 0.002973240832507433,
#  ('shuttleworth', 'is'): 0.25,
#  ('is', 'after'): 0.012195121951219513,
#  ('after', 'american'): 0.013157894736842105,
#  ('american', 'None'): 0.16666666666666666,
#  ('None', 'tito'): 0.00023479690068091102,
#  ('tito', 'after'): 0.25,
#  ('after', 'None'): 0.13157894736842105,
#  ('None', 'in history'): 0.00023479690068091102,
#  ('in history', 'second'): 1.0,
#  ('second', 'None'): 0.3333333333333333,
#  ('None', 'paying'): 0.00046959380136182204,
#  ('paying', 'None'): 0.6,
#  ('tourist', '.'): 0.2,
#  ('he', 'and'): 0.012195121951219513,
#  ('and', 'tito'): 0.0027397260273972603,
#  ('tito', 'both'): 0.25,
#  ('both', 'paid'): 0.06666666666666667,
#  ('paid', '20 million'): 0.5,
#  ('20 million', 'us dollars'): 0.75,
#  ('us dollars', 'None'): 0.19444444444444445,
#  ('None', 'chance'): 0.00023479690068091102,
#  ('chance', 'None'): 0.5,
#  ('travel', '.'): 0.16666666666666666,
#  ('shuttleworth', 'None'): 0.25,
#  ('None', 'on'): 0.0046959380136182205,
#  ('on', 'april'): 0.010638297872340425,
#  ('april', '25'): 0.1,
#  ('25', 'boarded'): 0.16666666666666666,
#  ('boarded', 'russian'): 0.5,
#  ('spacecraft', 'enter'): 0.25,
#  ('enter', 'space'): 1.0,
#  ('None', 'stayed'): 0.00046959380136182204,
#  ('stayed', 'None'): 1.0,
#  ('None', '10'): 0.00046959380136182204,
#  ('10', 'days'): 0.06666666666666667,
#  ('days', 'None'): 0.3333333333333333,
#  ('conduct', 'a series of'): 0.4,
#  ('a series of', 'medical'): 0.1111111111111111,
#  ('medical', 'and'): 0.3333333333333333,
#  ('and', 'biological'): 0.0027397260273972603,
#  ('biological', 'science'): 0.3333333333333333,
#  ('science', 'experiments'): 0.5,
#  ('experiments', '.'): 0.5,
#  ('.', 'with'): 0.0009910802775024777,
#  ('with', 'shuttleworth'): 0.012658227848101266,
#  ('shuttleworth', 'together'): 0.125,
#  ('together', 'returning'): 0.16666666666666666,
#  ('returning', 'earth'): 1.0,
#  ('earth', 'None'): 0.3333333333333333,
#  ('None', 'are'): 0.0011739845034045551,
#  ('are', 'None'): 0.2608695652173913,
#  ('None', 'with'): 0.0030523597088518433,
#  ('with', 'him'): 0.012658227848101266,
#  ('him', 'None'): 0.4,
#  ('None', 'entered'): 0.00023479690068091102,
#  ('entered', 'space'): 0.125,
#  ('spacecraft', 'commander'): 0.25,
#  ('commander', 'gidzenko'): 1.0,
#  ('gidzenko', 'and'): 1.0,
#  ('and', 'italian'): 0.0027397260273972603,
#  ('italian', 'engineer'): 0.3333333333333333,
#  ('engineer', 'vittori'): 1.0,
#  ('vittori', '.'): 1.0,
#  ('.', 'spacecraft'): 0.0009910802775024777,
#  ('spacecraft', 'landed'): 0.25,
#  ('landed', 'terra firma'): 0.5,
#  ('terra firma', 'after'): 1.0,
#  (',', 'shuttleworth'): 0.0014970059880239522,
#  ('shuttleworth', 'and'): 0.125,
#  ('and', 'two'): 0.0027397260273972603,
#  ('None', 'partners'): 0.00023479690068091102,
#  ('partners', 'will'): 1.0,
#  ('will', 'first'): 0.008547008547008548,
#  ('first', 'be given'): 0.030303030303030304,
#  ('be given', 'physical'): 1.0,
#  ('physical', 'exam'): 0.5,
#  ('exam', 'None'): 1.0,
#  ('None', 'before'): 0.00046959380136182204,
#  ('before', 'boarding'): 0.07142857142857142,
#  ('boarding', 'helicopter'): 1.0,
#  ('helicopter', 'fly to'): 1.0,
#  ('fly to', 'kazakhstan'): 1.0,
#  ('kazakhstan', 'None'): 0.3333333333333333,
#  ('None', 'astana'): 0.00023479690068091102,
#  ('astana', 'None'): 1.0,
#  ('on', 'same day'): 0.010638297872340425,
#  ('same day', 'transferred'): 0.3333333333333333,
#  ('transferred', 'to'): 1.0,
#  ('to', 'russian'): 0.009523809523809525,
#  ('russian', 'capital'): 0.125,
#  ('capital', 'moscow'): 0.07142857142857142,
#  ('moscow', '.'): 0.16666666666666666,
#  ('.', 'this year'): 0.003964321110009911,
#  ('this year', 'just'): 0.038461538461538464,
#  ('just', '28'): 0.125,
#  ('28', 'None'): 1.0,
#  ('None', 'shuttleworth'): 0.00023479690068091102,
#  ('is', 'a'): 0.04878048780487805,
#  ('None', 'very'): 0.0009391876027236441,
#  ('very', 'wealthy'): 0.125,
#  ('wealthy', 'None'): 1.0,
#  ('None', 'computer'): 0.00023479690068091102,
#  ('computer', 'information'): 0.3333333333333333,
#  ('information', 'businessman'): 0.1,
#  ('businessman', '.'): 0.5,
#  ('he', 'for'): 0.012195121951219513,
#  ('for', 'this'): 0.08333333333333333,
#  ('this', 'None'): 0.37209302325581395,
#  ('None', 'trip'): 0.00046959380136182204,
#  ('trip', 'paid'): 0.25,
#  ('us dollars', ','): 0.2222222222222222,
#  (',', '10-day'): 0.0014970059880239522,
#  ('10-day', '10-day'): 0.5,
#  ('10-day', 'None'): 0.5,
#  ('space', 'travel'): 0.21428571428571427,
#  ('travel', 'dream'): 0.08333333333333333,
#  ('dream', 'None'): 1.0,
#  ('None', 'fulfilling'): 0.00023479690068091102,
#  ('fulfilling', '.'): 1.0,
#  ('.', 'human history'): 0.0009910802775024777,
#  ('human history', 'first'): 1.0,
#  ('first', 'space'): 0.030303030303030304,
#  ('tourist', 'is'): 0.2,
#  ('is', 'this year'): 0.012195121951219513,
#  ('this year', '60'): 0.038461538461538464,
#  ('60', 'None'): 0.5,
#  ('None', 'businessman'): 0.00023479690068091102,
#  ('businessman', 'tito'): 0.5,
#  ('tito', '.'): 0.25,
#  ('None', 'last year'): 0.0009391876027236441,
#  ('last year', 'april'): 0.043478260869565216,
#  ('april', 'went on'): 0.1,
#  ('went on', 'paying'): 0.5,
#  ('paying', 'space'): 0.2,
#  ('travel', 'None'): 0.16666666666666666,
#  ('russian', 'medical'): 0.0625,
#  ('medical', 'specialists'): 0.3333333333333333,
#  ('specialists', 'earlier'): 1.0,
#  ('earlier', 'pointed out'): 0.1111111111111111,
#  ('pointed out', 'that'): 0.9375,
#  ('that', 'shuttleworth'): 0.006329113924050633,
#  ('shuttleworth', 'than'): 0.125,
#  ('than', 'tito'): 0.1,
#  ('tito', 'more'): 0.25,
#  ('more', 'None'): 0.23529411764705882,
#  ('None', 'suitable'): 0.00023479690068091102,
#  ('suitable', 'space'): 0.5,
#  ('he', 'during'): 0.024390243902439025,
#  ('during', 'this'): 0.10344827586206896,
#  ('this', 'space'): 0.011627906976744186,
#  ('travel', 'during'): 0.08333333333333333,
#  ('during', 'None'): 0.13793103448275862,
#  ('None', 'at'): 0.0030523597088518433,
#  ('at', 'international'): 0.012658227848101266,
#  ('space station', 'conducted'): 0.5,
#  ('conducted', 'a number of'): 0.2,
#  ('a number of', 'scientific'): 0.16666666666666666,
#  ('scientific', 'experiments'): 0.5,
#  ('experiments', ','): 0.5,
#  ('including', 'including'): 0.2222222222222222,
#  ('including', 'aids'): 0.037037037037037035,
#  ('aids', 'pathogens'): 0.5,
#  ('pathogens', 'study'): 1.0,
#  ('study', '.'): 0.16666666666666666,
#  ('travel', 'in'): 0.08333333333333333,
#  ('in', 'south africa'): 0.003703703703703704,
#  ('south africa', 'drawn'): 1.0,
#  ('drawn', 'great'): 0.5,
#  ('great', 'None'): 0.3076923076923077,
#  ('None', 'publicity'): 0.00023479690068091102,
#  ('publicity', 'None'): 1.0,
#  ('and', 'None'): 0.052054794520547946,
#  ('None', 'won the honor'): 0.00023479690068091102,
#  ('won the honor', 'since'): 1.0,
#  ('since', 'mandela'): 0.025,
#  ('mandela', 'from'): 1.0,
#  ('from', 'prison'): 0.027777777777777776,
#  ('prison', 'release'): 1.0,
#  ('release', 'since'): 0.5,
#  ('None', 'most'): 0.0011739845034045551,
#  ('most', 'important'): 0.07142857142857142,
#  ('important', 'None'): 0.7142857142857143,
#  ('None', 'news'): 0.0011739845034045551,
#  ('news', 'event'): 0.08333333333333333,
#  ('event', '.'): 1.0,
#  ('us', 'government'): 0.09345794392523364,
#  ('government', 'not impressed'): 0.014925373134328358,
#  ('not impressed', 'None'): 1.0,
#  ('None', 'castro'): 0.00023479690068091102,
#  ('castro', 'to'): 0.5,
#  ('to', 'carter'): 0.009523809523809525,
#  ('carter', 'None'): 0.14285714285714285,
#  ('None', 'goodwill'): 0.00046959380136182204,
#  ('goodwill', 'stance'): 1.0,
#  ('stance', '('): 0.3333333333333333,
#  ('afp', 'washington'): 0.22,
#  (')', 'us'): 0.11711711711711711,
#  ('us', 'president'): 0.09345794392523364,
#  ('president', 'bush'): 0.09210526315789473,
#  ('bush', "'s"): 0.05714285714285714,
#  ("'s", 'administration'): 0.022727272727272728,
#  ('administration', 'None'): 0.25,
#  ('None', 'cuban'): 0.00023479690068091102,
#  ('cuban', 'president'): 0.3333333333333333,
#  ('president', 'castro'): 0.013157894736842105,
#  ('to', 'former'): 0.009523809523809525,
#  ('former', 'us'): 0.18181818181818182,
#  ('president', 'carter'): 0.013157894736842105,
#  ('carter', 'extended'): 0.14285714285714285,
#  ('extended', 'None'): 0.5,
#  ('stance', 'None'): 0.6666666666666666,
#  ('None', 'not impressed'): 0.00023479690068091102,
#  ('None', 'is'): 0.004461141112937309,
#  ('is', 'None'): 0.0975609756097561,
#  ('None', 'communist'): 0.00023479690068091102,
#  ('communist', 'island nation'): 0.5,
#  ('island nation', 'cuba'): 1.0,
#  ('cuba', 'None'): 0.46153846153846156,
#  ('None', 'a'): 0.005635125616341864,
#  ('None', 'making'): 0.00023479690068091102,
#  ('making', 'landmark'): 0.14285714285714285,
#  ('landmark', 'None'): 1.0,
#  ('None', 'visit'): 0.00046959380136182204,
#  ('visit', '.'): 0.3125,
#  ('.', 'castro'): 0.0009910802775024777,
#  ('castro', 'expressed'): 0.25,
#  ('expressed', 'willingness'): 0.125,
#  ('willingness', 'allow'): 1.0,
#  ('allow', 'carter'): 0.25,
#  ('carter', 'freely'): 0.14285714285714285,
#  ('freely', 'meet'): 1.0,
#  ('meet', 'dissidents'): 0.1,
#  ('dissidents', 'dissidents'): 0.5,
#  ('dissidents', 'and'): 0.5,
#  ('and', 'visit'): 0.0027397260273972603,
#  ('visit', 'all'): 0.0625,
#  ('all', 'areas'): 0.045454545454545456,
#  ('areas', ','): 0.2857142857142857,
#  ('including', 'washington'): 0.037037037037037035,
#  ('washington', 'alleged'): 0.047619047619047616,
#  ('alleged', 'are'): 0.2,
#  ('are', 'manufacturing'): 0.043478260869565216,
#  ('manufacturing', 'biological weapon'): 0.3333333333333333,
#  ('biological weapon', 'key components'): 1.0,
#  ('key components', 'None'): 1.0,
#  ('None', 'labs'): 0.00046959380136182204,
#  ('labs', '.'): 0.3333333333333333,
#  ('.', 'white house'): 0.0009910802775024777,
#  ('white house', 'and'): 0.16666666666666666,
#  ('and', 'state department'): 0.0027397260273972603,
#  ('state department', 'said'): 0.3333333333333333,
#  ('None', 'these'): 0.000704390702042733,
#  ('these', 'proposals'): 0.0625,
#  ('proposals', 'meaningless'): 1.0,
#  ('meaningless', 'meaningless'): 0.5,
#  ('meaningless', '.'): 0.5,
#  ('.', 'state department'): 0.0009910802775024777,
#  ('state department', 'spokeswoman'): 0.3333333333333333,
#  ('spokeswoman', 'cassel'): 1.0,
#  ('cassel', 'None'): 1.0,
#  ('None', 'said'): 0.0039915473115754874,
#  ('"', 'carter'): 0.0032258064516129032,
#  ('carter', 'president'): 0.2857142857142857,
#  ('president', 'is'): 0.02631578947368421,
#  ('None', 'cuba'): 0.00023479690068091102,
#  ('None', 'private citizen'): 0.00023479690068091102,
#  ('private citizen', 'visiting'): 1.0,
#  ('visiting', '.'): 0.2,
#  ('None', 'not'): 0.0037567504108945763,
#  ('not', 'been'): 0.022727272727272728,
#  ('been', 'sent'): 0.14285714285714285,
#  ('sent', 'inspect'): 0.25,
#  ('inspect', 'possible'): 1.0,
#  ('possible', 'None'): 1.0,
#  ('None', 'chemical'): 0.00023479690068091102,
#  ('chemical', 'or'): 0.3333333333333333,
#  ('or', 'biological weapons'): 0.03571428571428571,
#  ('biological weapons', 'facilities'): 0.5,
#  ('facilities', '.'): 0.42857142857142855,
#  ('"', 'her'): 0.0032258064516129032,
#  ('her', 'her'): 0.375,
#  ('her', 'brief'): 0.0625,
#  ('brief', 'remark'): 0.5,
#  ('remark', 'seems'): 0.5,
#  ('seems', 'echo'): 0.5,
#  ('echo', 'None'): 1.0,
#  ('None', 'other'): 0.0011739845034045551,
#  ('other', 'commentators'): 0.03125,
#  ('commentators', 'of'): 1.0,
#  ('of', 'response'): 0.007751937984496124,
#  ('response', 'None'): 0.2,
#  ('None', 'pointed out'): 0.00046959380136182204,
#  ('that', 'carter'): 0.006329113924050633,
#  ('carter', 'neither nor'): 0.14285714285714285,
#  ('neither nor', 'his'): 0.3333333333333333,
#  ('his', 'delegation'): 0.025,
#  ('delegation', 'other'): 0.14285714285714285,
#  ('other', 'members'): 0.03125,
#  ('members', 'neither nor'): 0.07142857142857142,
#  ('neither nor', 'neither nor'): 0.3333333333333333,
#  ('neither nor', 'proper'): 0.3333333333333333,
#  ('proper', 'inspection'): 0.5,
#  ('inspection', 'labs'): 0.25,
#  ('labs', 'necessary'): 0.3333333333333333,
#  ('necessary', 'necessary'): 0.4,
#  ('necessary', 'None'): 0.4,
#  ('None', 'science'): 0.00023479690068091102,
#  ('science', 'background'): 0.5,
#  ('background', '.'): 1.0,
#  ('.', 'carter'): 0.0009910802775024777,
#  ('carter', 'insisted'): 0.14285714285714285,
#  ('insisted', 'that'): 1.0,
#  ('that', 'government'): 0.006329113924050633,
#  ('government', 'officials'): 0.029850746268656716,
#  ('officials', 'None'): 0.2631578947368421,
#  ('None', 'he'): 0.002582765907490021,
#  ('he', 'briefed'): 0.012195121951219513,
#  ('briefed', 'briefed'): 0.5,
#  ('briefed', 'while'): 0.5,
#  ('while', 'None'): 0.19047619047619047,
#  ('None', 'no'): 0.001408781404085466,
#  ('no', 'mention'): 0.058823529411764705,
#  ('mention', 'us'): 1.0,
#  ('us', 'concern'): 0.009345794392523364,
#  ('concern', 'cuba'): 0.5,
#  ('cuba', "'s"): 0.07692307692307693,
#  ("'s", 'biological weapons'): 0.022727272727272728,
#  ('biological weapons', 'plan'): 0.5,
#  ('plan', ','): 0.2857142857142857,
#  (',', 'but'): 0.03143712574850299,
#  ('but', 'us'): 0.08,
#  ('us', 'secretary of state'): 0.028037383177570093,
#  ('secretary of state', 'powell'): 0.75,
#  ('powell', 'indicated'): 0.2,
#  ('indicated', 'he'): 0.07692307692307693,
#  ('he', 'not'): 0.012195121951219513,
#  ('not', 'believe'): 0.022727272727272728,
#  ('believe', 'this'): 0.3333333333333333,
#  ('.', 'powell'): 0.0009910802775024777,
#  ('powell', 'told'): 0.2,
#  ('told', 'abc'): 0.125,
#  ('abc', 'abc'): 0.6666666666666666,
#  ('abc', 'network'): 0.3333333333333333,
#  ('network', 'None'): 0.6666666666666666,
#  ('None', ':'): 0.0011739845034045551,
#  ('"', 'i'): 0.01935483870967742,
#  ('i', "n't"): 0.047619047619047616,
#  ("n't", 'know'): 0.14285714285714285,
#  ('know', 'carter'): 0.3333333333333333,
#  ('president', 'was given'): 0.013157894736842105,
#  ('was given', 'None'): 1.0,
#  ('None', 'what'): 0.00023479690068091102,
#  ('what', 'briefing'): 0.25,
#  ('briefing', '.'): 0.5,
#  ('.', 'i'): 0.003964321110009911,
#  ('i', 'certain'): 0.047619047619047616,
#  ('certain', 'we'): 0.3333333333333333,
#  ('we', 'no'): 0.027777777777777776,
#  ('no', 'reservation'): 0.058823529411764705,
#  ('reservation', 'None'): 0.5,
#  ('None', 'our'): 0.00046959380136182204,
#  ('our', 'belief'): 0.07142857142857142,
#  ('belief', 'cuba'): 0.3333333333333333,
#  ('cuba', 'possesses'): 0.07692307692307693,
#  ('possesses', 'biological warfare'): 0.5,
#  ('biological warfare', 'None'): 1.0,
#  ('None', 'research'): 0.00023479690068091102,
#  ('research', 'capabilities'): 0.5,
#  ('capabilities', '.'): 1.0,
#  ('"', 'napster'): 0.0032258064516129032,
#  ('napster', 'ceo'): 0.25,
#  ('ceo', 'hilbers'): 0.5,
#  ('hilbers', 'resigns'): 0.25,
#  ('resigns', '('): 1.0,
#  ('afp', 'san francisco'): 0.04,
#  ('san francisco', 'None'): 0.25,
#  ('None', 'once'): 0.00046959380136182204,
#  ('once', 'all-popular'): 0.1111111111111111,
#  ('all-popular', 'None'): 1.0,
#  ('None', 'free'): 0.00046959380136182204,
#  ('free', 'downloading'): 0.1111111111111111,
#  ('downloading', 'music'): 1.0,
#  ('music', 'company'): 0.3333333333333333,
#  ('company', 'napster'): 0.037037037037037035,
#  ('napster', 'said'): 0.125,
#  ('that', 'None'): 0.0759493670886076,
#  ('None', 'chief executive'): 0.00023479690068091102,
#  ('chief executive', 'hilbers'): 0.5,
#  ('hilbers', 'resigned'): 0.25,
#  ('resigned', ','): 1.0,
#  (',', 'None'): 0.11676646706586827,
#  ('None', 'immediately'): 0.00046959380136182204,
#  ('immediately', 'effective'): 0.25,
#  ('effective', '.'): 0.14285714285714285,
#  ('.', 'hilbers'): 0.0009910802775024777,
#  ('hilbers', "'"): 0.25,
#  ("'", 'None'): 0.16666666666666666,
#  ('None', 'will'): 0.0037567504108945763,
#  ('will', 'None'): 0.1623931623931624,
#  ('None', 'who'): 0.00023479690068091102,
#  ('who', 'replacement'): 0.1,
#  ('replacement', 'None'): 1.0,
#  ('None', 'at present'): 0.00023479690068091102,
#  ('at present', 'still'): 0.13333333333333333,
#  ('still', 'unknown'): 0.05555555555555555,
#  ('unknown', '.'): 1.0,
#  ('.', 'napster'): 0.0019821605550049554,
#  ('napster', 'music'): 0.25,
#  ('music', 'website'): 0.6666666666666666,
#  ('website', 'ever since'): 0.25,
#  ('ever since', 'last year'): 0.25,
#  ('last year', 'court'): 0.043478260869565216,
#  ('court', 'ruled'): 0.13333333333333333,
#  ('ruled', 'its'): 0.5,
#  ('its', 'its'): 0.2857142857142857,
#  ('its', 'service'): 0.14285714285714285,
#  ('service', 'given rise to'): 0.1111111111111111,
#  ('given rise to', 'wide-spread'): 1.0,
#  ('wide-spread', 'copying'): 0.5,
#  ('copying', 'copying'): 0.5,
#  ('copying', 'ever since'): 0.5,
#  ('ever since', 'remained'): 0.25,
#  ('remained', 'closed'): 0.3333333333333333,
#  ('closed', 'None'): 0.5,
#  ('None', 'today'): 0.0009391876027236441,
#  ('today', '.'): 0.03571428571428571,
#  ('website', 'shut down'): 0.25,
#  ('shut down', 'after'): 0.5,
#  ('many', 'other'): 0.05263157894736842,
#  ('other', 'websites'): 0.03125,
#  ('websites', 'taken its place'): 1.0,
#  ('taken its place', '.'): 1.0,
#  ('.', 'california-based'): 0.0009910802775024777,
#  ('california-based', 'california-based'): 0.6666666666666666,
#  ('california-based', 'redwood'): 0.3333333333333333,
#  ('redwood', 'city'): 1.0,
#  ('city', 'None'): 0.4,
#  ('None', 'napster'): 0.00046959380136182204,
#  ('napster', 'None'): 0.125,
#  ('None', 'stated'): 0.00023479690068091102,
#  ('stated', ':'): 1.0,
#  ('"', 'we'): 0.025806451612903226,
#  ('we', 'deeply'): 0.027777777777777776,
#  ('deeply', 'regret'): 0.5,
#  ('regret', 'yet'): 1.0,
#  ('yet', "n't"): 0.05555555555555555,
#  ("n't", 'None'): 0.42857142857142855,
#  ('None', 'funding'): 0.00023479690068091102,
#  ('funding', 'None'): 1.0,
#  ('None', 'solution'): 0.00023479690068091102,
#  ('solution', 'None'): 0.3333333333333333,
#  ('None', 'would'): 0.0011739845034045551,
#  ('would', 'enable'): 0.07142857142857142,
#  ('enable', 'napster'): 0.5,
#  ('napster', 'launch'): 0.125,
#  ('launch', 'benefit'): 0.25,
#  ('benefit', 'artists'): 0.3333333333333333,
#  ('artists', 'artists'): 0.5,
#  ('artists', 'and'): 0.5,
#  ('and', 'website'): 0.0027397260273972603,
#  ('website', 'users'): 0.25,
#  ('users', 'None'): 1.0,
#  ('None', 'service'): 0.00046959380136182204,
#  ('service', 'service'): 0.1111111111111111,
#  ('service', '.'): 0.2222222222222222,
#  ('"', 'it'): 0.0032258064516129032,
#  ('it', 'went on'): 0.05263157894736842,
#  ('went on', 'say'): 0.5,
#  ('say', ':'): 0.5,
#  ('we', 'will'): 0.16666666666666666,
#  ('will', 'in'): 0.07692307692307693,
#  ('in', 'coming'): 0.003703703703703704,
#  ('coming', 'None'): 0.5,
#  ('None', 'week'): 0.000704390702042733,
#  ('week', 'take'): 0.09090909090909091,
#  ('take', 'measures'): 0.058823529411764705,
#  ('measures', 'None'): 0.5833333333333334,
#  ('None', 'further'): 0.001643578304766377,
#  ('further', 'cut'): 0.06666666666666667,
#  ('cut', 'expenses'): 0.3333333333333333,
#  ('expenses', '.'): 0.3333333333333333,
#  ('"', 'once'): 0.0032258064516129032,
#  ('once', 'None'): 0.2222222222222222,
#  ('None', 'german'): 0.00023479690068091102,
#  ('german', 'media'): 1.0,
#  ('media', 'giant'): 0.2857142857142857,
#  ('giant', 'bertelsmann'): 0.25,
#  ('bertelsmann', 'None'): 0.5,
#  ('None', 'executive officer'): 0.00023479690068091102,
#  ('executive officer', 'None'): 1.0,
#  ('None', 'hilbers'): 0.00023479690068091102,
#  ('hilbers', ','): 0.25,
#  (',', 'at'): 0.004491017964071856,
#  ('at', 'bertelsmann'): 0.012658227848101266,
#  ('bertelsmann', 'started'): 0.5,
#  ('started', 'help'): 0.14285714285714285,
#  ('help', 'struggling'): 0.07692307692307693,
#  ('struggling', 'struggling'): 0.3333333333333333,
#  ('struggling', 'None'): 0.3333333333333333,
#  ('napster', 'within'): 0.125,
#  ('within', 'court'): 0.14285714285714285,
#  ('court', 'ruling'): 0.06666666666666667,
#  ('ruling', 'None'): 0.4444444444444444,
#  ('None', 'framework'): 0.00046959380136182204,
#  ('framework', 'framework'): 0.3333333333333333,
#  ('framework', 'within'): 0.3333333333333333,
#  ('within', 'continue'): 0.14285714285714285,
#  ('continue', 'operation'): 0.16666666666666666,
#  ('operation', 'time'): 0.058823529411764705,
#  ('time', 'None'): 0.16666666666666666,
#  ('None', 'took'): 0.00023479690068091102,
#  ('took', 'took'): 0.3333333333333333,
#  ('took', 'napster'): 0.3333333333333333,
#  ('ceo', 'position'): 0.5,
#  ('position', '.'): 0.6,
#  ('.', 'oecd'): 0.0009910802775024777,
#  ('oecd', 'ministers examine'): 1.0,
#  ('ministers examine', 'in'): 1.0,
#  ('in', 'paris'): 0.007407407407407408,
#  ('paris', 'outlook'): 0.125,
#  ('outlook', 'world'): 1.0,
#  ('world', 'economy'): 0.043478260869565216,
#  ('economy', '('): 0.05555555555555555,
#  ('afp', 'paris'): 0.04,
#  ('paris', 'None'): 0.375,
#  (')', 'world'): 0.018018018018018018,
#  ('world', 'major'): 0.043478260869565216,
#  ('major', 'industrial nations'): 0.058823529411764705,
#  ('industrial nations', 'None'): 1.0,
#  ('None', 'senior'): 0.000704390702042733,
#  ('senior', 'ministers'): 0.14285714285714285,
#  ('ministers', 'None'): 0.4,
#  ('None', '15th'): 0.00023479690068091102,
#  ('15th', 'in'): 0.3333333333333333,
#  ('None', '2-day'): 0.00023479690068091102,
#  ('2-day', '2-day'): 0.5,
#  ('2-day', 'meeting'): 0.5,
#  ('meeting', '.'): 0.23529411764705882,
#  ('.', 'they'): 0.007928642220019821,
#  ('they', 'will'): 0.08,
#  ('will', 'examine'): 0.008547008547008548,
#  ('examine', 'promising'): 1.0,
#  ('promising', 'promising'): 0.5,
#  ('promising', 'of'): 0.5,
#  ('of', 'economy'): 0.015503875968992248,
#  ('economy', 'future'): 0.05555555555555555,
#  ('future', 'None'): 1.0,
#  ('None', 'as well as'): 0.000704390702042733,
#  ('as well as', 'confront'): 0.07692307692307693,
#  ('confront', 'united states'): 1.0,
#  ('united states', 'europe'): 0.018518518518518517,
#  ('europe', 'between'): 0.14285714285714285,
#  ('between', 'by'): 0.058823529411764705,
#  ('by', 'trade'): 0.02127659574468085,
#  ('trade', 'dispute'): 0.20833333333333334,
#  ('dispute', 'None'): 0.2727272727272727,
#  ('None', 'caused'): 0.0009391876027236441,
#  ('caused', 'None'): 0.3,
#  ('None', 'division'): 0.00023479690068091102,
#  ('division', 'looming'): 1.0,
#  ('looming', '.'): 1.0,
#  ('.', 'economic'): 0.0009910802775024777,
#  ('economic', 'cooperation'): 0.04,
#  ('cooperation', 'and'): 0.05555555555555555,
#  ('and', 'development'): 0.0027397260273972603,
#  ('development', 'organization'): 0.07142857142857142,
#  ('organization', '30'): 0.14285714285714285,
#  ('30', 'None'): 0.6,
#  ('None', 'member nations'): 0.00023479690068091102,
#  ('member nations', 'None'): 0.5,
#  ('None', 'representatives'): 0.00046959380136182204,
#  ('representatives', 'also'): 0.3333333333333333,
#  ('also', 'will'): 0.1724137931034483,
#  ('will', 'concern'): 0.008547008547008548,
#  ('concern', 'rich'): 0.5,
#  ('rich', 'None'): 0.5,
#  ('and', 'poor'): 0.0027397260273972603,
#  ('poor', 'nations'): 0.2727272727272727,
#  ('nations', 'between'): 0.043478260869565216,
#  ('None', 'abridge'): 0.00023479690068091102,
#  ('abridge', 'gap'): 1.0,
#  ('gap', 'None'): 1.0,
#  ('None', 'arising'): 0.00046959380136182204,
#  ('arising', 'None'): 1.0,
#  ('None', 'conflict'): 0.00023479690068091102,
#  ('conflict', '.'): 0.14285714285714285,
#  ('however', ','): 0.2,
#  (',', 'macroeconomics'): 0.0014970059880239522,
#  ('macroeconomics', 'macroeconomics'): 0.5,
#  ('macroeconomics', 'None'): 0.5,
#  ('None', 'discussion'): 0.000704390702042733,
#  ('discussion', 'may'): 0.2,
#  ('may', 'by'): 0.047619047619047616,
#  ('by', 'united states'): 0.02127659574468085,
#  ('and', 'european union'): 0.0027397260273972603,
#  ('european union', 'between'): 1.0,
#  ('between', 'trade'): 0.058823529411764705,
#  ('trade', 'friction'): 0.041666666666666664,
#  ('friction', 'None'): 1.0,
#  ('None', 'escalating'): 0.00046959380136182204,
#  ('escalating', 'None'): 0.5,
#  ('None', 'eclipsed'): 0.00023479690068091102,
#  ('eclipsed', '.'): 1.0,
#  ('.', 'european'): 0.002973240832507433,
#  ('european', 'nations'): 0.375,
#  ...}

# %%
hmm_model.bake()

# %%
# sample a state-path(observation)
hmm_model.sample(length= 6)
# Out:
# array(['这', '一', '了', '暴雨', '原因', '人民'], dtype='<U2')

# %%
def replace_unknown(sequence):
    return [w for w in sequence if w in DataSet_vocab_frozen]

# re-define the decoding--- state path might no exist!
def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    if state_path is not None:
        return [state[1].name for state in state_path[1:]]

# %% [markdown]
# see if this model works!

# %%
hmm_model.node_count()
# Out:
# 5678

# %%
# test the model
a = ['则', '警告', '：', '巴勒斯坦', '全国', '安全', '。']
hmm_model.log_probability(a)
# Out:
# -26.84114220862837

# %%
print(", ".join(state.name for i, state in hmm_model.viterbi(['则', '警告', '：', '巴勒斯坦', '全国', '安全', '。'])[1]))
# Out:
# base-hmm-translator-start, on the other hand, warned, :, palestinian, national, security, .

# %%
simplify_decoding(a, hmm_model)
# Out:
# ['on the other hand',
#  'warned',
#  ':',
#  'palestinian',
#  'national',
#  'security',
#  '.']

# %%
# a function that validate that there is a state path for input sentence
def testpath(X,model):
    _, state_path = model.viterbi(replace_unknown(X))
    if state_path != None:
        return True
    else:
        return False

# a more complex decoding, try to translate as much as possible words together
# there might be some case that we can not find a path for whole sentence, 
# but we can find a path for a part of sentence.
def decoding(X,model):
    X = replace_unknown(X)
    results = []
    start = 0
    end = 1
    tmp = []
    while len(results)!= len(X):
        while testpath(X[start:end],model) and end < len(X):
            if end <= len(X):
                end += 1
        # case 1: even can not translate a single word
        if end == start+1:
            results.append('None')
            start = end
            end += 1
        # case 2: can translate whole sentence
        elif start == 0 and end == len(X):
            results = simplify_decoding(X, model)
            end += 1
        # case 3: can translate part of sentence
        else:
            tmp = simplify_decoding(X[start:end-1], model)
            start = end
            end += 1
            results += tmp
    return results

# %%
# test the new decoding function
test = ['鼓励', '孩子', '发挥', '想象力', '，', '每天', '和', '孩子', '一', '起', '阅读', '。']
print(testpath(test,hmm_model))
decoding(test,hmm_model)
# Out:
# True
# ['To encourage',
#  "your youngster 's",
#  'None',
#  'imagination',
#  ',',
#  'every day',
#  'to',
#  'him',
#  'None',
#  'to',
#  'read',
#  '.']

# %%
for sentence, result in zip(TestSet_ch, TestSet_en):
    print("Sentence: {}\n".format(sentence))
    print("Predicted labels:\n-----------------")
#     print(simplify_decoding(sentence, hmm_model))
#     print()
#     print("decoding:")
    print(decoding(sentence, hmm_model))
    print()
    print("Actual labels:\n--------------")
    print(result)
    print("\n")
# Out:
# Sentence: ('目前', '，', '科学家', '们', '正在', '用', '三硝基', '甲苯', '（', '黄色炸药', '）', '饲养', '一', '群', '羊', '。')
#
# Predicted labels:
# -----------------
# ['None', '.', 'Scientists', 'Scientists', 'None', 'None', '(', 'a', 'crowd', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'scientists', 'scientists', 'is feeding to', 'is feeding to', 'TNT', 'TNT', 'None', 'TNT', 'None', 'is feeding to', 'a flock of', 'a flock of', 'sheep', '.')
#
#
# Sentence: ('美国', '俄勒冈', '大学', '的', '兽医学', '教授', '莫里', '克雷格', '发现', '，', '反刍', '的', '食物', '的', '哺乳类', '动物', '能够', '有效', '的', '清理', '爆炸物', '污染', '的', '土壤', '。')
#
# Predicted labels:
# -----------------
# ['us', 'None', 'None', ',', 'None', 'None', 'None', 'None', 'effective', 'None', 'Clean Up', 'Explosives', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'Oregon', 'State University', 'None', 'veterinary', 'scientist', 'Morrie', 'Craig', 'has found that', ',', 'cud-chewing', 'cud-chewing', 'cud-chewing', 'cud-chewing', 'mammals', 'mammals', 'can', 'efficiently', 'efficiently', 'clean up', 'explosives - contaminated', 'explosives - contaminated', 'explosives - contaminated', 'soil', ',')
#
#
# Sentence: ('在', '美国', '，', '军事', '训练', '产生', '的', '三硝基', '甲苯', '以及', '其他', '爆炸物', '以及', '一些', '老', '工厂', '的', '类似', '残留物', '共', '130', '万', '吨', '，')
#
# Predicted labels:
# -----------------
# ['in', 'united states', ',', 'None', 'training', 'None', 'as well as', 'other', 'None', 'None', 'old', 'None', 'None', 'total', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'the U.S.', 'None', 'military', 'munitions training', 'from', 'from', 'TNT', 'TNT', 'and', 'other', 'explosives', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '1.3 million', '1.3 million', 'tons', 'None')
#
#
# Sentence: ('这些', '爆炸', '残留物', '已经', '在', '美国', '的', '土地', '上', '残留', '了', '几十', '年')
#
# Predicted labels:
# -----------------
# ['these', 'None', 'in', 'united states', 'of', 'land', 'None', 'None', 'dozens', 'None', 'None']
#
# Actual labels:
# --------------
# ('the', 'remnants', 'remnants', 'remain for', 'in', 'None', 'None', 'the ground', 'in', 'remain for', 'remain for', 'decades', 'decades')
#
#
# Sentence: ('这些', '残留物', '并', '不', '会', '立即', '危害', '人类', '的', '健康', '，', '但是', '国防部', '官员', '表示', '，', '担忧', '这些', '残留物', '会', '渗', '到', '地下', '污染', '地下水', '或者', '毒害', '作物', '（', '以前', '发生', '过', '此类', '事件', '）', '。')
#
# Predicted labels:
# -----------------
# ['the', 'None', 'not', 'None', 'immediately', 'None', 'health', 'and', 'None', 'None', 'None', 'and', 'worries', 'None', 'to', 'None', '(', 'None', 'None', 'None', ')', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('This', 'residue', 'rarely', 'rarely', 'rarely', 'immediate', 'poses an threat', 'None', 'None', 'health', ',', 'but', 'the Department of Defense', 'officials', 'fear', 'fear', 'fear that', 'it', 'it', 'could', 'seep', 'into', 'None', 'None', 'groundwater', 'or', 'poison', 'plants', '(', 'before', 'has happened', 'has happened', 'which', 'which', ')', '.')
#
#
# Sentence: ('诸如', '燃烧', '土壤', '等', '传统', '清理', '技术', '不但', '昂贵', '而且', '耗时', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'None', 'None', 'while', 'None', 'None']
#
# Actual labels:
# --------------
# ('such as', 'incinerating', 'the soil', 'None', 'Conventional', 'cleanup', 'techniques', 'None', 'are expensive', 'and', 'time-consuming', '.')
#
#
# Sentence: ('然而', '羊儿', '们', '可以', '免费', '做', '这项', '工作', '。')
#
# Predicted labels:
# -----------------
# ['however', 'None', 'None', 'free', 'the', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'Sheep', 'Sheep', 'will', 'for free', 'work', 'work', 'work', '.')
#
#
# Sentence: ('2004', '年', '，', '克雷格', '发现', '羊', '胃', '里', '助', '消化', '的', '细菌', '能够', '迅速', '将', '三硝基', '甲苯', '转化', '为', '一', '种', '无害', '的', '化合物', '。')
#
# Predicted labels:
# -----------------
# ['2011', 'None', 'None', 'None', 'None', 'None', 'None', 'will', 'None', 'was', 'a', 'a', 'None', '.']
#
# Actual labels:
# --------------
# ('2004', '2004', ',', 'Craig', 'discovered', "a sheep 's", 'stomach', 'in', 'help', 'digest cellulose', 'in', 'the bacteria', 'can', 'rapidly', 'convert into', 'TNT', 'TNT', 'convert into', 'convert into', 'a', 'a', 'harmless', 'harmless', 'compound', '.')
#
#
# Sentence: ('在', '近期', '的', '一些', '实验', '中', '，', '克雷格', '以及', '美国', '农业部', '的', '一些', '研究者', '们', '通过', '用', '三硝基', '甲苯', '饲养', '羊', '三', '周')
#
# Predicted labels:
# -----------------
# ['in', 'None', 'some', 'during', ',', 'and', 'united states', 'None', 'None', 'Sheep', 'None', 'None', 'three', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('In', 'recent', 'recent', 'experiments', 'experiments', 'In', ',', 'he', 'and', 'the U.S. Department of Agriculture', 'the U.S. Department of Agriculture', 'None', 'None', 'researchers', 'researchers', 'None', 'fed for', 'TNT', 'TNT', 'fed for', 'sheep', 'three', 'weeks')
#
#
# Sentence: ('发现', '三硝基', '甲苯', '在', '羊', '体内', '分解', '的', '如此', '彻底', '，', '甚至', '在', '羊', '的', '粪便', '里', '没有', '任何', '残留', '，', '连', '类似', '相关', '的', '化合物', '都', '没有')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'those', 'such', 'None', 'in', 'None', 'None', 'no', 'any', 'None', 'None', 'sauce-related', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('found that', 'it', 'it', 'None', 'None', 'None', 'broke down', 'None', 'so', 'completely', 'that', 'that', 'in', 'the animals', "'", 'feces', 'in', 'no', 'None', 'traces', 'or', 'None', 'None', 'related', 'related', 'compounds', 'no any', 'no any')
#
#
# Sentence: ('克雷格', '和', '他', '的', '同事', '们', '计划', '在', '被', '炸药', '污染', '的', '土地', '上', '种草', '以', '吸收', '爆炸物', '。')
#
# Predicted labels:
# -----------------
# ['with', 'him', 'None', 'None', 'plan', 'before', 'None', 'None', 'land', 'None', 'so as to', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Craig', 'and', 'his', 'his', 'colleagues', 'colleagues', 'plan to', 'in', 'contaminated', 'TNT', 'contaminated', 'contaminated', 'soil', 'in', 'plant grasses', 'to', 'suck up', 'the explosives', '.')
#
#
# Sentence: ('在', '羊', '咀嚼', '的', '同时', '，', '羊', '消化道', '内', '的', '细菌', '就', '可以', '将', '残留', '的', '爆炸物', '分解', '。')
#
# Predicted labels:
# -----------------
# ['in', 'None', 'while', ',', 'over', 'None', 'None', 'None', 'will', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('While', 'the sheep', 'munch away', 'While', 'While', ',', 'their', 'digestive tract', 'in', 'None', 'the bacteria', 'None', 'None', 'take care of', 'the rest', 'the rest', 'the rest', 'take care of', '.')
#
#
# Sentence: ('克雷格', '的', '实验室', '正在', '对', '来自', '军事', '基地', '的', '食草', '动物', '进行', '测试', '，')
#
# Predicted labels:
# -----------------
# ['None', 'labs', 'from', 'taken', 'None', 'al qaeda', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Craig', "'s", 'lab', 'is testing', 'is testing', 'from', 'military', 'a base', 'None', 'on soil', 'the grazers', 'is testing', 'is testing', '.')
#
#
# Sentence: ('他', '估计', '20', '只', '的', '一', '群', '就', '可以', '在', '一个', '月', '内', '清理', '一', '英亩', '土地', '，', '在', '不到', '三', '年', '的', '时间', '内', '便', '可以', '彻底', '清除', '军事', '所', '用', '的', '爆炸', '残留物')
#
# Predicted labels:
# -----------------
# ['he', 'None', '20', 'None', 'None', 'a', 'group', 'will', 'can', 'None', 'None', 'months', 'None', 'Clean Up', 'None', 'None', 'after', 'three', 'years', 'None', 'time', 'in', 'None', 'can', 'military', 'None', 'to use', 'real', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('He', 'estimates that', '20', '20', 'None', 'a flock of', 'a flock of', 'None', 'could', 'in', 'a', 'month', 'in', 'clear', 'an', 'acre of', 'grass', ', and', 'in', 'less than', 'three', 'years', 'in', 'in', 'in', 'None', 'None', 'completely', 'rid', 'None', 'None', 'None', 'None', 'munitions', 'residue')
#
#
# Sentence: ('克雷格', '指出', '，', '即使', '是', '吃', '了', '炸药', '的', '羊', '的', '羊肉', '被', '做成', '烤肉', '，', '也', '不', '会', '爆炸', '或者', '危害', '健康', '：')
#
# Predicted labels:
# -----------------
# ['according to', ',', 'even', 'None', 'None', 'None', 'None', 'by', ',', 'yet', 'not', 'will', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Craig', 'points out', 'that', 'even if', 'None', 'TNT - eating', 'TNT - eating', 'TNT - eating', 'TNT - eating', 'sheep', "'s", 'meat', 'found its way onto a barbecue', 'found its way onto a barbecue', 'found its way onto a barbecue', ',', ',', 'never', 'could', 'explode', 'or', 'cause health problems', 'cause health problems', ':')
#
#
# Sentence: ('“', '摄取', '的', '炸药', '已经', '被', '分解', '成', '很', '小', '的', '分子', '，', '不', '可能', '形成', '和', '原', '化合物', '一样', '或者', '相似', '的', '东西', '。', '”')
#
# Predicted labels:
# -----------------
# ['None', 'has been', 'priced', 'None', 'None', 'small', 'None', 'None', 'nor', 'can', 'become', 'None', 'former', 'None', 'or', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('"', 'ingested', 'ingested', 'The TNT', 'None', 'is broken down', 'is broken down', 'is broken down into', 'small', 'small', 'small', 'molecules', 'None', 'are in no way similar to', 'are in no way similar to', 'None', 'None', 'original', 'the compound', 'are in no way similar to', 'are in no way similar to', 'are in no way similar to', 'None', 'None', '.', '"')
#
#
# Sentence: ('在', '上', '周五', '(', '2011', '年', '2', '月', '4', '日', ')', '的', '一个', '可能', '被', '称为', '“', '无人', '机', '的', '基蒂', '霍克', '时刻', '”', '中', '，', '一', '架', '实验性', '的', '无人机', '在', '空中', '飞行', '了', '29', '分钟', '，', '这', '架', '飞机', '不仅', '没有', '机上', '的', '飞行员', '，', '而且', '也', '没有', '远程', '操纵', '者', '。')
#
# Predicted labels:
# -----------------
# ['in', 'last', 'friday', '2011', '2011', 'None', 'four', 'None', 'None', 'a', 'None', 'None', 'nicknamed', 'None', 'during', ',', 'a', 'None', 'None', 'None', 'in the air', 'None', 'None', 'the', 'None', 'aircraft', 'nobody', 'None', 'None', 'while', 'None', 'no', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('In', 'late', 'Friday', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'a', 'may be', 'None', 'None', 'None', 'an unmanned', 'aircraft', 'None', 'Kitty', 'Hawk', 'moment', 'None', 'In', 'None', 'an', 'an', 'experimental', 'experimental', 'drone', 'None', 'None', 'made a flight', 'None', '29', 'minute', ',', 'None', 'None', 'None', 'not only', 'lacking', 'onboard', 'onboard', 'an pilot', ',', 'None', 'None', 'None', 'one flying the vehicle remotely', 'one flying the vehicle remotely', 'one flying the vehicle remotely', '.')
#
#
# Sentence: ('“', '我们', '正', '在', '创造', '历史', '”', '，', '为', '美国', '海军', '建造', 'X-47B', '的', '诺斯罗普', '格鲁门', '公司', '航天', '系统', '部门', '负责', '该', '项目', '的', '副', '总裁', '兼', '产品', '经理', 'Janis', 'Pamiljans', '说', '，')
#
# Predicted labels:
# -----------------
# ['we', 'None', 'None', 'set', 'None', 'None', 'us', 'navy', 'in', 'nbc', 'None', 'None', 'the', 'None', 'None', 'vice', 'governor', 'None', 'said', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('"', 'Such events are history in the making', 'Such events are history in the making', 'Such events are history in the making', 'Such events are history in the making', 'Such events are history in the making', '"', ',', 'for', 'the U.S.', 'Navy', 'built', 'the X-47B program', 'None', 'Northrop', 'Grumman', 'Grumman', 'Aerospace', 'Systems', 'None', 'None', 'None', 'None', 'None', 'vice', 'president', 'and', 'program', 'manager', 'Janis', 'Pamiljans', 'said', '.')
#
#
# Sentence: ('“', '我们', '已经', '超越', '了', '想', '在', '飞行器', '上', '所', '达到', '的', '目标', '！', '”')
#
# Predicted labels:
# -----------------
# ['we', 'already', 'None', 'None', 'over', 'previous', 'None', 'reached', 'None', 'goal']
#
# Actual labels:
# --------------
# ('"', 'We', 'surpassed', 'surpassed', 'surpassed', 'wanted to', 'with', 'the flight', 'with', 'None', 'achieve', 'None', 'what', '.', '"')
#
#
# Sentence: ('这', '架', '采用', '蝠', '翼', '无', '尾', '布局', '的', 'X-47B', '是', '诺斯罗普', '格鲁门', '公司', '制造', '的', '两', '架', '演示', '机', '中', '的', '一', '架', '，', '在', '首飞', '上', '飞', '到', '了', '5000', '英尺', '的', '高空', '，', '并', '准确', '地', '降落', '在', '目标', '上', '。')
#
# Predicted labels:
# -----------------
# ['the', 'None', 'None', 'no', 'The icing on the cake', 'is', 'None', 'None', 'None', 'two', 'None', 'in', 'None', 'a', 'None', ',', 'over', 'previous', 'None', 'None', '5,000', 'None', 'None', 'None', 'None', 'goal', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('The', 'The', 'None', 'bat', 'winged', 'less', 'tail', 'None', 'None', 'X-47B', ',', 'Northrop', 'Grumman', 'None', 'built', 'built', 'two', 'two', 'demonstrators', 'demonstrators', 'None', 'of', 'one', 'one', 'None', 'during', 'debut', 'during', 'flew', 'as high as', 'as high as', '5,000', 'feet', 'None', 'None', 'None', 'None', 'right', 'right', 'touched down', 'on', 'target', 'on', '.')
#
#
# Sentence: ('在', '随后', '召开', '的', '新闻', '发布会', '上', '，', '项目', '负责人', 'Jaime', 'Engdahl', '对', '媒体', '说', '：', '“', '我们', '的', '团队', '仍然', '在', '分析', '数据', '，', '但', '我', '可以', '告诉', '你', '，', '无人机', '的', '表现', '是', '无可', '挑剔', '的', '。')
#
# Predicted labels:
# -----------------
# ['in', 'None', 'None', 'news', 'None', ',', 'None', 'officials', 'on', 'None', 'said', ':', 'None', 'team', 'in', 'Apple', ',', 'but', 'None', 'None', 'told', 'None', 'None', 'performance', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '"', 'The', 'The', 'team', 'still', 'is analyzing', 'is analyzing', 'data', ',', 'but', 'I', 'will', 'tell', 'you', 'None', 'the air vehicle', 'None', 'performance', 'was', 'rock solid', 'rock solid', 'rock solid', '.')
#
#
# Sentence: ('它', '做到', '了', '我们', '所', '期望', '的', '事情', '。')
#
# Predicted labels:
# -----------------
# ['it', 'None', 'we', 'None', 'None', 'None', '.']
#
# Actual labels:
# --------------
# ('It', 'did', 'did', 'None', 'was', 'expected', 'what', 'what', '.')
#
#
# Sentence: ('从', '工程师', '那里', '得到', '的', '初步', '反馈', '表明', '试验', '机', '符合', '模型', '的', '空气', '动力学', '性能', '，', '并且', '导航', '和', '操纵', '都', '十分', '出色', '。')
#
# Predicted labels:
# -----------------
# ['from', 'None', 'seen', 'None', 'None', 'None', 'None', 'None', 'air', 'None', 'and', 'and', 'None', 'very', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('from', 'the engineers', 'None', 'None', 'None', 'preliminary', 'The feedback', 'was that', 'it', 'it', 'matched', 'the model', 'None', 'aerodynamics', 'aerodynamics', 'performance', 'and', 'and', 'guidance', 'and', 'control', 'None', 'very', 'well', '.')
#
#
# Sentence: ('这', '是', '对于', '团队', '在', '过去', '几', '年', '的', '努力', '工作', '和', '他们', '在', '这', '一', '领域', '的', '专业', '知识', '的', '最', '好', '证明', '。', '”')
#
# Predicted labels:
# -----------------
# ['this', 'is', 'None', 'team', 'prior to', 'None', 'a few', 'years', 'None', 'work', 'None', 'with', 'their', 'in', 'the', 'None', 'fields', 'None', 'None', 'None', 'largest', 'None', 'prove', 'None', 'None']
#
# Actual labels:
# --------------
# ('That', 'is', 'to', 'the teams', 'over', 'the last', 'few', 'years', 'None', 'hard', 'work', 'and', 'None', 'in', 'this', 'realm', 'realm', 'None', 'expertise', 'expertise', 'None', 'None', 'None', 'a testament', ',', '"')
#
#
# Sentence: ('在', '位于', '加州', '莫哈韦', '沙漠', '的', '爱德华', '空军', '基地', '，', 'X-47B', '完美', '的', '飞行', '和', '着陆', '向', '人们', '展示', '了', '由', '设计', '软件', '设计', '出', '的', '全自动', '无人', '驾驶', '飞机', '的', '精确性', '。')
#
# Predicted labels:
# -----------------
# ['in', 'ranked', 'None', 'None', 'air forces', 'None', 'grand', 'None', 'flight', 'None', 'None', 'people', 'None', 'None', 'None', 'None', 'None', 'None', 'aircraft', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('in', 'in', "California 's", 'Mojave', 'Desert', 'in', 'Edwards', 'Air Force', 'Base', 'None', "X-47B 's", 'flawless', 'flawless', 'flight', 'and', 'landing back', 'None', 'None', 'demonstrated', 'demonstrated', 'None', 'None', 'software', 'design', 'None', 'None', 'fully automated', 'unmanned', 'unmanned', 'aircraft', 'unmanned', 'the accuracy', '.')
#
#
# Sentence: ('项目', '负责人', '指出', '，', '试飞', '增强', '了', '人们', '对', 'X-47B', '在', '接下来', '的', '航母', '测试', '中', '成功', '的', '信心', '。')
#
# Predicted labels:
# -----------------
# ['None', 'officials', 'according to', 'None', 'stepped up', 'None', 'None', 'for', 'in', 'None', 'None', 'success', 'None', 'confidence', '.']
#
# Actual labels:
# --------------
# ('program', 'managers', 'said', ',', 'The trial run', 'bolstered', 'bolstered', 'None', 'confidence', 'X-47B', 'None', 'follow-on', 'follow-on', 'an aircraft carrier', 'test flights', 'None', 'be successful', 'confidence', 'confidence', '.')
#
#
# Sentence: ('人们', '希望', 'X-47B', '在', '爱德华', '空军', '基地', '的', '试飞', '频率', '随着', '飞机', '能力', '的', '提升', '，', '能够', '达到', '每周', '一', '次', '。')
#
# Predicted labels:
# -----------------
# ['None', 'hope', 'None', 'air forces', 'None', 'with', 'None', 'None', 'None', 'None', 'reached', 'a', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('are expected to', 'are expected to', 'None', 'None', 'Edwards', 'Air Force', 'Base', 'None', 'Flight', 'rates', 'as', 'the plane', 'capabilities', 'None', 'are expanded', 'None', 'None', 'None', 'per week', 'once', 'once', '.')
#
#
# Sentence: ('上', '周五', '试飞', '的', 'Air', 'Vehicle', '1', '（', '也', '被', '称为', 'AV-1', '）', '，', '将', '被', '转运', '到', '帕塔克森特', '河', '海军', '航空站', '，', '最终', '将', '在', '航空母舰', '上', '完成', '更', '多', '测试', '。')
#
# Predicted labels:
# -----------------
# ['last', 'friday', 'an', 'None', 'None', 'nicknamed', 'None', 'will', 'be', 'None', 'None', 'in the end', 'None', 'in', 'last', 'even', 'more', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Friday', 'Friday', 'flew', 'which', 'Air', 'Vehicle', '1', ',', 'or', 'or', 'or', 'AV-1', ',', ',', 'will', 'be transferred to', 'be transferred to', 'to', 'Patuxent', 'River', 'Naval', 'Air Station', '.', 'and eventually', 'None', 'loaded onto', 'an aircraft carrier', 'loaded onto', 'None', 'additional', 'additional', 'testing', 'None')
#
#
# Sentence: ('AV-1', '的', '姊妹', '机', 'AV-2', '将', '在', '下', '个', '月', '转运', '到', '爱德华', '空军', '基地', '，', '并', '在', '那里', '进行', '滑跑', '测试', '和', '发动机', '工作', '测试', '，', '预计', '将', '在', '今年', '夏天', '完成', '首', '飞', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'over', 'next', 'None', 'months', 'None', 'air forces', 'None', 'None', 'None', 'there', 'None', 'and', 'None', ',', 'estimated', 'in', 'this year', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'Sistership', 'Sistership', 'AV-2', 'is due to', 'None', 'next', 'next', 'month', 'be transferred to', 'to', 'Edwards', 'AFB', 'AFB', 'None', 'None', 'None', 'None', 'for', 'taxi', 'tests', 'and', 'engine', 'runs', 'None', ', and', 'is expected to', 'None', 'None', 'this', 'summer', 'make', 'first', 'flight', '.')
#
#
# Sentence: ('X-47B', '将', '是', '第一', '架', '在', '航空母舰', '上', '起飞', '并', '降落', '的', '无人机', '。')
#
# Predicted labels:
# -----------------
# ['None', 'is', 'first', 'None', 'over', 'previous', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('The X-47B', 'will', 'be', 'the first', 'the first', 'aboard', 'an aircraft carrier', 'aboard', 'take off', 'and', 'land', 'None', 'unmanned jet aircraft', '.')
#
#
# Sentence: ('它', '的', '翼展', '为', '52', '英尺', '，', '长', '38', '英尺', '，', '是', '美国', '海军', '现役', '舰载', '机', 'F/A-18C', '大小', '的', '87%', '。')
#
# Predicted labels:
# -----------------
# ['it', 'None', 'therefore', ',', 'None', 'None', 'is', 'us', 'navy', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('the X-47B', 'None', 'wingspan', 'With', '52 -', '- foot', 'and', 'length of', '38', 'feet', ',', 'is', 'Navy', 'Navy', 'currently', 'operating aboard aircraft carriers', 'aircraft', 'F/A-18C', 'the size', 'of', '87 percent', '.')
#
#
# Sentence: ('“', '舰载', '机', '从', '有人', '驾驶', '到', '无人', '驾驶', '是', '一个', '巨大', '的', '转变', '。', '”', 'Engdahl', '说道', '。')
#
# Predicted labels:
# -----------------
# ['None', 'from', 'to', 'is', 'a', 'big', 'None', 'None', '.', 'None', 'None']
#
# Actual labels:
# --------------
# ('"', 'on the carrier', 'None', 'None', 'manned', 'manned', 'to', 'unmanned', 'operation', 'None', 'None', 'big', 'big', 'paradigm shift', ',', '"', 'Engdahl', 'said', '.')
#
#
# Sentence: ('Engdahl', '是', '美国', '海军', '上校', '，', '说', '他', '参加', '这个', '项目', '的', '热情', '源于', '越战', '时', '，')
#
# Predicted labels:
# -----------------
# ['None', 'us', 'navy', 'and', 'said', 'None', 'participants', 'None', 'project', 'None', 'passion', 'None', 'None']
#
# Actual labels:
# --------------
# ('Engdahl', 'None', 'in the U.S.', 'Navy', 'a captain', ',', 'says', 'his', 'joining', 'the', 'service', 'his', 'inspiration', 'came from', 'the Vietnam-era', 'the Vietnam-era', 'None')
#
#
# Sentence: ('有', '飞行员', '说', '任务', '中', '最', '艰难', '的', '部分', '是', '在', '航母', '上', '降落', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'projects', 'The icing on the cake', 'The icing on the cake', 'The icing on the cake', 'is', 'after', 'on', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('who', 'pilots', 'said that', 'missions', 'of', 'the most', 'difficult', 'difficult', 'part', 'was', 'landing on', 'the carriers', 'landing on', 'landing on', '.')
#
#
# Sentence: ('Engdahl', '还', '说', '“', '这', '是', '海军', '无', '人', '验证', '机', '的', '第一', '次', '飞行', '，', '这', '可', '是', '大', '事儿', '，', '但', '仍然', '仅仅', '是', '这', '一', '项目', '的', '开始', '而已', '”', '。')
#
# Predicted labels:
# -----------------
# ['in addition', 'None', 'this', 'is', 'None', 'Some', 'None', 'first', 'None', 'flight', 'None', 'it', 'may', 'be', 'None', ',', 'yet', 'still', 'since', 'the', 'None', 'project', 'None', 'started', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Engdahl', 'None', 'said', '"', 'None', 'None', 'Navy', 'unmanned', 'unmanned', 'X-plane', 'a X-plane', 'of', 'First', 'First', 'flight', 'None', 'that', "'s", "'s", 'a huge deal', 'a huge deal', ',', 'but', 'None', 'just', "'s", 'this', 'this', 'program', 'to', 'one of the many firsts', 'just', '"', '.')
#
#
# Sentence: ('我们', '将', '见证', '更', '多', '的', '新', '面孔', '现身', '全明星', '舞台', '，', '尤其', '考虑', '到', '甜瓜', '马上', '即将', '东', '渡', '而', '姚', '明', '又', '再次', '报销', ',', '西部', '必', '将', '天下大乱', '。')
#
# Predicted labels:
# -----------------
# ['we', 'None', 'more', 'more', 'None', 'new', ',', 'especially', 'at', 'will', 'however', 'None', 'further', 'None', 'western', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'possibility', 'possibility', 'None', 'of a slew of', 'of a slew of', 'first-time', 'None', 'None', 'All-Stars', 'None', 'None', 'particularly', 'None', 'None', 'one current starter Carmelo Anthony', 'None', 'be', 'east', 'headed', 'None', 'Yao Ming', 'Ming', 'None', 'another', 'miss the game', 'None', 'the Western Conference', 'None', 'None', 'None', '.')
#
#
# Sentence: ('安东尼', '投奔', '篮网', '很', '有', '可能', '让', '家嫂', '在', '第二', '个', '前锋', '位置', '之', '争', '中', '突围', '，', '目前', '看来', '，', '腾出', '的', '这个', '位子', '非', '湖人', '二', '当家', '莫', '属', '了', '。')
#
# Predicted labels:
# -----------------
# ['nets', 'None', 'possible', 'None', 'after', 'second', 'None', 'None', 'in', ',', 'current', 'None', 'None', 'None', 'instead of', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ("Anthony 's", 'possible departure', 'New Jersey', 'None', 'would likely', 'would likely', 'result in', 'Pau Gasol him', 'None', 'the second', 'second', 'forward', 'spot', 'None', 'None', 'None', 'beating out', ',', 'None', 'None', 'None', 'freeing up', 'None', 'the reserve', 'slot', 'would likely go to', 'the Lakers', 'big man', 'big man', 'would likely go to', 'would likely go to', '.', '.')
#
#
# Sentence: ('斯特恩', '大人', '一', '句', '话', '，', '任何', '人', '都', '可能', '顶', '上', '姚', '明', '的', '首发', '位置', '，', '而', '教练', '们', '在', '选择', '替补', '球员', '时', '也', '有', '这种', '自由度', '。')
#
# Predicted labels:
# -----------------
# ['None', 'sentence', 'None', 'None', 'any', 'None', 'None', 'possible', 'None', 'None', 'initial release', 'None', 'instructor', 'None', 'choice', 'when', 'None', 'None', 'this', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('David Stern', 'David Stern', 'None', 'None', 'None', 'None', 'any', 'player', 'None', 'None', 'replace', 'replace', 'Yao', 'Yao', 'None', 'None', 'None', ',', 'and', 'the coaches who', 'coaches who', 'None', 'pick', 'backups', 'the backups', 'None', 'similar', 'have', 'flexibility', 'flexibility', ';')
#
#
# Sentence: ('虽然', '联盟', '定下', '规矩', '要', '选', '出', '双', '后卫', '，', '双', '前锋', '，', '一', '个', '中锋', '和', '两', '个', '任意', '位置')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'None', 'None', 'double', 'None', 'double', 'None', 'a', 'None', 'and', 'two', 'None', 'None']
#
# Actual labels:
# --------------
# ('though', 'league', 'require', 'rules', 'to', 'pick', 'pick', 'two', 'guards', ',', 'two', 'forwards', ',', 'a', 'a', 'center', 'and', 'two', 'two', 'wild', 'cards')
#
#
# Sentence: ('但', '规则', '同样', '也', '指出', '教练', '能', '选择', '任何', '他们', '认为', '对', '球队', '化学', '反应', '有益', '的', '球员', '。')
#
# Predicted labels:
# -----------------
# ['however', 'None', 'None', 'None', 'instructor', 'None', 'None', 'they', 'gain a sense of', 'None', 'chemical', 'None', 'athlete', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'those rules', 'same', 'None', 'give', 'coaches', 'give right to', 'designate', 'any', 'they', 'believe', 'benefit', 'None', 'the roster', 'the roster', 'benefit', 'benefit', 'player', '.')
#
#
# Sentence: ('因此', '，', '如果', '我们', '最终', '看到', '西部', '没', '有', '任何', '一', '位', '中锋', '现身', '，', '那', '也', '没', '什么', '可', '大惊小怪', '的', '。')
#
# Predicted labels:
# -----------------
# ['therefore', ',', 'None', 'our', 'final', 'None', 'None', 'having', 'any', 'None', 'None', 'None', 'there', 'None', 'not', 'None', 'inventory', 'of', 'None', 'None']
#
# Actual labels:
# --------------
# ('Therefore', ',', 'possible', 'None', 'None', 'None', 'the Western Conference', "won't", "won't", "won't a single", 'a', 'a', 'center', 'include', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('让我们', '先', '不要', '理会', '甜瓜', '和', '家嫂', '的', '那', '档子', '事', '，', '就', '先', '把', '这', '第二', '个', '前锋', '位置', '空', '出来', '吧', '。')
#
# Predicted labels:
# -----------------
# ['None', 'not', 'None', 'None', 'there', 'None', ',', 'None', 'first', 'None', 'None', 'second', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ("Let's", 'None', 'for a second', 'put on hold', 'Carmelo/Gasol', 'Carmelo/Gasol', 'Carmelo/Gasol', 'None', 'None', 'None', 'the thing', 'and', 'and', 'None', 'leave', 'that', 'second', 'second', 'starting forward', 'spot', 'blank', 'blank', '.', '.')
#
#
# Sentence: ('这样', '呢', '，', '我', '觉得', '首先', '下面', '六', '位', '球员', '已经', '锁定', '了', '2011年', '全明星', '大', '名单', '：')
#
# Predicted labels:
# -----------------
# ['None', 'None', ',', 'None', 'six', 'None', 'athlete', 'None', 'major', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('In that scenario', 'None', ',', 'I', 'consider', 'None', 'the following', 'six', 'six', 'players', "'d", 'locks', 'locks', 'None', 'All-Star', '12 slots', 'slots', ':')
#
#
# Sentence: ('1', '.')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('1', '.')
#
#
# Sentence: ('科比', ':')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('Kobe Bryant', ':')
#
#
# Sentence: ('将', '出任', '先', '发', '后卫', '。')
#
# Predicted labels:
# -----------------
# ['None', 'first', 'None', '.']
#
# Actual labels:
# --------------
# ('Will', 'be voted in as', 'starter', 'starter', 'starter', '.')
#
#
# Sentence: ('2', '.')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('2', '.')
#
#
# Sentence: ('保罗', '：')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('Chris Paul', ':')
#
#
# Sentence: ('杜兰特', '：')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('Kevin Durant', ':')
#
#
# Sentence: ('强劲', '势头', '领先', '前锋', '票', '选', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'None']
#
# Actual labels:
# --------------
# ('strong', 'margin', 'Leading', 'forwards', 'None', 'None', '.')
#
#
# Sentence: ('4', '.')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('4', '.')
#
#
# Sentence: ('吉诺比利', '：')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('Manu Ginobili', ':')
#
#
# Sentence: ('本', '季', '最', '佳', '球队', '的', '最', '佳', '球员', '，', '球队', '大', '脑', '，', '马', '刺', '攻防', '两', '端', '无处不在', '，', '实至名归', '。')
#
# Predicted labels:
# -----------------
# ['this', 'quarter', 'None', 'The icing on the cake', 'The icing on the cake', 'None', 'None', 'good Samaritans', 'and', 'two', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'the best', 'best', 'team', "'s been", 'the best', 'best', 'player', ',', 'None', 'record-wise', 'record-wise', ', and', 'None', 'None', 'None', 'both ends', 'ends', 'None', 'None', 'None', '.')
#
#
# Sentence: ('5', '.')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('5', '.')
#
#
# Sentence: ('诺维斯基', '：')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('Dirk Nowitzki', ':')
#
#
# Sentence: ('众多', 'MVP', '评选', '的', '大', '热门', '，', '毫', '无', '悬念', '。', '6', '.')
#
# Predicted labels:
# -----------------
# ['None', 'plunged', ',', 'no', 'None', 'six']
#
# Actual labels:
# --------------
# ('a lot', 'MVP', 'ballots', 'of', 'The front-runner', 'The front-runner', ', and', 'deservedly', 'deservedly', 'deservedly', '.', '6', '.')
#
#
# Sentence: ('德隆', ':')
#
# Predicted labels:
# -----------------
# ['None']
#
# Actual labels:
# --------------
# ('Deron Williams', ':')
#
#
# Sentence: ('在', '爵士', '体系', '中', '比', '以往', '担当', '了', '更', '多', '的', '得分', '任务', '，', '场', '均', '走', '上', '罚球', '线', '多', '达', '七', '次', '。')
#
# Predicted labels:
# -----------------
# ['in', 'in', 'None', 'so far', 'None', 'more', 'more', 'None', 'None', 'projects', '.', 'None', 'all', 'in', 'a number of', 'None', 'seven', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('in', 'Utah', 'Utah', 'in', 'than', 'ever before', 'shouldering', "'s shouldering", 'more', 'more', 'of', 'scoring', 'load', ', and', 'per game', 'per', 'getting', "'s getting", 'line', 'the line', 'more than', 'more than', 'seven', 'times', '.')
#
#
# Sentence: ('身体', '和', '技术', '都', '能', '摇摆', '到', '分位', '，', '防守', '上', '的', '出众', '表现', '使', '其', '在', '这', '张', '名单', '中', '干掉', '纳什', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'technology', 'None', 'None', 'None', 'None', 'previous', 'None', 'performance', 'None', 'them', 'in', 'None', 'zhang', 'in', 'None', 'None']
#
# Actual labels:
# --------------
# ('the size', 'and', 'flexibility', 'None', 'to', 'shift', 'to', 'shooting guard', ', and', 'defensively', 'None', 'None', 'enough', 'None', 'to', 'None', 'on', 'my', 'my', 'ballot', 'on', 'jump above', 'Steve Nash', '.')
#
#
# Sentence: ('以上', '都', '是', '板上定钉', '的', '了', '，', '西部', '剩下', '的', '六', '个', '位置', '我', '觉得', '至少', '将', '有', '20', '位', '球员', '有', '能力', '来', '竞争', '。')
#
# Predicted labels:
# -----------------
# ['above', 'None', 'None', 'None', 'None', 'None', 'western', 'None', 'six', 'months', 'None', 'at least', 'None', 'None', '20', 'None', 'athlete', 'None', 'None', 'rivalry', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Those', 'are', 'are', 'sure', 'sure', '.', '.', 'the West', 'the remaining', 'remaining', 'six', 'six', 'spots', 'by my count', 'by my count', 'None', 'leaves', 'leaves', '20', '20', 'players', 'None', 'None', 'for', 'competing', '.')
#
#
# Sentence: ('这', '20', '名', '球员', '中', '，', '14', '人', '已经', '当选', '过', '全', '明星', '。')
#
# Predicted labels:
# -----------------
# ['None', '20', 'None', 'athlete', 'None', '14-year-old', 'None', 'have', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('those', '20', '20', 'players', 'Of', ',', '14', '14', 'have', 'made', 'made', 'an All-Star', 'an All-Star', '.')
#
#
# Sentence: ('让', '我们', '按', '身高', '和', '技术', '特点', '而', '非', '官方', '位置', '来', '给', '他们', '排', '排序', '，', '大胆', '预测', '一下', '今年', '的', '最终', '阵容', '，', '其中', '可能', '迎来', '全明星', '处女秀', '的', '球员', '用', '斜体', '标', '出', '。')
#
# Predicted labels:
# -----------------
# ['None', 'we', 'None', 'and', 'technical', 'None', 'instead of', 'None', 'None', 'children', 'and', 'None', 'this year', 'None', 'in the end', ',', 'among', 'None', 'None', 'athlete', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Let', "'s", 'by', 'size', 'and', 'skill', 'skill', 'rather than', 'rather than', 'official', 'position', 'None', 'None', 'them', 'divide', 'divide up', 'to', 'better', 'get', 'get', 'None', 'of', 'realities', 'roster', ',', 'None', 'potential', 'with', 'None', 'first-timers', 'None', 'None', 'in', 'italics', 'italics', 'italics', '.')
#
#
# Sentence: ('（', '按', '名字', '首', '字母', '排', '序', '）')
#
# Predicted labels:
# -----------------
# ['(', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('(', 'in', 'None', 'alphabetical', 'alphabetical order', 'Lists', 'Lists', ')')
#
#
# Sentence: ('内线', '球员', '大家', '也', '看到', '了', '，', '这', '个', '位置', '真的', '很', '拥挤', '，', '这', '也', '就', '意味着', '更', '多', '表现', '不俗', '的', '球员', '将', '会', '与', '洛杉矶', '全明星', '无', '缘', '了', '。')
#
# Predicted labels:
# -----------------
# ['None', 'it', 'None', 'seen', 'None', ',', 'the', 'None', 'It was a very confident move by', 'It was a very confident move by', ',', 'which', 'which', 'which', 'even', 'more', 'None', 'None', 'athlete', 'None', 'None', 'los angeles', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('POST', 'PLAYERS', "you'll", 'None', 'see', 'see', ',', 'this', 'this', 'group', 'is', 'very', 'crowded', ',', 'which', 'None', 'None', 'means', 'a bunch of', 'a bunch of', 'None', 'deserving', 'deserving', 'guys', "aren't going", "aren't going", "aren't going to make it", 'None', 'None', "aren't going to make it", "aren't going to make it", 'None', '.')
#
#
# Sentence: ('阿德里尔奇', '(', '球员', '效率', '值', 'PER', ':')
#
# Predicted labels:
# -----------------
# ['None', 'athlete', 'None', 'None']
#
# Actual labels:
# --------------
# ('LaMarcus Aldridge', '(', 'Player', 'Efficiency', 'Rating', 'Player Efficiency Rating', ':')
#
#
# Sentence: ('20.68', '?', '28th', 'in', 'NBA', ')', ':')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'None']
#
# Actual labels:
# --------------
# ('20.68', 'None', '28th', 'in', 'NBA', ')', ':')
#
#
# Sentence: ('阿德里尔奇', '打', '出', '了', '生涯', '最佳', '表现', '，', '正', '在', '越来越', '多', '的', '获得', '罚球', '并', '冲击', '内线', '，', '而', '当', '他', '不', '在', '场上', '时', '开拓者', '攻防', '两', '端', '都', '尽', '显', '疲软', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'None', 'None', 'None', ',', 'currently', 'in', 'some', 'real', 'None', 'None', ',', 'None', 'after', 'he', 'not', 'in', 'None', 'two', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('Aldridge', 'having', 'having', 'is', 'his season', 'best', 'None', '.', "'s", "'s", 'more', 'more', 'more', "'s getting", 'the line', 'and', 'attacking', 'the rim', ',', 'and', 'when', 'Aldridge', 'sits', 'sits', 'sits', 'when', 'Portland', 'None', 'both', 'ends', 'both', 'None', 'None', 'dies', '.')
#
#
# Sentence: ('超出', '期待', '的', '表现', '令', '他', '成为', '全', '明星', '更', '有力', '的', '竞争者', '，', '考虑', '到', '队伍', '目前', '的', '困境', '，', '更', '会', '给', '他', '加', '分', '不', '少', '。')
#
# Predicted labels:
# -----------------
# ['None', 'performance', 'None', 'None', 'making', 'more', 'None', ',', 'None', 'team', 'None', 'None', 'None', ',', 'more', 'None', 'to', 'him', 'None', 'scoreless', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'None', 'None', 'None', 'None', 'All-Star', 'All-Star', 'better', 'better', 'better', 'candidate', ',', 'given', 'given', 'team', 'None', 'None', 'context', 'None', 'especially', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None')
#
#
# Sentence: ('邓肯', '(', 'PER', '21.60', '22nd', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Tim Duncan', '(', 'PER', '21.60', '22nd', ')', ':')
#
#
# Sentence: ('我们', '很', '难', '将', '一', '名', '场', '均', '不到', '30', '分钟', '的', '球员', '送', '到', '洛杉矶', '，', '而', '邓肯', '或许', '更', '乐意', '在', '职业', '生涯', '末', '段', '能', '多多', '休息', '。')
#
# Predicted labels:
# -----------------
# ['we', 'None', 'difficult', 'a', 'None', 'None', 'all', 'None', 'None', 'athlete', 'None', 'los angeles', 'None', 'None', 'None', 'of', 'professional', 'None', 'can', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'hard', 'hard', 'to', 'a', 'a', 'game', 'per', 'fewer than', '30', 'minutes', 'None', 'player', 'send', 'to', 'the All-Star Game', ',', 'and', 'Duncan', 'might', 'be', 'interested in', 'at', 'career', 'career', 'point', 'point', 'None', 'resting', 'resting', '.')
#
#
# Sentence: ('但', '他', '在', '马', '刺', '攻击', '端', '的', '挡拆', '技巧', '仍然', '犀利', '无比', '，', '而', '队伍', '还', '指望', '他', '在', '季后赛', '中', '的', '稳定', '发挥', '。')
#
# Predicted labels:
# -----------------
# ['but', 'he', 'None', 'attack', 'None', 'still', 'None', 'None', 'team', 'None', 'he', 'None', 'playoff', 'None', 'None', 'Using', 'None', 'None']
#
# Actual labels:
# --------------
# ('But', 'his', 'None', 'None', 'None', 'None', 'None', 'None', 'pick-and-roll', 'skill', 'remains', 'crucial', 'crucial', ',', 'and', 'the team', 'None', 'lean on', 'his', 'in', 'the playoffs', 'in', 'None', 'None', 'None', '.')
#
#
# Sentence: ('同时', '，', '他', '在', '马刺队', '的', '防守', '端', '的', '中流砥柱', '作用', '依然', '无', '人', '撼动', '。')
#
# Predicted labels:
# -----------------
# ['in the meantime', ',', 'he', 'in', 'None', 'None', 'role', 'None', 'Some', 'None', 'None']
#
# Actual labels:
# --------------
# ('And', 'And', 'he', 'None', 'the Spurs', 'of', 'defense', 'the back line', 'None', 'None', 'None', 'is', 'as solid as ever', 'as solid as ever', 'as solid as ever', '.')
#
#
# Sentence: ('保罗', '加索尔', '(', 'PER', '23.56', '11th', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Paul', 'Gasol', '(', 'PER', '23.56', '11th', ')', ':')
#
#
# Sentence: ('因为', '肌腱', '的', '酸痛', '，', '过去', '三', '周', '里', '保罗', '的', '表现', '有', '点', '退步', '，', '但', '他', '仍然', '是', '那个', '高', '效率', '低', '失误', '的', '进攻', '利器', '，', '在', '湖人', '的', '三角', '进攻', '中', '扮演', '着', '内线', '轴心', '。')
#
# Predicted labels:
# -----------------
# ['because', 'None', ',', 'past', 'None', 'week', 'None', 'None', 'performance', 'None', 'None', ',', 'but', 'None', 'still', 'None', 'then', 'None', 'None', 'correspondingly', ',', 'in', 'None', 'in', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('because of', 'hamstring', 'None', 'sore', ',', 'the last', 'three', 'three weeks', 'over', "He's", 'None', 'None', 'a step', 'a step', 'back', ',', 'but', "he's", 'still', "he's", 'the', 'high-efficiency', 'high-efficiency', 'low-turnover', 'low-turnover', 'None', 'skill', 'machine', 'that', 'None', 'the Lakers', 'of', 'triangle', 'offense', 'None', 'serves as', 'None', 'None', 'the hub', '.')
#
#
# Sentence: ('考虑', '到', '这', '是', '一', '次', '洛杉矶', '当地', '的', '全明星', '，', '相信', '他', '会', '入选', '的', '。')
#
# Predicted labels:
# -----------------
# ['None', 'to', 'this', 'is', 'a', 'None', 'los angeles', 'None', '.', 'believes', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'with', 'None', 'None', 'Los Angeles', 'None', 'None', 'the game', ',', 'None', 'He', "'s", 'getting in', 'None', 'None')
#
#
# Sentence: ('布雷克', '格里芬', '(', 'PER', '22.89', '15th', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Blake', 'Griffin', '(', 'PER', '22.89', '15th', ')', ':')
#
#
# Sentence: ('虽然', '作为', '新秀', '入选', '正', '赛', '还是', '有', '些', '难度', '，', '但', '给力芬', '已经', '准备', '好', '参加', '扣篮', '大赛', '了', '，', '而且', '他', '的', '表现', '比', '大家', '预想', '的', '可', '要', '劲', '爆', '多', '了', '。')
#
# Predicted labels:
# -----------------
# ['None', 'as', 'now', 'None', 'still', 'None', 'some', 'however', 'None', 'preparation', 'None', 'participants', 'None', 'None', 'while', 'his', 'None', 'performance', 'None', 'it', 'None', 'can', 'None', 'None', 'experiment with the variables', 'experiment with the variables', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'as', 'a rookie', 'make it', 'None', 'None', 'None', 'tough', 'None', 'tough', ',', 'but', "Griffin's", 'already', 'None', 'None', 'for', 'dunk', 'contest', 'None', ',', 'and', "he's", 'None', 'None', 'None', 'most folks', 'realize', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('即使', '没有', '开发', '出', '什么', '低位', '和', '左手', '技术', '，', '他', '依然', '能', '取得', '52%', '的', '命中率', '，', '平均', '一', '场', '比赛', '8', '次', '走', '上', '罚球', '线', '的', '同时', '他', '也', '成为', '了', '联盟', '最', '顶尖', '的', '篮板', '手', '之一', '（', '无论', '是', '进攻', '还', '是', '防守', '篮板', '）', '。')
#
# Predicted labels:
# -----------------
# ['even', 'None', 'development', 'None', 'nothing', 'None', 'technology', 'and', 'his', 'None', 'can', 'None', 'None', 'average', 'None', 'None', 'None', '8', 'None', 'at', 'None', 'while', 'his', 'None', 'making', 'None', 'None', 'largest', 'None', '(', 'None', 'which', 'still', 'None', ')', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'without', 'None', 'None', 'None', 'refined post game', 'or', 'left hand', 'left hand', 'None', "he's", 'None', 'None', 'None', '52 percent', 'None', 'shooting', ',', 'per', 'per', 'per', 'game', 'eight', 'times', 'getting to', 'getting to', 'the line', 'the line', 'None', 'and', "he's", 'None', 'been', "he's", 'None', 'best', 'best', 'None', 'rebounders', 'rebounders', 'one of', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('防守', '端', '他', '的', '位置', '感', '还', '不', '是', '很', '强', '，', '仍', '需', '学习', '如何', '应对', '挡拆', '。')
#
# Predicted labels:
# -----------------
# ['he', 'None', 'still', 'not', 'are', 'None', 'None', ',', 'None', 'required', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('defense', 'None', "He's", 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', ', and', 'still', 'None', 'learning', 'to', 'guard', 'the pick-and-roll', '.')
#
#
# Sentence: ('但是', '保证', '篮板', '也', '是', '防守', '的', '重要', '一', '部分', '，', '而', '快', '船队', '也', '因此', '悄悄', '挤', '进', '了', '防守', '篮板', '前', '十', '位', '。')
#
# Predicted labels:
# -----------------
# ['however', 'None', 'also', 'serves as', 'None', 'key', 'a', 'part', 'None', 'None', 'fastest', 'None', 'None', 'scored', 'None', 'None', 'dozens', 'None', '.']
#
# Actual labels:
# --------------
# ('But', 'securing', 'rebounds', 'None', 'is', 'defense', 'of', 'big', 'a', 'part', ',', 'and', 'the Clippers', 'the Clippers', 'None', 'None', 'None', 'inching', 'inching', 'toward', 'defensive', 'rebounding', 'the top', 'the 10', '10', 'None')
#
#
# Sentence: ('榜单', '中', '算是', '一', '名', '超', '有', '人气', '的', '候选人', '了', '。')
#
# Predicted labels:
# -----------------
# ['at', 'will', 'None', 'None', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'None', 'A', 'A', 'None', 'None', 'None', 'None', 'candidate', 'None', '.')
#
#
# Sentence: ('艾尔', '杰佛森', '(', 'PER', '18.02', '，', '53rd', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ')', 'None']
#
# Actual labels:
# --------------
# ('Al', 'Jefferson', '(', 'PER', '18.02', ',', '53rd', ')', ':')
#
#
# Sentence: ('完美', '地', '适应', '了', '新', '的', '队友', '和', '体系', '，', '但', '离', '全明星', '还', '稍', '有', '差距', '--', '尤其', '在', '犹他', '前锋线', '已经', '有', '了', '另', '一个', '强力', '竞争者', '的', '前提', '下', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'suitable', 'None', 'new', 'None', 'and', 'None', 'yet', 'still', 'have to learn to play', 'None', 'especially', 'since', 'None', 'None', 'None', 'another', 'None', 'strong', 'None', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('nice', 'nice', 'adjusting to', 'None', 'None', 'None', 'team', 'and', 'system', ',', 'but', 'to', 'All-Star', 'None', 'None', 'not enough', 'not enough', '—', 'especially', 'when on', "Utah's", 'front line', 'None', "there's", 'None', 'a', 'a', 'superior', 'candidate', 'None', 'when', 'when', 'None')
#
#
# Sentence: ('凯文', '拉夫', '(', 'PER', '24.38', '5th', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Kevin', 'Love', '(', 'PER', '24.38', '5th', ')', ':')
#
#
# Sentence: ('他', '对', '挡拆', '的', '防守', '以及', '相关', '技术', '有点', '不', '尽如人意', '，', '而且', '当', '拉夫', '先生', '坐', '上', '板凳', '席', '时', '似乎', '森林狼', '的', '防守', '更', '严实', '些', '。')
#
# Predicted labels:
# -----------------
# ['he', 'None', 'None', 'None', 'related', 'None', 'declined to', 'None', 'while', 'None', 'None', 'at', 'None', 'None', 'None', 'some', 'some', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('His', 'on', 'the pick-and-roll', 'None', 'defense', 'and', 'otherwise', 'None', 'is', 'a bit of a mess', 'a bit of a mess', ',', 'and', 'None', 'Love', 'Love', 'heads', 'heads to', 'the bench', 'None', 'None', 'None', 'the Wolves', 'None', 'None', 'much stingier', 'stingier', 'None', '.')
#
#
# Sentence: ('但', '这', '足', '以', '让', '人们', '无视', '他', '领导', '的', '队伍', '正', '在', '联盟', '垫底', '的', '事实', '吗', '？')
#
# Predicted labels:
# -----------------
# ['however', 'the', 'None', 'making', 'people', 'None', 'headed', 'None', 'team', 'None', 'None', 'eu', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'that', 'be enough', 'to', 'to', 'None', 'overcome', 'None', 'None', 'None', 'team', 'playing for', 'playing for', "league's", 'the worst', 'of', 'the stigma', '?', '?')
#
#
# Sentence: ('保罗', '米尔萨普', '(', 'PER', '21.36', '23rd', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Paul', 'Millsap', '(', 'PER', '21.36', '23rd', ')', ':')
#
#
# Sentence: ('爱神', '？', '阿德里尔奇', '？', '还', '是', '米尔萨普', '？')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'also', 'serves as', 'None']
#
# Actual labels:
# --------------
# ('Love', 'None', 'Aldridge', 'None', 'None', 'and', 'Millsap', '?')
#
#
# Sentence: ('恭喜', '你', '有', '得', '选', '了', '！')
#
# Predicted labels:
# -----------------
# ['You', 'are', 'None', 'None']
#
# Actual labels:
# --------------
# ('Good luck', 'Good luck', 'None', 'None', 'None', 'None', '.')
#
#
# Sentence: ('虽然', '随着', '本', '季', '上场', '时间', '的', '增长', '，', '米尔萨普', '的', '进攻', '篮板', '并没有', '保持', '超高', '水准', '，')
#
# Predicted labels:
# -----------------
# ['None', 'with', 'None', 'quarter', 'None', 'None', 'increasing', ',', 'None', 'maintained', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'as', 'None', 'None', 'None', 'minutes', 'None', 'have jumped', ',', 'Millsap', 'None', 'offensive', 'rebounder', "hasn't been able to", 'remain', 'off-the-charts', 'off-the-charts', ',')
#
#
# Sentence: ('但', '他', '55%', '的', '命中率', '与', '稳定', '的', '中', '投', '以及', '本', '季', '犹他', '内线', '防守', '核心', '的', '表现', '还', '是', '不容', '小视', '。')
#
# Predicted labels:
# -----------------
# ['but', 'he', 'None', 'with', 'None', 'china', 'and', 'None', 'quarter', 'None', 'None', 'also', 'is', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('but', 'he', '55 percent', 'None', "'s shooting", ',', 'stroking', 'None', 'the mid-range', 'jumper', 'and', 'this', 'season', "Utah's", 'interior', 'defender', 'defender', 'None', 'None', 'None', 'None', 'best', 'best', '.')
#
#
# Sentence: ('哥们', '，', '值得', '细细', '斟酌', '啊', '。')
#
# Predicted labels:
# -----------------
# ['None', 'None', 'None', '.']
#
# Actual labels:
# --------------
# ('None', 'None', 'Worth', 'None', 'None', 'None', '.')
#
#
# Sentence: ('内内', '(', 'PER', '20.73', '27th', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Nene', '(', 'PER', '20.73', '27th', ')', ':')
#
#
# Sentence: ('一', '名', '永远', '被', '人', '低估', '的', '球员', '，', '本', '季', '交出', '了', '生涯', '的', '代表作', '。')
#
# Predicted labels:
# -----------------
# ['a', 'None', 'perpetual', 'None', 'None', 'None', 'athlete', ',', 'this', 'quarter', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'None', 'Perpetually', 'underrated', 'None', 'underrated', 'None', 'None', 'and', 'season', 'season', 'having', 'having', 'career', 'of', 'the best', '.')
#
#
# Sentence: ('随着', '伤病', '一', '次次', '摧毁', '掘金', '的', '前锋', '线', '，', '巴西', '人', '在', '攻防', '两', '端', '承担', '了', '更', '多', '的', '责任', '，', '而且', '还', '能', '以', '63', '%', '的', '命中率', '领', '跑', '联盟', '。')
#
# Predicted labels:
# -----------------
# ['with', 'a', 'correspondingly', ',', 'brazil', 'None', 'in', 'None', 'take', 'None', 'more', 'more', 'None', 'responsibility', 'None', 'while', 'None', 'None', 'aimed', 'None', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('as', 'injuries', 'have', 'have', 'decimated', 'Denver', 'None', 'front', 'line', ',', 'None', 'None', 'None', 'None', 'both ends', 'ends', 'carry', 'None', 'a huge', 'a huge', 'huge', 'burden', ',', 'and', "'s 's 's", "'s 's 's", 'in', '63', 'percent', 'percent', 'field-goal percentage', 'leading', 'leading', 'the league', '.')
#
#
# Sentence: ('哦', '对了', '，', '他', '在', '这', '份', '名单', '中', '可能', '以', '中锋', '身份', '出现', '哦', '。')
#
# Predicted labels:
# -----------------
# ['None', 'he', 'during', 'this', 'None', 'during', 'can', 'None', 'posted', 'None', 'None']
#
# Actual labels:
# --------------
# ('None', 'A small plus', ':', 'He', 'None', 'the', 'the', 'ballot', 'None', 'actually', 'as', 'a center', 'center', "'s listed", 'None', '.')
#
#
# Sentence: ('扎克', '兰道夫', '(', 'PER', '21.81', '20th', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Zach', 'Randolph', '(', 'PER', '21.81', '20th', ')', ':')
#
#
# Sentence: ('去年', '已经', '进', '过', '全明星', '了', '，', '今年', '的', '表现', '依然', '出色', '。')
#
# Predicted labels:
# -----------------
# ['year ,', 'None', 'scored', 'None', 'None', ',', 'this year', 'None', 'performance', 'None', 'None', 'None']
#
# Actual labels:
# --------------
# ('last year', 'None', 'made', 'made', 'it', 'None', ',', 'this season', 'None', "'s playing", 'at least', 'well', '.')
#
#
# Sentence: ('斯科拉', '(', 'PER', '19.20', '43rd', ')', ':')
#
# Predicted labels:
# -----------------
# ['(', 'None', ':']
#
# Actual labels:
# --------------
# ('Luis Scola', '(', 'PER', '19.20', '43rd', ')', ':')

# %%
def accuracy(X, Y, model):
    correct = total_predictions = 0
    # The model.viterbi call in simplify_decoding will return None if the HMM
    # raises an error (for example, if a test sentence contains a word that
    # is out of vocabulary for the training set). Any exception counts the
    # full sentence as an error (which makes this a conservative estimate).
    for ch_sentence, en_sentence in zip(X, Y):
        try:
            most_likely_tags = simplify_decoding(ch_sentence, model)
            for word in en_sentence:
                if word in most_likely_tags:
                    correct += 1
        except:
            pass
        total_predictions += len(ch_sentence)    
    return correct / total_predictions

# %%
hmm_training_acc = accuracy(DataSet_ch, DataSet_en, hmm_model)
print("training accuracy hmm_model: {:.2f}%".format(100 * hmm_training_acc))
# Out:
# training accuracy hmm_model: 98.42%

# %%
hmm_testing_acc = accuracy(TestSet_ch, TestSet_en, hmm_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# testing accuracy mfc_model: 2.73%

# %% [markdown]
# HMM model goes pretty well at what it has learned(training data).
# However, the testing accuray is very low, note that we only have 1000 training data, as the training data become bigger, we can have better result.
